# %%
#RE ROUTING (HACO)
import pandas as pd
import networkx as nx
import random
import math
from collections import defaultdict

# --------------------------
# Hardcoded topology edges
# (Source, Target, Capacity)
# --------------------------
DEFAULT_EDGES = [
   ("Server", "RouterA", 100),
("Server", "RouterB", 200),
("Server", "RouterC", 150),
("RouterA", "Switch1", 140),
("RouterA", "Switch2", 170),
("Switch1", "Switch2", 120),
("Switch2", "user1", 140),
("Switch2", "RouterB", 160),
("RouterB", "Switch3", 80),
("Switch3", "user2", 110),
("Switch3", "Switch2", 100),
("RouterB", "Switch4", 160),
("Switch4", "user3", 120),
("Switch4", "RouterC", 120),
("RouterC", "Switch5", 140),
("Switch5", "Switch6", 180),
("Switch6", "user4", 100),
("Switch6", "Switch4", 200),
("Switch5", "user4", 130),

]

# --------------------------
# Utility: build graph from default edges
# returns undirected graph with capacity on edges
# --------------------------
def build_graph_from_defaults():
    G = nx.Graph()
    for u, v, cap in DEFAULT_EDGES:
        # if multiple parallel entries exist, keep max capacity
        if G.has_edge(u, v):
            # keep max capacity
            G[u][v]['capacity'] = max(G[u][v]['capacity'], float(cap))
        else:
            G.add_edge(u, v, capacity=float(cap))
    return G

# --------------------------
# Edge cost function
# static part: 1 / capacity (lower capacity => higher static cost)
# congestion penalty: if a node in path is RouterA/B/C apply penalty proportional to congestion %
# total edge cost used in ACO for choosing next hop will combine edge static cost and arriving-node congestion
# --------------------------
def build_edge_costs(G, cong_snapshot, node_penalty_weight=1.0):
    # cong_snapshot: dict mapping "RouterA" etc. to congestion %
    # returns a dict edge_costs[(u,v)] = cost
    edge_costs = {}
    for u, v, data in G.edges(data=True):
        cap = float(data.get('capacity', 1.0))
        static_cost = 1.0 / cap  # smaller capacity higher cost
        # congestion penalty: consider congestion at the destination node v if v is RouterA/B/C
        cong_v = cong_snapshot.get(v, 0.0)
        cong_u = cong_snapshot.get(u, 0.0)
        # We'll take avg congestion of endpoints scaled by node_penalty_weight
        node_penalty = node_penalty_weight * ((cong_u + cong_v) / 200.0)  # scale 0..1
        edge_costs[(u, v)] = static_cost + node_penalty
        edge_costs[(v, u)] = static_cost + node_penalty  # undirected
    return edge_costs

# --------------------------
# HACO (simplified ACO) for single source-dest
# returns best path found (list of nodes) and its cost
# --------------------------
def haco_for_pair(G, src, dst, edge_costs, ants=30, iterations=40, alpha=1.0, beta=3.0, evap=0.5, q0=100.0, seed=42):
    random.seed(seed)
    nodes = list(G.nodes())
    # initialize pheromone on edges
    pher = {}
    for u, v in G.edges():
        pher[(u, v)] = 1.0
        pher[(v, u)] = 1.0

    # helper: neighbors of a node
    nbrs = {n: list(G.neighbors(n)) for n in G.nodes()}

    def path_cost(path):
        # sum edge_costs
        c = 0.0
        for i in range(len(path)-1):
            u, v = path[i], path[i+1]
            c += edge_costs.get((u, v), 1e6)
        return c

    # seed pheromone using shortest path (fewest hops) if exists
    try:
        shortest_default = nx.shortest_path(G, source=src, target=dst)
        # deposit a bit of pheromone on edges of default path
        for i in range(len(shortest_default)-1):
            u, v = shortest_default[i], shortest_default[i+1]
            pher[(u, v)] += 5.0
            pher[(v, u)] += 5.0
    except Exception:
        shortest_default = None

    best_path = None
    best_cost = float('inf')
    # ACO loop
    for it in range(iterations):
        all_paths = []
        for a in range(ants):
            # build path probabilistically
            current = src
            visited = {current}
            path = [current]
            # simple greedy limit to avoid infinite loops
            max_hop = len(G.nodes()) * 2
            hop = 0
            while current != dst and hop < max_hop:
                neigh = [n for n in nbrs[current] if n not in visited or n==dst]
                if not neigh:
                    break
                # compute transition probabilities
                probs = []
                denom = 0.0
                for v in neigh:
                    tau = pher[(current, v)] ** alpha
                    eta = (1.0 / edge_costs.get((current, v), 1e6)) ** beta
                    val = tau * eta
                    probs.append((v, val))
                    denom += val
                if denom <= 0:
                    # fall back uniform
                    nxt = random.choice(neigh)
                else:
                    # roulette wheel
                    r = random.random()
                    # normalize
                    cumulative = 0.0
                    picked = None
                    for v, val in probs:
                        cumulative += val/denom
                        if r <= cumulative:
                            picked = v
                            break
                    nxt = picked if picked is not None else probs[-1][0]
                path.append(nxt)
                visited.add(nxt)
                current = nxt
                hop += 1
            # if ended at destination, evaluate
            if path[-1] == dst:
                c = path_cost(path)
                all_paths.append((path, c))
                if c < best_cost:
                    best_cost = c
                    best_path = path
        # global pheromone evaporation
        for e in list(pher.keys()):
            pher[e] *= (1.0 - evap)
            if pher[e] < 1e-6:
                pher[e] = 1e-6
        # deposit pheromone according to path quality
        for path, c in all_paths:
            deposit = q0 / (1.0 + c)
            for i in range(len(path)-1):
                u, v = path[i], path[i+1]
                pher[(u, v)] += deposit
                pher[(v, u)] += deposit
    # return best
    return best_path, best_cost, shortest_default

# --------------------------
# Main driver: dynamic rerouting per timestamp
# --------------------------
def dynamic_reroute_haco(congestion_csv, users=("User1","User2","User3","User4"),
                         node_penalty_weight=5.0,  # larger gives more weight to congestion
                         ants=20, iterations=30,
                         alpha=1.0, beta=2.0, evap=0.5):
    """
    congestion_csv: path to router_congestion_int.csv (columns RouterA,RouterB,RouterC, optional Time)
    For each timestep, prints default path (shortest ignoring congestion) and HACO-updated path (if different).
    """
    df = pd.read_csv(congestion_csv)
    # add Time if missing
    if "Time" not in df.columns:
        df.insert(0, "Time", [i*10 for i in range(len(df))])

    G_default = build_graph_from_defaults()

    for _, row in df.iterrows():
        time_label = row["Time"]
        # build congestion snapshot mapping node->% for RouterA/B/C
        cong_snapshot = {}
        for k in ["RouterA","RouterB","RouterC"]:
            if k in row:
                try:
                    cong_snapshot[k] = float(row[k])
                except:
                    cong_snapshot[k] = 0.0
        print(f"\n=== Time {time_label} sec ===")
        # build edge costs including congestion penalty
        # For HACO we compute costs on a fresh graph each time
        G = build_graph_from_defaults()
        edge_costs = build_edge_costs(G, cong_snapshot, node_penalty_weight=node_penalty_weight)

        # For each user, compute default shortest path (fewest hops) and HACO path
        for user in users:
            src = "Server"
            dst = user
            try:
                default_path = nx.shortest_path(G, source=src, target=dst)  # by hops
            except (nx.NetworkXNoPath, nx.NodeNotFound):
                print(f"{src} → {dst}: no default path found.")
                continue

            # run HACO seeded by default path
            best_path, best_cost, seeded = haco_for_pair(
                G, src, dst, edge_costs,
                ants=ants, iterations=iterations, alpha=alpha, beta=beta, evap=evap,
                seed=hash((time_label, src, dst)) & 0xffffffff
            )

            # If HACO failed (no path), fall back to default
            if best_path is None:
                print(f"{src} → {dst}: default path = {default_path} (HACO found no path).")
                continue

            # Compare
            if best_path == default_path:
                print(f"{src} → {dst}: default path (no change): {default_path}")
            else:
                print(f"{src} → {dst}: BEFORE (default) = {default_path}  ===> AFTER (HACO) = {best_path}")
    print("\nDone.")

# --------------------------
# Example usage:
# --------------------------
dynamic_reroute_haco("C:/Users/Mukta/OneDrive/Desktop/Orange Hackathon/router_congestion_int.csv")

# Adjust HACO params (ants, iterations, node_penalty_weight) to trade speed vs. exploration
# Out:
# === Time 0 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 10 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 20 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 30 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 40 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 50 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 60 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 70 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 80 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 90 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 100 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 110 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 120 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 130 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 140 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 150 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 160 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 170 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 180 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 190 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 200 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 210 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 220 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 230 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 240 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 250 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 260 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 270 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 280 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 290 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 300 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 310 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 320 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 330 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 340 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 350 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 360 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 370 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 380 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 390 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 400 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 410 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 420 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 430 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 440 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 450 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 460 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 470 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 480 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 490 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 500 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 510 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 520 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 530 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 540 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 550 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 560 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 570 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 580 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 590 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 600 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 610 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 620 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 630 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 640 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 650 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 660 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 670 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 680 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 690 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 700 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 710 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 720 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 730 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 740 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 750 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 760 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 770 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 780 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 790 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 800 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 810 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 820 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 830 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 840 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 850 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 860 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 870 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 880 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 890 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 900 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 910 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 920 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 930 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 940 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 950 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 960 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 970 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 980 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 990 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1000 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1010 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1020 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1030 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1040 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1050 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1060 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1070 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1080 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1090 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1100 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1110 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1120 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1130 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1140 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1150 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1160 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1170 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1180 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1190 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1200 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1210 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1220 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1230 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1240 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1250 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1260 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1270 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1280 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1290 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1300 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1310 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1320 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1330 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1340 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1350 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1360 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1370 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1380 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1390 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1400 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1410 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1420 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1430 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1440 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1450 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1460 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1470 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1480 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1490 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1500 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1510 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1520 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1530 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1540 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1550 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1560 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1570 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1580 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1590 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1600 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1610 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1620 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1630 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1640 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1650 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1660 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1670 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1680 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1690 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1700 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1710 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1720 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1730 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1740 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1750 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1760 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1770 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1780 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1790 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1800 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1810 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1820 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1830 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1840 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1850 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1860 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1870 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1880 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1890 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1900 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1910 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1920 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1930 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1940 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1950 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1960 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1970 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1980 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 1990 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2000 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2010 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2020 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2030 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2040 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2050 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2060 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2070 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2080 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2090 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2100 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2110 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2120 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2130 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2140 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2150 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2160 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2170 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2180 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2190 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2200 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2210 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2220 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2230 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2240 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2250 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2260 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2270 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2280 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2290 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2300 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2310 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2320 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2330 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2340 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2350 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2360 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2370 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2380 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2390 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2400 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2410 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2420 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2430 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2440 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2450 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2460 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2470 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2480 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2490 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2500 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2510 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2520 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2530 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2540 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2550 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2560 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2570 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2580 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2590 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2600 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2610 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2620 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2630 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2640 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2650 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2660 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2670 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 2680 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# ...
# Server → User4: no default path found.
#
# === Time 6110 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6120 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6130 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6140 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6150 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6160 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6170 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6180 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6190 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6200 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6210 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6220 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6230 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6240 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6250 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6260 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6270 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6280 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6290 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6300 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6310 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6320 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6330 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6340 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6350 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6360 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6370 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6380 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6390 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6400 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6410 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6420 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6430 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6440 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6450 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6460 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6470 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6480 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6490 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6500 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6510 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6520 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6530 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6540 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6550 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6560 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6570 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6580 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6590 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6600 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6610 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6620 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6630 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6640 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6650 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6660 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6670 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6680 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6690 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6700 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6710 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6720 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6730 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6740 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6750 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6760 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6770 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6780 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6790 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6800 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6810 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6820 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6830 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6840 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6850 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6860 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6870 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6880 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6890 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6900 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6910 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6920 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6930 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6940 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6950 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6960 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6970 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6980 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# === Time 6990 sec ===
# Server → User1: no default path found.
# Server → User2: no default path found.
# Server → User3: no default path found.
# Server → User4: no default path found.
#
# Done.

# %%
# BANDWIDTH ADJUSTMENT
import pandas as pd
import networkx as nx

def adjust_bandwidth(congestion_file, high_thresh=70, low_thresh=40, increase_factor=1.2, timestep=10):
    # Load congestion data
    df_cong = pd.read_csv(congestion_file)

    # Add Time column if missing
    if "Time" not in df_cong.columns:
        df_cong.insert(0, "Time", [i * timestep for i in range(len(df_cong))])

    # Ensure router columns exist
    expected_cols = {"RouterA", "RouterB", "RouterC"}
    if not expected_cols.issubset(set(df_cong.columns)):
        raise ValueError(f"Congestion CSV must contain {expected_cols}, found {df_cong.columns}")

    # --- Hardcoded topology (Source, Target, Capacity) ---
    default_edges = [
        ("User1", "Switch1", 110),
        ("Switch1", "Switch9", 80),
        ("Switch9", "Switch2", 120),
        ("Switch2", "Switch8", 130),
        ("Switch8", "RouterA", 90),
        ("RouterA", "Server", 180),
        ("User1", "Switch8", 140),
        ("Switch8", "Switch9", 180),
        ("Switch9", "Switch8", 190),
        ("Switch8", "Switch10", 180),
        ("Switch8", "Switch4", 140),
        ("Switch10", "User2", 110),
        ("Switch10", "Switch11", 130),
        ("Switch11", "Switch4", 80),
        ("Switch4", "RouterB", 100),
        ("RouterB", "Server", 120),
        ("Switch11", "Switch12", 60),
        ("Switch12", "User3", 160),
        ("Switch12", "Switch14", 100),
        ("Switch14", "RouterC", 130),
        ("RouterC", "Server", 180),
        ("Switch11", "Switch8", 60),
        ("Switch14", "Switch13", 120),
        ("Switch13", "User4", 80),
        ("Switch13", "Switch6", 190),
        ("Switch6", "Switch14", 70),
        ("Switch14", "RouterC", 70),
    ]

    # Iterate over time steps
    for _, row in df_cong.iterrows():
        time_label = row["Time"]
        routers = {col: float(row[col]) for col in df_cong.columns if col.startswith("Router")}

        # Reset graph to default every timestep
        G = nx.Graph()
        for src, tgt, cap in default_edges:
            G.add_edge(src, tgt, capacity=float(cap))

        print(f"\n⏱️ Time step {time_label} sec:")
        for r, load in routers.items():
            if load > high_thresh:
                status = "Congested"
            elif load > low_thresh:
                status = "Moderate"
            else:
                status = "Underloaded"
            print(f"Router {r} at {load:.0f}% → {status}")

        # Track changes
        changes = []
        for r, load in routers.items():
            if load > high_thresh:  # congested router
                neighbors = list(G.neighbors(r))
                underloaded_neighbors = [n for n in neighbors if n in routers and routers[n] < low_thresh]

                if underloaded_neighbors:
                    for n in underloaded_neighbors:
                        old_cap = float(G[r][n]["capacity"])
                        new_cap = old_cap * increase_factor
                        G[r][n]["capacity"] = new_cap
                        changes.append(f"  Bandwidth change: {r}–{n} (old={old_cap:.1f} → new={new_cap:.1f})")
                else:
                    # No underloaded neighbor → adjust busiest edge
                    edges = [(n, float(G[r][n]["capacity"])) for n in neighbors]
                    if edges:
                        n, old_cap = max(edges, key=lambda x: x[1])
                        new_cap = old_cap * increase_factor
                        G[r][n]["capacity"] = new_cap
                        changes.append(f"  QoS adjustment: {r}–{n} (old={old_cap:.1f} → new={new_cap:.1f})")

        if not changes:
            print("  No bandwidth changes at this step.")
        else:
            for c in changes:
                print(c)


# Example usage
congestion_file = "C:/Users/ASUS/Downloads/router_congestion_int.csv"
adjust_bandwidth(congestion_file)
# Out:
# ⏱️ Time step 0 sec:
# Router RouterA at 1% → Underloaded
# Router RouterB at 29% → Underloaded
# Router RouterC at 30% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 10 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 27% → Underloaded
# Router RouterC at 68% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 20 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 38% → Underloaded
# Router RouterC at 90% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 30 sec:
# Router RouterA at 97% → Congested
# Router RouterB at 66% → Moderate
# Router RouterC at 3% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 40 sec:
# Router RouterA at 45% → Moderate
# Router RouterB at 94% → Congested
# Router RouterC at 9% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 50 sec:
# Router RouterA at 2% → Underloaded
# Router RouterB at 16% → Underloaded
# Router RouterC at 31% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 60 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 9% → Underloaded
# Router RouterC at 62% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 70 sec:
# Router RouterA at 23% → Underloaded
# Router RouterB at 34% → Underloaded
# Router RouterC at 29% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 80 sec:
# Router RouterA at 22% → Underloaded
# Router RouterB at 95% → Congested
# Router RouterC at 83% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 90 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 92% → Congested
# Router RouterC at 13% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 100 sec:
# Router RouterA at 99% → Congested
# Router RouterB at 1% → Underloaded
# Router RouterC at 30% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 110 sec:
# Router RouterA at 71% → Congested
# Router RouterB at 28% → Underloaded
# Router RouterC at 73% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 120 sec:
# Router RouterA at 30% → Underloaded
# Router RouterB at 26% → Underloaded
# Router RouterC at 32% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 130 sec:
# Router RouterA at 96% → Congested
# Router RouterB at 65% → Moderate
# Router RouterC at 65% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 140 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 38% → Underloaded
# Router RouterC at 35% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 150 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 51% → Moderate
# Router RouterC at 30% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 160 sec:
# Router RouterA at 93% → Congested
# Router RouterB at 12% → Underloaded
# Router RouterC at 11% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 170 sec:
# Router RouterA at 10% → Underloaded
# Router RouterB at 85% → Congested
# Router RouterC at 53% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 180 sec:
# Router RouterA at 98% → Congested
# Router RouterB at 43% → Moderate
# Router RouterC at 46% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 190 sec:
# Router RouterA at 84% → Congested
# Router RouterB at 8% → Underloaded
# Router RouterC at 97% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 200 sec:
# Router RouterA at 2% → Underloaded
# Router RouterB at 39% → Underloaded
# Router RouterC at 0% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 210 sec:
# Router RouterA at 48% → Moderate
# Router RouterB at 11% → Underloaded
# Router RouterC at 31% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 220 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 71% → Congested
# Router RouterC at 30% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 230 sec:
# Router RouterA at 19% → Underloaded
# Router RouterB at 58% → Moderate
# Router RouterC at 97% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 240 sec:
# Router RouterA at 85% → Congested
# Router RouterB at 77% → Congested
# Router RouterC at 52% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 250 sec:
# Router RouterA at 97% → Congested
# Router RouterB at 90% → Congested
# Router RouterC at 88% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 260 sec:
# Router RouterA at 71% → Congested
# Router RouterB at 91% → Congested
# Router RouterC at 10% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 270 sec:
# Router RouterA at 61% → Moderate
# Router RouterB at 79% → Congested
# Router RouterC at 92% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 280 sec:
# Router RouterA at 75% → Congested
# Router RouterB at 15% → Underloaded
# Router RouterC at 41% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 290 sec:
# Router RouterA at 45% → Moderate
# Router RouterB at 28% → Underloaded
# Router RouterC at 98% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 300 sec:
# Router RouterA at 45% → Moderate
# Router RouterB at 68% → Moderate
# Router RouterC at 66% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 310 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 96% → Congested
# Router RouterC at 79% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 320 sec:
# Router RouterA at 62% → Moderate
# Router RouterB at 35% → Underloaded
# Router RouterC at 14% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 330 sec:
# Router RouterA at 34% → Underloaded
# Router RouterB at 10% → Underloaded
# Router RouterC at 70% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 340 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 58% → Moderate
# Router RouterC at 77% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 350 sec:
# Router RouterA at 45% → Moderate
# Router RouterB at 53% → Moderate
# Router RouterC at 78% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 360 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 46% → Moderate
# Router RouterC at 20% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 370 sec:
# Router RouterA at 26% → Underloaded
# Router RouterB at 40% → Underloaded
# Router RouterC at 73% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 380 sec:
# Router RouterA at 87% → Congested
# Router RouterB at 60% → Moderate
# Router RouterC at 95% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 390 sec:
# Router RouterA at 94% → Congested
# Router RouterB at 72% → Congested
# Router RouterC at 7% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 400 sec:
# Router RouterA at 1% → Underloaded
# Router RouterB at 5% → Underloaded
# Router RouterC at 33% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 410 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 66% → Moderate
# Router RouterC at 40% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 420 sec:
# Router RouterA at 77% → Congested
# Router RouterB at 98% → Congested
# Router RouterC at 11% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 430 sec:
# Router RouterA at 4% → Underloaded
# Router RouterB at 99% → Congested
# Router RouterC at 100% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 440 sec:
# Router RouterA at 31% → Underloaded
# Router RouterB at 76% → Congested
# Router RouterC at 77% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 450 sec:
# Router RouterA at 18% → Underloaded
# Router RouterB at 98% → Congested
# Router RouterC at 73% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 460 sec:
# Router RouterA at 9% → Underloaded
# Router RouterB at 55% → Moderate
# Router RouterC at 38% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 470 sec:
# Router RouterA at 10% → Underloaded
# Router RouterB at 17% → Underloaded
# Router RouterC at 60% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 480 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 16% → Underloaded
# Router RouterC at 89% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 490 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 54% → Moderate
# Router RouterC at 18% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 500 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 13% → Underloaded
# Router RouterC at 66% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 510 sec:
# Router RouterA at 48% → Moderate
# Router RouterB at 19% → Underloaded
# Router RouterC at 43% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 520 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 66% → Moderate
# Router RouterC at 93% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 530 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 59% → Moderate
# Router RouterC at 62% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 540 sec:
# Router RouterA at 39% → Underloaded
# Router RouterB at 17% → Underloaded
# Router RouterC at 18% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 550 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 4% → Underloaded
# Router RouterC at 69% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 560 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 98% → Congested
# Router RouterC at 94% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 570 sec:
# Router RouterA at 26% → Underloaded
# Router RouterB at 12% → Underloaded
# Router RouterC at 6% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 580 sec:
# Router RouterA at 66% → Moderate
# Router RouterB at 94% → Congested
# Router RouterC at 38% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 590 sec:
# Router RouterA at 62% → Moderate
# Router RouterB at 15% → Underloaded
# Router RouterC at 19% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 600 sec:
# Router RouterA at 82% → Congested
# Router RouterB at 72% → Congested
# Router RouterC at 43% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 610 sec:
# Router RouterA at 43% → Moderate
# Router RouterB at 88% → Congested
# Router RouterC at 59% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 620 sec:
# Router RouterA at 7% → Underloaded
# Router RouterB at 96% → Congested
# Router RouterC at 38% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 630 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 43% → Moderate
# Router RouterC at 38% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 640 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 98% → Congested
# Router RouterC at 26% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 650 sec:
# Router RouterA at 83% → Congested
# Router RouterB at 6% → Underloaded
# Router RouterC at 70% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 660 sec:
# Router RouterA at 13% → Underloaded
# Router RouterB at 59% → Moderate
# Router RouterC at 77% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 670 sec:
# Router RouterA at 6% → Underloaded
# Router RouterB at 18% → Underloaded
# Router RouterC at 4% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 680 sec:
# Router RouterA at 44% → Moderate
# Router RouterB at 93% → Congested
# Router RouterC at 63% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 690 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 76% → Congested
# Router RouterC at 64% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 700 sec:
# Router RouterA at 49% → Moderate
# Router RouterB at 7% → Underloaded
# Router RouterC at 78% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 710 sec:
# Router RouterA at 48% → Moderate
# Router RouterB at 100% → Congested
# Router RouterC at 25% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 720 sec:
# Router RouterA at 38% → Underloaded
# Router RouterB at 38% → Underloaded
# Router RouterC at 65% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 730 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 70% → Moderate
# Router RouterC at 85% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 740 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 43% → Moderate
# Router RouterC at 88% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 750 sec:
# Router RouterA at 2% → Underloaded
# Router RouterB at 46% → Moderate
# Router RouterC at 99% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 760 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 2% → Underloaded
# Router RouterC at 12% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 770 sec:
# Router RouterA at 32% → Underloaded
# Router RouterB at 14% → Underloaded
# Router RouterC at 14% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 780 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 27% → Underloaded
# Router RouterC at 82% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 790 sec:
# Router RouterA at 25% → Underloaded
# Router RouterB at 97% → Congested
# Router RouterC at 83% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 800 sec:
# Router RouterA at 91% → Congested
# Router RouterB at 73% → Congested
# Router RouterC at 88% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 810 sec:
# Router RouterA at 14% → Underloaded
# Router RouterB at 24% → Underloaded
# Router RouterC at 46% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 820 sec:
# Router RouterA at 72% → Congested
# Router RouterB at 92% → Congested
# Router RouterC at 7% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 830 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 15% → Underloaded
# Router RouterC at 4% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 840 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 6% → Underloaded
# Router RouterC at 98% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 850 sec:
# Router RouterA at 95% → Congested
# Router RouterB at 34% → Underloaded
# Router RouterC at 79% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 860 sec:
# Router RouterA at 65% → Moderate
# Router RouterB at 48% → Moderate
# Router RouterC at 30% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 870 sec:
# Router RouterA at 7% → Underloaded
# Router RouterB at 50% → Moderate
# Router RouterC at 50% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 880 sec:
# Router RouterA at 75% → Congested
# Router RouterB at 11% → Underloaded
# Router RouterC at 76% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 890 sec:
# Router RouterA at 76% → Congested
# Router RouterB at 38% → Underloaded
# Router RouterC at 75% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 900 sec:
# Router RouterA at 42% → Moderate
# Router RouterB at 22% → Underloaded
# Router RouterC at 96% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 910 sec:
# Router RouterA at 48% → Moderate
# Router RouterB at 34% → Underloaded
# Router RouterC at 66% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 920 sec:
# Router RouterA at 22% → Underloaded
# Router RouterB at 78% → Congested
# Router RouterC at 77% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 930 sec:
# Router RouterA at 14% → Underloaded
# Router RouterB at 97% → Congested
# Router RouterC at 98% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 940 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 47% → Moderate
# Router RouterC at 31% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 950 sec:
# Router RouterA at 84% → Congested
# Router RouterB at 1% → Underloaded
# Router RouterC at 34% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 960 sec:
# Router RouterA at 95% → Congested
# Router RouterB at 27% → Underloaded
# Router RouterC at 28% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 970 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 44% → Moderate
# Router RouterC at 81% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 980 sec:
# Router RouterA at 44% → Moderate
# Router RouterB at 87% → Congested
# Router RouterC at 14% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 990 sec:
# Router RouterA at 60% → Moderate
# Router RouterB at 1% → Underloaded
# Router RouterC at 89% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1000 sec:
# Router RouterA at 43% → Moderate
# Router RouterB at 43% → Moderate
# Router RouterC at 80% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1010 sec:
# Router RouterA at 13% → Underloaded
# Router RouterB at 18% → Underloaded
# Router RouterC at 88% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1020 sec:
# Router RouterA at 18% → Underloaded
# Router RouterB at 44% → Moderate
# Router RouterC at 82% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1030 sec:
# Router RouterA at 25% → Underloaded
# Router RouterB at 92% → Congested
# Router RouterC at 84% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1040 sec:
# Router RouterA at 50% → Moderate
# Router RouterB at 74% → Congested
# Router RouterC at 71% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1050 sec:
# Router RouterA at 41% → Moderate
# Router RouterB at 32% → Underloaded
# Router RouterC at 13% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1060 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 16% → Underloaded
# Router RouterC at 47% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1070 sec:
# Router RouterA at 10% → Underloaded
# Router RouterB at 21% → Underloaded
# Router RouterC at 31% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1080 sec:
# Router RouterA at 14% → Underloaded
# Router RouterB at 45% → Moderate
# Router RouterC at 72% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1090 sec:
# Router RouterA at 50% → Moderate
# Router RouterB at 96% → Congested
# Router RouterC at 40% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1100 sec:
# Router RouterA at 23% → Underloaded
# Router RouterB at 77% → Congested
# Router RouterC at 54% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1110 sec:
# Router RouterA at 14% → Underloaded
# Router RouterB at 40% → Underloaded
# Router RouterC at 25% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1120 sec:
# Router RouterA at 76% → Congested
# Router RouterB at 46% → Moderate
# Router RouterC at 0% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1130 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 40% → Underloaded
# Router RouterC at 60% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1140 sec:
# Router RouterA at 12% → Underloaded
# Router RouterB at 44% → Moderate
# Router RouterC at 71% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1150 sec:
# Router RouterA at 68% → Moderate
# Router RouterB at 61% → Moderate
# Router RouterC at 91% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1160 sec:
# Router RouterA at 98% → Congested
# Router RouterB at 65% → Moderate
# Router RouterC at 94% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1170 sec:
# Router RouterA at 63% → Moderate
# Router RouterB at 92% → Congested
# Router RouterC at 70% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1180 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 65% → Moderate
# Router RouterC at 37% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1190 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 25% → Underloaded
# Router RouterC at 43% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1200 sec:
# Router RouterA at 76% → Congested
# Router RouterB at 9% → Underloaded
# Router RouterC at 57% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1210 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 7% → Underloaded
# Router RouterC at 60% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1220 sec:
# Router RouterA at 40% → Underloaded
# Router RouterB at 54% → Moderate
# Router RouterC at 22% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1230 sec:
# Router RouterA at 59% → Moderate
# Router RouterB at 98% → Congested
# Router RouterC at 70% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1240 sec:
# Router RouterA at 18% → Underloaded
# Router RouterB at 69% → Moderate
# Router RouterC at 25% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1250 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 5% → Underloaded
# Router RouterC at 50% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1260 sec:
# Router RouterA at 68% → Moderate
# Router RouterB at 48% → Moderate
# Router RouterC at 44% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1270 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 64% → Moderate
# Router RouterC at 6% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1280 sec:
# Router RouterA at 38% → Underloaded
# Router RouterB at 91% → Congested
# Router RouterC at 94% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1290 sec:
# Router RouterA at 99% → Congested
# Router RouterB at 48% → Moderate
# Router RouterC at 48% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1300 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 40% → Underloaded
# Router RouterC at 40% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1310 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 18% → Underloaded
# Router RouterC at 74% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1320 sec:
# Router RouterA at 89% → Congested
# Router RouterB at 96% → Congested
# Router RouterC at 24% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1330 sec:
# Router RouterA at 89% → Congested
# Router RouterB at 29% → Underloaded
# Router RouterC at 28% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1340 sec:
# Router RouterA at 40% → Underloaded
# Router RouterB at 0% → Underloaded
# Router RouterC at 5% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1350 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 7% → Underloaded
# Router RouterC at 64% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1360 sec:
# Router RouterA at 68% → Moderate
# Router RouterB at 63% → Moderate
# Router RouterC at 45% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1370 sec:
# Router RouterA at 95% → Congested
# Router RouterB at 26% → Underloaded
# Router RouterC at 21% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1380 sec:
# Router RouterA at 81% → Congested
# Router RouterB at 91% → Congested
# Router RouterC at 39% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1390 sec:
# Router RouterA at 99% → Congested
# Router RouterB at 20% → Underloaded
# Router RouterC at 92% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1400 sec:
# Router RouterA at 42% → Moderate
# Router RouterB at 72% → Congested
# Router RouterC at 8% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1410 sec:
# Router RouterA at 16% → Underloaded
# Router RouterB at 20% → Underloaded
# Router RouterC at 93% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1420 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 82% → Congested
# Router RouterC at 91% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1430 sec:
# Router RouterA at 89% → Congested
# Router RouterB at 30% → Underloaded
# Router RouterC at 29% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1440 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 84% → Congested
# Router RouterC at 88% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1450 sec:
# Router RouterA at 20% → Underloaded
# Router RouterB at 33% → Underloaded
# Router RouterC at 71% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1460 sec:
# Router RouterA at 82% → Congested
# Router RouterB at 43% → Moderate
# Router RouterC at 77% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1470 sec:
# Router RouterA at 9% → Underloaded
# Router RouterB at 7% → Underloaded
# Router RouterC at 29% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1480 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 44% → Moderate
# Router RouterC at 14% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1490 sec:
# Router RouterA at 79% → Congested
# Router RouterB at 39% → Underloaded
# Router RouterC at 43% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1500 sec:
# Router RouterA at 60% → Moderate
# Router RouterB at 75% → Congested
# Router RouterC at 18% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1510 sec:
# Router RouterA at 92% → Congested
# Router RouterB at 30% → Underloaded
# Router RouterC at 62% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1520 sec:
# Router RouterA at 57% → Moderate
# Router RouterB at 49% → Moderate
# Router RouterC at 87% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1530 sec:
# Router RouterA at 61% → Moderate
# Router RouterB at 3% → Underloaded
# Router RouterC at 7% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1540 sec:
# Router RouterA at 1% → Underloaded
# Router RouterB at 77% → Congested
# Router RouterC at 25% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1550 sec:
# Router RouterA at 99% → Congested
# Router RouterB at 90% → Congested
# Router RouterC at 99% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1560 sec:
# Router RouterA at 57% → Moderate
# Router RouterB at 98% → Congested
# Router RouterC at 80% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1570 sec:
# Router RouterA at 93% → Congested
# Router RouterB at 17% → Underloaded
# Router RouterC at 16% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1580 sec:
# Router RouterA at 85% → Congested
# Router RouterB at 41% → Moderate
# Router RouterC at 6% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1590 sec:
# Router RouterA at 83% → Congested
# Router RouterB at 96% → Congested
# Router RouterC at 68% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1600 sec:
# Router RouterA at 41% → Moderate
# Router RouterB at 48% → Moderate
# Router RouterC at 87% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1610 sec:
# Router RouterA at 81% → Congested
# Router RouterB at 96% → Congested
# Router RouterC at 19% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1620 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 47% → Moderate
# Router RouterC at 58% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1630 sec:
# Router RouterA at 47% → Moderate
# Router RouterB at 7% → Underloaded
# Router RouterC at 39% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1640 sec:
# Router RouterA at 31% → Underloaded
# Router RouterB at 38% → Underloaded
# Router RouterC at 2% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1650 sec:
# Router RouterA at 51% → Moderate
# Router RouterB at 24% → Underloaded
# Router RouterC at 85% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1660 sec:
# Router RouterA at 34% → Underloaded
# Router RouterB at 14% → Underloaded
# Router RouterC at 27% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1670 sec:
# Router RouterA at 64% → Moderate
# Router RouterB at 45% → Moderate
# Router RouterC at 94% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1680 sec:
# Router RouterA at 37% → Underloaded
# Router RouterB at 4% → Underloaded
# Router RouterC at 86% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1690 sec:
# Router RouterA at 13% → Underloaded
# Router RouterB at 15% → Underloaded
# Router RouterC at 32% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1700 sec:
# Router RouterA at 1% → Underloaded
# Router RouterB at 88% → Congested
# Router RouterC at 88% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1710 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 31% → Underloaded
# Router RouterC at 22% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1720 sec:
# Router RouterA at 87% → Congested
# Router RouterB at 14% → Underloaded
# Router RouterC at 70% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1730 sec:
# Router RouterA at 25% → Underloaded
# Router RouterB at 50% → Moderate
# Router RouterC at 82% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1740 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 52% → Moderate
# Router RouterC at 46% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1750 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 77% → Congested
# Router RouterC at 44% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1760 sec:
# Router RouterA at 83% → Congested
# Router RouterB at 96% → Congested
# Router RouterC at 30% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1770 sec:
# Router RouterA at 39% → Underloaded
# Router RouterB at 61% → Moderate
# Router RouterC at 48% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1780 sec:
# Router RouterA at 40% → Underloaded
# Router RouterB at 10% → Underloaded
# Router RouterC at 95% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1790 sec:
# Router RouterA at 94% → Congested
# Router RouterB at 83% → Congested
# Router RouterC at 94% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1800 sec:
# Router RouterA at 24% → Underloaded
# Router RouterB at 58% → Moderate
# Router RouterC at 63% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1810 sec:
# Router RouterA at 89% → Congested
# Router RouterB at 59% → Moderate
# Router RouterC at 10% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1820 sec:
# Router RouterA at 24% → Underloaded
# Router RouterB at 69% → Moderate
# Router RouterC at 30% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1830 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 71% → Congested
# Router RouterC at 29% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1840 sec:
# Router RouterA at 83% → Congested
# Router RouterB at 7% → Underloaded
# Router RouterC at 42% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1850 sec:
# Router RouterA at 53% → Moderate
# Router RouterB at 26% → Underloaded
# Router RouterC at 21% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1860 sec:
# Router RouterA at 85% → Congested
# Router RouterB at 95% → Congested
# Router RouterC at 70% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1870 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 57% → Moderate
# Router RouterC at 91% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1880 sec:
# Router RouterA at 12% → Underloaded
# Router RouterB at 1% → Underloaded
# Router RouterC at 53% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1890 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 75% → Congested
# Router RouterC at 14% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1900 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 93% → Congested
# Router RouterC at 84% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1910 sec:
# Router RouterA at 59% → Moderate
# Router RouterB at 57% → Moderate
# Router RouterC at 91% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1920 sec:
# Router RouterA at 15% → Underloaded
# Router RouterB at 42% → Moderate
# Router RouterC at 32% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 1930 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 57% → Moderate
# Router RouterC at 13% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1940 sec:
# Router RouterA at 44% → Moderate
# Router RouterB at 63% → Moderate
# Router RouterC at 77% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1950 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 92% → Congested
# Router RouterC at 75% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1960 sec:
# Router RouterA at 65% → Moderate
# Router RouterB at 78% → Congested
# Router RouterC at 40% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1970 sec:
# Router RouterA at 96% → Congested
# Router RouterB at 70% → Moderate
# Router RouterC at 79% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1980 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 31% → Underloaded
# Router RouterC at 71% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1990 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 4% → Underloaded
# Router RouterC at 12% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2000 sec:
# Router RouterA at 40% → Underloaded
# Router RouterB at 67% → Moderate
# Router RouterC at 16% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2010 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 32% → Underloaded
# Router RouterC at 66% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2020 sec:
# Router RouterA at 72% → Congested
# Router RouterB at 79% → Congested
# Router RouterC at 51% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2030 sec:
# Router RouterA at 11% → Underloaded
# Router RouterB at 77% → Congested
# Router RouterC at 7% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2040 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 15% → Underloaded
# Router RouterC at 50% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2050 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 77% → Congested
# Router RouterC at 86% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2060 sec:
# Router RouterA at 6% → Underloaded
# Router RouterB at 64% → Moderate
# Router RouterC at 32% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2070 sec:
# Router RouterA at 30% → Underloaded
# Router RouterB at 98% → Congested
# Router RouterC at 100% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2080 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 28% → Underloaded
# Router RouterC at 71% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2090 sec:
# Router RouterA at 64% → Moderate
# Router RouterB at 47% → Moderate
# Router RouterC at 82% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2100 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 97% → Congested
# Router RouterC at 36% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2110 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 24% → Underloaded
# Router RouterC at 11% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2120 sec:
# Router RouterA at 95% → Congested
# Router RouterB at 14% → Underloaded
# Router RouterC at 3% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2130 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 100% → Congested
# Router RouterC at 70% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2140 sec:
# Router RouterA at 29% → Underloaded
# Router RouterB at 90% → Congested
# Router RouterC at 4% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2150 sec:
# Router RouterA at 48% → Moderate
# Router RouterB at 10% → Underloaded
# Router RouterC at 49% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2160 sec:
# Router RouterA at 6% → Underloaded
# Router RouterB at 15% → Underloaded
# Router RouterC at 14% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2170 sec:
# Router RouterA at 22% → Underloaded
# Router RouterB at 78% → Congested
# Router RouterC at 94% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2180 sec:
# Router RouterA at 19% → Underloaded
# Router RouterB at 92% → Congested
# Router RouterC at 96% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2190 sec:
# Router RouterA at 69% → Moderate
# Router RouterB at 31% → Underloaded
# Router RouterC at 65% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2200 sec:
# Router RouterA at 34% → Underloaded
# Router RouterB at 35% → Underloaded
# Router RouterC at 44% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2210 sec:
# Router RouterA at 5% → Underloaded
# Router RouterB at 89% → Congested
# Router RouterC at 51% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2220 sec:
# Router RouterA at 59% → Moderate
# Router RouterB at 74% → Congested
# Router RouterC at 97% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2230 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 56% → Moderate
# Router RouterC at 61% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2240 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 52% → Moderate
# Router RouterC at 73% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2250 sec:
# Router RouterA at 44% → Moderate
# Router RouterB at 89% → Congested
# Router RouterC at 40% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2260 sec:
# Router RouterA at 64% → Moderate
# Router RouterB at 71% → Congested
# Router RouterC at 74% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2270 sec:
# Router RouterA at 47% → Moderate
# Router RouterB at 90% → Congested
# Router RouterC at 46% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2280 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 53% → Moderate
# Router RouterC at 12% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2290 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 81% → Congested
# Router RouterC at 25% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2300 sec:
# Router RouterA at 72% → Congested
# Router RouterB at 28% → Underloaded
# Router RouterC at 98% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2310 sec:
# Router RouterA at 44% → Moderate
# Router RouterB at 22% → Underloaded
# Router RouterC at 0% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2320 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 62% → Moderate
# Router RouterC at 70% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2330 sec:
# Router RouterA at 83% → Congested
# Router RouterB at 82% → Congested
# Router RouterC at 51% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2340 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 6% → Underloaded
# Router RouterC at 6% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2350 sec:
# Router RouterA at 25% → Underloaded
# Router RouterB at 97% → Congested
# Router RouterC at 50% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2360 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 44% → Moderate
# Router RouterC at 27% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2370 sec:
# Router RouterA at 92% → Congested
# Router RouterB at 71% → Congested
# Router RouterC at 80% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2380 sec:
# Router RouterA at 11% → Underloaded
# Router RouterB at 69% → Moderate
# Router RouterC at 45% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2390 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 22% → Underloaded
# Router RouterC at 10% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2400 sec:
# Router RouterA at 88% → Congested
# Router RouterB at 45% → Moderate
# Router RouterC at 14% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2410 sec:
# Router RouterA at 40% → Underloaded
# Router RouterB at 20% → Underloaded
# Router RouterC at 3% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2420 sec:
# Router RouterA at 96% → Congested
# Router RouterB at 36% → Underloaded
# Router RouterC at 58% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2430 sec:
# Router RouterA at 61% → Moderate
# Router RouterB at 41% → Moderate
# Router RouterC at 61% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 2440 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 31% → Underloaded
# Router RouterC at 78% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2450 sec:
# Router RouterA at 93% → Congested
# Router RouterB at 84% → Congested
# Router RouterC at 85% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2460 sec:
# Router RouterA at 77% → Congested
# Router RouterB at 88% → Congested
# Router RouterC at 46% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2470 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 80% → Congested
# Router RouterC at 19% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2480 sec:
# Router RouterA at 1% → Underloaded
# Router RouterB at 66% → Moderate
# Router RouterC at 45% → Moderate
#   No bandwidth changes at this step.
#
# ...
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6150 sec:
# Router RouterA at 25% → Underloaded
# Router RouterB at 81% → Congested
# Router RouterC at 28% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6160 sec:
# Router RouterA at 82% → Congested
# Router RouterB at 94% → Congested
# Router RouterC at 90% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6170 sec:
# Router RouterA at 96% → Congested
# Router RouterB at 8% → Underloaded
# Router RouterC at 23% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6180 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 36% → Underloaded
# Router RouterC at 1% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6190 sec:
# Router RouterA at 41% → Moderate
# Router RouterB at 37% → Underloaded
# Router RouterC at 0% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6200 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 100% → Congested
# Router RouterC at 33% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6210 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 67% → Moderate
# Router RouterC at 55% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6220 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 72% → Congested
# Router RouterC at 89% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6230 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 35% → Underloaded
# Router RouterC at 62% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6240 sec:
# Router RouterA at 49% → Moderate
# Router RouterB at 21% → Underloaded
# Router RouterC at 32% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6250 sec:
# Router RouterA at 32% → Underloaded
# Router RouterB at 87% → Congested
# Router RouterC at 65% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6260 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 64% → Moderate
# Router RouterC at 71% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6270 sec:
# Router RouterA at 84% → Congested
# Router RouterB at 28% → Underloaded
# Router RouterC at 42% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6280 sec:
# Router RouterA at 68% → Moderate
# Router RouterB at 97% → Congested
# Router RouterC at 96% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6290 sec:
# Router RouterA at 57% → Moderate
# Router RouterB at 54% → Moderate
# Router RouterC at 82% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6300 sec:
# Router RouterA at 57% → Moderate
# Router RouterB at 58% → Moderate
# Router RouterC at 57% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6310 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 59% → Moderate
# Router RouterC at 29% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6320 sec:
# Router RouterA at 33% → Underloaded
# Router RouterB at 77% → Congested
# Router RouterC at 37% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6330 sec:
# Router RouterA at 53% → Moderate
# Router RouterB at 73% → Congested
# Router RouterC at 92% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6340 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 69% → Moderate
# Router RouterC at 53% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6350 sec:
# Router RouterA at 84% → Congested
# Router RouterB at 37% → Underloaded
# Router RouterC at 62% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6360 sec:
# Router RouterA at 79% → Congested
# Router RouterB at 60% → Moderate
# Router RouterC at 41% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6370 sec:
# Router RouterA at 63% → Moderate
# Router RouterB at 42% → Moderate
# Router RouterC at 52% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6380 sec:
# Router RouterA at 30% → Underloaded
# Router RouterB at 87% → Congested
# Router RouterC at 29% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6390 sec:
# Router RouterA at 41% → Moderate
# Router RouterB at 75% → Congested
# Router RouterC at 2% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6400 sec:
# Router RouterA at 86% → Congested
# Router RouterB at 43% → Moderate
# Router RouterC at 28% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6410 sec:
# Router RouterA at 27% → Underloaded
# Router RouterB at 87% → Congested
# Router RouterC at 84% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6420 sec:
# Router RouterA at 26% → Underloaded
# Router RouterB at 40% → Underloaded
# Router RouterC at 60% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6430 sec:
# Router RouterA at 87% → Congested
# Router RouterB at 46% → Moderate
# Router RouterC at 98% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6440 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 62% → Moderate
# Router RouterC at 99% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6450 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 88% → Congested
# Router RouterC at 58% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6460 sec:
# Router RouterA at 5% → Underloaded
# Router RouterB at 46% → Moderate
# Router RouterC at 94% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6470 sec:
# Router RouterA at 7% → Underloaded
# Router RouterB at 96% → Congested
# Router RouterC at 34% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6480 sec:
# Router RouterA at 20% → Underloaded
# Router RouterB at 71% → Congested
# Router RouterC at 8% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6490 sec:
# Router RouterA at 50% → Moderate
# Router RouterB at 15% → Underloaded
# Router RouterC at 76% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6500 sec:
# Router RouterA at 27% → Underloaded
# Router RouterB at 54% → Moderate
# Router RouterC at 16% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6510 sec:
# Router RouterA at 9% → Underloaded
# Router RouterB at 68% → Moderate
# Router RouterC at 68% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6520 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 78% → Congested
# Router RouterC at 83% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6530 sec:
# Router RouterA at 61% → Moderate
# Router RouterB at 53% → Moderate
# Router RouterC at 33% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6540 sec:
# Router RouterA at 34% → Underloaded
# Router RouterB at 66% → Moderate
# Router RouterC at 90% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6550 sec:
# Router RouterA at 88% → Congested
# Router RouterB at 6% → Underloaded
# Router RouterC at 45% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6560 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 61% → Moderate
# Router RouterC at 74% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6570 sec:
# Router RouterA at 82% → Congested
# Router RouterB at 25% → Underloaded
# Router RouterC at 35% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6580 sec:
# Router RouterA at 13% → Underloaded
# Router RouterB at 3% → Underloaded
# Router RouterC at 30% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6590 sec:
# Router RouterA at 63% → Moderate
# Router RouterB at 2% → Underloaded
# Router RouterC at 2% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6600 sec:
# Router RouterA at 91% → Congested
# Router RouterB at 16% → Underloaded
# Router RouterC at 17% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6610 sec:
# Router RouterA at 68% → Moderate
# Router RouterB at 22% → Underloaded
# Router RouterC at 90% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6620 sec:
# Router RouterA at 38% → Underloaded
# Router RouterB at 87% → Congested
# Router RouterC at 20% → Underloaded
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6630 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 26% → Underloaded
# Router RouterC at 91% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6640 sec:
# Router RouterA at 4% → Underloaded
# Router RouterB at 18% → Underloaded
# Router RouterC at 55% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6650 sec:
# Router RouterA at 71% → Congested
# Router RouterB at 23% → Underloaded
# Router RouterC at 91% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6660 sec:
# Router RouterA at 42% → Moderate
# Router RouterB at 51% → Moderate
# Router RouterC at 96% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6670 sec:
# Router RouterA at 62% → Moderate
# Router RouterB at 54% → Moderate
# Router RouterC at 65% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6680 sec:
# Router RouterA at 76% → Congested
# Router RouterB at 50% → Moderate
# Router RouterC at 9% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6690 sec:
# Router RouterA at 15% → Underloaded
# Router RouterB at 2% → Underloaded
# Router RouterC at 61% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6700 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 80% → Congested
# Router RouterC at 91% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6710 sec:
# Router RouterA at 23% → Underloaded
# Router RouterB at 89% → Congested
# Router RouterC at 85% → Congested
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6720 sec:
# Router RouterA at 72% → Congested
# Router RouterB at 58% → Moderate
# Router RouterC at 53% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6730 sec:
# Router RouterA at 79% → Congested
# Router RouterB at 0% → Underloaded
# Router RouterC at 4% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6740 sec:
# Router RouterA at 66% → Moderate
# Router RouterB at 7% → Underloaded
# Router RouterC at 74% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6750 sec:
# Router RouterA at 25% → Underloaded
# Router RouterB at 90% → Congested
# Router RouterC at 62% → Moderate
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6760 sec:
# Router RouterA at 69% → Moderate
# Router RouterB at 13% → Underloaded
# Router RouterC at 7% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6770 sec:
# Router RouterA at 49% → Moderate
# Router RouterB at 66% → Moderate
# Router RouterC at 18% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6780 sec:
# Router RouterA at 58% → Moderate
# Router RouterB at 36% → Underloaded
# Router RouterC at 33% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6790 sec:
# Router RouterA at 43% → Moderate
# Router RouterB at 24% → Underloaded
# Router RouterC at 65% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6800 sec:
# Router RouterA at 26% → Underloaded
# Router RouterB at 51% → Moderate
# Router RouterC at 27% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6810 sec:
# Router RouterA at 12% → Underloaded
# Router RouterB at 55% → Moderate
# Router RouterC at 100% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6820 sec:
# Router RouterA at 82% → Congested
# Router RouterB at 69% → Moderate
# Router RouterC at 3% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6830 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 42% → Moderate
# Router RouterC at 28% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6840 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 66% → Moderate
# Router RouterC at 43% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6850 sec:
# Router RouterA at 89% → Congested
# Router RouterB at 72% → Congested
# Router RouterC at 59% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6860 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 13% → Underloaded
# Router RouterC at 16% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6870 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 43% → Moderate
# Router RouterC at 95% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6880 sec:
# Router RouterA at 42% → Moderate
# Router RouterB at 6% → Underloaded
# Router RouterC at 13% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6890 sec:
# Router RouterA at 41% → Moderate
# Router RouterB at 68% → Moderate
# Router RouterC at 57% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6900 sec:
# Router RouterA at 19% → Underloaded
# Router RouterB at 17% → Underloaded
# Router RouterC at 59% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6910 sec:
# Router RouterA at 95% → Congested
# Router RouterB at 49% → Moderate
# Router RouterC at 57% → Moderate
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6920 sec:
# Router RouterA at 49% → Moderate
# Router RouterB at 34% → Underloaded
# Router RouterC at 86% → Congested
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6930 sec:
# Router RouterA at 84% → Congested
# Router RouterB at 92% → Congested
# Router RouterC at 71% → Congested
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#   QoS adjustment: RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6940 sec:
# Router RouterA at 99% → Congested
# Router RouterB at 19% → Underloaded
# Router RouterC at 24% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6950 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 13% → Underloaded
# Router RouterC at 52% → Moderate
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6960 sec:
# Router RouterA at 37% → Underloaded
# Router RouterB at 6% → Underloaded
# Router RouterC at 17% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6970 sec:
# Router RouterA at 38% → Underloaded
# Router RouterB at 22% → Underloaded
# Router RouterC at 38% → Underloaded
#   No bandwidth changes at this step.
#
# ⏱️ Time step 6980 sec:
# Router RouterA at 88% → Congested
# Router RouterB at 93% → Congested
# Router RouterC at 29% → Underloaded
#   QoS adjustment: RouterA–Server (old=180.0 → new=216.0)
#   QoS adjustment: RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6990 sec:
# Router RouterA at 64% → Moderate
# Router RouterB at 32% → Underloaded
# Router RouterC at 8% → Underloaded
#   No bandwidth changes at this step.

# %%
# POLICING
import pandas as pd
import networkx as nx

def run_policing_only(
    congestion_file,
    high_thresh=70,
    low_thresh=40,
    increase_factor=1.2,
    timestep=10,
):
    """
    Apply only policing (QoS adjustments) when routers are congested and
    no underloaded neighbors exist, across ALL timesteps.
    """

    # Load congestion data
    df_cong = pd.read_csv(congestion_file)

    # Add Time column if missing
    if "Time" not in df_cong.columns:
        df_cong.insert(0, "Time", [i * timestep for i in range(len(df_cong))])

    expected_cols = {"RouterA", "RouterB", "RouterC"}
    if not expected_cols.issubset(set(df_cong.columns)):
        raise ValueError(f"Congestion CSV must contain {expected_cols}, found {df_cong.columns}")

    # Hardcoded default topology
    default_edges = [
        ("User1", "Switch1", 110),
        ("Switch1", "Switch9", 80),
        ("Switch9", "Switch2", 120),
        ("Switch2", "Switch8", 130),
        ("Switch8", "RouterA", 90),
        ("RouterA", "Server", 180),
        ("User1", "Switch8", 140),
        ("Switch8", "Switch9", 180),
        ("Switch9", "Switch8", 190),
        ("Switch8", "Switch10", 180),
        ("Switch8", "Switch4", 140),
        ("Switch10", "User2", 110),
        ("Switch10", "Switch11", 130),
        ("Switch11", "Switch4", 80),
        ("Switch4", "RouterB", 100),
        ("RouterB", "Server", 120),
        ("Switch11", "Switch12", 60),
        ("Switch12", "User3", 160),
        ("Switch12", "Switch14", 100),
        ("Switch14", "RouterC", 130),
        ("RouterC", "Server", 180),
        ("Switch11", "Switch8", 60),
        ("Switch14", "Switch13", 120),
        ("Switch13", "User4", 80),
        ("Switch13", "Switch6", 190),
        ("Switch6", "Switch14", 70),
        ("Switch14", "RouterC", 70),
    ]

    # Iterate over timesteps and print logs
    for _, row in df_cong.iterrows():
        time_label = row["Time"]
        routers = {col: float(row[col]) for col in df_cong.columns if col.startswith("Router")}

        # Reset topology each timestep
        G = nx.Graph()
        for src, tgt, cap in default_edges:
            G.add_edge(src, tgt, capacity=float(cap))

        print(f"\n⏱️ Time step {time_label} sec:")

        # Report router states
        for r, load in routers.items():
            if load > high_thresh:
                status = "Congested"
            elif load > low_thresh:
                status = "Moderate"
            else:
                status = "Underloaded"
            print(f"Router {r} at {load:.0f}% → {status}")

        # Apply policing only
        actions = []
        for r, load in routers.items():
            if load > high_thresh:
                neighbors = list(G.neighbors(r))
                underloaded_neighbors = [n for n in neighbors if n in routers and routers[n] < low_thresh]

                if not underloaded_neighbors and neighbors:
                    busiest = max(neighbors, key=lambda n: G[r][n]["capacity"])
                    old_cap = G[r][busiest]["capacity"]
                    new_cap = old_cap * increase_factor
                    G[r][busiest]["capacity"] = new_cap
                    actions.append(
                        f"QoS adjustment (Policing): {r}–{busiest} (old={old_cap:.1f} → new={new_cap:.1f})"
                    )

        if not actions:
            print("No policing applied this step.")
        else:
            for act in actions:
                print(act)
run_policing_only("C:/Users/ASUS/Downloads/router_congestion_int.csv")
# Out:
# ⏱️ Time step 0 sec:
# Router RouterA at 1% → Underloaded
# Router RouterB at 29% → Underloaded
# Router RouterC at 30% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 10 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 27% → Underloaded
# Router RouterC at 68% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 20 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 38% → Underloaded
# Router RouterC at 90% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 30 sec:
# Router RouterA at 97% → Congested
# Router RouterB at 66% → Moderate
# Router RouterC at 3% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 40 sec:
# Router RouterA at 45% → Moderate
# Router RouterB at 94% → Congested
# Router RouterC at 9% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 50 sec:
# Router RouterA at 2% → Underloaded
# Router RouterB at 16% → Underloaded
# Router RouterC at 31% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 60 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 9% → Underloaded
# Router RouterC at 62% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 70 sec:
# Router RouterA at 23% → Underloaded
# Router RouterB at 34% → Underloaded
# Router RouterC at 29% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 80 sec:
# Router RouterA at 22% → Underloaded
# Router RouterB at 95% → Congested
# Router RouterC at 83% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 90 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 92% → Congested
# Router RouterC at 13% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 100 sec:
# Router RouterA at 99% → Congested
# Router RouterB at 1% → Underloaded
# Router RouterC at 30% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 110 sec:
# Router RouterA at 71% → Congested
# Router RouterB at 28% → Underloaded
# Router RouterC at 73% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 120 sec:
# Router RouterA at 30% → Underloaded
# Router RouterB at 26% → Underloaded
# Router RouterC at 32% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 130 sec:
# Router RouterA at 96% → Congested
# Router RouterB at 65% → Moderate
# Router RouterC at 65% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 140 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 38% → Underloaded
# Router RouterC at 35% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 150 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 51% → Moderate
# Router RouterC at 30% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 160 sec:
# Router RouterA at 93% → Congested
# Router RouterB at 12% → Underloaded
# Router RouterC at 11% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 170 sec:
# Router RouterA at 10% → Underloaded
# Router RouterB at 85% → Congested
# Router RouterC at 53% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 180 sec:
# Router RouterA at 98% → Congested
# Router RouterB at 43% → Moderate
# Router RouterC at 46% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 190 sec:
# Router RouterA at 84% → Congested
# Router RouterB at 8% → Underloaded
# Router RouterC at 97% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 200 sec:
# Router RouterA at 2% → Underloaded
# Router RouterB at 39% → Underloaded
# Router RouterC at 0% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 210 sec:
# Router RouterA at 48% → Moderate
# Router RouterB at 11% → Underloaded
# Router RouterC at 31% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 220 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 71% → Congested
# Router RouterC at 30% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 230 sec:
# Router RouterA at 19% → Underloaded
# Router RouterB at 58% → Moderate
# Router RouterC at 97% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 240 sec:
# Router RouterA at 85% → Congested
# Router RouterB at 77% → Congested
# Router RouterC at 52% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 250 sec:
# Router RouterA at 97% → Congested
# Router RouterB at 90% → Congested
# Router RouterC at 88% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 260 sec:
# Router RouterA at 71% → Congested
# Router RouterB at 91% → Congested
# Router RouterC at 10% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 270 sec:
# Router RouterA at 61% → Moderate
# Router RouterB at 79% → Congested
# Router RouterC at 92% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 280 sec:
# Router RouterA at 75% → Congested
# Router RouterB at 15% → Underloaded
# Router RouterC at 41% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 290 sec:
# Router RouterA at 45% → Moderate
# Router RouterB at 28% → Underloaded
# Router RouterC at 98% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 300 sec:
# Router RouterA at 45% → Moderate
# Router RouterB at 68% → Moderate
# Router RouterC at 66% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 310 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 96% → Congested
# Router RouterC at 79% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 320 sec:
# Router RouterA at 62% → Moderate
# Router RouterB at 35% → Underloaded
# Router RouterC at 14% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 330 sec:
# Router RouterA at 34% → Underloaded
# Router RouterB at 10% → Underloaded
# Router RouterC at 70% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 340 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 58% → Moderate
# Router RouterC at 77% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 350 sec:
# Router RouterA at 45% → Moderate
# Router RouterB at 53% → Moderate
# Router RouterC at 78% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 360 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 46% → Moderate
# Router RouterC at 20% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 370 sec:
# Router RouterA at 26% → Underloaded
# Router RouterB at 40% → Underloaded
# Router RouterC at 73% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 380 sec:
# Router RouterA at 87% → Congested
# Router RouterB at 60% → Moderate
# Router RouterC at 95% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 390 sec:
# Router RouterA at 94% → Congested
# Router RouterB at 72% → Congested
# Router RouterC at 7% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 400 sec:
# Router RouterA at 1% → Underloaded
# Router RouterB at 5% → Underloaded
# Router RouterC at 33% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 410 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 66% → Moderate
# Router RouterC at 40% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 420 sec:
# Router RouterA at 77% → Congested
# Router RouterB at 98% → Congested
# Router RouterC at 11% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 430 sec:
# Router RouterA at 4% → Underloaded
# Router RouterB at 99% → Congested
# Router RouterC at 100% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 440 sec:
# Router RouterA at 31% → Underloaded
# Router RouterB at 76% → Congested
# Router RouterC at 77% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 450 sec:
# Router RouterA at 18% → Underloaded
# Router RouterB at 98% → Congested
# Router RouterC at 73% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 460 sec:
# Router RouterA at 9% → Underloaded
# Router RouterB at 55% → Moderate
# Router RouterC at 38% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 470 sec:
# Router RouterA at 10% → Underloaded
# Router RouterB at 17% → Underloaded
# Router RouterC at 60% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 480 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 16% → Underloaded
# Router RouterC at 89% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 490 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 54% → Moderate
# Router RouterC at 18% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 500 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 13% → Underloaded
# Router RouterC at 66% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 510 sec:
# Router RouterA at 48% → Moderate
# Router RouterB at 19% → Underloaded
# Router RouterC at 43% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 520 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 66% → Moderate
# Router RouterC at 93% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 530 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 59% → Moderate
# Router RouterC at 62% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 540 sec:
# Router RouterA at 39% → Underloaded
# Router RouterB at 17% → Underloaded
# Router RouterC at 18% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 550 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 4% → Underloaded
# Router RouterC at 69% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 560 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 98% → Congested
# Router RouterC at 94% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 570 sec:
# Router RouterA at 26% → Underloaded
# Router RouterB at 12% → Underloaded
# Router RouterC at 6% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 580 sec:
# Router RouterA at 66% → Moderate
# Router RouterB at 94% → Congested
# Router RouterC at 38% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 590 sec:
# Router RouterA at 62% → Moderate
# Router RouterB at 15% → Underloaded
# Router RouterC at 19% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 600 sec:
# Router RouterA at 82% → Congested
# Router RouterB at 72% → Congested
# Router RouterC at 43% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 610 sec:
# Router RouterA at 43% → Moderate
# Router RouterB at 88% → Congested
# Router RouterC at 59% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 620 sec:
# Router RouterA at 7% → Underloaded
# Router RouterB at 96% → Congested
# Router RouterC at 38% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 630 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 43% → Moderate
# Router RouterC at 38% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 640 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 98% → Congested
# Router RouterC at 26% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 650 sec:
# Router RouterA at 83% → Congested
# Router RouterB at 6% → Underloaded
# Router RouterC at 70% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 660 sec:
# Router RouterA at 13% → Underloaded
# Router RouterB at 59% → Moderate
# Router RouterC at 77% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 670 sec:
# Router RouterA at 6% → Underloaded
# Router RouterB at 18% → Underloaded
# Router RouterC at 4% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 680 sec:
# Router RouterA at 44% → Moderate
# Router RouterB at 93% → Congested
# Router RouterC at 63% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 690 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 76% → Congested
# Router RouterC at 64% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 700 sec:
# Router RouterA at 49% → Moderate
# Router RouterB at 7% → Underloaded
# Router RouterC at 78% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 710 sec:
# Router RouterA at 48% → Moderate
# Router RouterB at 100% → Congested
# Router RouterC at 25% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 720 sec:
# Router RouterA at 38% → Underloaded
# Router RouterB at 38% → Underloaded
# Router RouterC at 65% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 730 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 70% → Moderate
# Router RouterC at 85% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 740 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 43% → Moderate
# Router RouterC at 88% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 750 sec:
# Router RouterA at 2% → Underloaded
# Router RouterB at 46% → Moderate
# Router RouterC at 99% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 760 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 2% → Underloaded
# Router RouterC at 12% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 770 sec:
# Router RouterA at 32% → Underloaded
# Router RouterB at 14% → Underloaded
# Router RouterC at 14% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 780 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 27% → Underloaded
# Router RouterC at 82% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 790 sec:
# Router RouterA at 25% → Underloaded
# Router RouterB at 97% → Congested
# Router RouterC at 83% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 800 sec:
# Router RouterA at 91% → Congested
# Router RouterB at 73% → Congested
# Router RouterC at 88% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 810 sec:
# Router RouterA at 14% → Underloaded
# Router RouterB at 24% → Underloaded
# Router RouterC at 46% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 820 sec:
# Router RouterA at 72% → Congested
# Router RouterB at 92% → Congested
# Router RouterC at 7% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 830 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 15% → Underloaded
# Router RouterC at 4% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 840 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 6% → Underloaded
# Router RouterC at 98% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 850 sec:
# Router RouterA at 95% → Congested
# Router RouterB at 34% → Underloaded
# Router RouterC at 79% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 860 sec:
# Router RouterA at 65% → Moderate
# Router RouterB at 48% → Moderate
# Router RouterC at 30% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 870 sec:
# Router RouterA at 7% → Underloaded
# Router RouterB at 50% → Moderate
# Router RouterC at 50% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 880 sec:
# Router RouterA at 75% → Congested
# Router RouterB at 11% → Underloaded
# Router RouterC at 76% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 890 sec:
# Router RouterA at 76% → Congested
# Router RouterB at 38% → Underloaded
# Router RouterC at 75% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 900 sec:
# Router RouterA at 42% → Moderate
# Router RouterB at 22% → Underloaded
# Router RouterC at 96% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 910 sec:
# Router RouterA at 48% → Moderate
# Router RouterB at 34% → Underloaded
# Router RouterC at 66% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 920 sec:
# Router RouterA at 22% → Underloaded
# Router RouterB at 78% → Congested
# Router RouterC at 77% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 930 sec:
# Router RouterA at 14% → Underloaded
# Router RouterB at 97% → Congested
# Router RouterC at 98% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 940 sec:
# Router RouterA at 3% → Underloaded
# Router RouterB at 47% → Moderate
# Router RouterC at 31% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 950 sec:
# Router RouterA at 84% → Congested
# Router RouterB at 1% → Underloaded
# Router RouterC at 34% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 960 sec:
# Router RouterA at 95% → Congested
# Router RouterB at 27% → Underloaded
# Router RouterC at 28% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 970 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 44% → Moderate
# Router RouterC at 81% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 980 sec:
# Router RouterA at 44% → Moderate
# Router RouterB at 87% → Congested
# Router RouterC at 14% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 990 sec:
# Router RouterA at 60% → Moderate
# Router RouterB at 1% → Underloaded
# Router RouterC at 89% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1000 sec:
# Router RouterA at 43% → Moderate
# Router RouterB at 43% → Moderate
# Router RouterC at 80% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1010 sec:
# Router RouterA at 13% → Underloaded
# Router RouterB at 18% → Underloaded
# Router RouterC at 88% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1020 sec:
# Router RouterA at 18% → Underloaded
# Router RouterB at 44% → Moderate
# Router RouterC at 82% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1030 sec:
# Router RouterA at 25% → Underloaded
# Router RouterB at 92% → Congested
# Router RouterC at 84% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1040 sec:
# Router RouterA at 50% → Moderate
# Router RouterB at 74% → Congested
# Router RouterC at 71% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1050 sec:
# Router RouterA at 41% → Moderate
# Router RouterB at 32% → Underloaded
# Router RouterC at 13% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1060 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 16% → Underloaded
# Router RouterC at 47% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 1070 sec:
# Router RouterA at 10% → Underloaded
# Router RouterB at 21% → Underloaded
# Router RouterC at 31% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1080 sec:
# Router RouterA at 14% → Underloaded
# Router RouterB at 45% → Moderate
# Router RouterC at 72% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1090 sec:
# Router RouterA at 50% → Moderate
# Router RouterB at 96% → Congested
# Router RouterC at 40% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1100 sec:
# Router RouterA at 23% → Underloaded
# Router RouterB at 77% → Congested
# Router RouterC at 54% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1110 sec:
# Router RouterA at 14% → Underloaded
# Router RouterB at 40% → Underloaded
# Router RouterC at 25% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1120 sec:
# Router RouterA at 76% → Congested
# Router RouterB at 46% → Moderate
# Router RouterC at 0% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1130 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 40% → Underloaded
# Router RouterC at 60% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 1140 sec:
# Router RouterA at 12% → Underloaded
# Router RouterB at 44% → Moderate
# Router RouterC at 71% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1150 sec:
# Router RouterA at 68% → Moderate
# Router RouterB at 61% → Moderate
# Router RouterC at 91% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1160 sec:
# Router RouterA at 98% → Congested
# Router RouterB at 65% → Moderate
# Router RouterC at 94% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1170 sec:
# Router RouterA at 63% → Moderate
# Router RouterB at 92% → Congested
# Router RouterC at 70% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1180 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 65% → Moderate
# Router RouterC at 37% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1190 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 25% → Underloaded
# Router RouterC at 43% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1200 sec:
# Router RouterA at 76% → Congested
# Router RouterB at 9% → Underloaded
# Router RouterC at 57% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1210 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 7% → Underloaded
# Router RouterC at 60% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1220 sec:
# Router RouterA at 40% → Underloaded
# Router RouterB at 54% → Moderate
# Router RouterC at 22% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1230 sec:
# Router RouterA at 59% → Moderate
# Router RouterB at 98% → Congested
# Router RouterC at 70% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1240 sec:
# Router RouterA at 18% → Underloaded
# Router RouterB at 69% → Moderate
# Router RouterC at 25% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1250 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 5% → Underloaded
# Router RouterC at 50% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 1260 sec:
# Router RouterA at 68% → Moderate
# Router RouterB at 48% → Moderate
# Router RouterC at 44% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 1270 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 64% → Moderate
# Router RouterC at 6% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1280 sec:
# Router RouterA at 38% → Underloaded
# Router RouterB at 91% → Congested
# Router RouterC at 94% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1290 sec:
# Router RouterA at 99% → Congested
# Router RouterB at 48% → Moderate
# Router RouterC at 48% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1300 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 40% → Underloaded
# Router RouterC at 40% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1310 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 18% → Underloaded
# Router RouterC at 74% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1320 sec:
# Router RouterA at 89% → Congested
# Router RouterB at 96% → Congested
# Router RouterC at 24% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1330 sec:
# Router RouterA at 89% → Congested
# Router RouterB at 29% → Underloaded
# Router RouterC at 28% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1340 sec:
# Router RouterA at 40% → Underloaded
# Router RouterB at 0% → Underloaded
# Router RouterC at 5% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1350 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 7% → Underloaded
# Router RouterC at 64% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1360 sec:
# Router RouterA at 68% → Moderate
# Router RouterB at 63% → Moderate
# Router RouterC at 45% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 1370 sec:
# Router RouterA at 95% → Congested
# Router RouterB at 26% → Underloaded
# Router RouterC at 21% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1380 sec:
# Router RouterA at 81% → Congested
# Router RouterB at 91% → Congested
# Router RouterC at 39% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1390 sec:
# Router RouterA at 99% → Congested
# Router RouterB at 20% → Underloaded
# Router RouterC at 92% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1400 sec:
# Router RouterA at 42% → Moderate
# Router RouterB at 72% → Congested
# Router RouterC at 8% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1410 sec:
# Router RouterA at 16% → Underloaded
# Router RouterB at 20% → Underloaded
# Router RouterC at 93% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1420 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 82% → Congested
# Router RouterC at 91% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1430 sec:
# Router RouterA at 89% → Congested
# Router RouterB at 30% → Underloaded
# Router RouterC at 29% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1440 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 84% → Congested
# Router RouterC at 88% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1450 sec:
# Router RouterA at 20% → Underloaded
# Router RouterB at 33% → Underloaded
# Router RouterC at 71% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1460 sec:
# Router RouterA at 82% → Congested
# Router RouterB at 43% → Moderate
# Router RouterC at 77% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1470 sec:
# Router RouterA at 9% → Underloaded
# Router RouterB at 7% → Underloaded
# Router RouterC at 29% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1480 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 44% → Moderate
# Router RouterC at 14% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1490 sec:
# Router RouterA at 79% → Congested
# Router RouterB at 39% → Underloaded
# Router RouterC at 43% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1500 sec:
# Router RouterA at 60% → Moderate
# Router RouterB at 75% → Congested
# Router RouterC at 18% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1510 sec:
# Router RouterA at 92% → Congested
# Router RouterB at 30% → Underloaded
# Router RouterC at 62% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1520 sec:
# Router RouterA at 57% → Moderate
# Router RouterB at 49% → Moderate
# Router RouterC at 87% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1530 sec:
# Router RouterA at 61% → Moderate
# Router RouterB at 3% → Underloaded
# Router RouterC at 7% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1540 sec:
# Router RouterA at 1% → Underloaded
# Router RouterB at 77% → Congested
# Router RouterC at 25% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1550 sec:
# Router RouterA at 99% → Congested
# Router RouterB at 90% → Congested
# Router RouterC at 99% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1560 sec:
# Router RouterA at 57% → Moderate
# Router RouterB at 98% → Congested
# Router RouterC at 80% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1570 sec:
# Router RouterA at 93% → Congested
# Router RouterB at 17% → Underloaded
# Router RouterC at 16% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1580 sec:
# Router RouterA at 85% → Congested
# Router RouterB at 41% → Moderate
# Router RouterC at 6% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1590 sec:
# Router RouterA at 83% → Congested
# Router RouterB at 96% → Congested
# Router RouterC at 68% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1600 sec:
# Router RouterA at 41% → Moderate
# Router RouterB at 48% → Moderate
# Router RouterC at 87% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1610 sec:
# Router RouterA at 81% → Congested
# Router RouterB at 96% → Congested
# Router RouterC at 19% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1620 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 47% → Moderate
# Router RouterC at 58% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 1630 sec:
# Router RouterA at 47% → Moderate
# Router RouterB at 7% → Underloaded
# Router RouterC at 39% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1640 sec:
# Router RouterA at 31% → Underloaded
# Router RouterB at 38% → Underloaded
# Router RouterC at 2% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1650 sec:
# Router RouterA at 51% → Moderate
# Router RouterB at 24% → Underloaded
# Router RouterC at 85% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1660 sec:
# Router RouterA at 34% → Underloaded
# Router RouterB at 14% → Underloaded
# Router RouterC at 27% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1670 sec:
# Router RouterA at 64% → Moderate
# Router RouterB at 45% → Moderate
# Router RouterC at 94% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1680 sec:
# Router RouterA at 37% → Underloaded
# Router RouterB at 4% → Underloaded
# Router RouterC at 86% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1690 sec:
# Router RouterA at 13% → Underloaded
# Router RouterB at 15% → Underloaded
# Router RouterC at 32% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1700 sec:
# Router RouterA at 1% → Underloaded
# Router RouterB at 88% → Congested
# Router RouterC at 88% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1710 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 31% → Underloaded
# Router RouterC at 22% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1720 sec:
# Router RouterA at 87% → Congested
# Router RouterB at 14% → Underloaded
# Router RouterC at 70% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1730 sec:
# Router RouterA at 25% → Underloaded
# Router RouterB at 50% → Moderate
# Router RouterC at 82% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1740 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 52% → Moderate
# Router RouterC at 46% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1750 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 77% → Congested
# Router RouterC at 44% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1760 sec:
# Router RouterA at 83% → Congested
# Router RouterB at 96% → Congested
# Router RouterC at 30% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1770 sec:
# Router RouterA at 39% → Underloaded
# Router RouterB at 61% → Moderate
# Router RouterC at 48% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 1780 sec:
# Router RouterA at 40% → Underloaded
# Router RouterB at 10% → Underloaded
# Router RouterC at 95% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1790 sec:
# Router RouterA at 94% → Congested
# Router RouterB at 83% → Congested
# Router RouterC at 94% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1800 sec:
# Router RouterA at 24% → Underloaded
# Router RouterB at 58% → Moderate
# Router RouterC at 63% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 1810 sec:
# Router RouterA at 89% → Congested
# Router RouterB at 59% → Moderate
# Router RouterC at 10% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1820 sec:
# Router RouterA at 24% → Underloaded
# Router RouterB at 69% → Moderate
# Router RouterC at 30% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1830 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 71% → Congested
# Router RouterC at 29% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1840 sec:
# Router RouterA at 83% → Congested
# Router RouterB at 7% → Underloaded
# Router RouterC at 42% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1850 sec:
# Router RouterA at 53% → Moderate
# Router RouterB at 26% → Underloaded
# Router RouterC at 21% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1860 sec:
# Router RouterA at 85% → Congested
# Router RouterB at 95% → Congested
# Router RouterC at 70% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1870 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 57% → Moderate
# Router RouterC at 91% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1880 sec:
# Router RouterA at 12% → Underloaded
# Router RouterB at 1% → Underloaded
# Router RouterC at 53% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 1890 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 75% → Congested
# Router RouterC at 14% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1900 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 93% → Congested
# Router RouterC at 84% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1910 sec:
# Router RouterA at 59% → Moderate
# Router RouterB at 57% → Moderate
# Router RouterC at 91% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1920 sec:
# Router RouterA at 15% → Underloaded
# Router RouterB at 42% → Moderate
# Router RouterC at 32% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 1930 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 57% → Moderate
# Router RouterC at 13% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1940 sec:
# Router RouterA at 44% → Moderate
# Router RouterB at 63% → Moderate
# Router RouterC at 77% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1950 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 92% → Congested
# Router RouterC at 75% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1960 sec:
# Router RouterA at 65% → Moderate
# Router RouterB at 78% → Congested
# Router RouterC at 40% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 1970 sec:
# Router RouterA at 96% → Congested
# Router RouterB at 70% → Moderate
# Router RouterC at 79% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1980 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 31% → Underloaded
# Router RouterC at 71% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 1990 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 4% → Underloaded
# Router RouterC at 12% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 2000 sec:
# Router RouterA at 40% → Underloaded
# Router RouterB at 67% → Moderate
# Router RouterC at 16% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 2010 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 32% → Underloaded
# Router RouterC at 66% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 2020 sec:
# Router RouterA at 72% → Congested
# Router RouterB at 79% → Congested
# Router RouterC at 51% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2030 sec:
# Router RouterA at 11% → Underloaded
# Router RouterB at 77% → Congested
# Router RouterC at 7% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2040 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 15% → Underloaded
# Router RouterC at 50% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 2050 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 77% → Congested
# Router RouterC at 86% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2060 sec:
# Router RouterA at 6% → Underloaded
# Router RouterB at 64% → Moderate
# Router RouterC at 32% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 2070 sec:
# Router RouterA at 30% → Underloaded
# Router RouterB at 98% → Congested
# Router RouterC at 100% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2080 sec:
# Router RouterA at 74% → Congested
# Router RouterB at 28% → Underloaded
# Router RouterC at 71% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2090 sec:
# Router RouterA at 64% → Moderate
# Router RouterB at 47% → Moderate
# Router RouterC at 82% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2100 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 97% → Congested
# Router RouterC at 36% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2110 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 24% → Underloaded
# Router RouterC at 11% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 2120 sec:
# Router RouterA at 95% → Congested
# Router RouterB at 14% → Underloaded
# Router RouterC at 3% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2130 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 100% → Congested
# Router RouterC at 70% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2140 sec:
# Router RouterA at 29% → Underloaded
# Router RouterB at 90% → Congested
# Router RouterC at 4% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2150 sec:
# Router RouterA at 48% → Moderate
# Router RouterB at 10% → Underloaded
# Router RouterC at 49% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 2160 sec:
# Router RouterA at 6% → Underloaded
# Router RouterB at 15% → Underloaded
# Router RouterC at 14% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 2170 sec:
# Router RouterA at 22% → Underloaded
# Router RouterB at 78% → Congested
# Router RouterC at 94% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2180 sec:
# Router RouterA at 19% → Underloaded
# Router RouterB at 92% → Congested
# Router RouterC at 96% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2190 sec:
# Router RouterA at 69% → Moderate
# Router RouterB at 31% → Underloaded
# Router RouterC at 65% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 2200 sec:
# Router RouterA at 34% → Underloaded
# Router RouterB at 35% → Underloaded
# Router RouterC at 44% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 2210 sec:
# Router RouterA at 5% → Underloaded
# Router RouterB at 89% → Congested
# Router RouterC at 51% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2220 sec:
# Router RouterA at 59% → Moderate
# Router RouterB at 74% → Congested
# Router RouterC at 97% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2230 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 56% → Moderate
# Router RouterC at 61% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2240 sec:
# Router RouterA at 52% → Moderate
# Router RouterB at 52% → Moderate
# Router RouterC at 73% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2250 sec:
# Router RouterA at 44% → Moderate
# Router RouterB at 89% → Congested
# Router RouterC at 40% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2260 sec:
# Router RouterA at 64% → Moderate
# Router RouterB at 71% → Congested
# Router RouterC at 74% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2270 sec:
# Router RouterA at 47% → Moderate
# Router RouterB at 90% → Congested
# Router RouterC at 46% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2280 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 53% → Moderate
# Router RouterC at 12% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 2290 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 81% → Congested
# Router RouterC at 25% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2300 sec:
# Router RouterA at 72% → Congested
# Router RouterB at 28% → Underloaded
# Router RouterC at 98% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2310 sec:
# Router RouterA at 44% → Moderate
# Router RouterB at 22% → Underloaded
# Router RouterC at 0% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 2320 sec:
# Router RouterA at 36% → Underloaded
# Router RouterB at 62% → Moderate
# Router RouterC at 70% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 2330 sec:
# Router RouterA at 83% → Congested
# Router RouterB at 82% → Congested
# Router RouterC at 51% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2340 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 6% → Underloaded
# Router RouterC at 6% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 2350 sec:
# Router RouterA at 25% → Underloaded
# Router RouterB at 97% → Congested
# Router RouterC at 50% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 2360 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 44% → Moderate
# Router RouterC at 27% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 2370 sec:
# Router RouterA at 92% → Congested
# Router RouterB at 71% → Congested
# Router RouterC at 80% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2380 sec:
# Router RouterA at 11% → Underloaded
# Router RouterB at 69% → Moderate
# Router RouterC at 45% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 2390 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 22% → Underloaded
# Router RouterC at 10% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 2400 sec:
# Router RouterA at 88% → Congested
# Router RouterB at 45% → Moderate
# Router RouterC at 14% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 2410 sec:
# ...
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6170 sec:
# Router RouterA at 96% → Congested
# Router RouterB at 8% → Underloaded
# Router RouterC at 23% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6180 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 36% → Underloaded
# Router RouterC at 1% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6190 sec:
# Router RouterA at 41% → Moderate
# Router RouterB at 37% → Underloaded
# Router RouterC at 0% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6200 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 100% → Congested
# Router RouterC at 33% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6210 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 67% → Moderate
# Router RouterC at 55% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6220 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 72% → Congested
# Router RouterC at 89% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6230 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 35% → Underloaded
# Router RouterC at 62% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6240 sec:
# Router RouterA at 49% → Moderate
# Router RouterB at 21% → Underloaded
# Router RouterC at 32% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6250 sec:
# Router RouterA at 32% → Underloaded
# Router RouterB at 87% → Congested
# Router RouterC at 65% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6260 sec:
# Router RouterA at 46% → Moderate
# Router RouterB at 64% → Moderate
# Router RouterC at 71% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6270 sec:
# Router RouterA at 84% → Congested
# Router RouterB at 28% → Underloaded
# Router RouterC at 42% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6280 sec:
# Router RouterA at 68% → Moderate
# Router RouterB at 97% → Congested
# Router RouterC at 96% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6290 sec:
# Router RouterA at 57% → Moderate
# Router RouterB at 54% → Moderate
# Router RouterC at 82% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6300 sec:
# Router RouterA at 57% → Moderate
# Router RouterB at 58% → Moderate
# Router RouterC at 57% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6310 sec:
# Router RouterA at 0% → Underloaded
# Router RouterB at 59% → Moderate
# Router RouterC at 29% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6320 sec:
# Router RouterA at 33% → Underloaded
# Router RouterB at 77% → Congested
# Router RouterC at 37% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6330 sec:
# Router RouterA at 53% → Moderate
# Router RouterB at 73% → Congested
# Router RouterC at 92% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6340 sec:
# Router RouterA at 73% → Congested
# Router RouterB at 69% → Moderate
# Router RouterC at 53% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6350 sec:
# Router RouterA at 84% → Congested
# Router RouterB at 37% → Underloaded
# Router RouterC at 62% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6360 sec:
# Router RouterA at 79% → Congested
# Router RouterB at 60% → Moderate
# Router RouterC at 41% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6370 sec:
# Router RouterA at 63% → Moderate
# Router RouterB at 42% → Moderate
# Router RouterC at 52% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6380 sec:
# Router RouterA at 30% → Underloaded
# Router RouterB at 87% → Congested
# Router RouterC at 29% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6390 sec:
# Router RouterA at 41% → Moderate
# Router RouterB at 75% → Congested
# Router RouterC at 2% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6400 sec:
# Router RouterA at 86% → Congested
# Router RouterB at 43% → Moderate
# Router RouterC at 28% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6410 sec:
# Router RouterA at 27% → Underloaded
# Router RouterB at 87% → Congested
# Router RouterC at 84% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6420 sec:
# Router RouterA at 26% → Underloaded
# Router RouterB at 40% → Underloaded
# Router RouterC at 60% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6430 sec:
# Router RouterA at 87% → Congested
# Router RouterB at 46% → Moderate
# Router RouterC at 98% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6440 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 62% → Moderate
# Router RouterC at 99% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6450 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 88% → Congested
# Router RouterC at 58% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6460 sec:
# Router RouterA at 5% → Underloaded
# Router RouterB at 46% → Moderate
# Router RouterC at 94% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6470 sec:
# Router RouterA at 7% → Underloaded
# Router RouterB at 96% → Congested
# Router RouterC at 34% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6480 sec:
# Router RouterA at 20% → Underloaded
# Router RouterB at 71% → Congested
# Router RouterC at 8% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6490 sec:
# Router RouterA at 50% → Moderate
# Router RouterB at 15% → Underloaded
# Router RouterC at 76% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6500 sec:
# Router RouterA at 27% → Underloaded
# Router RouterB at 54% → Moderate
# Router RouterC at 16% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6510 sec:
# Router RouterA at 9% → Underloaded
# Router RouterB at 68% → Moderate
# Router RouterC at 68% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6520 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 78% → Congested
# Router RouterC at 83% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6530 sec:
# Router RouterA at 61% → Moderate
# Router RouterB at 53% → Moderate
# Router RouterC at 33% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6540 sec:
# Router RouterA at 34% → Underloaded
# Router RouterB at 66% → Moderate
# Router RouterC at 90% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6550 sec:
# Router RouterA at 88% → Congested
# Router RouterB at 6% → Underloaded
# Router RouterC at 45% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6560 sec:
# Router RouterA at 35% → Underloaded
# Router RouterB at 61% → Moderate
# Router RouterC at 74% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6570 sec:
# Router RouterA at 82% → Congested
# Router RouterB at 25% → Underloaded
# Router RouterC at 35% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6580 sec:
# Router RouterA at 13% → Underloaded
# Router RouterB at 3% → Underloaded
# Router RouterC at 30% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6590 sec:
# Router RouterA at 63% → Moderate
# Router RouterB at 2% → Underloaded
# Router RouterC at 2% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6600 sec:
# Router RouterA at 91% → Congested
# Router RouterB at 16% → Underloaded
# Router RouterC at 17% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6610 sec:
# Router RouterA at 68% → Moderate
# Router RouterB at 22% → Underloaded
# Router RouterC at 90% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6620 sec:
# Router RouterA at 38% → Underloaded
# Router RouterB at 87% → Congested
# Router RouterC at 20% → Underloaded
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6630 sec:
# Router RouterA at 28% → Underloaded
# Router RouterB at 26% → Underloaded
# Router RouterC at 91% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6640 sec:
# Router RouterA at 4% → Underloaded
# Router RouterB at 18% → Underloaded
# Router RouterC at 55% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6650 sec:
# Router RouterA at 71% → Congested
# Router RouterB at 23% → Underloaded
# Router RouterC at 91% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6660 sec:
# Router RouterA at 42% → Moderate
# Router RouterB at 51% → Moderate
# Router RouterC at 96% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6670 sec:
# Router RouterA at 62% → Moderate
# Router RouterB at 54% → Moderate
# Router RouterC at 65% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6680 sec:
# Router RouterA at 76% → Congested
# Router RouterB at 50% → Moderate
# Router RouterC at 9% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6690 sec:
# Router RouterA at 15% → Underloaded
# Router RouterB at 2% → Underloaded
# Router RouterC at 61% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6700 sec:
# Router RouterA at 67% → Moderate
# Router RouterB at 80% → Congested
# Router RouterC at 91% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6710 sec:
# Router RouterA at 23% → Underloaded
# Router RouterB at 89% → Congested
# Router RouterC at 85% → Congested
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6720 sec:
# Router RouterA at 72% → Congested
# Router RouterB at 58% → Moderate
# Router RouterC at 53% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6730 sec:
# Router RouterA at 79% → Congested
# Router RouterB at 0% → Underloaded
# Router RouterC at 4% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6740 sec:
# Router RouterA at 66% → Moderate
# Router RouterB at 7% → Underloaded
# Router RouterC at 74% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6750 sec:
# Router RouterA at 25% → Underloaded
# Router RouterB at 90% → Congested
# Router RouterC at 62% → Moderate
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6760 sec:
# Router RouterA at 69% → Moderate
# Router RouterB at 13% → Underloaded
# Router RouterC at 7% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6770 sec:
# Router RouterA at 49% → Moderate
# Router RouterB at 66% → Moderate
# Router RouterC at 18% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6780 sec:
# Router RouterA at 58% → Moderate
# Router RouterB at 36% → Underloaded
# Router RouterC at 33% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6790 sec:
# Router RouterA at 43% → Moderate
# Router RouterB at 24% → Underloaded
# Router RouterC at 65% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6800 sec:
# Router RouterA at 26% → Underloaded
# Router RouterB at 51% → Moderate
# Router RouterC at 27% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6810 sec:
# Router RouterA at 12% → Underloaded
# Router RouterB at 55% → Moderate
# Router RouterC at 100% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6820 sec:
# Router RouterA at 82% → Congested
# Router RouterB at 69% → Moderate
# Router RouterC at 3% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6830 sec:
# Router RouterA at 56% → Moderate
# Router RouterB at 42% → Moderate
# Router RouterC at 28% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6840 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 66% → Moderate
# Router RouterC at 43% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6850 sec:
# Router RouterA at 89% → Congested
# Router RouterB at 72% → Congested
# Router RouterC at 59% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6860 sec:
# Router RouterA at 78% → Congested
# Router RouterB at 13% → Underloaded
# Router RouterC at 16% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6870 sec:
# Router RouterA at 21% → Underloaded
# Router RouterB at 43% → Moderate
# Router RouterC at 95% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6880 sec:
# Router RouterA at 42% → Moderate
# Router RouterB at 6% → Underloaded
# Router RouterC at 13% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6890 sec:
# Router RouterA at 41% → Moderate
# Router RouterB at 68% → Moderate
# Router RouterC at 57% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6900 sec:
# Router RouterA at 19% → Underloaded
# Router RouterB at 17% → Underloaded
# Router RouterC at 59% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6910 sec:
# Router RouterA at 95% → Congested
# Router RouterB at 49% → Moderate
# Router RouterC at 57% → Moderate
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6920 sec:
# Router RouterA at 49% → Moderate
# Router RouterB at 34% → Underloaded
# Router RouterC at 86% → Congested
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6930 sec:
# Router RouterA at 84% → Congested
# Router RouterB at 92% → Congested
# Router RouterC at 71% → Congested
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
# QoS adjustment (Policing): RouterC–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6940 sec:
# Router RouterA at 99% → Congested
# Router RouterB at 19% → Underloaded
# Router RouterC at 24% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
#
# ⏱️ Time step 6950 sec:
# Router RouterA at 70% → Moderate
# Router RouterB at 13% → Underloaded
# Router RouterC at 52% → Moderate
# No policing applied this step.
#
# ⏱️ Time step 6960 sec:
# Router RouterA at 37% → Underloaded
# Router RouterB at 6% → Underloaded
# Router RouterC at 17% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6970 sec:
# Router RouterA at 38% → Underloaded
# Router RouterB at 22% → Underloaded
# Router RouterC at 38% → Underloaded
# No policing applied this step.
#
# ⏱️ Time step 6980 sec:
# Router RouterA at 88% → Congested
# Router RouterB at 93% → Congested
# Router RouterC at 29% → Underloaded
# QoS adjustment (Policing): RouterA–Server (old=180.0 → new=216.0)
# QoS adjustment (Policing): RouterB–Server (old=120.0 → new=144.0)
#
# ⏱️ Time step 6990 sec:
# Router RouterA at 64% → Moderate
# Router RouterB at 32% → Underloaded
# Router RouterC at 8% → Underloaded
# No policing applied this step.

# %%
#ACTIVE QUEUE MANAGEMENT
import pandas as pd

def run_aqm(
    congestion_file,
    high_thresh=80,
    moderate_thresh=50,
    timestep=10,
):
    """
    Apply Active Queue Management (AQM) across all timesteps.
    Simulates early packet drop/marking depending on router load.
    """

    # Load congestion data
    df_cong = pd.read_csv(congestion_file)

    # Add Time column if missing
    if "Time" not in df_cong.columns:
        df_cong.insert(0, "Time", [i * timestep for i in range(len(df_cong))])

    expected_cols = {"RouterA", "RouterB", "RouterC"}
    if not expected_cols.issubset(set(df_cong.columns)):
        raise ValueError(f"Congestion CSV must contain {expected_cols}, found {df_cong.columns}")

    # Iterate over timesteps
    for _, row in df_cong.iterrows():
        time_label = row["Time"]
        routers = {col: float(row[col]) for col in df_cong.columns if col.startswith("Router")}

        print(f"\n⏱️ Time step {time_label} sec:")

        for r, load in routers.items():
            if load >= high_thresh:
                action = f"AQM: Router {r} → Heavy congestion ({load:.0f}%). Aggressive early drop applied."
            elif load >= moderate_thresh:
                action = f"AQM: Router {r} → Moderate load ({load:.0f}%). Random early drop/mark applied."
            else:
                action = f"AQM: Router {r} → Low load ({load:.0f}%). No drops."

            print(action)
run_aqm("C:/Users/ASUS/Downloads/router_congestion_int.csv")
# Out:
# ⏱️ Time step 0 sec:
# AQM: Router RouterA → Low load (1%). No drops.
# AQM: Router RouterB → Low load (29%). No drops.
# AQM: Router RouterC → Low load (30%). No drops.
#
# ⏱️ Time step 10 sec:
# AQM: Router RouterA → Low load (3%). No drops.
# AQM: Router RouterB → Low load (27%). No drops.
# AQM: Router RouterC → Moderate load (68%). Random early drop/mark applied.
#
# ⏱️ Time step 20 sec:
# AQM: Router RouterA → Low load (35%). No drops.
# AQM: Router RouterB → Low load (38%). No drops.
# AQM: Router RouterC → Heavy congestion (90%). Aggressive early drop applied.
#
# ⏱️ Time step 30 sec:
# AQM: Router RouterA → Heavy congestion (97%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (66%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (3%). No drops.
#
# ⏱️ Time step 40 sec:
# AQM: Router RouterA → Low load (45%). No drops.
# AQM: Router RouterB → Heavy congestion (94%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (9%). No drops.
#
# ⏱️ Time step 50 sec:
# AQM: Router RouterA → Low load (2%). No drops.
# AQM: Router RouterB → Low load (16%). No drops.
# AQM: Router RouterC → Low load (31%). No drops.
#
# ⏱️ Time step 60 sec:
# AQM: Router RouterA → Low load (36%). No drops.
# AQM: Router RouterB → Low load (9%). No drops.
# AQM: Router RouterC → Moderate load (62%). Random early drop/mark applied.
#
# ⏱️ Time step 70 sec:
# AQM: Router RouterA → Low load (23%). No drops.
# AQM: Router RouterB → Low load (34%). No drops.
# AQM: Router RouterC → Low load (29%). No drops.
#
# ⏱️ Time step 80 sec:
# AQM: Router RouterA → Low load (22%). No drops.
# AQM: Router RouterB → Heavy congestion (95%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (83%). Aggressive early drop applied.
#
# ⏱️ Time step 90 sec:
# AQM: Router RouterA → Moderate load (56%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (92%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (13%). No drops.
#
# ⏱️ Time step 100 sec:
# AQM: Router RouterA → Heavy congestion (99%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (1%). No drops.
# AQM: Router RouterC → Low load (30%). No drops.
#
# ⏱️ Time step 110 sec:
# AQM: Router RouterA → Moderate load (71%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (28%). No drops.
# AQM: Router RouterC → Moderate load (73%). Random early drop/mark applied.
#
# ⏱️ Time step 120 sec:
# AQM: Router RouterA → Low load (30%). No drops.
# AQM: Router RouterB → Low load (26%). No drops.
# AQM: Router RouterC → Low load (32%). No drops.
#
# ⏱️ Time step 130 sec:
# AQM: Router RouterA → Heavy congestion (96%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (65%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (65%). Random early drop/mark applied.
#
# ⏱️ Time step 140 sec:
# AQM: Router RouterA → Low load (21%). No drops.
# AQM: Router RouterB → Low load (38%). No drops.
# AQM: Router RouterC → Low load (35%). No drops.
#
# ⏱️ Time step 150 sec:
# AQM: Router RouterA → Moderate load (56%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (51%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (30%). No drops.
#
# ⏱️ Time step 160 sec:
# AQM: Router RouterA → Heavy congestion (93%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (12%). No drops.
# AQM: Router RouterC → Low load (11%). No drops.
#
# ⏱️ Time step 170 sec:
# AQM: Router RouterA → Low load (10%). No drops.
# AQM: Router RouterB → Heavy congestion (85%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (53%). Random early drop/mark applied.
#
# ⏱️ Time step 180 sec:
# AQM: Router RouterA → Heavy congestion (98%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (43%). No drops.
# AQM: Router RouterC → Low load (46%). No drops.
#
# ⏱️ Time step 190 sec:
# AQM: Router RouterA → Heavy congestion (84%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (8%). No drops.
# AQM: Router RouterC → Heavy congestion (97%). Aggressive early drop applied.
#
# ⏱️ Time step 200 sec:
# AQM: Router RouterA → Low load (2%). No drops.
# AQM: Router RouterB → Low load (39%). No drops.
# AQM: Router RouterC → Low load (0%). No drops.
#
# ⏱️ Time step 210 sec:
# AQM: Router RouterA → Low load (48%). No drops.
# AQM: Router RouterB → Low load (11%). No drops.
# AQM: Router RouterC → Low load (31%). No drops.
#
# ⏱️ Time step 220 sec:
# AQM: Router RouterA → Moderate load (67%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (71%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (30%). No drops.
#
# ⏱️ Time step 230 sec:
# AQM: Router RouterA → Low load (19%). No drops.
# AQM: Router RouterB → Moderate load (58%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (97%). Aggressive early drop applied.
#
# ⏱️ Time step 240 sec:
# AQM: Router RouterA → Heavy congestion (85%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (77%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (52%). Random early drop/mark applied.
#
# ⏱️ Time step 250 sec:
# AQM: Router RouterA → Heavy congestion (97%). Aggressive early drop applied.
# AQM: Router RouterB → Heavy congestion (90%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (88%). Aggressive early drop applied.
#
# ⏱️ Time step 260 sec:
# AQM: Router RouterA → Moderate load (71%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (91%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (10%). No drops.
#
# ⏱️ Time step 270 sec:
# AQM: Router RouterA → Moderate load (61%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (79%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (92%). Aggressive early drop applied.
#
# ⏱️ Time step 280 sec:
# AQM: Router RouterA → Moderate load (75%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (15%). No drops.
# AQM: Router RouterC → Low load (41%). No drops.
#
# ⏱️ Time step 290 sec:
# AQM: Router RouterA → Low load (45%). No drops.
# AQM: Router RouterB → Low load (28%). No drops.
# AQM: Router RouterC → Heavy congestion (98%). Aggressive early drop applied.
#
# ⏱️ Time step 300 sec:
# AQM: Router RouterA → Low load (45%). No drops.
# AQM: Router RouterB → Moderate load (68%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (66%). Random early drop/mark applied.
#
# ⏱️ Time step 310 sec:
# AQM: Router RouterA → Moderate load (67%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (96%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (79%). Random early drop/mark applied.
#
# ⏱️ Time step 320 sec:
# AQM: Router RouterA → Moderate load (62%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (35%). No drops.
# AQM: Router RouterC → Low load (14%). No drops.
#
# ⏱️ Time step 330 sec:
# AQM: Router RouterA → Low load (34%). No drops.
# AQM: Router RouterB → Low load (10%). No drops.
# AQM: Router RouterC → Moderate load (70%). Random early drop/mark applied.
#
# ⏱️ Time step 340 sec:
# AQM: Router RouterA → Low load (36%). No drops.
# AQM: Router RouterB → Moderate load (58%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (77%). Random early drop/mark applied.
#
# ⏱️ Time step 350 sec:
# AQM: Router RouterA → Low load (45%). No drops.
# AQM: Router RouterB → Moderate load (53%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (78%). Random early drop/mark applied.
#
# ⏱️ Time step 360 sec:
# AQM: Router RouterA → Low load (46%). No drops.
# AQM: Router RouterB → Low load (46%). No drops.
# AQM: Router RouterC → Low load (20%). No drops.
#
# ⏱️ Time step 370 sec:
# AQM: Router RouterA → Low load (26%). No drops.
# AQM: Router RouterB → Low load (40%). No drops.
# AQM: Router RouterC → Moderate load (73%). Random early drop/mark applied.
#
# ⏱️ Time step 380 sec:
# AQM: Router RouterA → Heavy congestion (87%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (60%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (95%). Aggressive early drop applied.
#
# ⏱️ Time step 390 sec:
# AQM: Router RouterA → Heavy congestion (94%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (72%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (7%). No drops.
#
# ⏱️ Time step 400 sec:
# AQM: Router RouterA → Low load (1%). No drops.
# AQM: Router RouterB → Low load (5%). No drops.
# AQM: Router RouterC → Low load (33%). No drops.
#
# ⏱️ Time step 410 sec:
# AQM: Router RouterA → Low load (46%). No drops.
# AQM: Router RouterB → Moderate load (66%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (40%). No drops.
#
# ⏱️ Time step 420 sec:
# AQM: Router RouterA → Moderate load (77%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (98%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (11%). No drops.
#
# ⏱️ Time step 430 sec:
# AQM: Router RouterA → Low load (4%). No drops.
# AQM: Router RouterB → Heavy congestion (99%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (100%). Aggressive early drop applied.
#
# ⏱️ Time step 440 sec:
# AQM: Router RouterA → Low load (31%). No drops.
# AQM: Router RouterB → Moderate load (76%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (77%). Random early drop/mark applied.
#
# ⏱️ Time step 450 sec:
# AQM: Router RouterA → Low load (18%). No drops.
# AQM: Router RouterB → Heavy congestion (98%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (73%). Random early drop/mark applied.
#
# ⏱️ Time step 460 sec:
# AQM: Router RouterA → Low load (9%). No drops.
# AQM: Router RouterB → Moderate load (55%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (38%). No drops.
#
# ⏱️ Time step 470 sec:
# AQM: Router RouterA → Low load (10%). No drops.
# AQM: Router RouterB → Low load (17%). No drops.
# AQM: Router RouterC → Moderate load (60%). Random early drop/mark applied.
#
# ⏱️ Time step 480 sec:
# AQM: Router RouterA → Low load (0%). No drops.
# AQM: Router RouterB → Low load (16%). No drops.
# AQM: Router RouterC → Heavy congestion (89%). Aggressive early drop applied.
#
# ⏱️ Time step 490 sec:
# AQM: Router RouterA → Moderate load (73%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (54%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (18%). No drops.
#
# ⏱️ Time step 500 sec:
# AQM: Router RouterA → Low load (28%). No drops.
# AQM: Router RouterB → Low load (13%). No drops.
# AQM: Router RouterC → Moderate load (66%). Random early drop/mark applied.
#
# ⏱️ Time step 510 sec:
# AQM: Router RouterA → Low load (48%). No drops.
# AQM: Router RouterB → Low load (19%). No drops.
# AQM: Router RouterC → Low load (43%). No drops.
#
# ⏱️ Time step 520 sec:
# AQM: Router RouterA → Low load (36%). No drops.
# AQM: Router RouterB → Moderate load (66%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (93%). Aggressive early drop applied.
#
# ⏱️ Time step 530 sec:
# AQM: Router RouterA → Low load (3%). No drops.
# AQM: Router RouterB → Moderate load (59%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (62%). Random early drop/mark applied.
#
# ⏱️ Time step 540 sec:
# AQM: Router RouterA → Low load (39%). No drops.
# AQM: Router RouterB → Low load (17%). No drops.
# AQM: Router RouterC → Low load (18%). No drops.
#
# ⏱️ Time step 550 sec:
# AQM: Router RouterA → Moderate load (67%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (4%). No drops.
# AQM: Router RouterC → Moderate load (69%). Random early drop/mark applied.
#
# ⏱️ Time step 560 sec:
# AQM: Router RouterA → Low load (0%). No drops.
# AQM: Router RouterB → Heavy congestion (98%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (94%). Aggressive early drop applied.
#
# ⏱️ Time step 570 sec:
# AQM: Router RouterA → Low load (26%). No drops.
# AQM: Router RouterB → Low load (12%). No drops.
# AQM: Router RouterC → Low load (6%). No drops.
#
# ⏱️ Time step 580 sec:
# AQM: Router RouterA → Moderate load (66%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (94%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (38%). No drops.
#
# ⏱️ Time step 590 sec:
# AQM: Router RouterA → Moderate load (62%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (15%). No drops.
# AQM: Router RouterC → Low load (19%). No drops.
#
# ⏱️ Time step 600 sec:
# AQM: Router RouterA → Heavy congestion (82%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (72%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (43%). No drops.
#
# ⏱️ Time step 610 sec:
# AQM: Router RouterA → Low load (43%). No drops.
# AQM: Router RouterB → Heavy congestion (88%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (59%). Random early drop/mark applied.
#
# ⏱️ Time step 620 sec:
# AQM: Router RouterA → Low load (7%). No drops.
# AQM: Router RouterB → Heavy congestion (96%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (38%). No drops.
#
# ⏱️ Time step 630 sec:
# AQM: Router RouterA → Low load (3%). No drops.
# AQM: Router RouterB → Low load (43%). No drops.
# AQM: Router RouterC → Low load (38%). No drops.
#
# ⏱️ Time step 640 sec:
# AQM: Router RouterA → Moderate load (74%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (98%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (26%). No drops.
#
# ⏱️ Time step 650 sec:
# AQM: Router RouterA → Heavy congestion (83%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (6%). No drops.
# AQM: Router RouterC → Moderate load (70%). Random early drop/mark applied.
#
# ⏱️ Time step 660 sec:
# AQM: Router RouterA → Low load (13%). No drops.
# AQM: Router RouterB → Moderate load (59%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (77%). Random early drop/mark applied.
#
# ⏱️ Time step 670 sec:
# AQM: Router RouterA → Low load (6%). No drops.
# AQM: Router RouterB → Low load (18%). No drops.
# AQM: Router RouterC → Low load (4%). No drops.
#
# ⏱️ Time step 680 sec:
# AQM: Router RouterA → Low load (44%). No drops.
# AQM: Router RouterB → Heavy congestion (93%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (63%). Random early drop/mark applied.
#
# ⏱️ Time step 690 sec:
# AQM: Router RouterA → Low load (3%). No drops.
# AQM: Router RouterB → Moderate load (76%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (64%). Random early drop/mark applied.
#
# ⏱️ Time step 700 sec:
# AQM: Router RouterA → Low load (49%). No drops.
# AQM: Router RouterB → Low load (7%). No drops.
# AQM: Router RouterC → Moderate load (78%). Random early drop/mark applied.
#
# ⏱️ Time step 710 sec:
# AQM: Router RouterA → Low load (48%). No drops.
# AQM: Router RouterB → Heavy congestion (100%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (25%). No drops.
#
# ⏱️ Time step 720 sec:
# AQM: Router RouterA → Low load (38%). No drops.
# AQM: Router RouterB → Low load (38%). No drops.
# AQM: Router RouterC → Moderate load (65%). Random early drop/mark applied.
#
# ⏱️ Time step 730 sec:
# AQM: Router RouterA → Low load (46%). No drops.
# AQM: Router RouterB → Moderate load (70%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (85%). Aggressive early drop applied.
#
# ⏱️ Time step 740 sec:
# AQM: Router RouterA → Low load (3%). No drops.
# AQM: Router RouterB → Low load (43%). No drops.
# AQM: Router RouterC → Heavy congestion (88%). Aggressive early drop applied.
#
# ⏱️ Time step 750 sec:
# AQM: Router RouterA → Low load (2%). No drops.
# AQM: Router RouterB → Low load (46%). No drops.
# AQM: Router RouterC → Heavy congestion (99%). Aggressive early drop applied.
#
# ⏱️ Time step 760 sec:
# AQM: Router RouterA → Moderate load (52%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (2%). No drops.
# AQM: Router RouterC → Low load (12%). No drops.
#
# ⏱️ Time step 770 sec:
# AQM: Router RouterA → Low load (32%). No drops.
# AQM: Router RouterB → Low load (14%). No drops.
# AQM: Router RouterC → Low load (14%). No drops.
#
# ⏱️ Time step 780 sec:
# AQM: Router RouterA → Moderate load (74%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (27%). No drops.
# AQM: Router RouterC → Heavy congestion (82%). Aggressive early drop applied.
#
# ⏱️ Time step 790 sec:
# AQM: Router RouterA → Low load (25%). No drops.
# AQM: Router RouterB → Heavy congestion (97%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (83%). Aggressive early drop applied.
#
# ⏱️ Time step 800 sec:
# AQM: Router RouterA → Heavy congestion (91%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (73%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (88%). Aggressive early drop applied.
#
# ⏱️ Time step 810 sec:
# AQM: Router RouterA → Low load (14%). No drops.
# AQM: Router RouterB → Low load (24%). No drops.
# AQM: Router RouterC → Low load (46%). No drops.
#
# ⏱️ Time step 820 sec:
# AQM: Router RouterA → Moderate load (72%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (92%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (7%). No drops.
#
# ⏱️ Time step 830 sec:
# AQM: Router RouterA → Low load (21%). No drops.
# AQM: Router RouterB → Low load (15%). No drops.
# AQM: Router RouterC → Low load (4%). No drops.
#
# ⏱️ Time step 840 sec:
# AQM: Router RouterA → Moderate load (52%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (6%). No drops.
# AQM: Router RouterC → Heavy congestion (98%). Aggressive early drop applied.
#
# ⏱️ Time step 850 sec:
# AQM: Router RouterA → Heavy congestion (95%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (34%). No drops.
# AQM: Router RouterC → Moderate load (79%). Random early drop/mark applied.
#
# ⏱️ Time step 860 sec:
# AQM: Router RouterA → Moderate load (65%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (48%). No drops.
# AQM: Router RouterC → Low load (30%). No drops.
#
# ⏱️ Time step 870 sec:
# AQM: Router RouterA → Low load (7%). No drops.
# AQM: Router RouterB → Moderate load (50%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (50%). Random early drop/mark applied.
#
# ⏱️ Time step 880 sec:
# AQM: Router RouterA → Moderate load (75%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (11%). No drops.
# AQM: Router RouterC → Moderate load (76%). Random early drop/mark applied.
#
# ⏱️ Time step 890 sec:
# AQM: Router RouterA → Moderate load (76%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (38%). No drops.
# AQM: Router RouterC → Moderate load (75%). Random early drop/mark applied.
#
# ⏱️ Time step 900 sec:
# AQM: Router RouterA → Low load (42%). No drops.
# AQM: Router RouterB → Low load (22%). No drops.
# AQM: Router RouterC → Heavy congestion (96%). Aggressive early drop applied.
#
# ⏱️ Time step 910 sec:
# AQM: Router RouterA → Low load (48%). No drops.
# AQM: Router RouterB → Low load (34%). No drops.
# AQM: Router RouterC → Moderate load (66%). Random early drop/mark applied.
#
# ⏱️ Time step 920 sec:
# AQM: Router RouterA → Low load (22%). No drops.
# AQM: Router RouterB → Moderate load (78%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (77%). Random early drop/mark applied.
#
# ⏱️ Time step 930 sec:
# AQM: Router RouterA → Low load (14%). No drops.
# AQM: Router RouterB → Heavy congestion (97%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (98%). Aggressive early drop applied.
#
# ⏱️ Time step 940 sec:
# AQM: Router RouterA → Low load (3%). No drops.
# AQM: Router RouterB → Low load (47%). No drops.
# AQM: Router RouterC → Low load (31%). No drops.
#
# ⏱️ Time step 950 sec:
# AQM: Router RouterA → Heavy congestion (84%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (1%). No drops.
# AQM: Router RouterC → Low load (34%). No drops.
#
# ⏱️ Time step 960 sec:
# AQM: Router RouterA → Heavy congestion (95%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (27%). No drops.
# AQM: Router RouterC → Low load (28%). No drops.
#
# ⏱️ Time step 970 sec:
# AQM: Router RouterA → Low load (0%). No drops.
# AQM: Router RouterB → Low load (44%). No drops.
# AQM: Router RouterC → Heavy congestion (81%). Aggressive early drop applied.
#
# ⏱️ Time step 980 sec:
# AQM: Router RouterA → Low load (44%). No drops.
# AQM: Router RouterB → Heavy congestion (87%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (14%). No drops.
#
# ⏱️ Time step 990 sec:
# AQM: Router RouterA → Moderate load (60%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (1%). No drops.
# AQM: Router RouterC → Heavy congestion (89%). Aggressive early drop applied.
#
# ⏱️ Time step 1000 sec:
# AQM: Router RouterA → Low load (43%). No drops.
# AQM: Router RouterB → Low load (43%). No drops.
# AQM: Router RouterC → Heavy congestion (80%). Aggressive early drop applied.
#
# ⏱️ Time step 1010 sec:
# AQM: Router RouterA → Low load (13%). No drops.
# AQM: Router RouterB → Low load (18%). No drops.
# AQM: Router RouterC → Heavy congestion (88%). Aggressive early drop applied.
#
# ⏱️ Time step 1020 sec:
# AQM: Router RouterA → Low load (18%). No drops.
# AQM: Router RouterB → Low load (44%). No drops.
# AQM: Router RouterC → Heavy congestion (82%). Aggressive early drop applied.
#
# ⏱️ Time step 1030 sec:
# AQM: Router RouterA → Low load (25%). No drops.
# AQM: Router RouterB → Heavy congestion (92%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (84%). Aggressive early drop applied.
#
# ⏱️ Time step 1040 sec:
# AQM: Router RouterA → Moderate load (50%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (74%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (71%). Random early drop/mark applied.
#
# ⏱️ Time step 1050 sec:
# AQM: Router RouterA → Low load (41%). No drops.
# AQM: Router RouterB → Low load (32%). No drops.
# AQM: Router RouterC → Low load (13%). No drops.
#
# ⏱️ Time step 1060 sec:
# AQM: Router RouterA → Moderate load (70%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (16%). No drops.
# AQM: Router RouterC → Low load (47%). No drops.
#
# ⏱️ Time step 1070 sec:
# AQM: Router RouterA → Low load (10%). No drops.
# AQM: Router RouterB → Low load (21%). No drops.
# AQM: Router RouterC → Low load (31%). No drops.
#
# ⏱️ Time step 1080 sec:
# AQM: Router RouterA → Low load (14%). No drops.
# AQM: Router RouterB → Low load (45%). No drops.
# AQM: Router RouterC → Moderate load (72%). Random early drop/mark applied.
#
# ⏱️ Time step 1090 sec:
# AQM: Router RouterA → Moderate load (50%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (96%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (40%). No drops.
#
# ⏱️ Time step 1100 sec:
# AQM: Router RouterA → Low load (23%). No drops.
# AQM: Router RouterB → Moderate load (77%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (54%). Random early drop/mark applied.
#
# ⏱️ Time step 1110 sec:
# AQM: Router RouterA → Low load (14%). No drops.
# AQM: Router RouterB → Low load (40%). No drops.
# AQM: Router RouterC → Low load (25%). No drops.
#
# ⏱️ Time step 1120 sec:
# AQM: Router RouterA → Moderate load (76%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (46%). No drops.
# AQM: Router RouterC → Low load (0%). No drops.
#
# ⏱️ Time step 1130 sec:
# AQM: Router RouterA → Low load (28%). No drops.
# AQM: Router RouterB → Low load (40%). No drops.
# AQM: Router RouterC → Moderate load (60%). Random early drop/mark applied.
#
# ⏱️ Time step 1140 sec:
# AQM: Router RouterA → Low load (12%). No drops.
# AQM: Router RouterB → Low load (44%). No drops.
# AQM: Router RouterC → Moderate load (71%). Random early drop/mark applied.
#
# ⏱️ Time step 1150 sec:
# AQM: Router RouterA → Moderate load (68%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (61%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (91%). Aggressive early drop applied.
#
# ⏱️ Time step 1160 sec:
# AQM: Router RouterA → Heavy congestion (98%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (65%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (94%). Aggressive early drop applied.
#
# ⏱️ Time step 1170 sec:
# AQM: Router RouterA → Moderate load (63%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (92%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (70%). Random early drop/mark applied.
#
# ⏱️ Time step 1180 sec:
# AQM: Router RouterA → Low load (35%). No drops.
# AQM: Router RouterB → Moderate load (65%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (37%). No drops.
#
# ⏱️ Time step 1190 sec:
# AQM: Router RouterA → Moderate load (73%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (25%). No drops.
# AQM: Router RouterC → Low load (43%). No drops.
#
# ⏱️ Time step 1200 sec:
# AQM: Router RouterA → Moderate load (76%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (9%). No drops.
# AQM: Router RouterC → Moderate load (57%). Random early drop/mark applied.
#
# ⏱️ Time step 1210 sec:
# AQM: Router RouterA → Moderate load (74%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (7%). No drops.
# AQM: Router RouterC → Moderate load (60%). Random early drop/mark applied.
#
# ⏱️ Time step 1220 sec:
# AQM: Router RouterA → Low load (40%). No drops.
# AQM: Router RouterB → Moderate load (54%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (22%). No drops.
#
# ⏱️ Time step 1230 sec:
# AQM: Router RouterA → Moderate load (59%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (98%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (70%). Random early drop/mark applied.
#
# ⏱️ Time step 1240 sec:
# AQM: Router RouterA → Low load (18%). No drops.
# AQM: Router RouterB → Moderate load (69%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (25%). No drops.
#
# ⏱️ Time step 1250 sec:
# AQM: Router RouterA → Low load (36%). No drops.
# AQM: Router RouterB → Low load (5%). No drops.
# AQM: Router RouterC → Moderate load (50%). Random early drop/mark applied.
#
# ⏱️ Time step 1260 sec:
# AQM: Router RouterA → Moderate load (68%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (48%). No drops.
# AQM: Router RouterC → Low load (44%). No drops.
#
# ⏱️ Time step 1270 sec:
# AQM: Router RouterA → Moderate load (70%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (64%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (6%). No drops.
#
# ⏱️ Time step 1280 sec:
# AQM: Router RouterA → Low load (38%). No drops.
# AQM: Router RouterB → Heavy congestion (91%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (94%). Aggressive early drop applied.
#
# ⏱️ Time step 1290 sec:
# AQM: Router RouterA → Heavy congestion (99%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (48%). No drops.
# AQM: Router RouterC → Low load (48%). No drops.
#
# ⏱️ Time step 1300 sec:
# AQM: Router RouterA → Low load (0%). No drops.
# AQM: Router RouterB → Low load (40%). No drops.
# AQM: Router RouterC → Low load (40%). No drops.
#
# ⏱️ Time step 1310 sec:
# AQM: Router RouterA → Low load (28%). No drops.
# AQM: Router RouterB → Low load (18%). No drops.
# AQM: Router RouterC → Moderate load (74%). Random early drop/mark applied.
#
# ⏱️ Time step 1320 sec:
# AQM: Router RouterA → Heavy congestion (89%). Aggressive early drop applied.
# AQM: Router RouterB → Heavy congestion (96%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (24%). No drops.
#
# ⏱️ Time step 1330 sec:
# AQM: Router RouterA → Heavy congestion (89%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (29%). No drops.
# AQM: Router RouterC → Low load (28%). No drops.
#
# ⏱️ Time step 1340 sec:
# AQM: Router RouterA → Low load (40%). No drops.
# AQM: Router RouterB → Low load (0%). No drops.
# AQM: Router RouterC → Low load (5%). No drops.
#
# ⏱️ Time step 1350 sec:
# AQM: Router RouterA → Moderate load (74%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (7%). No drops.
# AQM: Router RouterC → Moderate load (64%). Random early drop/mark applied.
#
# ⏱️ Time step 1360 sec:
# AQM: Router RouterA → Moderate load (68%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (63%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (45%). No drops.
#
# ⏱️ Time step 1370 sec:
# AQM: Router RouterA → Heavy congestion (95%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (26%). No drops.
# AQM: Router RouterC → Low load (21%). No drops.
#
# ⏱️ Time step 1380 sec:
# AQM: Router RouterA → Heavy congestion (81%). Aggressive early drop applied.
# AQM: Router RouterB → Heavy congestion (91%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (39%). No drops.
#
# ⏱️ Time step 1390 sec:
# AQM: Router RouterA → Heavy congestion (99%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (20%). No drops.
# AQM: Router RouterC → Heavy congestion (92%). Aggressive early drop applied.
#
# ⏱️ Time step 1400 sec:
# AQM: Router RouterA → Low load (42%). No drops.
# AQM: Router RouterB → Moderate load (72%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (8%). No drops.
#
# ⏱️ Time step 1410 sec:
# AQM: Router RouterA → Low load (16%). No drops.
# AQM: Router RouterB → Low load (20%). No drops.
# AQM: Router RouterC → Heavy congestion (93%). Aggressive early drop applied.
#
# ⏱️ Time step 1420 sec:
# AQM: Router RouterA → Moderate load (78%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (82%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (91%). Aggressive early drop applied.
#
# ⏱️ Time step 1430 sec:
# AQM: Router RouterA → Heavy congestion (89%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (30%). No drops.
# AQM: Router RouterC → Low load (29%). No drops.
#
# ⏱️ Time step 1440 sec:
# AQM: Router RouterA → Moderate load (73%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (84%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (88%). Aggressive early drop applied.
#
# ⏱️ Time step 1450 sec:
# AQM: Router RouterA → Low load (20%). No drops.
# AQM: Router RouterB → Low load (33%). No drops.
# AQM: Router RouterC → Moderate load (71%). Random early drop/mark applied.
#
# ⏱️ Time step 1460 sec:
# AQM: Router RouterA → Heavy congestion (82%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (43%). No drops.
# AQM: Router RouterC → Moderate load (77%). Random early drop/mark applied.
#
# ⏱️ Time step 1470 sec:
# AQM: Router RouterA → Low load (9%). No drops.
# AQM: Router RouterB → Low load (7%). No drops.
# AQM: Router RouterC → Low load (29%). No drops.
#
# ⏱️ Time step 1480 sec:
# AQM: Router RouterA → Moderate load (74%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (44%). No drops.
# AQM: Router RouterC → Low load (14%). No drops.
#
# ⏱️ Time step 1490 sec:
# AQM: Router RouterA → Moderate load (79%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (39%). No drops.
# AQM: Router RouterC → Low load (43%). No drops.
#
# ⏱️ Time step 1500 sec:
# AQM: Router RouterA → Moderate load (60%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (75%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (18%). No drops.
#
# ⏱️ Time step 1510 sec:
# AQM: Router RouterA → Heavy congestion (92%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (30%). No drops.
# AQM: Router RouterC → Moderate load (62%). Random early drop/mark applied.
#
# ⏱️ Time step 1520 sec:
# AQM: Router RouterA → Moderate load (57%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (49%). No drops.
# AQM: Router RouterC → Heavy congestion (87%). Aggressive early drop applied.
#
# ⏱️ Time step 1530 sec:
# AQM: Router RouterA → Moderate load (61%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (3%). No drops.
# AQM: Router RouterC → Low load (7%). No drops.
#
# ⏱️ Time step 1540 sec:
# AQM: Router RouterA → Low load (1%). No drops.
# AQM: Router RouterB → Moderate load (77%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (25%). No drops.
#
# ⏱️ Time step 1550 sec:
# AQM: Router RouterA → Heavy congestion (99%). Aggressive early drop applied.
# AQM: Router RouterB → Heavy congestion (90%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (99%). Aggressive early drop applied.
#
# ⏱️ Time step 1560 sec:
# AQM: Router RouterA → Moderate load (57%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (98%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (80%). Aggressive early drop applied.
#
# ⏱️ Time step 1570 sec:
# AQM: Router RouterA → Heavy congestion (93%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (17%). No drops.
# AQM: Router RouterC → Low load (16%). No drops.
#
# ⏱️ Time step 1580 sec:
# AQM: Router RouterA → Heavy congestion (85%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (41%). No drops.
# AQM: Router RouterC → Low load (6%). No drops.
#
# ⏱️ Time step 1590 sec:
# AQM: Router RouterA → Heavy congestion (83%). Aggressive early drop applied.
# AQM: Router RouterB → Heavy congestion (96%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (68%). Random early drop/mark applied.
#
# ⏱️ Time step 1600 sec:
# AQM: Router RouterA → Low load (41%). No drops.
# AQM: Router RouterB → Low load (48%). No drops.
# AQM: Router RouterC → Heavy congestion (87%). Aggressive early drop applied.
#
# ⏱️ Time step 1610 sec:
# AQM: Router RouterA → Heavy congestion (81%). Aggressive early drop applied.
# AQM: Router RouterB → Heavy congestion (96%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (19%). No drops.
#
# ⏱️ Time step 1620 sec:
# AQM: Router RouterA → Moderate load (52%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (47%). No drops.
# AQM: Router RouterC → Moderate load (58%). Random early drop/mark applied.
#
# ⏱️ Time step 1630 sec:
# AQM: Router RouterA → Low load (47%). No drops.
# AQM: Router RouterB → Low load (7%). No drops.
# AQM: Router RouterC → Low load (39%). No drops.
#
# ⏱️ Time step 1640 sec:
# AQM: Router RouterA → Low load (31%). No drops.
# AQM: Router RouterB → Low load (38%). No drops.
# AQM: Router RouterC → Low load (2%). No drops.
#
# ⏱️ Time step 1650 sec:
# AQM: Router RouterA → Moderate load (51%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (24%). No drops.
# AQM: Router RouterC → Heavy congestion (85%). Aggressive early drop applied.
#
# ⏱️ Time step 1660 sec:
# AQM: Router RouterA → Low load (34%). No drops.
# AQM: Router RouterB → Low load (14%). No drops.
# AQM: Router RouterC → Low load (27%). No drops.
#
# ⏱️ Time step 1670 sec:
# AQM: Router RouterA → Moderate load (64%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (45%). No drops.
# AQM: Router RouterC → Heavy congestion (94%). Aggressive early drop applied.
#
# ⏱️ Time step 1680 sec:
# AQM: Router RouterA → Low load (37%). No drops.
# AQM: Router RouterB → Low load (4%). No drops.
# AQM: Router RouterC → Heavy congestion (86%). Aggressive early drop applied.
#
# ⏱️ Time step 1690 sec:
# AQM: Router RouterA → Low load (13%). No drops.
# AQM: Router RouterB → Low load (15%). No drops.
# AQM: Router RouterC → Low load (32%). No drops.
#
# ⏱️ Time step 1700 sec:
# AQM: Router RouterA → Low load (1%). No drops.
# AQM: Router RouterB → Heavy congestion (88%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (88%). Aggressive early drop applied.
#
# ⏱️ Time step 1710 sec:
# AQM: Router RouterA → Moderate load (78%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (31%). No drops.
# AQM: Router RouterC → Low load (22%). No drops.
#
# ⏱️ Time step 1720 sec:
# AQM: Router RouterA → Heavy congestion (87%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (14%). No drops.
# AQM: Router RouterC → Moderate load (70%). Random early drop/mark applied.
#
# ⏱️ Time step 1730 sec:
# AQM: Router RouterA → Low load (25%). No drops.
# AQM: Router RouterB → Moderate load (50%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (82%). Aggressive early drop applied.
#
# ⏱️ Time step 1740 sec:
# AQM: Router RouterA → Moderate load (73%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (52%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (46%). No drops.
#
# ⏱️ Time step 1750 sec:
# AQM: Router RouterA → Moderate load (67%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (77%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (44%). No drops.
#
# ⏱️ Time step 1760 sec:
# AQM: Router RouterA → Heavy congestion (83%). Aggressive early drop applied.
# AQM: Router RouterB → Heavy congestion (96%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (30%). No drops.
#
# ⏱️ Time step 1770 sec:
# AQM: Router RouterA → Low load (39%). No drops.
# AQM: Router RouterB → Moderate load (61%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (48%). No drops.
#
# ⏱️ Time step 1780 sec:
# AQM: Router RouterA → Low load (40%). No drops.
# AQM: Router RouterB → Low load (10%). No drops.
# AQM: Router RouterC → Heavy congestion (95%). Aggressive early drop applied.
#
# ⏱️ Time step 1790 sec:
# AQM: Router RouterA → Heavy congestion (94%). Aggressive early drop applied.
# AQM: Router RouterB → Heavy congestion (83%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (94%). Aggressive early drop applied.
#
# ⏱️ Time step 1800 sec:
# AQM: Router RouterA → Low load (24%). No drops.
# AQM: Router RouterB → Moderate load (58%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (63%). Random early drop/mark applied.
#
# ⏱️ Time step 1810 sec:
# AQM: Router RouterA → Heavy congestion (89%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (59%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (10%). No drops.
#
# ⏱️ Time step 1820 sec:
# AQM: Router RouterA → Low load (24%). No drops.
# AQM: Router RouterB → Moderate load (69%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (30%). No drops.
#
# ⏱️ Time step 1830 sec:
# AQM: Router RouterA → Moderate load (70%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (71%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (29%). No drops.
#
# ⏱️ Time step 1840 sec:
# AQM: Router RouterA → Heavy congestion (83%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (7%). No drops.
# AQM: Router RouterC → Low load (42%). No drops.
#
# ⏱️ Time step 1850 sec:
# AQM: Router RouterA → Moderate load (53%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (26%). No drops.
# AQM: Router RouterC → Low load (21%). No drops.
#
# ⏱️ Time step 1860 sec:
# AQM: Router RouterA → Heavy congestion (85%). Aggressive early drop applied.
# AQM: Router RouterB → Heavy congestion (95%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (70%). Random early drop/mark applied.
#
# ⏱️ Time step 1870 sec:
# AQM: Router RouterA → Moderate load (56%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (57%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (91%). Aggressive early drop applied.
#
# ⏱️ Time step 1880 sec:
# AQM: Router RouterA → Low load (12%). No drops.
# AQM: Router RouterB → Low load (1%). No drops.
# AQM: Router RouterC → Moderate load (53%). Random early drop/mark applied.
#
# ⏱️ Time step 1890 sec:
# AQM: Router RouterA → Low load (46%). No drops.
# AQM: Router RouterB → Moderate load (75%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (14%). No drops.
#
# ⏱️ Time step 1900 sec:
# AQM: Router RouterA → Low load (35%). No drops.
# AQM: Router RouterB → Heavy congestion (93%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (84%). Aggressive early drop applied.
#
# ⏱️ Time step 1910 sec:
# AQM: Router RouterA → Moderate load (59%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (57%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (91%). Aggressive early drop applied.
#
# ⏱️ Time step 1920 sec:
# AQM: Router RouterA → Low load (15%). No drops.
# AQM: Router RouterB → Low load (42%). No drops.
# AQM: Router RouterC → Low load (32%). No drops.
#
# ⏱️ Time step 1930 sec:
# AQM: Router RouterA → Moderate load (78%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (57%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (13%). No drops.
#
# ⏱️ Time step 1940 sec:
# AQM: Router RouterA → Low load (44%). No drops.
# AQM: Router RouterB → Moderate load (63%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (77%). Random early drop/mark applied.
#
# ⏱️ Time step 1950 sec:
# AQM: Router RouterA → Low load (28%). No drops.
# AQM: Router RouterB → Heavy congestion (92%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (75%). Random early drop/mark applied.
#
# ⏱️ Time step 1960 sec:
# AQM: Router RouterA → Moderate load (65%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (78%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (40%). No drops.
#
# ⏱️ Time step 1970 sec:
# AQM: Router RouterA → Heavy congestion (96%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (70%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (79%). Random early drop/mark applied.
#
# ⏱️ Time step 1980 sec:
# AQM: Router RouterA → Moderate load (52%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (31%). No drops.
# AQM: Router RouterC → Moderate load (71%). Random early drop/mark applied.
#
# ⏱️ Time step 1990 sec:
# AQM: Router RouterA → Low load (46%). No drops.
# AQM: Router RouterB → Low load (4%). No drops.
# AQM: Router RouterC → Low load (12%). No drops.
#
# ⏱️ Time step 2000 sec:
# AQM: Router RouterA → Low load (40%). No drops.
# AQM: Router RouterB → Moderate load (67%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (16%). No drops.
#
# ⏱️ Time step 2010 sec:
# AQM: Router RouterA → Moderate load (52%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (32%). No drops.
# AQM: Router RouterC → Moderate load (66%). Random early drop/mark applied.
#
# ⏱️ Time step 2020 sec:
# AQM: Router RouterA → Moderate load (72%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (79%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (51%). Random early drop/mark applied.
#
# ⏱️ Time step 2030 sec:
# AQM: Router RouterA → Low load (11%). No drops.
# AQM: Router RouterB → Moderate load (77%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (7%). No drops.
#
# ⏱️ Time step 2040 sec:
# AQM: Router RouterA → Low load (36%). No drops.
# AQM: Router RouterB → Low load (15%). No drops.
# AQM: Router RouterC → Moderate load (50%). Random early drop/mark applied.
#
# ⏱️ Time step 2050 sec:
# AQM: Router RouterA → Low load (46%). No drops.
# AQM: Router RouterB → Moderate load (77%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (86%). Aggressive early drop applied.
#
# ⏱️ Time step 2060 sec:
# AQM: Router RouterA → Low load (6%). No drops.
# AQM: Router RouterB → Moderate load (64%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (32%). No drops.
#
# ⏱️ Time step 2070 sec:
# AQM: Router RouterA → Low load (30%). No drops.
# AQM: Router RouterB → Heavy congestion (98%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (100%). Aggressive early drop applied.
#
# ⏱️ Time step 2080 sec:
# AQM: Router RouterA → Moderate load (74%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (28%). No drops.
# AQM: Router RouterC → Moderate load (71%). Random early drop/mark applied.
#
# ⏱️ Time step 2090 sec:
# AQM: Router RouterA → Moderate load (64%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (47%). No drops.
# AQM: Router RouterC → Heavy congestion (82%). Aggressive early drop applied.
#
# ⏱️ Time step 2100 sec:
# AQM: Router RouterA → Moderate load (56%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (97%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (36%). No drops.
#
# ⏱️ Time step 2110 sec:
# AQM: Router RouterA → Moderate load (52%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (24%). No drops.
# AQM: Router RouterC → Low load (11%). No drops.
#
# ⏱️ Time step 2120 sec:
# AQM: Router RouterA → Heavy congestion (95%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (14%). No drops.
# AQM: Router RouterC → Low load (3%). No drops.
#
# ⏱️ Time step 2130 sec:
# AQM: Router RouterA → Moderate load (56%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (100%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (70%). Random early drop/mark applied.
#
# ⏱️ Time step 2140 sec:
# AQM: Router RouterA → Low load (29%). No drops.
# AQM: Router RouterB → Heavy congestion (90%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (4%). No drops.
#
# ⏱️ Time step 2150 sec:
# AQM: Router RouterA → Low load (48%). No drops.
# AQM: Router RouterB → Low load (10%). No drops.
# AQM: Router RouterC → Low load (49%). No drops.
#
# ⏱️ Time step 2160 sec:
# AQM: Router RouterA → Low load (6%). No drops.
# AQM: Router RouterB → Low load (15%). No drops.
# AQM: Router RouterC → Low load (14%). No drops.
#
# ⏱️ Time step 2170 sec:
# AQM: Router RouterA → Low load (22%). No drops.
# AQM: Router RouterB → Moderate load (78%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (94%). Aggressive early drop applied.
#
# ⏱️ Time step 2180 sec:
# AQM: Router RouterA → Low load (19%). No drops.
# AQM: Router RouterB → Heavy congestion (92%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (96%). Aggressive early drop applied.
#
# ⏱️ Time step 2190 sec:
# AQM: Router RouterA → Moderate load (69%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (31%). No drops.
# AQM: Router RouterC → Moderate load (65%). Random early drop/mark applied.
#
# ⏱️ Time step 2200 sec:
# AQM: Router RouterA → Low load (34%). No drops.
# AQM: Router RouterB → Low load (35%). No drops.
# AQM: Router RouterC → Low load (44%). No drops.
#
# ⏱️ Time step 2210 sec:
# AQM: Router RouterA → Low load (5%). No drops.
# AQM: Router RouterB → Heavy congestion (89%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (51%). Random early drop/mark applied.
#
# ⏱️ Time step 2220 sec:
# AQM: Router RouterA → Moderate load (59%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (74%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (97%). Aggressive early drop applied.
#
# ⏱️ Time step 2230 sec:
# AQM: Router RouterA → Moderate load (73%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (56%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (61%). Random early drop/mark applied.
#
# ⏱️ Time step 2240 sec:
# AQM: Router RouterA → Moderate load (52%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (52%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (73%). Random early drop/mark applied.
#
# ⏱️ Time step 2250 sec:
# AQM: Router RouterA → Low load (44%). No drops.
# AQM: Router RouterB → Heavy congestion (89%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (40%). No drops.
#
# ⏱️ Time step 2260 sec:
# AQM: Router RouterA → Moderate load (64%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (71%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (74%). Random early drop/mark applied.
#
# ⏱️ Time step 2270 sec:
# AQM: Router RouterA → Low load (47%). No drops.
# AQM: Router RouterB → Heavy congestion (90%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (46%). No drops.
#
# ⏱️ Time step 2280 sec:
# AQM: Router RouterA → Moderate load (70%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (53%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (12%). No drops.
#
# ⏱️ Time step 2290 sec:
# AQM: Router RouterA → Low load (35%). No drops.
# AQM: Router RouterB → Heavy congestion (81%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (25%). No drops.
#
# ...
# AQM: Router RouterC → Low load (32%). No drops.
#
# ⏱️ Time step 6250 sec:
# AQM: Router RouterA → Low load (32%). No drops.
# AQM: Router RouterB → Heavy congestion (87%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (65%). Random early drop/mark applied.
#
# ⏱️ Time step 6260 sec:
# AQM: Router RouterA → Low load (46%). No drops.
# AQM: Router RouterB → Moderate load (64%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (71%). Random early drop/mark applied.
#
# ⏱️ Time step 6270 sec:
# AQM: Router RouterA → Heavy congestion (84%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (28%). No drops.
# AQM: Router RouterC → Low load (42%). No drops.
#
# ⏱️ Time step 6280 sec:
# AQM: Router RouterA → Moderate load (68%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (97%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (96%). Aggressive early drop applied.
#
# ⏱️ Time step 6290 sec:
# AQM: Router RouterA → Moderate load (57%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (54%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (82%). Aggressive early drop applied.
#
# ⏱️ Time step 6300 sec:
# AQM: Router RouterA → Moderate load (57%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (58%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (57%). Random early drop/mark applied.
#
# ⏱️ Time step 6310 sec:
# AQM: Router RouterA → Low load (0%). No drops.
# AQM: Router RouterB → Moderate load (59%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (29%). No drops.
#
# ⏱️ Time step 6320 sec:
# AQM: Router RouterA → Low load (33%). No drops.
# AQM: Router RouterB → Moderate load (77%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (37%). No drops.
#
# ⏱️ Time step 6330 sec:
# AQM: Router RouterA → Moderate load (53%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (73%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (92%). Aggressive early drop applied.
#
# ⏱️ Time step 6340 sec:
# AQM: Router RouterA → Moderate load (73%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (69%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (53%). Random early drop/mark applied.
#
# ⏱️ Time step 6350 sec:
# AQM: Router RouterA → Heavy congestion (84%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (37%). No drops.
# AQM: Router RouterC → Moderate load (62%). Random early drop/mark applied.
#
# ⏱️ Time step 6360 sec:
# AQM: Router RouterA → Moderate load (79%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (60%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (41%). No drops.
#
# ⏱️ Time step 6370 sec:
# AQM: Router RouterA → Moderate load (63%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (42%). No drops.
# AQM: Router RouterC → Moderate load (52%). Random early drop/mark applied.
#
# ⏱️ Time step 6380 sec:
# AQM: Router RouterA → Low load (30%). No drops.
# AQM: Router RouterB → Heavy congestion (87%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (29%). No drops.
#
# ⏱️ Time step 6390 sec:
# AQM: Router RouterA → Low load (41%). No drops.
# AQM: Router RouterB → Moderate load (75%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (2%). No drops.
#
# ⏱️ Time step 6400 sec:
# AQM: Router RouterA → Heavy congestion (86%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (43%). No drops.
# AQM: Router RouterC → Low load (28%). No drops.
#
# ⏱️ Time step 6410 sec:
# AQM: Router RouterA → Low load (27%). No drops.
# AQM: Router RouterB → Heavy congestion (87%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (84%). Aggressive early drop applied.
#
# ⏱️ Time step 6420 sec:
# AQM: Router RouterA → Low load (26%). No drops.
# AQM: Router RouterB → Low load (40%). No drops.
# AQM: Router RouterC → Moderate load (60%). Random early drop/mark applied.
#
# ⏱️ Time step 6430 sec:
# AQM: Router RouterA → Heavy congestion (87%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (46%). No drops.
# AQM: Router RouterC → Heavy congestion (98%). Aggressive early drop applied.
#
# ⏱️ Time step 6440 sec:
# AQM: Router RouterA → Low load (21%). No drops.
# AQM: Router RouterB → Moderate load (62%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (99%). Aggressive early drop applied.
#
# ⏱️ Time step 6450 sec:
# AQM: Router RouterA → Low load (21%). No drops.
# AQM: Router RouterB → Heavy congestion (88%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (58%). Random early drop/mark applied.
#
# ⏱️ Time step 6460 sec:
# AQM: Router RouterA → Low load (5%). No drops.
# AQM: Router RouterB → Low load (46%). No drops.
# AQM: Router RouterC → Heavy congestion (94%). Aggressive early drop applied.
#
# ⏱️ Time step 6470 sec:
# AQM: Router RouterA → Low load (7%). No drops.
# AQM: Router RouterB → Heavy congestion (96%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (34%). No drops.
#
# ⏱️ Time step 6480 sec:
# AQM: Router RouterA → Low load (20%). No drops.
# AQM: Router RouterB → Moderate load (71%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (8%). No drops.
#
# ⏱️ Time step 6490 sec:
# AQM: Router RouterA → Moderate load (50%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (15%). No drops.
# AQM: Router RouterC → Moderate load (76%). Random early drop/mark applied.
#
# ⏱️ Time step 6500 sec:
# AQM: Router RouterA → Low load (27%). No drops.
# AQM: Router RouterB → Moderate load (54%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (16%). No drops.
#
# ⏱️ Time step 6510 sec:
# AQM: Router RouterA → Low load (9%). No drops.
# AQM: Router RouterB → Moderate load (68%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (68%). Random early drop/mark applied.
#
# ⏱️ Time step 6520 sec:
# AQM: Router RouterA → Low load (28%). No drops.
# AQM: Router RouterB → Moderate load (78%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (83%). Aggressive early drop applied.
#
# ⏱️ Time step 6530 sec:
# AQM: Router RouterA → Moderate load (61%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (53%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (33%). No drops.
#
# ⏱️ Time step 6540 sec:
# AQM: Router RouterA → Low load (34%). No drops.
# AQM: Router RouterB → Moderate load (66%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (90%). Aggressive early drop applied.
#
# ⏱️ Time step 6550 sec:
# AQM: Router RouterA → Heavy congestion (88%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (6%). No drops.
# AQM: Router RouterC → Low load (45%). No drops.
#
# ⏱️ Time step 6560 sec:
# AQM: Router RouterA → Low load (35%). No drops.
# AQM: Router RouterB → Moderate load (61%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (74%). Random early drop/mark applied.
#
# ⏱️ Time step 6570 sec:
# AQM: Router RouterA → Heavy congestion (82%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (25%). No drops.
# AQM: Router RouterC → Low load (35%). No drops.
#
# ⏱️ Time step 6580 sec:
# AQM: Router RouterA → Low load (13%). No drops.
# AQM: Router RouterB → Low load (3%). No drops.
# AQM: Router RouterC → Low load (30%). No drops.
#
# ⏱️ Time step 6590 sec:
# AQM: Router RouterA → Moderate load (63%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (2%). No drops.
# AQM: Router RouterC → Low load (2%). No drops.
#
# ⏱️ Time step 6600 sec:
# AQM: Router RouterA → Heavy congestion (91%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (16%). No drops.
# AQM: Router RouterC → Low load (17%). No drops.
#
# ⏱️ Time step 6610 sec:
# AQM: Router RouterA → Moderate load (68%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (22%). No drops.
# AQM: Router RouterC → Heavy congestion (90%). Aggressive early drop applied.
#
# ⏱️ Time step 6620 sec:
# AQM: Router RouterA → Low load (38%). No drops.
# AQM: Router RouterB → Heavy congestion (87%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (20%). No drops.
#
# ⏱️ Time step 6630 sec:
# AQM: Router RouterA → Low load (28%). No drops.
# AQM: Router RouterB → Low load (26%). No drops.
# AQM: Router RouterC → Heavy congestion (91%). Aggressive early drop applied.
#
# ⏱️ Time step 6640 sec:
# AQM: Router RouterA → Low load (4%). No drops.
# AQM: Router RouterB → Low load (18%). No drops.
# AQM: Router RouterC → Moderate load (55%). Random early drop/mark applied.
#
# ⏱️ Time step 6650 sec:
# AQM: Router RouterA → Moderate load (71%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (23%). No drops.
# AQM: Router RouterC → Heavy congestion (91%). Aggressive early drop applied.
#
# ⏱️ Time step 6660 sec:
# AQM: Router RouterA → Low load (42%). No drops.
# AQM: Router RouterB → Moderate load (51%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (96%). Aggressive early drop applied.
#
# ⏱️ Time step 6670 sec:
# AQM: Router RouterA → Moderate load (62%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (54%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (65%). Random early drop/mark applied.
#
# ⏱️ Time step 6680 sec:
# AQM: Router RouterA → Moderate load (76%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (50%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (9%). No drops.
#
# ⏱️ Time step 6690 sec:
# AQM: Router RouterA → Low load (15%). No drops.
# AQM: Router RouterB → Low load (2%). No drops.
# AQM: Router RouterC → Moderate load (61%). Random early drop/mark applied.
#
# ⏱️ Time step 6700 sec:
# AQM: Router RouterA → Moderate load (67%). Random early drop/mark applied.
# AQM: Router RouterB → Heavy congestion (80%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (91%). Aggressive early drop applied.
#
# ⏱️ Time step 6710 sec:
# AQM: Router RouterA → Low load (23%). No drops.
# AQM: Router RouterB → Heavy congestion (89%). Aggressive early drop applied.
# AQM: Router RouterC → Heavy congestion (85%). Aggressive early drop applied.
#
# ⏱️ Time step 6720 sec:
# AQM: Router RouterA → Moderate load (72%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (58%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (53%). Random early drop/mark applied.
#
# ⏱️ Time step 6730 sec:
# AQM: Router RouterA → Moderate load (79%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (0%). No drops.
# AQM: Router RouterC → Low load (4%). No drops.
#
# ⏱️ Time step 6740 sec:
# AQM: Router RouterA → Moderate load (66%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (7%). No drops.
# AQM: Router RouterC → Moderate load (74%). Random early drop/mark applied.
#
# ⏱️ Time step 6750 sec:
# AQM: Router RouterA → Low load (25%). No drops.
# AQM: Router RouterB → Heavy congestion (90%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (62%). Random early drop/mark applied.
#
# ⏱️ Time step 6760 sec:
# AQM: Router RouterA → Moderate load (69%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (13%). No drops.
# AQM: Router RouterC → Low load (7%). No drops.
#
# ⏱️ Time step 6770 sec:
# AQM: Router RouterA → Low load (49%). No drops.
# AQM: Router RouterB → Moderate load (66%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (18%). No drops.
#
# ⏱️ Time step 6780 sec:
# AQM: Router RouterA → Moderate load (58%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (36%). No drops.
# AQM: Router RouterC → Low load (33%). No drops.
#
# ⏱️ Time step 6790 sec:
# AQM: Router RouterA → Low load (43%). No drops.
# AQM: Router RouterB → Low load (24%). No drops.
# AQM: Router RouterC → Moderate load (65%). Random early drop/mark applied.
#
# ⏱️ Time step 6800 sec:
# AQM: Router RouterA → Low load (26%). No drops.
# AQM: Router RouterB → Moderate load (51%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (27%). No drops.
#
# ⏱️ Time step 6810 sec:
# AQM: Router RouterA → Low load (12%). No drops.
# AQM: Router RouterB → Moderate load (55%). Random early drop/mark applied.
# AQM: Router RouterC → Heavy congestion (100%). Aggressive early drop applied.
#
# ⏱️ Time step 6820 sec:
# AQM: Router RouterA → Heavy congestion (82%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (69%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (3%). No drops.
#
# ⏱️ Time step 6830 sec:
# AQM: Router RouterA → Moderate load (56%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (42%). No drops.
# AQM: Router RouterC → Low load (28%). No drops.
#
# ⏱️ Time step 6840 sec:
# AQM: Router RouterA → Moderate load (78%). Random early drop/mark applied.
# AQM: Router RouterB → Moderate load (66%). Random early drop/mark applied.
# AQM: Router RouterC → Low load (43%). No drops.
#
# ⏱️ Time step 6850 sec:
# AQM: Router RouterA → Heavy congestion (89%). Aggressive early drop applied.
# AQM: Router RouterB → Moderate load (72%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (59%). Random early drop/mark applied.
#
# ⏱️ Time step 6860 sec:
# AQM: Router RouterA → Moderate load (78%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (13%). No drops.
# AQM: Router RouterC → Low load (16%). No drops.
#
# ⏱️ Time step 6870 sec:
# AQM: Router RouterA → Low load (21%). No drops.
# AQM: Router RouterB → Low load (43%). No drops.
# AQM: Router RouterC → Heavy congestion (95%). Aggressive early drop applied.
#
# ⏱️ Time step 6880 sec:
# AQM: Router RouterA → Low load (42%). No drops.
# AQM: Router RouterB → Low load (6%). No drops.
# AQM: Router RouterC → Low load (13%). No drops.
#
# ⏱️ Time step 6890 sec:
# AQM: Router RouterA → Low load (41%). No drops.
# AQM: Router RouterB → Moderate load (68%). Random early drop/mark applied.
# AQM: Router RouterC → Moderate load (57%). Random early drop/mark applied.
#
# ⏱️ Time step 6900 sec:
# AQM: Router RouterA → Low load (19%). No drops.
# AQM: Router RouterB → Low load (17%). No drops.
# AQM: Router RouterC → Moderate load (59%). Random early drop/mark applied.
#
# ⏱️ Time step 6910 sec:
# AQM: Router RouterA → Heavy congestion (95%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (49%). No drops.
# AQM: Router RouterC → Moderate load (57%). Random early drop/mark applied.
#
# ⏱️ Time step 6920 sec:
# AQM: Router RouterA → Low load (49%). No drops.
# AQM: Router RouterB → Low load (34%). No drops.
# AQM: Router RouterC → Heavy congestion (86%). Aggressive early drop applied.
#
# ⏱️ Time step 6930 sec:
# AQM: Router RouterA → Heavy congestion (84%). Aggressive early drop applied.
# AQM: Router RouterB → Heavy congestion (92%). Aggressive early drop applied.
# AQM: Router RouterC → Moderate load (71%). Random early drop/mark applied.
#
# ⏱️ Time step 6940 sec:
# AQM: Router RouterA → Heavy congestion (99%). Aggressive early drop applied.
# AQM: Router RouterB → Low load (19%). No drops.
# AQM: Router RouterC → Low load (24%). No drops.
#
# ⏱️ Time step 6950 sec:
# AQM: Router RouterA → Moderate load (70%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (13%). No drops.
# AQM: Router RouterC → Moderate load (52%). Random early drop/mark applied.
#
# ⏱️ Time step 6960 sec:
# AQM: Router RouterA → Low load (37%). No drops.
# AQM: Router RouterB → Low load (6%). No drops.
# AQM: Router RouterC → Low load (17%). No drops.
#
# ⏱️ Time step 6970 sec:
# AQM: Router RouterA → Low load (38%). No drops.
# AQM: Router RouterB → Low load (22%). No drops.
# AQM: Router RouterC → Low load (38%). No drops.
#
# ⏱️ Time step 6980 sec:
# AQM: Router RouterA → Heavy congestion (88%). Aggressive early drop applied.
# AQM: Router RouterB → Heavy congestion (93%). Aggressive early drop applied.
# AQM: Router RouterC → Low load (29%). No drops.
#
# ⏱️ Time step 6990 sec:
# AQM: Router RouterA → Moderate load (64%). Random early drop/mark applied.
# AQM: Router RouterB → Low load (32%). No drops.
# AQM: Router RouterC → Low load (8%). No drops.

# %%
#CONGESTION CONTROL PROTOCOLS (END TO END)
import pandas as pd

def run_end_to_end_cc(
    congestion_file,
    high_thresh=80,
    moderate_thresh=50,
    timestep=10,
    init_rate=1000  # arbitrary units (e.g., Mbps)
):
    """
    Simulate end-to-end congestion control (like TCP AIMD).
    Adjusts sending rate per flow depending on router congestion.
    """

    # Load congestion data
    df_cong = pd.read_csv(congestion_file)

    # Add Time column if missing
    if "Time" not in df_cong.columns:
        df_cong.insert(0, "Time", [i * timestep for i in range(len(df_cong))])

    expected_cols = {"RouterA", "RouterB", "RouterC"}
    if not expected_cols.issubset(set(df_cong.columns)):
        raise ValueError(f"Congestion CSV must contain {expected_cols}, found {df_cong.columns}")

    # Initialize sending rates for 4 users
    rates = {"User1": init_rate, "User2": init_rate, "User3": init_rate, "User4": init_rate}

    # Iterate over timesteps
    for _, row in df_cong.iterrows():
        time_label = row["Time"]
        routers = {col: float(row[col]) for col in df_cong.columns if col.startswith("Router")}

        print(f"\n⏱️ Time step {time_label} sec:")

        # Decision: check worst congestion
        worst_router = max(routers, key=routers.get)
        worst_load = routers[worst_router]

        if worst_load >= high_thresh:
            # Multiplicative Decrease
            for u in rates:
                old = rates[u]
                rates[u] *= 0.5
                print(f"  {u}: High congestion at {worst_router} ({worst_load:.0f}%). "
                      f"Rate reduced {old:.1f} → {rates[u]:.1f}")
        elif worst_load >= moderate_thresh:
            # Keep or slow additive increase
            for u in rates:
                old = rates[u]
                rates[u] += 50
                print(f"  {u}: Moderate load at {worst_router} ({worst_load:.0f}%). "
                      f"Rate adjusted {old:.1f} → {rates[u]:.1f}")
        else:
            # Additive Increase
            for u in rates:
                old = rates[u]
                rates[u] += 100
                print(f"  {u}: Low load at {worst_router} ({worst_load:.0f}%). "
                      f"Rate increased {old:.1f} → {rates[u]:.1f}")
run_end_to_end_cc("C:/Users/ASUS/Downloads/router_congestion_int.csv")
# Out:
# ⏱️ Time step 0 sec:
#   User1: Low load at RouterC (30%). Rate increased 1000.0 → 1100.0
#   User2: Low load at RouterC (30%). Rate increased 1000.0 → 1100.0
#   User3: Low load at RouterC (30%). Rate increased 1000.0 → 1100.0
#   User4: Low load at RouterC (30%). Rate increased 1000.0 → 1100.0
#
# ⏱️ Time step 10 sec:
#   User1: Moderate load at RouterC (68%). Rate adjusted 1100.0 → 1150.0
#   User2: Moderate load at RouterC (68%). Rate adjusted 1100.0 → 1150.0
#   User3: Moderate load at RouterC (68%). Rate adjusted 1100.0 → 1150.0
#   User4: Moderate load at RouterC (68%). Rate adjusted 1100.0 → 1150.0
#
# ⏱️ Time step 20 sec:
#   User1: High congestion at RouterC (90%). Rate reduced 1150.0 → 575.0
#   User2: High congestion at RouterC (90%). Rate reduced 1150.0 → 575.0
#   User3: High congestion at RouterC (90%). Rate reduced 1150.0 → 575.0
#   User4: High congestion at RouterC (90%). Rate reduced 1150.0 → 575.0
#
# ⏱️ Time step 30 sec:
#   User1: High congestion at RouterA (97%). Rate reduced 575.0 → 287.5
#   User2: High congestion at RouterA (97%). Rate reduced 575.0 → 287.5
#   User3: High congestion at RouterA (97%). Rate reduced 575.0 → 287.5
#   User4: High congestion at RouterA (97%). Rate reduced 575.0 → 287.5
#
# ⏱️ Time step 40 sec:
#   User1: High congestion at RouterB (94%). Rate reduced 287.5 → 143.8
#   User2: High congestion at RouterB (94%). Rate reduced 287.5 → 143.8
#   User3: High congestion at RouterB (94%). Rate reduced 287.5 → 143.8
#   User4: High congestion at RouterB (94%). Rate reduced 287.5 → 143.8
#
# ⏱️ Time step 50 sec:
#   User1: Low load at RouterC (31%). Rate increased 143.8 → 243.8
#   User2: Low load at RouterC (31%). Rate increased 143.8 → 243.8
#   User3: Low load at RouterC (31%). Rate increased 143.8 → 243.8
#   User4: Low load at RouterC (31%). Rate increased 143.8 → 243.8
#
# ⏱️ Time step 60 sec:
#   User1: Moderate load at RouterC (62%). Rate adjusted 243.8 → 293.8
#   User2: Moderate load at RouterC (62%). Rate adjusted 243.8 → 293.8
#   User3: Moderate load at RouterC (62%). Rate adjusted 243.8 → 293.8
#   User4: Moderate load at RouterC (62%). Rate adjusted 243.8 → 293.8
#
# ⏱️ Time step 70 sec:
#   User1: Low load at RouterB (34%). Rate increased 293.8 → 393.8
#   User2: Low load at RouterB (34%). Rate increased 293.8 → 393.8
#   User3: Low load at RouterB (34%). Rate increased 293.8 → 393.8
#   User4: Low load at RouterB (34%). Rate increased 293.8 → 393.8
#
# ⏱️ Time step 80 sec:
#   User1: High congestion at RouterB (95%). Rate reduced 393.8 → 196.9
#   User2: High congestion at RouterB (95%). Rate reduced 393.8 → 196.9
#   User3: High congestion at RouterB (95%). Rate reduced 393.8 → 196.9
#   User4: High congestion at RouterB (95%). Rate reduced 393.8 → 196.9
#
# ⏱️ Time step 90 sec:
#   User1: High congestion at RouterB (92%). Rate reduced 196.9 → 98.4
#   User2: High congestion at RouterB (92%). Rate reduced 196.9 → 98.4
#   User3: High congestion at RouterB (92%). Rate reduced 196.9 → 98.4
#   User4: High congestion at RouterB (92%). Rate reduced 196.9 → 98.4
#
# ⏱️ Time step 100 sec:
#   User1: High congestion at RouterA (99%). Rate reduced 98.4 → 49.2
#   User2: High congestion at RouterA (99%). Rate reduced 98.4 → 49.2
#   User3: High congestion at RouterA (99%). Rate reduced 98.4 → 49.2
#   User4: High congestion at RouterA (99%). Rate reduced 98.4 → 49.2
#
# ⏱️ Time step 110 sec:
#   User1: Moderate load at RouterC (73%). Rate adjusted 49.2 → 99.2
#   User2: Moderate load at RouterC (73%). Rate adjusted 49.2 → 99.2
#   User3: Moderate load at RouterC (73%). Rate adjusted 49.2 → 99.2
#   User4: Moderate load at RouterC (73%). Rate adjusted 49.2 → 99.2
#
# ⏱️ Time step 120 sec:
#   User1: Low load at RouterC (32%). Rate increased 99.2 → 199.2
#   User2: Low load at RouterC (32%). Rate increased 99.2 → 199.2
#   User3: Low load at RouterC (32%). Rate increased 99.2 → 199.2
#   User4: Low load at RouterC (32%). Rate increased 99.2 → 199.2
#
# ⏱️ Time step 130 sec:
#   User1: High congestion at RouterA (96%). Rate reduced 199.2 → 99.6
#   User2: High congestion at RouterA (96%). Rate reduced 199.2 → 99.6
#   User3: High congestion at RouterA (96%). Rate reduced 199.2 → 99.6
#   User4: High congestion at RouterA (96%). Rate reduced 199.2 → 99.6
#
# ⏱️ Time step 140 sec:
#   User1: Low load at RouterB (38%). Rate increased 99.6 → 199.6
#   User2: Low load at RouterB (38%). Rate increased 99.6 → 199.6
#   User3: Low load at RouterB (38%). Rate increased 99.6 → 199.6
#   User4: Low load at RouterB (38%). Rate increased 99.6 → 199.6
#
# ⏱️ Time step 150 sec:
#   User1: Moderate load at RouterA (56%). Rate adjusted 199.6 → 249.6
#   User2: Moderate load at RouterA (56%). Rate adjusted 199.6 → 249.6
#   User3: Moderate load at RouterA (56%). Rate adjusted 199.6 → 249.6
#   User4: Moderate load at RouterA (56%). Rate adjusted 199.6 → 249.6
#
# ⏱️ Time step 160 sec:
#   User1: High congestion at RouterA (93%). Rate reduced 249.6 → 124.8
#   User2: High congestion at RouterA (93%). Rate reduced 249.6 → 124.8
#   User3: High congestion at RouterA (93%). Rate reduced 249.6 → 124.8
#   User4: High congestion at RouterA (93%). Rate reduced 249.6 → 124.8
#
# ⏱️ Time step 170 sec:
#   User1: High congestion at RouterB (85%). Rate reduced 124.8 → 62.4
#   User2: High congestion at RouterB (85%). Rate reduced 124.8 → 62.4
#   User3: High congestion at RouterB (85%). Rate reduced 124.8 → 62.4
#   User4: High congestion at RouterB (85%). Rate reduced 124.8 → 62.4
#
# ⏱️ Time step 180 sec:
#   User1: High congestion at RouterA (98%). Rate reduced 62.4 → 31.2
#   User2: High congestion at RouterA (98%). Rate reduced 62.4 → 31.2
#   User3: High congestion at RouterA (98%). Rate reduced 62.4 → 31.2
#   User4: High congestion at RouterA (98%). Rate reduced 62.4 → 31.2
#
# ⏱️ Time step 190 sec:
#   User1: High congestion at RouterC (97%). Rate reduced 31.2 → 15.6
#   User2: High congestion at RouterC (97%). Rate reduced 31.2 → 15.6
#   User3: High congestion at RouterC (97%). Rate reduced 31.2 → 15.6
#   User4: High congestion at RouterC (97%). Rate reduced 31.2 → 15.6
#
# ⏱️ Time step 200 sec:
#   User1: Low load at RouterB (39%). Rate increased 15.6 → 115.6
#   User2: Low load at RouterB (39%). Rate increased 15.6 → 115.6
#   User3: Low load at RouterB (39%). Rate increased 15.6 → 115.6
#   User4: Low load at RouterB (39%). Rate increased 15.6 → 115.6
#
# ⏱️ Time step 210 sec:
#   User1: Low load at RouterA (48%). Rate increased 115.6 → 215.6
#   User2: Low load at RouterA (48%). Rate increased 115.6 → 215.6
#   User3: Low load at RouterA (48%). Rate increased 115.6 → 215.6
#   User4: Low load at RouterA (48%). Rate increased 115.6 → 215.6
#
# ⏱️ Time step 220 sec:
#   User1: Moderate load at RouterB (71%). Rate adjusted 215.6 → 265.6
#   User2: Moderate load at RouterB (71%). Rate adjusted 215.6 → 265.6
#   User3: Moderate load at RouterB (71%). Rate adjusted 215.6 → 265.6
#   User4: Moderate load at RouterB (71%). Rate adjusted 215.6 → 265.6
#
# ⏱️ Time step 230 sec:
#   User1: High congestion at RouterC (97%). Rate reduced 265.6 → 132.8
#   User2: High congestion at RouterC (97%). Rate reduced 265.6 → 132.8
#   User3: High congestion at RouterC (97%). Rate reduced 265.6 → 132.8
#   User4: High congestion at RouterC (97%). Rate reduced 265.6 → 132.8
#
# ⏱️ Time step 240 sec:
#   User1: High congestion at RouterA (85%). Rate reduced 132.8 → 66.4
#   User2: High congestion at RouterA (85%). Rate reduced 132.8 → 66.4
#   User3: High congestion at RouterA (85%). Rate reduced 132.8 → 66.4
#   User4: High congestion at RouterA (85%). Rate reduced 132.8 → 66.4
#
# ⏱️ Time step 250 sec:
#   User1: High congestion at RouterA (97%). Rate reduced 66.4 → 33.2
#   User2: High congestion at RouterA (97%). Rate reduced 66.4 → 33.2
#   User3: High congestion at RouterA (97%). Rate reduced 66.4 → 33.2
#   User4: High congestion at RouterA (97%). Rate reduced 66.4 → 33.2
#
# ⏱️ Time step 260 sec:
#   User1: High congestion at RouterB (91%). Rate reduced 33.2 → 16.6
#   User2: High congestion at RouterB (91%). Rate reduced 33.2 → 16.6
#   User3: High congestion at RouterB (91%). Rate reduced 33.2 → 16.6
#   User4: High congestion at RouterB (91%). Rate reduced 33.2 → 16.6
#
# ⏱️ Time step 270 sec:
#   User1: High congestion at RouterC (92%). Rate reduced 16.6 → 8.3
#   User2: High congestion at RouterC (92%). Rate reduced 16.6 → 8.3
#   User3: High congestion at RouterC (92%). Rate reduced 16.6 → 8.3
#   User4: High congestion at RouterC (92%). Rate reduced 16.6 → 8.3
#
# ⏱️ Time step 280 sec:
#   User1: Moderate load at RouterA (75%). Rate adjusted 8.3 → 58.3
#   User2: Moderate load at RouterA (75%). Rate adjusted 8.3 → 58.3
#   User3: Moderate load at RouterA (75%). Rate adjusted 8.3 → 58.3
#   User4: Moderate load at RouterA (75%). Rate adjusted 8.3 → 58.3
#
# ⏱️ Time step 290 sec:
#   User1: High congestion at RouterC (98%). Rate reduced 58.3 → 29.2
#   User2: High congestion at RouterC (98%). Rate reduced 58.3 → 29.2
#   User3: High congestion at RouterC (98%). Rate reduced 58.3 → 29.2
#   User4: High congestion at RouterC (98%). Rate reduced 58.3 → 29.2
#
# ⏱️ Time step 300 sec:
#   User1: Moderate load at RouterB (68%). Rate adjusted 29.2 → 79.2
#   User2: Moderate load at RouterB (68%). Rate adjusted 29.2 → 79.2
#   User3: Moderate load at RouterB (68%). Rate adjusted 29.2 → 79.2
#   User4: Moderate load at RouterB (68%). Rate adjusted 29.2 → 79.2
#
# ⏱️ Time step 310 sec:
#   User1: High congestion at RouterB (96%). Rate reduced 79.2 → 39.6
#   User2: High congestion at RouterB (96%). Rate reduced 79.2 → 39.6
#   User3: High congestion at RouterB (96%). Rate reduced 79.2 → 39.6
#   User4: High congestion at RouterB (96%). Rate reduced 79.2 → 39.6
#
# ⏱️ Time step 320 sec:
#   User1: Moderate load at RouterA (62%). Rate adjusted 39.6 → 89.6
#   User2: Moderate load at RouterA (62%). Rate adjusted 39.6 → 89.6
#   User3: Moderate load at RouterA (62%). Rate adjusted 39.6 → 89.6
#   User4: Moderate load at RouterA (62%). Rate adjusted 39.6 → 89.6
#
# ⏱️ Time step 330 sec:
#   User1: Moderate load at RouterC (70%). Rate adjusted 89.6 → 139.6
#   User2: Moderate load at RouterC (70%). Rate adjusted 89.6 → 139.6
#   User3: Moderate load at RouterC (70%). Rate adjusted 89.6 → 139.6
#   User4: Moderate load at RouterC (70%). Rate adjusted 89.6 → 139.6
#
# ⏱️ Time step 340 sec:
#   User1: Moderate load at RouterC (77%). Rate adjusted 139.6 → 189.6
#   User2: Moderate load at RouterC (77%). Rate adjusted 139.6 → 189.6
#   User3: Moderate load at RouterC (77%). Rate adjusted 139.6 → 189.6
#   User4: Moderate load at RouterC (77%). Rate adjusted 139.6 → 189.6
#
# ⏱️ Time step 350 sec:
#   User1: Moderate load at RouterC (78%). Rate adjusted 189.6 → 239.6
#   User2: Moderate load at RouterC (78%). Rate adjusted 189.6 → 239.6
#   User3: Moderate load at RouterC (78%). Rate adjusted 189.6 → 239.6
#   User4: Moderate load at RouterC (78%). Rate adjusted 189.6 → 239.6
#
# ⏱️ Time step 360 sec:
#   User1: Low load at RouterA (46%). Rate increased 239.6 → 339.6
#   User2: Low load at RouterA (46%). Rate increased 239.6 → 339.6
#   User3: Low load at RouterA (46%). Rate increased 239.6 → 339.6
#   User4: Low load at RouterA (46%). Rate increased 239.6 → 339.6
#
# ⏱️ Time step 370 sec:
#   User1: Moderate load at RouterC (73%). Rate adjusted 339.6 → 389.6
#   User2: Moderate load at RouterC (73%). Rate adjusted 339.6 → 389.6
#   User3: Moderate load at RouterC (73%). Rate adjusted 339.6 → 389.6
#   User4: Moderate load at RouterC (73%). Rate adjusted 339.6 → 389.6
#
# ⏱️ Time step 380 sec:
#   User1: High congestion at RouterC (95%). Rate reduced 389.6 → 194.8
#   User2: High congestion at RouterC (95%). Rate reduced 389.6 → 194.8
#   User3: High congestion at RouterC (95%). Rate reduced 389.6 → 194.8
#   User4: High congestion at RouterC (95%). Rate reduced 389.6 → 194.8
#
# ⏱️ Time step 390 sec:
#   User1: High congestion at RouterA (94%). Rate reduced 194.8 → 97.4
#   User2: High congestion at RouterA (94%). Rate reduced 194.8 → 97.4
#   User3: High congestion at RouterA (94%). Rate reduced 194.8 → 97.4
#   User4: High congestion at RouterA (94%). Rate reduced 194.8 → 97.4
#
# ⏱️ Time step 400 sec:
#   User1: Low load at RouterC (33%). Rate increased 97.4 → 197.4
#   User2: Low load at RouterC (33%). Rate increased 97.4 → 197.4
#   User3: Low load at RouterC (33%). Rate increased 97.4 → 197.4
#   User4: Low load at RouterC (33%). Rate increased 97.4 → 197.4
#
# ⏱️ Time step 410 sec:
#   User1: Moderate load at RouterB (66%). Rate adjusted 197.4 → 247.4
#   User2: Moderate load at RouterB (66%). Rate adjusted 197.4 → 247.4
#   User3: Moderate load at RouterB (66%). Rate adjusted 197.4 → 247.4
#   User4: Moderate load at RouterB (66%). Rate adjusted 197.4 → 247.4
#
# ⏱️ Time step 420 sec:
#   User1: High congestion at RouterB (98%). Rate reduced 247.4 → 123.7
#   User2: High congestion at RouterB (98%). Rate reduced 247.4 → 123.7
#   User3: High congestion at RouterB (98%). Rate reduced 247.4 → 123.7
#   User4: High congestion at RouterB (98%). Rate reduced 247.4 → 123.7
#
# ⏱️ Time step 430 sec:
#   User1: High congestion at RouterC (100%). Rate reduced 123.7 → 61.8
#   User2: High congestion at RouterC (100%). Rate reduced 123.7 → 61.8
#   User3: High congestion at RouterC (100%). Rate reduced 123.7 → 61.8
#   User4: High congestion at RouterC (100%). Rate reduced 123.7 → 61.8
#
# ⏱️ Time step 440 sec:
#   User1: Moderate load at RouterC (77%). Rate adjusted 61.8 → 111.8
#   User2: Moderate load at RouterC (77%). Rate adjusted 61.8 → 111.8
#   User3: Moderate load at RouterC (77%). Rate adjusted 61.8 → 111.8
#   User4: Moderate load at RouterC (77%). Rate adjusted 61.8 → 111.8
#
# ⏱️ Time step 450 sec:
#   User1: High congestion at RouterB (98%). Rate reduced 111.8 → 55.9
#   User2: High congestion at RouterB (98%). Rate reduced 111.8 → 55.9
#   User3: High congestion at RouterB (98%). Rate reduced 111.8 → 55.9
#   User4: High congestion at RouterB (98%). Rate reduced 111.8 → 55.9
#
# ⏱️ Time step 460 sec:
#   User1: Moderate load at RouterB (55%). Rate adjusted 55.9 → 105.9
#   User2: Moderate load at RouterB (55%). Rate adjusted 55.9 → 105.9
#   User3: Moderate load at RouterB (55%). Rate adjusted 55.9 → 105.9
#   User4: Moderate load at RouterB (55%). Rate adjusted 55.9 → 105.9
#
# ⏱️ Time step 470 sec:
#   User1: Moderate load at RouterC (60%). Rate adjusted 105.9 → 155.9
#   User2: Moderate load at RouterC (60%). Rate adjusted 105.9 → 155.9
#   User3: Moderate load at RouterC (60%). Rate adjusted 105.9 → 155.9
#   User4: Moderate load at RouterC (60%). Rate adjusted 105.9 → 155.9
#
# ⏱️ Time step 480 sec:
#   User1: High congestion at RouterC (89%). Rate reduced 155.9 → 78.0
#   User2: High congestion at RouterC (89%). Rate reduced 155.9 → 78.0
#   User3: High congestion at RouterC (89%). Rate reduced 155.9 → 78.0
#   User4: High congestion at RouterC (89%). Rate reduced 155.9 → 78.0
#
# ⏱️ Time step 490 sec:
#   User1: Moderate load at RouterA (73%). Rate adjusted 78.0 → 128.0
#   User2: Moderate load at RouterA (73%). Rate adjusted 78.0 → 128.0
#   User3: Moderate load at RouterA (73%). Rate adjusted 78.0 → 128.0
#   User4: Moderate load at RouterA (73%). Rate adjusted 78.0 → 128.0
#
# ⏱️ Time step 500 sec:
#   User1: Moderate load at RouterC (66%). Rate adjusted 128.0 → 178.0
#   User2: Moderate load at RouterC (66%). Rate adjusted 128.0 → 178.0
#   User3: Moderate load at RouterC (66%). Rate adjusted 128.0 → 178.0
#   User4: Moderate load at RouterC (66%). Rate adjusted 128.0 → 178.0
#
# ⏱️ Time step 510 sec:
#   User1: Low load at RouterA (48%). Rate increased 178.0 → 278.0
#   User2: Low load at RouterA (48%). Rate increased 178.0 → 278.0
#   User3: Low load at RouterA (48%). Rate increased 178.0 → 278.0
#   User4: Low load at RouterA (48%). Rate increased 178.0 → 278.0
#
# ⏱️ Time step 520 sec:
#   User1: High congestion at RouterC (93%). Rate reduced 278.0 → 139.0
#   User2: High congestion at RouterC (93%). Rate reduced 278.0 → 139.0
#   User3: High congestion at RouterC (93%). Rate reduced 278.0 → 139.0
#   User4: High congestion at RouterC (93%). Rate reduced 278.0 → 139.0
#
# ⏱️ Time step 530 sec:
#   User1: Moderate load at RouterC (62%). Rate adjusted 139.0 → 189.0
#   User2: Moderate load at RouterC (62%). Rate adjusted 139.0 → 189.0
#   User3: Moderate load at RouterC (62%). Rate adjusted 139.0 → 189.0
#   User4: Moderate load at RouterC (62%). Rate adjusted 139.0 → 189.0
#
# ⏱️ Time step 540 sec:
#   User1: Low load at RouterA (39%). Rate increased 189.0 → 289.0
#   User2: Low load at RouterA (39%). Rate increased 189.0 → 289.0
#   User3: Low load at RouterA (39%). Rate increased 189.0 → 289.0
#   User4: Low load at RouterA (39%). Rate increased 189.0 → 289.0
#
# ⏱️ Time step 550 sec:
#   User1: Moderate load at RouterC (69%). Rate adjusted 289.0 → 339.0
#   User2: Moderate load at RouterC (69%). Rate adjusted 289.0 → 339.0
#   User3: Moderate load at RouterC (69%). Rate adjusted 289.0 → 339.0
#   User4: Moderate load at RouterC (69%). Rate adjusted 289.0 → 339.0
#
# ⏱️ Time step 560 sec:
#   User1: High congestion at RouterB (98%). Rate reduced 339.0 → 169.5
#   User2: High congestion at RouterB (98%). Rate reduced 339.0 → 169.5
#   User3: High congestion at RouterB (98%). Rate reduced 339.0 → 169.5
#   User4: High congestion at RouterB (98%). Rate reduced 339.0 → 169.5
#
# ⏱️ Time step 570 sec:
#   User1: Low load at RouterA (26%). Rate increased 169.5 → 269.5
#   User2: Low load at RouterA (26%). Rate increased 169.5 → 269.5
#   User3: Low load at RouterA (26%). Rate increased 169.5 → 269.5
#   User4: Low load at RouterA (26%). Rate increased 169.5 → 269.5
#
# ⏱️ Time step 580 sec:
#   User1: High congestion at RouterB (94%). Rate reduced 269.5 → 134.7
#   User2: High congestion at RouterB (94%). Rate reduced 269.5 → 134.7
#   User3: High congestion at RouterB (94%). Rate reduced 269.5 → 134.7
#   User4: High congestion at RouterB (94%). Rate reduced 269.5 → 134.7
#
# ⏱️ Time step 590 sec:
#   User1: Moderate load at RouterA (62%). Rate adjusted 134.7 → 184.7
#   User2: Moderate load at RouterA (62%). Rate adjusted 134.7 → 184.7
#   User3: Moderate load at RouterA (62%). Rate adjusted 134.7 → 184.7
#   User4: Moderate load at RouterA (62%). Rate adjusted 134.7 → 184.7
#
# ⏱️ Time step 600 sec:
#   User1: High congestion at RouterA (82%). Rate reduced 184.7 → 92.4
#   User2: High congestion at RouterA (82%). Rate reduced 184.7 → 92.4
#   User3: High congestion at RouterA (82%). Rate reduced 184.7 → 92.4
#   User4: High congestion at RouterA (82%). Rate reduced 184.7 → 92.4
#
# ⏱️ Time step 610 sec:
#   User1: High congestion at RouterB (88%). Rate reduced 92.4 → 46.2
#   User2: High congestion at RouterB (88%). Rate reduced 92.4 → 46.2
#   User3: High congestion at RouterB (88%). Rate reduced 92.4 → 46.2
#   User4: High congestion at RouterB (88%). Rate reduced 92.4 → 46.2
#
# ⏱️ Time step 620 sec:
#   User1: High congestion at RouterB (96%). Rate reduced 46.2 → 23.1
#   User2: High congestion at RouterB (96%). Rate reduced 46.2 → 23.1
#   User3: High congestion at RouterB (96%). Rate reduced 46.2 → 23.1
#   User4: High congestion at RouterB (96%). Rate reduced 46.2 → 23.1
#
# ⏱️ Time step 630 sec:
#   User1: Low load at RouterB (43%). Rate increased 23.1 → 123.1
#   User2: Low load at RouterB (43%). Rate increased 23.1 → 123.1
#   User3: Low load at RouterB (43%). Rate increased 23.1 → 123.1
#   User4: Low load at RouterB (43%). Rate increased 23.1 → 123.1
#
# ⏱️ Time step 640 sec:
#   User1: High congestion at RouterB (98%). Rate reduced 123.1 → 61.5
#   User2: High congestion at RouterB (98%). Rate reduced 123.1 → 61.5
#   User3: High congestion at RouterB (98%). Rate reduced 123.1 → 61.5
#   User4: High congestion at RouterB (98%). Rate reduced 123.1 → 61.5
#
# ⏱️ Time step 650 sec:
#   User1: High congestion at RouterA (83%). Rate reduced 61.5 → 30.8
#   User2: High congestion at RouterA (83%). Rate reduced 61.5 → 30.8
#   User3: High congestion at RouterA (83%). Rate reduced 61.5 → 30.8
#   User4: High congestion at RouterA (83%). Rate reduced 61.5 → 30.8
#
# ⏱️ Time step 660 sec:
#   User1: Moderate load at RouterC (77%). Rate adjusted 30.8 → 80.8
#   User2: Moderate load at RouterC (77%). Rate adjusted 30.8 → 80.8
#   User3: Moderate load at RouterC (77%). Rate adjusted 30.8 → 80.8
#   User4: Moderate load at RouterC (77%). Rate adjusted 30.8 → 80.8
#
# ⏱️ Time step 670 sec:
#   User1: Low load at RouterB (18%). Rate increased 80.8 → 180.8
#   User2: Low load at RouterB (18%). Rate increased 80.8 → 180.8
#   User3: Low load at RouterB (18%). Rate increased 80.8 → 180.8
#   User4: Low load at RouterB (18%). Rate increased 80.8 → 180.8
#
# ⏱️ Time step 680 sec:
#   User1: High congestion at RouterB (93%). Rate reduced 180.8 → 90.4
#   User2: High congestion at RouterB (93%). Rate reduced 180.8 → 90.4
#   User3: High congestion at RouterB (93%). Rate reduced 180.8 → 90.4
#   User4: High congestion at RouterB (93%). Rate reduced 180.8 → 90.4
#
# ⏱️ Time step 690 sec:
#   User1: Moderate load at RouterB (76%). Rate adjusted 90.4 → 140.4
#   User2: Moderate load at RouterB (76%). Rate adjusted 90.4 → 140.4
#   User3: Moderate load at RouterB (76%). Rate adjusted 90.4 → 140.4
#   User4: Moderate load at RouterB (76%). Rate adjusted 90.4 → 140.4
#
# ⏱️ Time step 700 sec:
#   User1: Moderate load at RouterC (78%). Rate adjusted 140.4 → 190.4
#   User2: Moderate load at RouterC (78%). Rate adjusted 140.4 → 190.4
#   User3: Moderate load at RouterC (78%). Rate adjusted 140.4 → 190.4
#   User4: Moderate load at RouterC (78%). Rate adjusted 140.4 → 190.4
#
# ⏱️ Time step 710 sec:
#   User1: High congestion at RouterB (100%). Rate reduced 190.4 → 95.2
#   User2: High congestion at RouterB (100%). Rate reduced 190.4 → 95.2
#   User3: High congestion at RouterB (100%). Rate reduced 190.4 → 95.2
#   User4: High congestion at RouterB (100%). Rate reduced 190.4 → 95.2
#
# ⏱️ Time step 720 sec:
#   User1: Moderate load at RouterC (65%). Rate adjusted 95.2 → 145.2
#   User2: Moderate load at RouterC (65%). Rate adjusted 95.2 → 145.2
#   User3: Moderate load at RouterC (65%). Rate adjusted 95.2 → 145.2
#   User4: Moderate load at RouterC (65%). Rate adjusted 95.2 → 145.2
#
# ⏱️ Time step 730 sec:
#   User1: High congestion at RouterC (85%). Rate reduced 145.2 → 72.6
#   User2: High congestion at RouterC (85%). Rate reduced 145.2 → 72.6
#   User3: High congestion at RouterC (85%). Rate reduced 145.2 → 72.6
#   User4: High congestion at RouterC (85%). Rate reduced 145.2 → 72.6
#
# ⏱️ Time step 740 sec:
#   User1: High congestion at RouterC (88%). Rate reduced 72.6 → 36.3
#   User2: High congestion at RouterC (88%). Rate reduced 72.6 → 36.3
#   User3: High congestion at RouterC (88%). Rate reduced 72.6 → 36.3
#   User4: High congestion at RouterC (88%). Rate reduced 72.6 → 36.3
#
# ⏱️ Time step 750 sec:
#   User1: High congestion at RouterC (99%). Rate reduced 36.3 → 18.1
#   User2: High congestion at RouterC (99%). Rate reduced 36.3 → 18.1
#   User3: High congestion at RouterC (99%). Rate reduced 36.3 → 18.1
#   User4: High congestion at RouterC (99%). Rate reduced 36.3 → 18.1
#
# ⏱️ Time step 760 sec:
#   User1: Moderate load at RouterA (52%). Rate adjusted 18.1 → 68.1
#   User2: Moderate load at RouterA (52%). Rate adjusted 18.1 → 68.1
#   User3: Moderate load at RouterA (52%). Rate adjusted 18.1 → 68.1
#   User4: Moderate load at RouterA (52%). Rate adjusted 18.1 → 68.1
#
# ⏱️ Time step 770 sec:
#   User1: Low load at RouterA (32%). Rate increased 68.1 → 168.1
#   User2: Low load at RouterA (32%). Rate increased 68.1 → 168.1
#   User3: Low load at RouterA (32%). Rate increased 68.1 → 168.1
#   User4: Low load at RouterA (32%). Rate increased 68.1 → 168.1
#
# ⏱️ Time step 780 sec:
#   User1: High congestion at RouterC (82%). Rate reduced 168.1 → 84.1
#   User2: High congestion at RouterC (82%). Rate reduced 168.1 → 84.1
#   User3: High congestion at RouterC (82%). Rate reduced 168.1 → 84.1
#   User4: High congestion at RouterC (82%). Rate reduced 168.1 → 84.1
#
# ⏱️ Time step 790 sec:
#   User1: High congestion at RouterB (97%). Rate reduced 84.1 → 42.0
#   User2: High congestion at RouterB (97%). Rate reduced 84.1 → 42.0
#   User3: High congestion at RouterB (97%). Rate reduced 84.1 → 42.0
#   User4: High congestion at RouterB (97%). Rate reduced 84.1 → 42.0
#
# ⏱️ Time step 800 sec:
#   User1: High congestion at RouterA (91%). Rate reduced 42.0 → 21.0
#   User2: High congestion at RouterA (91%). Rate reduced 42.0 → 21.0
#   User3: High congestion at RouterA (91%). Rate reduced 42.0 → 21.0
#   User4: High congestion at RouterA (91%). Rate reduced 42.0 → 21.0
#
# ⏱️ Time step 810 sec:
#   User1: Low load at RouterC (46%). Rate increased 21.0 → 121.0
#   User2: Low load at RouterC (46%). Rate increased 21.0 → 121.0
#   User3: Low load at RouterC (46%). Rate increased 21.0 → 121.0
#   User4: Low load at RouterC (46%). Rate increased 21.0 → 121.0
#
# ⏱️ Time step 820 sec:
#   User1: High congestion at RouterB (92%). Rate reduced 121.0 → 60.5
#   User2: High congestion at RouterB (92%). Rate reduced 121.0 → 60.5
#   User3: High congestion at RouterB (92%). Rate reduced 121.0 → 60.5
#   User4: High congestion at RouterB (92%). Rate reduced 121.0 → 60.5
#
# ⏱️ Time step 830 sec:
#   User1: Low load at RouterA (21%). Rate increased 60.5 → 160.5
#   User2: Low load at RouterA (21%). Rate increased 60.5 → 160.5
#   User3: Low load at RouterA (21%). Rate increased 60.5 → 160.5
#   User4: Low load at RouterA (21%). Rate increased 60.5 → 160.5
#
# ⏱️ Time step 840 sec:
#   User1: High congestion at RouterC (98%). Rate reduced 160.5 → 80.3
#   User2: High congestion at RouterC (98%). Rate reduced 160.5 → 80.3
#   User3: High congestion at RouterC (98%). Rate reduced 160.5 → 80.3
#   User4: High congestion at RouterC (98%). Rate reduced 160.5 → 80.3
#
# ⏱️ Time step 850 sec:
#   User1: High congestion at RouterA (95%). Rate reduced 80.3 → 40.1
#   User2: High congestion at RouterA (95%). Rate reduced 80.3 → 40.1
#   User3: High congestion at RouterA (95%). Rate reduced 80.3 → 40.1
#   User4: High congestion at RouterA (95%). Rate reduced 80.3 → 40.1
#
# ⏱️ Time step 860 sec:
#   User1: Moderate load at RouterA (65%). Rate adjusted 40.1 → 90.1
#   User2: Moderate load at RouterA (65%). Rate adjusted 40.1 → 90.1
#   User3: Moderate load at RouterA (65%). Rate adjusted 40.1 → 90.1
#   User4: Moderate load at RouterA (65%). Rate adjusted 40.1 → 90.1
#
# ⏱️ Time step 870 sec:
#   User1: Moderate load at RouterB (50%). Rate adjusted 90.1 → 140.1
#   User2: Moderate load at RouterB (50%). Rate adjusted 90.1 → 140.1
#   User3: Moderate load at RouterB (50%). Rate adjusted 90.1 → 140.1
#   User4: Moderate load at RouterB (50%). Rate adjusted 90.1 → 140.1
#
# ⏱️ Time step 880 sec:
#   User1: Moderate load at RouterC (76%). Rate adjusted 140.1 → 190.1
#   User2: Moderate load at RouterC (76%). Rate adjusted 140.1 → 190.1
#   User3: Moderate load at RouterC (76%). Rate adjusted 140.1 → 190.1
#   User4: Moderate load at RouterC (76%). Rate adjusted 140.1 → 190.1
#
# ⏱️ Time step 890 sec:
#   User1: Moderate load at RouterA (76%). Rate adjusted 190.1 → 240.1
#   User2: Moderate load at RouterA (76%). Rate adjusted 190.1 → 240.1
#   User3: Moderate load at RouterA (76%). Rate adjusted 190.1 → 240.1
#   User4: Moderate load at RouterA (76%). Rate adjusted 190.1 → 240.1
#
# ⏱️ Time step 900 sec:
#   User1: High congestion at RouterC (96%). Rate reduced 240.1 → 120.1
#   User2: High congestion at RouterC (96%). Rate reduced 240.1 → 120.1
#   User3: High congestion at RouterC (96%). Rate reduced 240.1 → 120.1
#   User4: High congestion at RouterC (96%). Rate reduced 240.1 → 120.1
#
# ⏱️ Time step 910 sec:
#   User1: Moderate load at RouterC (66%). Rate adjusted 120.1 → 170.1
#   User2: Moderate load at RouterC (66%). Rate adjusted 120.1 → 170.1
#   User3: Moderate load at RouterC (66%). Rate adjusted 120.1 → 170.1
#   User4: Moderate load at RouterC (66%). Rate adjusted 120.1 → 170.1
#
# ⏱️ Time step 920 sec:
#   User1: Moderate load at RouterB (78%). Rate adjusted 170.1 → 220.1
#   User2: Moderate load at RouterB (78%). Rate adjusted 170.1 → 220.1
#   User3: Moderate load at RouterB (78%). Rate adjusted 170.1 → 220.1
#   User4: Moderate load at RouterB (78%). Rate adjusted 170.1 → 220.1
#
# ⏱️ Time step 930 sec:
#   User1: High congestion at RouterC (98%). Rate reduced 220.1 → 110.0
#   User2: High congestion at RouterC (98%). Rate reduced 220.1 → 110.0
#   User3: High congestion at RouterC (98%). Rate reduced 220.1 → 110.0
#   User4: High congestion at RouterC (98%). Rate reduced 220.1 → 110.0
#
# ⏱️ Time step 940 sec:
#   User1: Low load at RouterB (47%). Rate increased 110.0 → 210.0
#   User2: Low load at RouterB (47%). Rate increased 110.0 → 210.0
#   User3: Low load at RouterB (47%). Rate increased 110.0 → 210.0
#   User4: Low load at RouterB (47%). Rate increased 110.0 → 210.0
#
# ⏱️ Time step 950 sec:
#   User1: High congestion at RouterA (84%). Rate reduced 210.0 → 105.0
#   User2: High congestion at RouterA (84%). Rate reduced 210.0 → 105.0
#   User3: High congestion at RouterA (84%). Rate reduced 210.0 → 105.0
#   User4: High congestion at RouterA (84%). Rate reduced 210.0 → 105.0
#
# ⏱️ Time step 960 sec:
#   User1: High congestion at RouterA (95%). Rate reduced 105.0 → 52.5
#   User2: High congestion at RouterA (95%). Rate reduced 105.0 → 52.5
#   User3: High congestion at RouterA (95%). Rate reduced 105.0 → 52.5
#   User4: High congestion at RouterA (95%). Rate reduced 105.0 → 52.5
#
# ⏱️ Time step 970 sec:
#   User1: High congestion at RouterC (81%). Rate reduced 52.5 → 26.3
#   User2: High congestion at RouterC (81%). Rate reduced 52.5 → 26.3
#   User3: High congestion at RouterC (81%). Rate reduced 52.5 → 26.3
#   User4: High congestion at RouterC (81%). Rate reduced 52.5 → 26.3
#
# ⏱️ Time step 980 sec:
#   User1: High congestion at RouterB (87%). Rate reduced 26.3 → 13.1
#   User2: High congestion at RouterB (87%). Rate reduced 26.3 → 13.1
#   User3: High congestion at RouterB (87%). Rate reduced 26.3 → 13.1
#   User4: High congestion at RouterB (87%). Rate reduced 26.3 → 13.1
#
# ⏱️ Time step 990 sec:
#   User1: High congestion at RouterC (89%). Rate reduced 13.1 → 6.6
#   User2: High congestion at RouterC (89%). Rate reduced 13.1 → 6.6
#   User3: High congestion at RouterC (89%). Rate reduced 13.1 → 6.6
#   User4: High congestion at RouterC (89%). Rate reduced 13.1 → 6.6
#
# ⏱️ Time step 1000 sec:
#   User1: High congestion at RouterC (80%). Rate reduced 6.6 → 3.3
#   User2: High congestion at RouterC (80%). Rate reduced 6.6 → 3.3
#   User3: High congestion at RouterC (80%). Rate reduced 6.6 → 3.3
#   User4: High congestion at RouterC (80%). Rate reduced 6.6 → 3.3
#
# ⏱️ Time step 1010 sec:
#   User1: High congestion at RouterC (88%). Rate reduced 3.3 → 1.6
#   User2: High congestion at RouterC (88%). Rate reduced 3.3 → 1.6
#   User3: High congestion at RouterC (88%). Rate reduced 3.3 → 1.6
#   User4: High congestion at RouterC (88%). Rate reduced 3.3 → 1.6
#
# ⏱️ Time step 1020 sec:
#   User1: High congestion at RouterC (82%). Rate reduced 1.6 → 0.8
#   User2: High congestion at RouterC (82%). Rate reduced 1.6 → 0.8
#   User3: High congestion at RouterC (82%). Rate reduced 1.6 → 0.8
#   User4: High congestion at RouterC (82%). Rate reduced 1.6 → 0.8
#
# ⏱️ Time step 1030 sec:
#   User1: High congestion at RouterB (92%). Rate reduced 0.8 → 0.4
#   User2: High congestion at RouterB (92%). Rate reduced 0.8 → 0.4
#   User3: High congestion at RouterB (92%). Rate reduced 0.8 → 0.4
#   User4: High congestion at RouterB (92%). Rate reduced 0.8 → 0.4
#
# ⏱️ Time step 1040 sec:
#   User1: Moderate load at RouterB (74%). Rate adjusted 0.4 → 50.4
#   User2: Moderate load at RouterB (74%). Rate adjusted 0.4 → 50.4
#   User3: Moderate load at RouterB (74%). Rate adjusted 0.4 → 50.4
#   User4: Moderate load at RouterB (74%). Rate adjusted 0.4 → 50.4
#
# ⏱️ Time step 1050 sec:
#   User1: Low load at RouterA (41%). Rate increased 50.4 → 150.4
#   User2: Low load at RouterA (41%). Rate increased 50.4 → 150.4
#   User3: Low load at RouterA (41%). Rate increased 50.4 → 150.4
#   User4: Low load at RouterA (41%). Rate increased 50.4 → 150.4
#
# ⏱️ Time step 1060 sec:
#   User1: Moderate load at RouterA (70%). Rate adjusted 150.4 → 200.4
#   User2: Moderate load at RouterA (70%). Rate adjusted 150.4 → 200.4
#   User3: Moderate load at RouterA (70%). Rate adjusted 150.4 → 200.4
#   User4: Moderate load at RouterA (70%). Rate adjusted 150.4 → 200.4
#
# ⏱️ Time step 1070 sec:
#   User1: Low load at RouterC (31%). Rate increased 200.4 → 300.4
#   User2: Low load at RouterC (31%). Rate increased 200.4 → 300.4
#   User3: Low load at RouterC (31%). Rate increased 200.4 → 300.4
#   User4: Low load at RouterC (31%). Rate increased 200.4 → 300.4
#
# ⏱️ Time step 1080 sec:
#   User1: Moderate load at RouterC (72%). Rate adjusted 300.4 → 350.4
#   User2: Moderate load at RouterC (72%). Rate adjusted 300.4 → 350.4
#   User3: Moderate load at RouterC (72%). Rate adjusted 300.4 → 350.4
#   User4: Moderate load at RouterC (72%). Rate adjusted 300.4 → 350.4
#
# ⏱️ Time step 1090 sec:
#   User1: High congestion at RouterB (96%). Rate reduced 350.4 → 175.2
#   User2: High congestion at RouterB (96%). Rate reduced 350.4 → 175.2
#   User3: High congestion at RouterB (96%). Rate reduced 350.4 → 175.2
#   User4: High congestion at RouterB (96%). Rate reduced 350.4 → 175.2
#
# ⏱️ Time step 1100 sec:
#   User1: Moderate load at RouterB (77%). Rate adjusted 175.2 → 225.2
#   User2: Moderate load at RouterB (77%). Rate adjusted 175.2 → 225.2
#   User3: Moderate load at RouterB (77%). Rate adjusted 175.2 → 225.2
#   User4: Moderate load at RouterB (77%). Rate adjusted 175.2 → 225.2
#
# ⏱️ Time step 1110 sec:
#   User1: Low load at RouterB (40%). Rate increased 225.2 → 325.2
#   User2: Low load at RouterB (40%). Rate increased 225.2 → 325.2
#   User3: Low load at RouterB (40%). Rate increased 225.2 → 325.2
#   User4: Low load at RouterB (40%). Rate increased 225.2 → 325.2
#
# ⏱️ Time step 1120 sec:
#   User1: Moderate load at RouterA (76%). Rate adjusted 325.2 → 375.2
#   User2: Moderate load at RouterA (76%). Rate adjusted 325.2 → 375.2
#   User3: Moderate load at RouterA (76%). Rate adjusted 325.2 → 375.2
#   User4: Moderate load at RouterA (76%). Rate adjusted 325.2 → 375.2
#
# ⏱️ Time step 1130 sec:
#   User1: Moderate load at RouterC (60%). Rate adjusted 375.2 → 425.2
#   User2: Moderate load at RouterC (60%). Rate adjusted 375.2 → 425.2
#   User3: Moderate load at RouterC (60%). Rate adjusted 375.2 → 425.2
#   User4: Moderate load at RouterC (60%). Rate adjusted 375.2 → 425.2
#
# ⏱️ Time step 1140 sec:
#   User1: Moderate load at RouterC (71%). Rate adjusted 425.2 → 475.2
#   User2: Moderate load at RouterC (71%). Rate adjusted 425.2 → 475.2
#   User3: Moderate load at RouterC (71%). Rate adjusted 425.2 → 475.2
#   User4: Moderate load at RouterC (71%). Rate adjusted 425.2 → 475.2
#
# ⏱️ Time step 1150 sec:
#   User1: High congestion at RouterC (91%). Rate reduced 475.2 → 237.6
#   User2: High congestion at RouterC (91%). Rate reduced 475.2 → 237.6
#   User3: High congestion at RouterC (91%). Rate reduced 475.2 → 237.6
#   User4: High congestion at RouterC (91%). Rate reduced 475.2 → 237.6
#
# ⏱️ Time step 1160 sec:
#   User1: High congestion at RouterA (98%). Rate reduced 237.6 → 118.8
#   User2: High congestion at RouterA (98%). Rate reduced 237.6 → 118.8
#   User3: High congestion at RouterA (98%). Rate reduced 237.6 → 118.8
#   User4: High congestion at RouterA (98%). Rate reduced 237.6 → 118.8
#
# ⏱️ Time step 1170 sec:
#   User1: High congestion at RouterB (92%). Rate reduced 118.8 → 59.4
#   User2: High congestion at RouterB (92%). Rate reduced 118.8 → 59.4
#   User3: High congestion at RouterB (92%). Rate reduced 118.8 → 59.4
#   User4: High congestion at RouterB (92%). Rate reduced 118.8 → 59.4
#
# ⏱️ Time step 1180 sec:
#   User1: Moderate load at RouterB (65%). Rate adjusted 59.4 → 109.4
#   User2: Moderate load at RouterB (65%). Rate adjusted 59.4 → 109.4
#   User3: Moderate load at RouterB (65%). Rate adjusted 59.4 → 109.4
#   User4: Moderate load at RouterB (65%). Rate adjusted 59.4 → 109.4
#
# ⏱️ Time step 1190 sec:
#   User1: Moderate load at RouterA (73%). Rate adjusted 109.4 → 159.4
#   User2: Moderate load at RouterA (73%). Rate adjusted 109.4 → 159.4
#   User3: Moderate load at RouterA (73%). Rate adjusted 109.4 → 159.4
#   User4: Moderate load at RouterA (73%). Rate adjusted 109.4 → 159.4
#
# ⏱️ Time step 1200 sec:
#   User1: Moderate load at RouterA (76%). Rate adjusted 159.4 → 209.4
#   User2: Moderate load at RouterA (76%). Rate adjusted 159.4 → 209.4
#   User3: Moderate load at RouterA (76%). Rate adjusted 159.4 → 209.4
#   User4: Moderate load at RouterA (76%). Rate adjusted 159.4 → 209.4
#
# ⏱️ Time step 1210 sec:
#   User1: Moderate load at RouterA (74%). Rate adjusted 209.4 → 259.4
#   User2: Moderate load at RouterA (74%). Rate adjusted 209.4 → 259.4
#   User3: Moderate load at RouterA (74%). Rate adjusted 209.4 → 259.4
#   User4: Moderate load at RouterA (74%). Rate adjusted 209.4 → 259.4
#
# ⏱️ Time step 1220 sec:
#   User1: Moderate load at RouterB (54%). Rate adjusted 259.4 → 309.4
#   User2: Moderate load at RouterB (54%). Rate adjusted 259.4 → 309.4
#   User3: Moderate load at RouterB (54%). Rate adjusted 259.4 → 309.4
#   User4: Moderate load at RouterB (54%). Rate adjusted 259.4 → 309.4
#
# ⏱️ Time step 1230 sec:
#   User1: High congestion at RouterB (98%). Rate reduced 309.4 → 154.7
#   User2: High congestion at RouterB (98%). Rate reduced 309.4 → 154.7
#   User3: High congestion at RouterB (98%). Rate reduced 309.4 → 154.7
#   User4: High congestion at RouterB (98%). Rate reduced 309.4 → 154.7
#
# ⏱️ Time step 1240 sec:
#   User1: Moderate load at RouterB (69%). Rate adjusted 154.7 → 204.7
#   User2: Moderate load at RouterB (69%). Rate adjusted 154.7 → 204.7
#   User3: Moderate load at RouterB (69%). Rate adjusted 154.7 → 204.7
#   User4: Moderate load at RouterB (69%). Rate adjusted 154.7 → 204.7
#
# ⏱️ Time step 1250 sec:
#   User1: Moderate load at RouterC (50%). Rate adjusted 204.7 → 254.7
#   User2: Moderate load at RouterC (50%). Rate adjusted 204.7 → 254.7
#   User3: Moderate load at RouterC (50%). Rate adjusted 204.7 → 254.7
#   User4: Moderate load at RouterC (50%). Rate adjusted 204.7 → 254.7
#
# ⏱️ Time step 1260 sec:
#   User1: Moderate load at RouterA (68%). Rate adjusted 254.7 → 304.7
#   User2: Moderate load at RouterA (68%). Rate adjusted 254.7 → 304.7
#   User3: Moderate load at RouterA (68%). Rate adjusted 254.7 → 304.7
#   User4: Moderate load at RouterA (68%). Rate adjusted 254.7 → 304.7
#
# ⏱️ Time step 1270 sec:
#   User1: Moderate load at RouterA (70%). Rate adjusted 304.7 → 354.7
#   User2: Moderate load at RouterA (70%). Rate adjusted 304.7 → 354.7
#   User3: Moderate load at RouterA (70%). Rate adjusted 304.7 → 354.7
#   User4: Moderate load at RouterA (70%). Rate adjusted 304.7 → 354.7
#
# ⏱️ Time step 1280 sec:
#   User1: High congestion at RouterC (94%). Rate reduced 354.7 → 177.4
#   User2: High congestion at RouterC (94%). Rate reduced 354.7 → 177.4
#   User3: High congestion at RouterC (94%). Rate reduced 354.7 → 177.4
#   User4: High congestion at RouterC (94%). Rate reduced 354.7 → 177.4
#
# ⏱️ Time step 1290 sec:
#   User1: High congestion at RouterA (99%). Rate reduced 177.4 → 88.7
#   User2: High congestion at RouterA (99%). Rate reduced 177.4 → 88.7
#   User3: High congestion at RouterA (99%). Rate reduced 177.4 → 88.7
#   User4: High congestion at RouterA (99%). Rate reduced 177.4 → 88.7
#
# ⏱️ Time step 1300 sec:
#   User1: Low load at RouterB (40%). Rate increased 88.7 → 188.7
#   User2: Low load at RouterB (40%). Rate increased 88.7 → 188.7
#   User3: Low load at RouterB (40%). Rate increased 88.7 → 188.7
#   User4: Low load at RouterB (40%). Rate increased 88.7 → 188.7
#
# ⏱️ Time step 1310 sec:
#   User1: Moderate load at RouterC (74%). Rate adjusted 188.7 → 238.7
#   User2: Moderate load at RouterC (74%). Rate adjusted 188.7 → 238.7
#   User3: Moderate load at RouterC (74%). Rate adjusted 188.7 → 238.7
#   User4: Moderate load at RouterC (74%). Rate adjusted 188.7 → 238.7
#
# ⏱️ Time step 1320 sec:
#   User1: High congestion at RouterB (96%). Rate reduced 238.7 → 119.3
#   User2: High congestion at RouterB (96%). Rate reduced 238.7 → 119.3
#   User3: High congestion at RouterB (96%). Rate reduced 238.7 → 119.3
#   User4: High congestion at RouterB (96%). Rate reduced 238.7 → 119.3
#
# ⏱️ Time step 1330 sec:
#   User1: High congestion at RouterA (89%). Rate reduced 119.3 → 59.7
#   User2: High congestion at RouterA (89%). Rate reduced 119.3 → 59.7
#   User3: High congestion at RouterA (89%). Rate reduced 119.3 → 59.7
#   User4: High congestion at RouterA (89%). Rate reduced 119.3 → 59.7
#
# ⏱️ Time step 1340 sec:
#   User1: Low load at RouterA (40%). Rate increased 59.7 → 159.7
#   User2: Low load at RouterA (40%). Rate increased 59.7 → 159.7
#   User3: Low load at RouterA (40%). Rate increased 59.7 → 159.7
#   User4: Low load at RouterA (40%). Rate increased 59.7 → 159.7
#
# ⏱️ Time step 1350 sec:
#   User1: Moderate load at RouterA (74%). Rate adjusted 159.7 → 209.7
#   User2: Moderate load at RouterA (74%). Rate adjusted 159.7 → 209.7
#   User3: Moderate load at RouterA (74%). Rate adjusted 159.7 → 209.7
#   User4: Moderate load at RouterA (74%). Rate adjusted 159.7 → 209.7
#
# ⏱️ Time step 1360 sec:
#   User1: Moderate load at RouterA (68%). Rate adjusted 209.7 → 259.7
#   User2: Moderate load at RouterA (68%). Rate adjusted 209.7 → 259.7
#   User3: Moderate load at RouterA (68%). Rate adjusted 209.7 → 259.7
#   User4: Moderate load at RouterA (68%). Rate adjusted 209.7 → 259.7
#
# ⏱️ Time step 1370 sec:
#   User1: High congestion at RouterA (95%). Rate reduced 259.7 → 129.8
#   User2: High congestion at RouterA (95%). Rate reduced 259.7 → 129.8
#   User3: High congestion at RouterA (95%). Rate reduced 259.7 → 129.8
#   User4: High congestion at RouterA (95%). Rate reduced 259.7 → 129.8
#
# ⏱️ Time step 1380 sec:
#   User1: High congestion at RouterB (91%). Rate reduced 129.8 → 64.9
#   User2: High congestion at RouterB (91%). Rate reduced 129.8 → 64.9
#   User3: High congestion at RouterB (91%). Rate reduced 129.8 → 64.9
#   User4: High congestion at RouterB (91%). Rate reduced 129.8 → 64.9
#
# ⏱️ Time step 1390 sec:
#   User1: High congestion at RouterA (99%). Rate reduced 64.9 → 32.5
#   User2: High congestion at RouterA (99%). Rate reduced 64.9 → 32.5
#   User3: High congestion at RouterA (99%). Rate reduced 64.9 → 32.5
#   User4: High congestion at RouterA (99%). Rate reduced 64.9 → 32.5
#
# ⏱️ Time step 1400 sec:
#   User1: Moderate load at RouterB (72%). Rate adjusted 32.5 → 82.5
#   User2: Moderate load at RouterB (72%). Rate adjusted 32.5 → 82.5
#   User3: Moderate load at RouterB (72%). Rate adjusted 32.5 → 82.5
#   User4: Moderate load at RouterB (72%). Rate adjusted 32.5 → 82.5
#
# ⏱️ Time step 1410 sec:
#   User1: High congestion at RouterC (93%). Rate reduced 82.5 → 41.2
#   User2: High congestion at RouterC (93%). Rate reduced 82.5 → 41.2
#   User3: High congestion at RouterC (93%). Rate reduced 82.5 → 41.2
#   User4: High congestion at RouterC (93%). Rate reduced 82.5 → 41.2
#
# ⏱️ Time step 1420 sec:
#   User1: High congestion at RouterC (91%). Rate reduced 41.2 → 20.6
#   User2: High congestion at RouterC (91%). Rate reduced 41.2 → 20.6
#   User3: High congestion at RouterC (91%). Rate reduced 41.2 → 20.6
#   User4: High congestion at RouterC (91%). Rate reduced 41.2 → 20.6
#
# ⏱️ Time step 1430 sec:
#   User1: High congestion at RouterA (89%). Rate reduced 20.6 → 10.3
#   User2: High congestion at RouterA (89%). Rate reduced 20.6 → 10.3
#   User3: High congestion at RouterA (89%). Rate reduced 20.6 → 10.3
#   User4: High congestion at RouterA (89%). Rate reduced 20.6 → 10.3
#
# ⏱️ Time step 1440 sec:
#   User1: High congestion at RouterC (88%). Rate reduced 10.3 → 5.2
#   User2: High congestion at RouterC (88%). Rate reduced 10.3 → 5.2
#   User3: High congestion at RouterC (88%). Rate reduced 10.3 → 5.2
#   User4: High congestion at RouterC (88%). Rate reduced 10.3 → 5.2
#
# ⏱️ Time step 1450 sec:
#   User1: Moderate load at RouterC (71%). Rate adjusted 5.2 → 55.2
#   User2: Moderate load at RouterC (71%). Rate adjusted 5.2 → 55.2
#   User3: Moderate load at RouterC (71%). Rate adjusted 5.2 → 55.2
#   User4: Moderate load at RouterC (71%). Rate adjusted 5.2 → 55.2
#
# ⏱️ Time step 1460 sec:
#   User1: High congestion at RouterA (82%). Rate reduced 55.2 → 27.6
#   User2: High congestion at RouterA (82%). Rate reduced 55.2 → 27.6
#   User3: High congestion at RouterA (82%). Rate reduced 55.2 → 27.6
#   User4: High congestion at RouterA (82%). Rate reduced 55.2 → 27.6
#
# ⏱️ Time step 1470 sec:
#   User1: Low load at RouterC (29%). Rate increased 27.6 → 127.6
#   User2: Low load at RouterC (29%). Rate increased 27.6 → 127.6
#   User3: Low load at RouterC (29%). Rate increased 27.6 → 127.6
#   User4: Low load at RouterC (29%). Rate increased 27.6 → 127.6
#
# ⏱️ Time step 1480 sec:
#   User1: Moderate load at RouterA (74%). Rate adjusted 127.6 → 177.6
#   User2: Moderate load at RouterA (74%). Rate adjusted 127.6 → 177.6
#   User3: Moderate load at RouterA (74%). Rate adjusted 127.6 → 177.6
#   User4: Moderate load at RouterA (74%). Rate adjusted 127.6 → 177.6
#
# ⏱️ Time step 1490 sec:
#   User1: Moderate load at RouterA (79%). Rate adjusted 177.6 → 227.6
#   User2: Moderate load at RouterA (79%). Rate adjusted 177.6 → 227.6
#   User3: Moderate load at RouterA (79%). Rate adjusted 177.6 → 227.6
#   User4: Moderate load at RouterA (79%). Rate adjusted 177.6 → 227.6
#
# ⏱️ Time step 1500 sec:
#   User1: Moderate load at RouterB (75%). Rate adjusted 227.6 → 277.6
#   User2: Moderate load at RouterB (75%). Rate adjusted 227.6 → 277.6
#   User3: Moderate load at RouterB (75%). Rate adjusted 227.6 → 277.6
#   User4: Moderate load at RouterB (75%). Rate adjusted 227.6 → 277.6
#
# ⏱️ Time step 1510 sec:
#   User1: High congestion at RouterA (92%). Rate reduced 277.6 → 138.8
#   User2: High congestion at RouterA (92%). Rate reduced 277.6 → 138.8
#   User3: High congestion at RouterA (92%). Rate reduced 277.6 → 138.8
#   User4: High congestion at RouterA (92%). Rate reduced 277.6 → 138.8
#
# ⏱️ Time step 1520 sec:
#   User1: High congestion at RouterC (87%). Rate reduced 138.8 → 69.4
#   User2: High congestion at RouterC (87%). Rate reduced 138.8 → 69.4
#   User3: High congestion at RouterC (87%). Rate reduced 138.8 → 69.4
#   User4: High congestion at RouterC (87%). Rate reduced 138.8 → 69.4
#
# ⏱️ Time step 1530 sec:
#   User1: Moderate load at RouterA (61%). Rate adjusted 69.4 → 119.4
#   User2: Moderate load at RouterA (61%). Rate adjusted 69.4 → 119.4
#   User3: Moderate load at RouterA (61%). Rate adjusted 69.4 → 119.4
#   User4: Moderate load at RouterA (61%). Rate adjusted 69.4 → 119.4
#
# ⏱️ Time step 1540 sec:
#   User1: Moderate load at RouterB (77%). Rate adjusted 119.4 → 169.4
#   User2: Moderate load at RouterB (77%). Rate adjusted 119.4 → 169.4
#   User3: Moderate load at RouterB (77%). Rate adjusted 119.4 → 169.4
#   User4: Moderate load at RouterB (77%). Rate adjusted 119.4 → 169.4
#
# ⏱️ Time step 1550 sec:
#   User1: High congestion at RouterA (99%). Rate reduced 169.4 → 84.7
#   User2: High congestion at RouterA (99%). Rate reduced 169.4 → 84.7
#   User3: High congestion at RouterA (99%). Rate reduced 169.4 → 84.7
#   User4: High congestion at RouterA (99%). Rate reduced 169.4 → 84.7
#
# ⏱️ Time step 1560 sec:
#   User1: High congestion at RouterB (98%). Rate reduced 84.7 → 42.3
#   User2: High congestion at RouterB (98%). Rate reduced 84.7 → 42.3
#   User3: High congestion at RouterB (98%). Rate reduced 84.7 → 42.3
#   User4: High congestion at RouterB (98%). Rate reduced 84.7 → 42.3
#
# ⏱️ Time step 1570 sec:
#   User1: High congestion at RouterA (93%). Rate reduced 42.3 → 21.2
#   User2: High congestion at RouterA (93%). Rate reduced 42.3 → 21.2
#   User3: High congestion at RouterA (93%). Rate reduced 42.3 → 21.2
#   User4: High congestion at RouterA (93%). Rate reduced 42.3 → 21.2
#
# ⏱️ Time step 1580 sec:
#   User1: High congestion at RouterA (85%). Rate reduced 21.2 → 10.6
#   User2: High congestion at RouterA (85%). Rate reduced 21.2 → 10.6
#   User3: High congestion at RouterA (85%). Rate reduced 21.2 → 10.6
#   User4: High congestion at RouterA (85%). Rate reduced 21.2 → 10.6
#
# ⏱️ Time step 1590 sec:
#   User1: High congestion at RouterB (96%). Rate reduced 10.6 → 5.3
#   User2: High congestion at RouterB (96%). Rate reduced 10.6 → 5.3
#   User3: High congestion at RouterB (96%). Rate reduced 10.6 → 5.3
#   User4: High congestion at RouterB (96%). Rate reduced 10.6 → 5.3
#
# ⏱️ Time step 1600 sec:
#   User1: High congestion at RouterC (87%). Rate reduced 5.3 → 2.6
#   User2: High congestion at RouterC (87%). Rate reduced 5.3 → 2.6
#   User3: High congestion at RouterC (87%). Rate reduced 5.3 → 2.6
#   User4: High congestion at RouterC (87%). Rate reduced 5.3 → 2.6
#
# ⏱️ Time step 1610 sec:
#   User1: High congestion at RouterB (96%). Rate reduced 2.6 → 1.3
#   User2: High congestion at RouterB (96%). Rate reduced 2.6 → 1.3
#   User3: High congestion at RouterB (96%). Rate reduced 2.6 → 1.3
#   User4: High congestion at RouterB (96%). Rate reduced 2.6 → 1.3
#
# ⏱️ Time step 1620 sec:
#   User1: Moderate load at RouterC (58%). Rate adjusted 1.3 → 51.3
#   User2: Moderate load at RouterC (58%). Rate adjusted 1.3 → 51.3
# ...
#   User1: High congestion at RouterC (94%). Rate reduced 10.4 → 5.2
#   User2: High congestion at RouterC (94%). Rate reduced 10.4 → 5.2
#   User3: High congestion at RouterC (94%). Rate reduced 10.4 → 5.2
#   User4: High congestion at RouterC (94%). Rate reduced 10.4 → 5.2
#
# ⏱️ Time step 6470 sec:
#   User1: High congestion at RouterB (96%). Rate reduced 5.2 → 2.6
#   User2: High congestion at RouterB (96%). Rate reduced 5.2 → 2.6
#   User3: High congestion at RouterB (96%). Rate reduced 5.2 → 2.6
#   User4: High congestion at RouterB (96%). Rate reduced 5.2 → 2.6
#
# ⏱️ Time step 6480 sec:
#   User1: Moderate load at RouterB (71%). Rate adjusted 2.6 → 52.6
#   User2: Moderate load at RouterB (71%). Rate adjusted 2.6 → 52.6
#   User3: Moderate load at RouterB (71%). Rate adjusted 2.6 → 52.6
#   User4: Moderate load at RouterB (71%). Rate adjusted 2.6 → 52.6
#
# ⏱️ Time step 6490 sec:
#   User1: Moderate load at RouterC (76%). Rate adjusted 52.6 → 102.6
#   User2: Moderate load at RouterC (76%). Rate adjusted 52.6 → 102.6
#   User3: Moderate load at RouterC (76%). Rate adjusted 52.6 → 102.6
#   User4: Moderate load at RouterC (76%). Rate adjusted 52.6 → 102.6
#
# ⏱️ Time step 6500 sec:
#   User1: Moderate load at RouterB (54%). Rate adjusted 102.6 → 152.6
#   User2: Moderate load at RouterB (54%). Rate adjusted 102.6 → 152.6
#   User3: Moderate load at RouterB (54%). Rate adjusted 102.6 → 152.6
#   User4: Moderate load at RouterB (54%). Rate adjusted 102.6 → 152.6
#
# ⏱️ Time step 6510 sec:
#   User1: Moderate load at RouterB (68%). Rate adjusted 152.6 → 202.6
#   User2: Moderate load at RouterB (68%). Rate adjusted 152.6 → 202.6
#   User3: Moderate load at RouterB (68%). Rate adjusted 152.6 → 202.6
#   User4: Moderate load at RouterB (68%). Rate adjusted 152.6 → 202.6
#
# ⏱️ Time step 6520 sec:
#   User1: High congestion at RouterC (83%). Rate reduced 202.6 → 101.3
#   User2: High congestion at RouterC (83%). Rate reduced 202.6 → 101.3
#   User3: High congestion at RouterC (83%). Rate reduced 202.6 → 101.3
#   User4: High congestion at RouterC (83%). Rate reduced 202.6 → 101.3
#
# ⏱️ Time step 6530 sec:
#   User1: Moderate load at RouterA (61%). Rate adjusted 101.3 → 151.3
#   User2: Moderate load at RouterA (61%). Rate adjusted 101.3 → 151.3
#   User3: Moderate load at RouterA (61%). Rate adjusted 101.3 → 151.3
#   User4: Moderate load at RouterA (61%). Rate adjusted 101.3 → 151.3
#
# ⏱️ Time step 6540 sec:
#   User1: High congestion at RouterC (90%). Rate reduced 151.3 → 75.7
#   User2: High congestion at RouterC (90%). Rate reduced 151.3 → 75.7
#   User3: High congestion at RouterC (90%). Rate reduced 151.3 → 75.7
#   User4: High congestion at RouterC (90%). Rate reduced 151.3 → 75.7
#
# ⏱️ Time step 6550 sec:
#   User1: High congestion at RouterA (88%). Rate reduced 75.7 → 37.8
#   User2: High congestion at RouterA (88%). Rate reduced 75.7 → 37.8
#   User3: High congestion at RouterA (88%). Rate reduced 75.7 → 37.8
#   User4: High congestion at RouterA (88%). Rate reduced 75.7 → 37.8
#
# ⏱️ Time step 6560 sec:
#   User1: Moderate load at RouterC (74%). Rate adjusted 37.8 → 87.8
#   User2: Moderate load at RouterC (74%). Rate adjusted 37.8 → 87.8
#   User3: Moderate load at RouterC (74%). Rate adjusted 37.8 → 87.8
#   User4: Moderate load at RouterC (74%). Rate adjusted 37.8 → 87.8
#
# ⏱️ Time step 6570 sec:
#   User1: High congestion at RouterA (82%). Rate reduced 87.8 → 43.9
#   User2: High congestion at RouterA (82%). Rate reduced 87.8 → 43.9
#   User3: High congestion at RouterA (82%). Rate reduced 87.8 → 43.9
#   User4: High congestion at RouterA (82%). Rate reduced 87.8 → 43.9
#
# ⏱️ Time step 6580 sec:
#   User1: Low load at RouterC (30%). Rate increased 43.9 → 143.9
#   User2: Low load at RouterC (30%). Rate increased 43.9 → 143.9
#   User3: Low load at RouterC (30%). Rate increased 43.9 → 143.9
#   User4: Low load at RouterC (30%). Rate increased 43.9 → 143.9
#
# ⏱️ Time step 6590 sec:
#   User1: Moderate load at RouterA (63%). Rate adjusted 143.9 → 193.9
#   User2: Moderate load at RouterA (63%). Rate adjusted 143.9 → 193.9
#   User3: Moderate load at RouterA (63%). Rate adjusted 143.9 → 193.9
#   User4: Moderate load at RouterA (63%). Rate adjusted 143.9 → 193.9
#
# ⏱️ Time step 6600 sec:
#   User1: High congestion at RouterA (91%). Rate reduced 193.9 → 97.0
#   User2: High congestion at RouterA (91%). Rate reduced 193.9 → 97.0
#   User3: High congestion at RouterA (91%). Rate reduced 193.9 → 97.0
#   User4: High congestion at RouterA (91%). Rate reduced 193.9 → 97.0
#
# ⏱️ Time step 6610 sec:
#   User1: High congestion at RouterC (90%). Rate reduced 97.0 → 48.5
#   User2: High congestion at RouterC (90%). Rate reduced 97.0 → 48.5
#   User3: High congestion at RouterC (90%). Rate reduced 97.0 → 48.5
#   User4: High congestion at RouterC (90%). Rate reduced 97.0 → 48.5
#
# ⏱️ Time step 6620 sec:
#   User1: High congestion at RouterB (87%). Rate reduced 48.5 → 24.2
#   User2: High congestion at RouterB (87%). Rate reduced 48.5 → 24.2
#   User3: High congestion at RouterB (87%). Rate reduced 48.5 → 24.2
#   User4: High congestion at RouterB (87%). Rate reduced 48.5 → 24.2
#
# ⏱️ Time step 6630 sec:
#   User1: High congestion at RouterC (91%). Rate reduced 24.2 → 12.1
#   User2: High congestion at RouterC (91%). Rate reduced 24.2 → 12.1
#   User3: High congestion at RouterC (91%). Rate reduced 24.2 → 12.1
#   User4: High congestion at RouterC (91%). Rate reduced 24.2 → 12.1
#
# ⏱️ Time step 6640 sec:
#   User1: Moderate load at RouterC (55%). Rate adjusted 12.1 → 62.1
#   User2: Moderate load at RouterC (55%). Rate adjusted 12.1 → 62.1
#   User3: Moderate load at RouterC (55%). Rate adjusted 12.1 → 62.1
#   User4: Moderate load at RouterC (55%). Rate adjusted 12.1 → 62.1
#
# ⏱️ Time step 6650 sec:
#   User1: High congestion at RouterC (91%). Rate reduced 62.1 → 31.1
#   User2: High congestion at RouterC (91%). Rate reduced 62.1 → 31.1
#   User3: High congestion at RouterC (91%). Rate reduced 62.1 → 31.1
#   User4: High congestion at RouterC (91%). Rate reduced 62.1 → 31.1
#
# ⏱️ Time step 6660 sec:
#   User1: High congestion at RouterC (96%). Rate reduced 31.1 → 15.5
#   User2: High congestion at RouterC (96%). Rate reduced 31.1 → 15.5
#   User3: High congestion at RouterC (96%). Rate reduced 31.1 → 15.5
#   User4: High congestion at RouterC (96%). Rate reduced 31.1 → 15.5
#
# ⏱️ Time step 6670 sec:
#   User1: Moderate load at RouterC (65%). Rate adjusted 15.5 → 65.5
#   User2: Moderate load at RouterC (65%). Rate adjusted 15.5 → 65.5
#   User3: Moderate load at RouterC (65%). Rate adjusted 15.5 → 65.5
#   User4: Moderate load at RouterC (65%). Rate adjusted 15.5 → 65.5
#
# ⏱️ Time step 6680 sec:
#   User1: Moderate load at RouterA (76%). Rate adjusted 65.5 → 115.5
#   User2: Moderate load at RouterA (76%). Rate adjusted 65.5 → 115.5
#   User3: Moderate load at RouterA (76%). Rate adjusted 65.5 → 115.5
#   User4: Moderate load at RouterA (76%). Rate adjusted 65.5 → 115.5
#
# ⏱️ Time step 6690 sec:
#   User1: Moderate load at RouterC (61%). Rate adjusted 115.5 → 165.5
#   User2: Moderate load at RouterC (61%). Rate adjusted 115.5 → 165.5
#   User3: Moderate load at RouterC (61%). Rate adjusted 115.5 → 165.5
#   User4: Moderate load at RouterC (61%). Rate adjusted 115.5 → 165.5
#
# ⏱️ Time step 6700 sec:
#   User1: High congestion at RouterC (91%). Rate reduced 165.5 → 82.8
#   User2: High congestion at RouterC (91%). Rate reduced 165.5 → 82.8
#   User3: High congestion at RouterC (91%). Rate reduced 165.5 → 82.8
#   User4: High congestion at RouterC (91%). Rate reduced 165.5 → 82.8
#
# ⏱️ Time step 6710 sec:
#   User1: High congestion at RouterB (89%). Rate reduced 82.8 → 41.4
#   User2: High congestion at RouterB (89%). Rate reduced 82.8 → 41.4
#   User3: High congestion at RouterB (89%). Rate reduced 82.8 → 41.4
#   User4: High congestion at RouterB (89%). Rate reduced 82.8 → 41.4
#
# ⏱️ Time step 6720 sec:
#   User1: Moderate load at RouterA (72%). Rate adjusted 41.4 → 91.4
#   User2: Moderate load at RouterA (72%). Rate adjusted 41.4 → 91.4
#   User3: Moderate load at RouterA (72%). Rate adjusted 41.4 → 91.4
#   User4: Moderate load at RouterA (72%). Rate adjusted 41.4 → 91.4
#
# ⏱️ Time step 6730 sec:
#   User1: Moderate load at RouterA (79%). Rate adjusted 91.4 → 141.4
#   User2: Moderate load at RouterA (79%). Rate adjusted 91.4 → 141.4
#   User3: Moderate load at RouterA (79%). Rate adjusted 91.4 → 141.4
#   User4: Moderate load at RouterA (79%). Rate adjusted 91.4 → 141.4
#
# ⏱️ Time step 6740 sec:
#   User1: Moderate load at RouterC (74%). Rate adjusted 141.4 → 191.4
#   User2: Moderate load at RouterC (74%). Rate adjusted 141.4 → 191.4
#   User3: Moderate load at RouterC (74%). Rate adjusted 141.4 → 191.4
#   User4: Moderate load at RouterC (74%). Rate adjusted 141.4 → 191.4
#
# ⏱️ Time step 6750 sec:
#   User1: High congestion at RouterB (90%). Rate reduced 191.4 → 95.7
#   User2: High congestion at RouterB (90%). Rate reduced 191.4 → 95.7
#   User3: High congestion at RouterB (90%). Rate reduced 191.4 → 95.7
#   User4: High congestion at RouterB (90%). Rate reduced 191.4 → 95.7
#
# ⏱️ Time step 6760 sec:
#   User1: Moderate load at RouterA (69%). Rate adjusted 95.7 → 145.7
#   User2: Moderate load at RouterA (69%). Rate adjusted 95.7 → 145.7
#   User3: Moderate load at RouterA (69%). Rate adjusted 95.7 → 145.7
#   User4: Moderate load at RouterA (69%). Rate adjusted 95.7 → 145.7
#
# ⏱️ Time step 6770 sec:
#   User1: Moderate load at RouterB (66%). Rate adjusted 145.7 → 195.7
#   User2: Moderate load at RouterB (66%). Rate adjusted 145.7 → 195.7
#   User3: Moderate load at RouterB (66%). Rate adjusted 145.7 → 195.7
#   User4: Moderate load at RouterB (66%). Rate adjusted 145.7 → 195.7
#
# ⏱️ Time step 6780 sec:
#   User1: Moderate load at RouterA (58%). Rate adjusted 195.7 → 245.7
#   User2: Moderate load at RouterA (58%). Rate adjusted 195.7 → 245.7
#   User3: Moderate load at RouterA (58%). Rate adjusted 195.7 → 245.7
#   User4: Moderate load at RouterA (58%). Rate adjusted 195.7 → 245.7
#
# ⏱️ Time step 6790 sec:
#   User1: Moderate load at RouterC (65%). Rate adjusted 245.7 → 295.7
#   User2: Moderate load at RouterC (65%). Rate adjusted 245.7 → 295.7
#   User3: Moderate load at RouterC (65%). Rate adjusted 245.7 → 295.7
#   User4: Moderate load at RouterC (65%). Rate adjusted 245.7 → 295.7
#
# ⏱️ Time step 6800 sec:
#   User1: Moderate load at RouterB (51%). Rate adjusted 295.7 → 345.7
#   User2: Moderate load at RouterB (51%). Rate adjusted 295.7 → 345.7
#   User3: Moderate load at RouterB (51%). Rate adjusted 295.7 → 345.7
#   User4: Moderate load at RouterB (51%). Rate adjusted 295.7 → 345.7
#
# ⏱️ Time step 6810 sec:
#   User1: High congestion at RouterC (100%). Rate reduced 345.7 → 172.8
#   User2: High congestion at RouterC (100%). Rate reduced 345.7 → 172.8
#   User3: High congestion at RouterC (100%). Rate reduced 345.7 → 172.8
#   User4: High congestion at RouterC (100%). Rate reduced 345.7 → 172.8
#
# ⏱️ Time step 6820 sec:
#   User1: High congestion at RouterA (82%). Rate reduced 172.8 → 86.4
#   User2: High congestion at RouterA (82%). Rate reduced 172.8 → 86.4
#   User3: High congestion at RouterA (82%). Rate reduced 172.8 → 86.4
#   User4: High congestion at RouterA (82%). Rate reduced 172.8 → 86.4
#
# ⏱️ Time step 6830 sec:
#   User1: Moderate load at RouterA (56%). Rate adjusted 86.4 → 136.4
#   User2: Moderate load at RouterA (56%). Rate adjusted 86.4 → 136.4
#   User3: Moderate load at RouterA (56%). Rate adjusted 86.4 → 136.4
#   User4: Moderate load at RouterA (56%). Rate adjusted 86.4 → 136.4
#
# ⏱️ Time step 6840 sec:
#   User1: Moderate load at RouterA (78%). Rate adjusted 136.4 → 186.4
#   User2: Moderate load at RouterA (78%). Rate adjusted 136.4 → 186.4
#   User3: Moderate load at RouterA (78%). Rate adjusted 136.4 → 186.4
#   User4: Moderate load at RouterA (78%). Rate adjusted 136.4 → 186.4
#
# ⏱️ Time step 6850 sec:
#   User1: High congestion at RouterA (89%). Rate reduced 186.4 → 93.2
#   User2: High congestion at RouterA (89%). Rate reduced 186.4 → 93.2
#   User3: High congestion at RouterA (89%). Rate reduced 186.4 → 93.2
#   User4: High congestion at RouterA (89%). Rate reduced 186.4 → 93.2
#
# ⏱️ Time step 6860 sec:
#   User1: Moderate load at RouterA (78%). Rate adjusted 93.2 → 143.2
#   User2: Moderate load at RouterA (78%). Rate adjusted 93.2 → 143.2
#   User3: Moderate load at RouterA (78%). Rate adjusted 93.2 → 143.2
#   User4: Moderate load at RouterA (78%). Rate adjusted 93.2 → 143.2
#
# ⏱️ Time step 6870 sec:
#   User1: High congestion at RouterC (95%). Rate reduced 143.2 → 71.6
#   User2: High congestion at RouterC (95%). Rate reduced 143.2 → 71.6
#   User3: High congestion at RouterC (95%). Rate reduced 143.2 → 71.6
#   User4: High congestion at RouterC (95%). Rate reduced 143.2 → 71.6
#
# ⏱️ Time step 6880 sec:
#   User1: Low load at RouterA (42%). Rate increased 71.6 → 171.6
#   User2: Low load at RouterA (42%). Rate increased 71.6 → 171.6
#   User3: Low load at RouterA (42%). Rate increased 71.6 → 171.6
#   User4: Low load at RouterA (42%). Rate increased 71.6 → 171.6
#
# ⏱️ Time step 6890 sec:
#   User1: Moderate load at RouterB (68%). Rate adjusted 171.6 → 221.6
#   User2: Moderate load at RouterB (68%). Rate adjusted 171.6 → 221.6
#   User3: Moderate load at RouterB (68%). Rate adjusted 171.6 → 221.6
#   User4: Moderate load at RouterB (68%). Rate adjusted 171.6 → 221.6
#
# ⏱️ Time step 6900 sec:
#   User1: Moderate load at RouterC (59%). Rate adjusted 221.6 → 271.6
#   User2: Moderate load at RouterC (59%). Rate adjusted 221.6 → 271.6
#   User3: Moderate load at RouterC (59%). Rate adjusted 221.6 → 271.6
#   User4: Moderate load at RouterC (59%). Rate adjusted 221.6 → 271.6
#
# ⏱️ Time step 6910 sec:
#   User1: High congestion at RouterA (95%). Rate reduced 271.6 → 135.8
#   User2: High congestion at RouterA (95%). Rate reduced 271.6 → 135.8
#   User3: High congestion at RouterA (95%). Rate reduced 271.6 → 135.8
#   User4: High congestion at RouterA (95%). Rate reduced 271.6 → 135.8
#
# ⏱️ Time step 6920 sec:
#   User1: High congestion at RouterC (86%). Rate reduced 135.8 → 67.9
#   User2: High congestion at RouterC (86%). Rate reduced 135.8 → 67.9
#   User3: High congestion at RouterC (86%). Rate reduced 135.8 → 67.9
#   User4: High congestion at RouterC (86%). Rate reduced 135.8 → 67.9
#
# ⏱️ Time step 6930 sec:
#   User1: High congestion at RouterB (92%). Rate reduced 67.9 → 34.0
#   User2: High congestion at RouterB (92%). Rate reduced 67.9 → 34.0
#   User3: High congestion at RouterB (92%). Rate reduced 67.9 → 34.0
#   User4: High congestion at RouterB (92%). Rate reduced 67.9 → 34.0
#
# ⏱️ Time step 6940 sec:
#   User1: High congestion at RouterA (99%). Rate reduced 34.0 → 17.0
#   User2: High congestion at RouterA (99%). Rate reduced 34.0 → 17.0
#   User3: High congestion at RouterA (99%). Rate reduced 34.0 → 17.0
#   User4: High congestion at RouterA (99%). Rate reduced 34.0 → 17.0
#
# ⏱️ Time step 6950 sec:
#   User1: Moderate load at RouterA (70%). Rate adjusted 17.0 → 67.0
#   User2: Moderate load at RouterA (70%). Rate adjusted 17.0 → 67.0
#   User3: Moderate load at RouterA (70%). Rate adjusted 17.0 → 67.0
#   User4: Moderate load at RouterA (70%). Rate adjusted 17.0 → 67.0
#
# ⏱️ Time step 6960 sec:
#   User1: Low load at RouterA (37%). Rate increased 67.0 → 167.0
#   User2: Low load at RouterA (37%). Rate increased 67.0 → 167.0
#   User3: Low load at RouterA (37%). Rate increased 67.0 → 167.0
#   User4: Low load at RouterA (37%). Rate increased 67.0 → 167.0
#
# ⏱️ Time step 6970 sec:
#   User1: Low load at RouterA (38%). Rate increased 167.0 → 267.0
#   User2: Low load at RouterA (38%). Rate increased 167.0 → 267.0
#   User3: Low load at RouterA (38%). Rate increased 167.0 → 267.0
#   User4: Low load at RouterA (38%). Rate increased 167.0 → 267.0
#
# ⏱️ Time step 6980 sec:
#   User1: High congestion at RouterB (93%). Rate reduced 267.0 → 133.5
#   User2: High congestion at RouterB (93%). Rate reduced 267.0 → 133.5
#   User3: High congestion at RouterB (93%). Rate reduced 267.0 → 133.5
#   User4: High congestion at RouterB (93%). Rate reduced 267.0 → 133.5
#
# ⏱️ Time step 6990 sec:
#   User1: Moderate load at RouterA (64%). Rate adjusted 133.5 → 183.5
#   User2: Moderate load at RouterA (64%). Rate adjusted 133.5 → 183.5
#   User3: Moderate load at RouterA (64%). Rate adjusted 133.5 → 183.5
#   User4: Moderate load at RouterA (64%). Rate adjusted 133.5 → 183.5

# %%
#BUFFER MANAGEMENT
import pandas as pd

def run_buffer_management(
    congestion_file,
    high_thresh=80,
    moderate_thresh=50,
    timestep=10,
    buffer_capacity=1000  # per router (in packets, arbitrary units)
):
    """
    Simulate buffer management for each router across timesteps.
    Adjusts buffer occupancy and applies drop policies when overloaded.
    """

    # Load congestion data
    df_cong = pd.read_csv(congestion_file)

    # Add Time column if missing
    if "Time" not in df_cong.columns:
        df_cong.insert(0, "Time", [i * timestep for i in range(len(df_cong))])

    expected_cols = {"RouterA", "RouterB", "RouterC"}
    if not expected_cols.issubset(set(df_cong.columns)):
        raise ValueError(f"Congestion CSV must contain {expected_cols}, found {df_cong.columns}")

    # Initialize buffers for routers
    buffers = {"RouterA": 0, "RouterB": 0, "RouterC": 0}

    # Iterate over timesteps
    for _, row in df_cong.iterrows():
        time_label = row["Time"]
        routers = {col: float(row[col]) for col in df_cong.columns if col.startswith("Router")}

        print(f"\n⏱️ Time step {time_label} sec:")

        for r, load in routers.items():
            # Approximate packets arriving proportional to load
            arrivals = int((load / 100) * (buffer_capacity / 2))  

            # Add arrivals to buffer
            buffers[r] += arrivals

            if load >= high_thresh:
                # Tail drop: buffer capped at capacity
                if buffers[r] > buffer_capacity:
                    dropped = buffers[r] - buffer_capacity
                    buffers[r] = buffer_capacity
                    print(f"  {r}: High congestion ({load:.0f}%). Tail drop {dropped} packets.")
                else:
                    print(f"  {r}: High congestion ({load:.0f}%). Buffer at {buffers[r]}/{buffer_capacity}.")
            elif load >= moderate_thresh:
                # Priority drop: drop 20% of arrivals (simulate dropping low-priority traffic)
                drop = int(arrivals * 0.2)
                buffers[r] = max(0, buffers[r] - drop)
                print(f"  {r}: Moderate load ({load:.0f}%). Priority drop {drop} packets. Buffer={buffers[r]}.")
            else:
                # Low load: buffer drains naturally
                drain = int(buffers[r] * 0.3)
                buffers[r] = max(0, buffers[r] - drain)
                print(f"  {r}: Low load ({load:.0f}%). Buffer drains {drain}. Buffer={buffers[r]}.")
run_buffer_management("C:/Users/ASUS/Downloads/router_congestion_int.csv")
# Out:
# ⏱️ Time step 0 sec:
#   RouterA: Low load (1%). Buffer drains 1. Buffer=4.
#   RouterB: Low load (29%). Buffer drains 43. Buffer=102.
#   RouterC: Low load (30%). Buffer drains 45. Buffer=105.
#
# ⏱️ Time step 10 sec:
#   RouterA: Low load (3%). Buffer drains 5. Buffer=14.
#   RouterB: Low load (27%). Buffer drains 71. Buffer=166.
#   RouterC: Moderate load (68%). Priority drop 68 packets. Buffer=377.
#
# ⏱️ Time step 20 sec:
#   RouterA: Low load (35%). Buffer drains 56. Buffer=133.
#   RouterB: Low load (38%). Buffer drains 106. Buffer=250.
#   RouterC: High congestion (90%). Buffer at 827/1000.
#
# ⏱️ Time step 30 sec:
#   RouterA: High congestion (97%). Buffer at 618/1000.
#   RouterB: Moderate load (66%). Priority drop 66 packets. Buffer=514.
#   RouterC: Low load (3%). Buffer drains 252. Buffer=590.
#
# ⏱️ Time step 40 sec:
#   RouterA: Low load (45%). Buffer drains 252. Buffer=591.
#   RouterB: High congestion (94%). Buffer at 984/1000.
#   RouterC: Low load (9%). Buffer drains 190. Buffer=445.
#
# ⏱️ Time step 50 sec:
#   RouterA: Low load (2%). Buffer drains 180. Buffer=421.
#   RouterB: Low load (16%). Buffer drains 319. Buffer=745.
#   RouterC: Low load (31%). Buffer drains 180. Buffer=420.
#
# ⏱️ Time step 60 sec:
#   RouterA: Low load (36%). Buffer drains 180. Buffer=421.
#   RouterB: Low load (9%). Buffer drains 237. Buffer=553.
#   RouterC: Moderate load (62%). Priority drop 62 packets. Buffer=668.
#
# ⏱️ Time step 70 sec:
#   RouterA: Low load (23%). Buffer drains 160. Buffer=376.
#   RouterB: Low load (34%). Buffer drains 216. Buffer=507.
#   RouterC: Low load (29%). Buffer drains 243. Buffer=570.
#
# ⏱️ Time step 80 sec:
#   RouterA: Low load (22%). Buffer drains 145. Buffer=341.
#   RouterB: High congestion (95%). Buffer at 982/1000.
#   RouterC: High congestion (83%). Buffer at 985/1000.
#
# ⏱️ Time step 90 sec:
#   RouterA: Moderate load (56%). Priority drop 56 packets. Buffer=565.
#   RouterB: High congestion (92%). Tail drop 442 packets.
#   RouterC: Low load (13%). Buffer drains 315. Buffer=735.
#
# ⏱️ Time step 100 sec:
#   RouterA: High congestion (99%). Tail drop 60 packets.
#   RouterB: Low load (1%). Buffer drains 301. Buffer=704.
#   RouterC: Low load (30%). Buffer drains 265. Buffer=620.
#
# ⏱️ Time step 110 sec:
#   RouterA: Moderate load (71%). Priority drop 71 packets. Buffer=1284.
#   RouterB: Low load (28%). Buffer drains 253. Buffer=591.
#   RouterC: Moderate load (73%). Priority drop 73 packets. Buffer=912.
#
# ⏱️ Time step 120 sec:
#   RouterA: Low load (30%). Buffer drains 430. Buffer=1004.
#   RouterB: Low load (26%). Buffer drains 216. Buffer=505.
#   RouterC: Low load (32%). Buffer drains 321. Buffer=751.
#
# ⏱️ Time step 130 sec:
#   RouterA: High congestion (96%). Tail drop 484 packets.
#   RouterB: Moderate load (65%). Priority drop 65 packets. Buffer=765.
#   RouterC: Moderate load (65%). Priority drop 65 packets. Buffer=1011.
#
# ⏱️ Time step 140 sec:
#   RouterA: Low load (21%). Buffer drains 331. Buffer=774.
#   RouterB: Low load (38%). Buffer drains 286. Buffer=669.
#   RouterC: Low load (35%). Buffer drains 355. Buffer=831.
#
# ⏱️ Time step 150 sec:
#   RouterA: Moderate load (56%). Priority drop 56 packets. Buffer=998.
#   RouterB: Moderate load (51%). Priority drop 51 packets. Buffer=873.
#   RouterC: Low load (30%). Buffer drains 294. Buffer=687.
#
# ⏱️ Time step 160 sec:
#   RouterA: High congestion (93%). Tail drop 463 packets.
#   RouterB: Low load (12%). Buffer drains 279. Buffer=654.
#   RouterC: Low load (11%). Buffer drains 222. Buffer=520.
#
# ⏱️ Time step 170 sec:
#   RouterA: Low load (10%). Buffer drains 315. Buffer=735.
#   RouterB: High congestion (85%). Tail drop 79 packets.
#   RouterC: Moderate load (53%). Priority drop 53 packets. Buffer=732.
#
# ⏱️ Time step 180 sec:
#   RouterA: High congestion (98%). Tail drop 225 packets.
#   RouterB: Low load (43%). Buffer drains 364. Buffer=851.
#   RouterC: Low load (46%). Buffer drains 288. Buffer=674.
#
# ⏱️ Time step 190 sec:
#   RouterA: High congestion (84%). Tail drop 420 packets.
#   RouterB: Low load (8%). Buffer drains 267. Buffer=624.
#   RouterC: High congestion (97%). Tail drop 159 packets.
#
# ⏱️ Time step 200 sec:
#   RouterA: Low load (2%). Buffer drains 303. Buffer=707.
#   RouterB: Low load (39%). Buffer drains 245. Buffer=574.
#   RouterC: Low load (0%). Buffer drains 300. Buffer=700.
#
# ⏱️ Time step 210 sec:
#   RouterA: Low load (48%). Buffer drains 284. Buffer=663.
#   RouterB: Low load (11%). Buffer drains 188. Buffer=441.
#   RouterC: Low load (31%). Buffer drains 256. Buffer=599.
#
# ⏱️ Time step 220 sec:
#   RouterA: Moderate load (67%). Priority drop 67 packets. Buffer=931.
#   RouterB: Moderate load (71%). Priority drop 71 packets. Buffer=725.
#   RouterC: Low load (30%). Buffer drains 224. Buffer=525.
#
# ⏱️ Time step 230 sec:
#   RouterA: Low load (19%). Buffer drains 307. Buffer=719.
#   RouterB: Moderate load (58%). Priority drop 58 packets. Buffer=957.
#   RouterC: High congestion (97%). Tail drop 10 packets.
#
# ⏱️ Time step 240 sec:
#   RouterA: High congestion (85%). Tail drop 144 packets.
#   RouterB: Moderate load (77%). Priority drop 77 packets. Buffer=1265.
#   RouterC: Moderate load (52%). Priority drop 52 packets. Buffer=1208.
#
# ⏱️ Time step 250 sec:
#   RouterA: High congestion (97%). Tail drop 485 packets.
#   RouterB: High congestion (90%). Tail drop 715 packets.
#   RouterC: High congestion (88%). Tail drop 648 packets.
#
# ⏱️ Time step 260 sec:
#   RouterA: Moderate load (71%). Priority drop 71 packets. Buffer=1284.
#   RouterB: High congestion (91%). Tail drop 455 packets.
#   RouterC: Low load (10%). Buffer drains 315. Buffer=735.
#
# ⏱️ Time step 270 sec:
#   RouterA: Moderate load (61%). Priority drop 61 packets. Buffer=1528.
#   RouterB: Moderate load (79%). Priority drop 79 packets. Buffer=1316.
#   RouterC: High congestion (92%). Tail drop 195 packets.
#
# ⏱️ Time step 280 sec:
#   RouterA: Moderate load (75%). Priority drop 75 packets. Buffer=1828.
#   RouterB: Low load (15%). Buffer drains 417. Buffer=974.
#   RouterC: Low load (41%). Buffer drains 361. Buffer=844.
#
# ⏱️ Time step 290 sec:
#   RouterA: Low load (45%). Buffer drains 615. Buffer=1438.
#   RouterB: Low load (28%). Buffer drains 334. Buffer=780.
#   RouterC: High congestion (98%). Tail drop 334 packets.
#
# ⏱️ Time step 300 sec:
#   RouterA: Low load (45%). Buffer drains 498. Buffer=1165.
#   RouterB: Moderate load (68%). Priority drop 68 packets. Buffer=1052.
#   RouterC: Moderate load (66%). Priority drop 66 packets. Buffer=1264.
#
# ⏱️ Time step 310 sec:
#   RouterA: Moderate load (67%). Priority drop 67 packets. Buffer=1433.
#   RouterB: High congestion (96%). Tail drop 532 packets.
#   RouterC: Moderate load (79%). Priority drop 79 packets. Buffer=1580.
#
# ⏱️ Time step 320 sec:
#   RouterA: Moderate load (62%). Priority drop 62 packets. Buffer=1681.
#   RouterB: Low load (35%). Buffer drains 352. Buffer=823.
#   RouterC: Low load (14%). Buffer drains 495. Buffer=1155.
#
# ⏱️ Time step 330 sec:
#   RouterA: Low load (34%). Buffer drains 555. Buffer=1296.
#   RouterB: Low load (10%). Buffer drains 261. Buffer=612.
#   RouterC: Moderate load (70%). Priority drop 70 packets. Buffer=1435.
#
# ⏱️ Time step 340 sec:
#   RouterA: Low load (36%). Buffer drains 442. Buffer=1034.
#   RouterB: Moderate load (58%). Priority drop 58 packets. Buffer=844.
#   RouterC: Moderate load (77%). Priority drop 77 packets. Buffer=1743.
#
# ⏱️ Time step 350 sec:
#   RouterA: Low load (45%). Buffer drains 377. Buffer=882.
#   RouterB: Moderate load (53%). Priority drop 53 packets. Buffer=1056.
#   RouterC: Moderate load (78%). Priority drop 78 packets. Buffer=2055.
#
# ⏱️ Time step 360 sec:
#   RouterA: Low load (46%). Buffer drains 333. Buffer=779.
#   RouterB: Low load (46%). Buffer drains 385. Buffer=901.
#   RouterC: Low load (20%). Buffer drains 646. Buffer=1509.
#
# ⏱️ Time step 370 sec:
#   RouterA: Low load (26%). Buffer drains 272. Buffer=637.
#   RouterB: Low load (40%). Buffer drains 330. Buffer=771.
#   RouterC: Moderate load (73%). Priority drop 73 packets. Buffer=1801.
#
# ⏱️ Time step 380 sec:
#   RouterA: High congestion (87%). Tail drop 72 packets.
#   RouterB: Moderate load (60%). Priority drop 60 packets. Buffer=1011.
#   RouterC: High congestion (95%). Tail drop 1276 packets.
#
# ⏱️ Time step 390 sec:
#   RouterA: High congestion (94%). Tail drop 470 packets.
#   RouterB: Moderate load (72%). Priority drop 72 packets. Buffer=1299.
#   RouterC: Low load (7%). Buffer drains 310. Buffer=725.
#
# ⏱️ Time step 400 sec:
#   RouterA: Low load (1%). Buffer drains 301. Buffer=704.
#   RouterB: Low load (5%). Buffer drains 397. Buffer=927.
#   RouterC: Low load (33%). Buffer drains 267. Buffer=623.
#
# ⏱️ Time step 410 sec:
#   RouterA: Low load (46%). Buffer drains 280. Buffer=654.
#   RouterB: Moderate load (66%). Priority drop 66 packets. Buffer=1191.
#   RouterC: Low load (40%). Buffer drains 246. Buffer=577.
#
# ⏱️ Time step 420 sec:
#   RouterA: Moderate load (77%). Priority drop 77 packets. Buffer=962.
#   RouterB: High congestion (98%). Tail drop 681 packets.
#   RouterC: Low load (11%). Buffer drains 189. Buffer=443.
#
# ⏱️ Time step 430 sec:
#   RouterA: Low load (4%). Buffer drains 294. Buffer=688.
#   RouterB: High congestion (99%). Tail drop 495 packets.
#   RouterC: High congestion (100%). Buffer at 943/1000.
#
# ⏱️ Time step 440 sec:
#   RouterA: Low load (31%). Buffer drains 252. Buffer=591.
#   RouterB: Moderate load (76%). Priority drop 76 packets. Buffer=1304.
#   RouterC: Moderate load (77%). Priority drop 77 packets. Buffer=1251.
#
# ⏱️ Time step 450 sec:
#   RouterA: Low load (18%). Buffer drains 204. Buffer=477.
#   RouterB: High congestion (98%). Tail drop 794 packets.
#   RouterC: Moderate load (73%). Priority drop 73 packets. Buffer=1543.
#
# ⏱️ Time step 460 sec:
#   RouterA: Low load (9%). Buffer drains 156. Buffer=366.
#   RouterB: Moderate load (55%). Priority drop 55 packets. Buffer=1220.
#   RouterC: Low load (38%). Buffer drains 519. Buffer=1214.
#
# ⏱️ Time step 470 sec:
#   RouterA: Low load (10%). Buffer drains 124. Buffer=292.
#   RouterB: Low load (17%). Buffer drains 391. Buffer=914.
#   RouterC: Moderate load (60%). Priority drop 60 packets. Buffer=1454.
#
# ⏱️ Time step 480 sec:
#   RouterA: Low load (0%). Buffer drains 87. Buffer=205.
#   RouterB: Low load (16%). Buffer drains 298. Buffer=696.
#   RouterC: High congestion (89%). Tail drop 899 packets.
#
# ⏱️ Time step 490 sec:
#   RouterA: Moderate load (73%). Priority drop 73 packets. Buffer=497.
#   RouterB: Moderate load (54%). Priority drop 54 packets. Buffer=912.
#   RouterC: Low load (18%). Buffer drains 327. Buffer=763.
#
# ⏱️ Time step 500 sec:
#   RouterA: Low load (28%). Buffer drains 191. Buffer=446.
#   RouterB: Low load (13%). Buffer drains 293. Buffer=684.
#   RouterC: Moderate load (66%). Priority drop 66 packets. Buffer=1027.
#
# ⏱️ Time step 510 sec:
#   RouterA: Low load (48%). Buffer drains 205. Buffer=481.
#   RouterB: Low load (19%). Buffer drains 233. Buffer=546.
#   RouterC: Low load (43%). Buffer drains 372. Buffer=870.
#
# ⏱️ Time step 520 sec:
#   RouterA: Low load (36%). Buffer drains 198. Buffer=463.
#   RouterB: Moderate load (66%). Priority drop 66 packets. Buffer=810.
#   RouterC: High congestion (93%). Tail drop 335 packets.
#
# ⏱️ Time step 530 sec:
#   RouterA: Low load (3%). Buffer drains 143. Buffer=335.
#   RouterB: Moderate load (59%). Priority drop 59 packets. Buffer=1046.
#   RouterC: Moderate load (62%). Priority drop 62 packets. Buffer=1248.
#
# ⏱️ Time step 540 sec:
#   RouterA: Low load (39%). Buffer drains 159. Buffer=371.
#   RouterB: Low load (17%). Buffer drains 339. Buffer=792.
#   RouterC: Low load (18%). Buffer drains 401. Buffer=937.
#
# ⏱️ Time step 550 sec:
#   RouterA: Moderate load (67%). Priority drop 67 packets. Buffer=639.
#   RouterB: Low load (4%). Buffer drains 243. Buffer=569.
#   RouterC: Moderate load (69%). Priority drop 69 packets. Buffer=1213.
#
# ⏱️ Time step 560 sec:
#   RouterA: Low load (0%). Buffer drains 191. Buffer=448.
#   RouterB: High congestion (98%). Tail drop 59 packets.
#   RouterC: High congestion (94%). Tail drop 683 packets.
#
# ⏱️ Time step 570 sec:
#   RouterA: Low load (26%). Buffer drains 173. Buffer=405.
#   RouterB: Low load (12%). Buffer drains 318. Buffer=742.
#   RouterC: Low load (6%). Buffer drains 309. Buffer=721.
#
# ⏱️ Time step 580 sec:
#   RouterA: Moderate load (66%). Priority drop 66 packets. Buffer=669.
#   RouterB: High congestion (94%). Tail drop 212 packets.
#   RouterC: Low load (38%). Buffer drains 273. Buffer=638.
#
# ⏱️ Time step 590 sec:
#   RouterA: Moderate load (62%). Priority drop 62 packets. Buffer=917.
#   RouterB: Low load (15%). Buffer drains 322. Buffer=753.
#   RouterC: Low load (19%). Buffer drains 219. Buffer=514.
#
# ⏱️ Time step 600 sec:
#   RouterA: High congestion (82%). Tail drop 327 packets.
#   RouterB: Moderate load (72%). Priority drop 72 packets. Buffer=1041.
#   RouterC: Low load (43%). Buffer drains 218. Buffer=511.
#
# ⏱️ Time step 610 sec:
#   RouterA: Low load (43%). Buffer drains 364. Buffer=851.
#   RouterB: High congestion (88%). Tail drop 481 packets.
#   RouterC: Moderate load (59%). Priority drop 59 packets. Buffer=747.
#
# ⏱️ Time step 620 sec:
#   RouterA: Low load (7%). Buffer drains 265. Buffer=621.
#   RouterB: High congestion (96%). Tail drop 480 packets.
#   RouterC: Low load (38%). Buffer drains 281. Buffer=656.
#
# ⏱️ Time step 630 sec:
#   RouterA: Low load (3%). Buffer drains 190. Buffer=446.
#   RouterB: Low load (43%). Buffer drains 364. Buffer=851.
#   RouterC: Low load (38%). Buffer drains 253. Buffer=593.
#
# ⏱️ Time step 640 sec:
#   RouterA: Moderate load (74%). Priority drop 74 packets. Buffer=742.
#   RouterB: High congestion (98%). Tail drop 341 packets.
#   RouterC: Low load (26%). Buffer drains 216. Buffer=507.
#
# ⏱️ Time step 650 sec:
#   RouterA: High congestion (83%). Tail drop 157 packets.
#   RouterB: Low load (6%). Buffer drains 309. Buffer=721.
#   RouterC: Moderate load (70%). Priority drop 70 packets. Buffer=787.
#
# ⏱️ Time step 660 sec:
#   RouterA: Low load (13%). Buffer drains 319. Buffer=746.
#   RouterB: Moderate load (59%). Priority drop 59 packets. Buffer=957.
#   RouterC: Moderate load (77%). Priority drop 77 packets. Buffer=1095.
#
# ⏱️ Time step 670 sec:
#   RouterA: Low load (6%). Buffer drains 232. Buffer=544.
#   RouterB: Low load (18%). Buffer drains 314. Buffer=733.
#   RouterC: Low load (4%). Buffer drains 334. Buffer=781.
#
# ⏱️ Time step 680 sec:
#   RouterA: Low load (44%). Buffer drains 229. Buffer=535.
#   RouterB: High congestion (93%). Tail drop 198 packets.
#   RouterC: Moderate load (63%). Priority drop 63 packets. Buffer=1033.
#
# ⏱️ Time step 690 sec:
#   RouterA: Low load (3%). Buffer drains 165. Buffer=385.
#   RouterB: Moderate load (76%). Priority drop 76 packets. Buffer=1304.
#   RouterC: Moderate load (64%). Priority drop 64 packets. Buffer=1289.
#
# ⏱️ Time step 700 sec:
#   RouterA: Low load (49%). Buffer drains 189. Buffer=441.
#   RouterB: Low load (7%). Buffer drains 401. Buffer=938.
#   RouterC: Moderate load (78%). Priority drop 78 packets. Buffer=1601.
#
# ⏱️ Time step 710 sec:
#   RouterA: Low load (48%). Buffer drains 204. Buffer=477.
#   RouterB: High congestion (100%). Tail drop 438 packets.
#   RouterC: Low load (25%). Buffer drains 517. Buffer=1209.
#
# ⏱️ Time step 720 sec:
#   RouterA: Low load (38%). Buffer drains 200. Buffer=467.
#   RouterB: Low load (38%). Buffer drains 357. Buffer=833.
#   RouterC: Moderate load (65%). Priority drop 65 packets. Buffer=1469.
#
# ⏱️ Time step 730 sec:
#   RouterA: Low load (46%). Buffer drains 209. Buffer=488.
#   RouterB: Moderate load (70%). Priority drop 70 packets. Buffer=1113.
#   RouterC: High congestion (85%). Tail drop 894 packets.
#
# ⏱️ Time step 740 sec:
#   RouterA: Low load (3%). Buffer drains 150. Buffer=353.
#   RouterB: Low load (43%). Buffer drains 398. Buffer=930.
#   RouterC: High congestion (88%). Tail drop 440 packets.
#
# ⏱️ Time step 750 sec:
#   RouterA: Low load (2%). Buffer drains 108. Buffer=255.
#   RouterB: Low load (46%). Buffer drains 348. Buffer=812.
#   RouterC: High congestion (99%). Tail drop 495 packets.
#
# ⏱️ Time step 760 sec:
#   RouterA: Moderate load (52%). Priority drop 52 packets. Buffer=463.
#   RouterB: Low load (2%). Buffer drains 246. Buffer=576.
#   RouterC: Low load (12%). Buffer drains 318. Buffer=742.
#
# ⏱️ Time step 770 sec:
#   RouterA: Low load (32%). Buffer drains 186. Buffer=437.
#   RouterB: Low load (14%). Buffer drains 193. Buffer=453.
#   RouterC: Low load (14%). Buffer drains 243. Buffer=569.
#
# ⏱️ Time step 780 sec:
#   RouterA: Moderate load (74%). Priority drop 74 packets. Buffer=733.
#   RouterB: Low load (27%). Buffer drains 176. Buffer=412.
#   RouterC: High congestion (82%). Buffer at 979/1000.
#
# ⏱️ Time step 790 sec:
#   RouterA: Low load (25%). Buffer drains 257. Buffer=601.
#   RouterB: High congestion (97%). Buffer at 897/1000.
#   RouterC: High congestion (83%). Tail drop 394 packets.
#
# ⏱️ Time step 800 sec:
#   RouterA: High congestion (91%). Tail drop 56 packets.
#   RouterB: Moderate load (73%). Priority drop 73 packets. Buffer=1189.
#   RouterC: High congestion (88%). Tail drop 440 packets.
#
# ⏱️ Time step 810 sec:
#   RouterA: Low load (14%). Buffer drains 321. Buffer=749.
#   RouterB: Low load (24%). Buffer drains 392. Buffer=917.
#   RouterC: Low load (46%). Buffer drains 369. Buffer=861.
#
# ⏱️ Time step 820 sec:
#   RouterA: Moderate load (72%). Priority drop 72 packets. Buffer=1037.
#   RouterB: High congestion (92%). Tail drop 377 packets.
#   RouterC: Low load (7%). Buffer drains 268. Buffer=628.
#
# ⏱️ Time step 830 sec:
#   RouterA: Low load (21%). Buffer drains 342. Buffer=800.
#   RouterB: Low load (15%). Buffer drains 322. Buffer=753.
#   RouterC: Low load (4%). Buffer drains 194. Buffer=454.
#
# ⏱️ Time step 840 sec:
#   RouterA: Moderate load (52%). Priority drop 52 packets. Buffer=1008.
#   RouterB: Low load (6%). Buffer drains 234. Buffer=549.
#   RouterC: High congestion (98%). Buffer at 944/1000.
#
# ⏱️ Time step 850 sec:
#   RouterA: High congestion (95%). Tail drop 483 packets.
#   RouterB: Low load (34%). Buffer drains 215. Buffer=504.
#   RouterC: Moderate load (79%). Priority drop 79 packets. Buffer=1260.
#
# ⏱️ Time step 860 sec:
#   RouterA: Moderate load (65%). Priority drop 65 packets. Buffer=1260.
#   RouterB: Low load (48%). Buffer drains 223. Buffer=521.
#   RouterC: Low load (30%). Buffer drains 423. Buffer=987.
#
# ⏱️ Time step 870 sec:
#   RouterA: Low load (7%). Buffer drains 388. Buffer=907.
#   RouterB: Moderate load (50%). Priority drop 50 packets. Buffer=721.
#   RouterC: Moderate load (50%). Priority drop 50 packets. Buffer=1187.
#
# ⏱️ Time step 880 sec:
#   RouterA: Moderate load (75%). Priority drop 75 packets. Buffer=1207.
#   RouterB: Low load (11%). Buffer drains 232. Buffer=544.
#   RouterC: Moderate load (76%). Priority drop 76 packets. Buffer=1491.
#
# ⏱️ Time step 890 sec:
#   RouterA: Moderate load (76%). Priority drop 76 packets. Buffer=1511.
#   RouterB: Low load (38%). Buffer drains 220. Buffer=514.
#   RouterC: Moderate load (75%). Priority drop 75 packets. Buffer=1791.
#
# ⏱️ Time step 900 sec:
#   RouterA: Low load (42%). Buffer drains 516. Buffer=1205.
#   RouterB: Low load (22%). Buffer drains 187. Buffer=437.
#   RouterC: High congestion (96%). Tail drop 1271 packets.
#
# ⏱️ Time step 910 sec:
#   RouterA: Low load (48%). Buffer drains 433. Buffer=1012.
#   RouterB: Low load (34%). Buffer drains 182. Buffer=425.
#   RouterC: Moderate load (66%). Priority drop 66 packets. Buffer=1264.
#
# ⏱️ Time step 920 sec:
#   RouterA: Low load (22%). Buffer drains 336. Buffer=786.
#   RouterB: Moderate load (78%). Priority drop 78 packets. Buffer=737.
#   RouterC: Moderate load (77%). Priority drop 77 packets. Buffer=1572.
#
# ⏱️ Time step 930 sec:
#   RouterA: Low load (14%). Buffer drains 256. Buffer=600.
#   RouterB: High congestion (97%). Tail drop 222 packets.
#   RouterC: High congestion (98%). Tail drop 1062 packets.
#
# ⏱️ Time step 940 sec:
#   RouterA: Low load (3%). Buffer drains 184. Buffer=431.
#   RouterB: Low load (47%). Buffer drains 370. Buffer=865.
#   RouterC: Low load (31%). Buffer drains 346. Buffer=809.
#
# ⏱️ Time step 950 sec:
#   RouterA: High congestion (84%). Buffer at 851/1000.
#   RouterB: Low load (1%). Buffer drains 261. Buffer=609.
#   RouterC: Low load (34%). Buffer drains 293. Buffer=686.
#
# ⏱️ Time step 960 sec:
#   RouterA: High congestion (95%). Tail drop 326 packets.
#   RouterB: Low load (27%). Buffer drains 223. Buffer=521.
#   RouterC: Low load (28%). Buffer drains 247. Buffer=579.
#
# ⏱️ Time step 970 sec:
#   RouterA: Low load (0%). Buffer drains 300. Buffer=700.
#   RouterB: Low load (44%). Buffer drains 222. Buffer=519.
#   RouterC: High congestion (81%). Buffer at 984/1000.
#
# ⏱️ Time step 980 sec:
#   RouterA: Low load (44%). Buffer drains 276. Buffer=644.
#   RouterB: High congestion (87%). Buffer at 954/1000.
#   RouterC: Low load (14%). Buffer drains 316. Buffer=738.
#
# ⏱️ Time step 990 sec:
#   RouterA: Moderate load (60%). Priority drop 60 packets. Buffer=884.
#   RouterB: Low load (1%). Buffer drains 287. Buffer=672.
#   RouterC: High congestion (89%). Tail drop 183 packets.
#
# ⏱️ Time step 1000 sec:
#   RouterA: Low load (43%). Buffer drains 329. Buffer=770.
#   RouterB: Low load (43%). Buffer drains 266. Buffer=621.
#   RouterC: High congestion (80%). Tail drop 400 packets.
#
# ⏱️ Time step 1010 sec:
#   RouterA: Low load (13%). Buffer drains 250. Buffer=585.
#   RouterB: Low load (18%). Buffer drains 213. Buffer=498.
#   RouterC: High congestion (88%). Tail drop 440 packets.
#
# ⏱️ Time step 1020 sec:
#   RouterA: Low load (18%). Buffer drains 202. Buffer=473.
#   RouterB: Low load (44%). Buffer drains 215. Buffer=503.
#   RouterC: High congestion (82%). Tail drop 410 packets.
#
# ⏱️ Time step 1030 sec:
#   RouterA: Low load (25%). Buffer drains 179. Buffer=419.
#   RouterB: High congestion (92%). Buffer at 963/1000.
#   RouterC: High congestion (84%). Tail drop 420 packets.
#
# ⏱️ Time step 1040 sec:
#   RouterA: Moderate load (50%). Priority drop 50 packets. Buffer=619.
#   RouterB: Moderate load (74%). Priority drop 74 packets. Buffer=1259.
#   RouterC: Moderate load (71%). Priority drop 71 packets. Buffer=1284.
#
# ⏱️ Time step 1050 sec:
#   RouterA: Low load (41%). Buffer drains 247. Buffer=577.
#   RouterB: Low load (32%). Buffer drains 425. Buffer=994.
#   RouterC: Low load (13%). Buffer drains 404. Buffer=945.
#
# ⏱️ Time step 1060 sec:
#   RouterA: Moderate load (70%). Priority drop 70 packets. Buffer=857.
#   RouterB: Low load (16%). Buffer drains 322. Buffer=752.
#   RouterC: Low load (47%). Buffer drains 354. Buffer=826.
#
# ⏱️ Time step 1070 sec:
#   RouterA: Low load (10%). Buffer drains 272. Buffer=635.
#   RouterB: Low load (21%). Buffer drains 257. Buffer=600.
#   RouterC: Low load (31%). Buffer drains 294. Buffer=687.
#
# ⏱️ Time step 1080 sec:
#   RouterA: Low load (14%). Buffer drains 211. Buffer=494.
#   RouterB: Low load (45%). Buffer drains 247. Buffer=578.
#   RouterC: Moderate load (72%). Priority drop 72 packets. Buffer=975.
#
# ⏱️ Time step 1090 sec:
#   RouterA: Moderate load (50%). Priority drop 50 packets. Buffer=694.
#   RouterB: High congestion (96%). Tail drop 58 packets.
#   RouterC: Low load (40%). Buffer drains 352. Buffer=823.
#
# ⏱️ Time step 1100 sec:
#   RouterA: Low load (23%). Buffer drains 242. Buffer=567.
#   RouterB: Moderate load (77%). Priority drop 77 packets. Buffer=1308.
#   RouterC: Moderate load (54%). Priority drop 54 packets. Buffer=1039.
#
# ⏱️ Time step 1110 sec:
#   RouterA: Low load (14%). Buffer drains 191. Buffer=446.
#   RouterB: Low load (40%). Buffer drains 452. Buffer=1056.
#   RouterC: Low load (25%). Buffer drains 349. Buffer=815.
#
# ⏱️ Time step 1120 sec:
#   RouterA: Moderate load (76%). Priority drop 76 packets. Buffer=750.
#   RouterB: Low load (46%). Buffer drains 385. Buffer=901.
#   RouterC: Low load (0%). Buffer drains 244. Buffer=571.
#
# ⏱️ Time step 1130 sec:
#   RouterA: Low load (28%). Buffer drains 267. Buffer=623.
#   RouterB: Low load (40%). Buffer drains 330. Buffer=771.
#   RouterC: Moderate load (60%). Priority drop 60 packets. Buffer=811.
#
# ⏱️ Time step 1140 sec:
#   RouterA: Low load (12%). Buffer drains 204. Buffer=479.
#   RouterB: Low load (44%). Buffer drains 297. Buffer=694.
#   RouterC: Moderate load (71%). Priority drop 71 packets. Buffer=1095.
#
# ⏱️ Time step 1150 sec:
#   RouterA: Moderate load (68%). Priority drop 68 packets. Buffer=751.
#   RouterB: Moderate load (61%). Priority drop 61 packets. Buffer=938.
#   RouterC: High congestion (91%). Tail drop 550 packets.
#
# ⏱️ Time step 1160 sec:
#   RouterA: High congestion (98%). Tail drop 241 packets.
#   RouterB: Moderate load (65%). Priority drop 65 packets. Buffer=1198.
#   RouterC: High congestion (94%). Tail drop 470 packets.
#
# ⏱️ Time step 1170 sec:
#   RouterA: Moderate load (63%). Priority drop 63 packets. Buffer=1252.
#   RouterB: High congestion (92%). Tail drop 658 packets.
#   RouterC: Moderate load (70%). Priority drop 70 packets. Buffer=1280.
#
# ⏱️ Time step 1180 sec:
#   RouterA: Low load (35%). Buffer drains 428. Buffer=999.
#   RouterB: Moderate load (65%). Priority drop 65 packets. Buffer=1260.
#   RouterC: Low load (37%). Buffer drains 439. Buffer=1026.
#
# ⏱️ Time step 1190 sec:
#   RouterA: Moderate load (73%). Priority drop 73 packets. Buffer=1291.
#   RouterB: Low load (25%). Buffer drains 415. Buffer=970.
#   RouterC: Low load (43%). Buffer drains 372. Buffer=869.
#
# ⏱️ Time step 1200 sec:
#   RouterA: Moderate load (76%). Priority drop 76 packets. Buffer=1595.
#   RouterB: Low load (9%). Buffer drains 304. Buffer=711.
#   RouterC: Moderate load (57%). Priority drop 57 packets. Buffer=1097.
#
# ⏱️ Time step 1210 sec:
#   RouterA: Moderate load (74%). Priority drop 74 packets. Buffer=1891.
#   RouterB: Low load (7%). Buffer drains 223. Buffer=523.
#   RouterC: Moderate load (60%). Priority drop 60 packets. Buffer=1337.
#
# ⏱️ Time step 1220 sec:
#   RouterA: Low load (40%). Buffer drains 627. Buffer=1464.
#   RouterB: Moderate load (54%). Priority drop 54 packets. Buffer=739.
#   RouterC: Low load (22%). Buffer drains 434. Buffer=1013.
#
# ⏱️ Time step 1230 sec:
#   RouterA: Moderate load (59%). Priority drop 59 packets. Buffer=1700.
#   RouterB: High congestion (98%). Tail drop 229 packets.
#   RouterC: Moderate load (70%). Priority drop 70 packets. Buffer=1293.
#
# ⏱️ Time step 1240 sec:
#   RouterA: Low load (18%). Buffer drains 537. Buffer=1253.
#   RouterB: Moderate load (69%). Priority drop 69 packets. Buffer=1276.
#   RouterC: Low load (25%). Buffer drains 425. Buffer=993.
#
# ⏱️ Time step 1250 sec:
#   RouterA: Low load (36%). Buffer drains 429. Buffer=1004.
#   RouterB: Low load (5%). Buffer drains 390. Buffer=911.
#   RouterC: Moderate load (50%). Priority drop 50 packets. Buffer=1193.
#
# ⏱️ Time step 1260 sec:
#   RouterA: Moderate load (68%). Priority drop 68 packets. Buffer=1276.
#   RouterB: Low load (48%). Buffer drains 345. Buffer=806.
#   RouterC: Low load (44%). Buffer drains 423. Buffer=990.
#
# ⏱️ Time step 1270 sec:
#   RouterA: Moderate load (70%). Priority drop 70 packets. Buffer=1556.
#   RouterB: Moderate load (64%). Priority drop 64 packets. Buffer=1062.
#   RouterC: Low load (6%). Buffer drains 306. Buffer=714.
#
# ⏱️ Time step 1280 sec:
#   RouterA: Low load (38%). Buffer drains 523. Buffer=1223.
#   RouterB: High congestion (91%). Tail drop 517 packets.
#   RouterC: High congestion (94%). Tail drop 184 packets.
#
# ⏱️ Time step 1290 sec:
#   RouterA: High congestion (99%). Tail drop 718 packets.
#   RouterB: Low load (48%). Buffer drains 372. Buffer=868.
#   RouterC: Low load (48%). Buffer drains 372. Buffer=868.
#
# ⏱️ Time step 1300 sec:
#   RouterA: Low load (0%). Buffer drains 300. Buffer=700.
#   RouterB: Low load (40%). Buffer drains 320. Buffer=748.
#   RouterC: Low load (40%). Buffer drains 320. Buffer=748.
#
# ⏱️ Time step 1310 sec:
#   RouterA: Low load (28%). Buffer drains 252. Buffer=588.
#   RouterB: Low load (18%). Buffer drains 251. Buffer=587.
#   RouterC: Moderate load (74%). Priority drop 74 packets. Buffer=1044.
#
# ⏱️ Time step 1320 sec:
#   RouterA: High congestion (89%). Tail drop 33 packets.
#   RouterB: High congestion (96%). Tail drop 67 packets.
#   RouterC: Low load (24%). Buffer drains 349. Buffer=815.
#
# ⏱️ Time step 1330 sec:
#   RouterA: High congestion (89%). Tail drop 445 packets.
#   RouterB: Low load (29%). Buffer drains 343. Buffer=802.
#   RouterC: Low load (28%). Buffer drains 286. Buffer=669.
#
# ⏱️ Time step 1340 sec:
#   RouterA: Low load (40%). Buffer drains 360. Buffer=840.
#   RouterB: Low load (0%). Buffer drains 240. Buffer=562.
#   RouterC: Low load (5%). Buffer drains 208. Buffer=486.
#
# ⏱️ Time step 1350 sec:
#   RouterA: Moderate load (74%). Priority drop 74 packets. Buffer=1136.
#   RouterB: Low load (7%). Buffer drains 179. Buffer=418.
#   RouterC: Moderate load (64%). Priority drop 64 packets. Buffer=742.
#
# ⏱️ Time step 1360 sec:
#   RouterA: Moderate load (68%). Priority drop 68 packets. Buffer=1408.
#   RouterB: Moderate load (63%). Priority drop 63 packets. Buffer=670.
#   RouterC: Low load (45%). Buffer drains 290. Buffer=677.
#
# ⏱️ Time step 1370 sec:
#   RouterA: High congestion (95%). Tail drop 883 packets.
#   RouterB: Low load (26%). Buffer drains 240. Buffer=560.
#   RouterC: Low load (21%). Buffer drains 234. Buffer=548.
#
# ⏱️ Time step 1380 sec:
#   RouterA: High congestion (81%). Tail drop 405 packets.
#   RouterB: High congestion (91%). Tail drop 15 packets.
#   RouterC: Low load (39%). Buffer drains 222. Buffer=521.
#
# ⏱️ Time step 1390 sec:
#   RouterA: High congestion (99%). Tail drop 495 packets.
#   RouterB: Low load (20%). Buffer drains 330. Buffer=770.
#   RouterC: High congestion (92%). Buffer at 981/1000.
#
# ⏱️ Time step 1400 sec:
#   RouterA: Low load (42%). Buffer drains 363. Buffer=847.
#   RouterB: Moderate load (72%). Priority drop 72 packets. Buffer=1058.
#   RouterC: Low load (8%). Buffer drains 306. Buffer=715.
#
# ⏱️ Time step 1410 sec:
#   RouterA: Low load (16%). Buffer drains 278. Buffer=649.
#   RouterB: Low load (20%). Buffer drains 347. Buffer=811.
#   RouterC: High congestion (93%). Tail drop 180 packets.
#
# ⏱️ Time step 1420 sec:
#   RouterA: Moderate load (78%). Priority drop 78 packets. Buffer=961.
#   RouterB: High congestion (82%). Tail drop 221 packets.
#   RouterC: High congestion (91%). Tail drop 455 packets.
#
# ⏱️ Time step 1430 sec:
#   RouterA: High congestion (89%). Tail drop 406 packets.
#   RouterB: Low load (30%). Buffer drains 345. Buffer=805.
#   RouterC: Low load (29%). Buffer drains 343. Buffer=802.
#
# ⏱️ Time step 1440 sec:
#   RouterA: Moderate load (73%). Priority drop 73 packets. Buffer=1292.
#   RouterB: High congestion (84%). Tail drop 225 packets.
#   RouterC: High congestion (88%). Tail drop 242 packets.
#
# ⏱️ Time step 1450 sec:
#   RouterA: Low load (20%). Buffer drains 417. Buffer=975.
#   RouterB: Low load (33%). Buffer drains 349. Buffer=816.
#   RouterC: Moderate load (71%). Priority drop 71 packets. Buffer=1284.
#
# ⏱️ Time step 1460 sec:
#   RouterA: High congestion (82%). Tail drop 385 packets.
#   RouterB: Low load (43%). Buffer drains 309. Buffer=722.
#   RouterC: Moderate load (77%). Priority drop 77 packets. Buffer=1592.
#
# ⏱️ Time step 1470 sec:
#   RouterA: Low load (9%). Buffer drains 313. Buffer=732.
#   RouterB: Low load (7%). Buffer drains 227. Buffer=530.
#   RouterC: Low load (29%). Buffer drains 521. Buffer=1216.
#
# ⏱️ Time step 1480 sec:
#   RouterA: Moderate load (74%). Priority drop 74 packets. Buffer=1028.
#   RouterB: Low load (44%). Buffer drains 225. Buffer=525.
#   RouterC: Low load (14%). Buffer drains 385. Buffer=901.
#
# ⏱️ Time step 1490 sec:
#   RouterA: Moderate load (79%). Priority drop 79 packets. Buffer=1344.
#   RouterB: Low load (39%). Buffer drains 216. Buffer=504.
#   RouterC: Low load (43%). Buffer drains 334. Buffer=782.
#
# ⏱️ Time step 1500 sec:
#   RouterA: Moderate load (60%). Priority drop 60 packets. Buffer=1584.
#   RouterB: Moderate load (75%). Priority drop 75 packets. Buffer=804.
#   RouterC: Low load (18%). Buffer drains 261. Buffer=611.
#
# ⏱️ Time step 1510 sec:
#   RouterA: High congestion (92%). Tail drop 1044 packets.
#   RouterB: Low load (30%). Buffer drains 286. Buffer=668.
#   RouterC: Moderate load (62%). Priority drop 62 packets. Buffer=859.
#
# ⏱️ Time step 1520 sec:
#   RouterA: Moderate load (57%). Priority drop 57 packets. Buffer=1228.
#   RouterB: Low load (49%). Buffer drains 273. Buffer=640.
#   RouterC: High congestion (87%). Tail drop 294 packets.
#
# ⏱️ Time step 1530 sec:
#   RouterA: Moderate load (61%). Priority drop 61 packets. Buffer=1472.
#   RouterB: Low load (3%). Buffer drains 196. Buffer=459.
#   RouterC: Low load (7%). Buffer drains 310. Buffer=725.
#
# ⏱️ Time step 1540 sec:
#   RouterA: Low load (1%). Buffer drains 443. Buffer=1034.
#   RouterB: Moderate load (77%). Priority drop 77 packets. Buffer=767.
#   RouterC: Low load (25%). Buffer drains 255. Buffer=595.
#
# ⏱️ Time step 1550 sec:
#   RouterA: High congestion (99%). Tail drop 529 packets.
#   RouterB: High congestion (90%). Tail drop 217 packets.
#   RouterC: High congestion (99%). Tail drop 90 packets.
#
# ⏱️ Time step 1560 sec:
#   RouterA: Moderate load (57%). Priority drop 57 packets. Buffer=1228.
#   RouterB: High congestion (98%). Tail drop 490 packets.
#   RouterC: High congestion (80%). Tail drop 400 packets.
#
# ⏱️ Time step 1570 sec:
#   RouterA: High congestion (93%). Tail drop 693 packets.
#   RouterB: Low load (17%). Buffer drains 325. Buffer=760.
#   RouterC: Low load (16%). Buffer drains 324. Buffer=756.
#
# ⏱️ Time step 1580 sec:
#   RouterA: High congestion (85%). Tail drop 425 packets.
#   RouterB: Low load (41%). Buffer drains 289. Buffer=676.
#   RouterC: Low load (6%). Buffer drains 235. Buffer=551.
#
# ⏱️ Time step 1590 sec:
#   RouterA: High congestion (83%). Tail drop 415 packets.
#   RouterB: High congestion (96%). Tail drop 156 packets.
#   RouterC: Moderate load (68%). Priority drop 68 packets. Buffer=823.
#
# ⏱️ Time step 1600 sec:
#   RouterA: Low load (41%). Buffer drains 361. Buffer=844.
#   RouterB: Low load (48%). Buffer drains 372. Buffer=868.
#   RouterC: High congestion (87%). Tail drop 258 packets.
#
# ⏱️ Time step 1610 sec:
#   RouterA: High congestion (81%). Tail drop 249 packets.
#   RouterB: High congestion (96%). Tail drop 348 packets.
#   RouterC: Low load (19%). Buffer drains 328. Buffer=767.
#
# ⏱️ Time step 1620 sec:
#   RouterA: Moderate load (52%). Priority drop 52 packets. Buffer=1208.
#   RouterB: Low load (47%). Buffer drains 370. Buffer=865.
#   RouterC: Moderate load (58%). Priority drop 58 packets. Buffer=999.
#
# ⏱️ Time step 1630 sec:
#   RouterA: Low load (47%). Buffer drains 432. Buffer=1011.
#   RouterB: Low load (7%). Buffer drains 270. Buffer=630.
#   RouterC: Low load (39%). Buffer drains 358. Buffer=836.
#
# ⏱️ Time step 1640 sec:
#   RouterA: Low load (31%). Buffer drains 349. Buffer=817.
#   RouterB: Low load (38%). Buffer drains 246. Buffer=574.
#   RouterC: Low load (2%). Buffer drains 253. Buffer=593.
#
# ⏱️ Time step 1650 sec:
#   RouterA: Moderate load (51%). Priority drop 51 packets. Buffer=1021.
#   RouterB: Low load (24%). Buffer drains 208. Buffer=486.
#   RouterC: High congestion (85%). Tail drop 18 packets.
#
# ⏱️ Time step 1660 sec:
#   RouterA: Low load (34%). Buffer drains 357. Buffer=834.
#   RouterB: Low load (14%). Buffer drains 166. Buffer=390.
#   RouterC: Low load (27%). Buffer drains 340. Buffer=795.
#
# ⏱️ Time step 1670 sec:
#   RouterA: Moderate load (64%). Priority drop 64 packets. Buffer=1090.
#   RouterB: Low load (45%). Buffer drains 184. Buffer=431.
#   RouterC: High congestion (94%). Tail drop 265 packets.
#
# ⏱️ Time step 1680 sec:
#   RouterA: Low load (37%). Buffer drains 382. Buffer=893.
#   RouterB: Low load (4%). Buffer drains 135. Buffer=316.
#   RouterC: High congestion (86%). Tail drop 430 packets.
#
# ⏱️ Time step 1690 sec:
#   RouterA: Low load (13%). Buffer drains 287. Buffer=671.
#   RouterB: Low load (15%). Buffer drains 117. Buffer=274.
#   RouterC: Low load (32%). Buffer drains 348. Buffer=812.
#
# ⏱️ Time step 1700 sec:
#   RouterA: Low load (1%). Buffer drains 202. Buffer=474.
#   RouterB: High congestion (88%). Buffer at 714/1000.
#   RouterC: High congestion (88%). Tail drop 252 packets.
#
# ⏱️ Time step 1710 sec:
#   RouterA: Moderate load (78%). Priority drop 78 packets. Buffer=786.
#   RouterB: Low load (31%). Buffer drains 260. Buffer=609.
#   RouterC: Low load (22%). Buffer drains 333. Buffer=777.
#
# ⏱️ Time step 1720 sec:
#   RouterA: High congestion (87%). Tail drop 221 packets.
#   RouterB: Low load (14%). Buffer drains 203. Buffer=476.
#   RouterC: Moderate load (70%). Priority drop 70 packets. Buffer=1057.
#
# ⏱️ Time step 1730 sec:
#   RouterA: Low load (25%). Buffer drains 337. Buffer=788.
#   RouterB: Moderate load (50%). Priority drop 50 packets. Buffer=676.
#   RouterC: High congestion (82%). Tail drop 467 packets.
#
# ⏱️ Time step 1740 sec:
#   RouterA: Moderate load (73%). Priority drop 73 packets. Buffer=1080.
#   RouterB: Moderate load (52%). Priority drop 52 packets. Buffer=884.
#   RouterC: Low load (46%). Buffer drains 369. Buffer=861.
#
# ⏱️ Time step 1750 sec:
#   RouterA: Moderate load (67%). Priority drop 67 packets. Buffer=1348.
#   RouterB: Moderate load (77%). Priority drop 77 packets. Buffer=1192.
#   RouterC: Low load (44%). Buffer drains 324. Buffer=757.
#
# ⏱️ Time step 1760 sec:
#   RouterA: High congestion (83%). Tail drop 763 packets.
#   RouterB: High congestion (96%). Tail drop 672 packets.
#   RouterC: Low load (30%). Buffer drains 272. Buffer=635.
#
# ⏱️ Time step 1770 sec:
#   RouterA: Low load (39%). Buffer drains 358. Buffer=837.
#   RouterB: Moderate load (61%). Priority drop 61 packets. Buffer=1244.
#   RouterC: Low load (48%). Buffer drains 262. Buffer=613.
#
# ⏱️ Time step 1780 sec:
#   RouterA: Low load (40%). Buffer drains 311. Buffer=726.
#   RouterB: Low load (10%). Buffer drains 388. Buffer=906.
#   RouterC: High congestion (95%). Tail drop 88 packets.
#
# ⏱️ Time step 1790 sec:
#   RouterA: High congestion (94%). Tail drop 196 packets.
#   RouterB: High congestion (83%). Tail drop 321 packets.
#   RouterC: High congestion (94%). Tail drop 470 packets.
#
# ⏱️ Time step 1800 sec:
#   RouterA: Low load (24%). Buffer drains 336. Buffer=784.
#   RouterB: Moderate load (58%). Priority drop 58 packets. Buffer=1232.
#   RouterC: Moderate load (63%). Priority drop 63 packets. Buffer=1252.
#
# ⏱️ Time step 1810 sec:
#   RouterA: High congestion (89%). Tail drop 229 packets.
#   RouterB: Moderate load (59%). Priority drop 59 packets. Buffer=1468.
#   RouterC: Low load (10%). Buffer drains 390. Buffer=912.
#
# ⏱️ Time step 1820 sec:
#   RouterA: Low load (24%). Buffer drains 336. Buffer=784.
#   RouterB: Moderate load (69%). Priority drop 69 packets. Buffer=1744.
#   RouterC: Low load (30%). Buffer drains 318. Buffer=744.
#
# ⏱️ Time step 1830 sec:
#   RouterA: Moderate load (70%). Priority drop 70 packets. Buffer=1064.
#   RouterB: Moderate load (71%). Priority drop 71 packets. Buffer=2028.
#   RouterC: Low load (29%). Buffer drains 266. Buffer=623.
#
# ⏱️ Time step 1840 sec:
#   RouterA: High congestion (83%). Tail drop 479 packets.
#   RouterB: Low load (7%). Buffer drains 618. Buffer=1445.
#   RouterC: Low load (42%). Buffer drains 249. Buffer=584.
#
# ⏱️ Time step 1850 sec:
#   RouterA: Moderate load (53%). Priority drop 53 packets. Buffer=1212.
#   RouterB: Low load (26%). Buffer drains 472. Buffer=1103.
#   RouterC: Low load (21%). Buffer drains 206. Buffer=483.
#
# ⏱️ Time step 1860 sec:
#   RouterA: High congestion (85%). Tail drop 637 packets.
#   RouterB: High congestion (95%). Tail drop 578 packets.
#   RouterC: Moderate load (70%). Priority drop 70 packets. Buffer=763.
#
# ⏱️ Time step 1870 sec:
#   RouterA: Moderate load (56%). Priority drop 56 packets. Buffer=1224.
#   RouterB: Moderate load (57%). Priority drop 57 packets. Buffer=1228.
#   RouterC: High congestion (91%). Tail drop 218 packets.
#
# ⏱️ Time step 1880 sec:
#   RouterA: Low load (12%). Buffer drains 385. Buffer=899.
#   RouterB: Low load (1%). Buffer drains 369. Buffer=864.
#   RouterC: Moderate load (53%). Priority drop 53 packets. Buffer=1212.
#
# ⏱️ Time step 1890 sec:
#   RouterA: Low load (46%). Buffer drains 338. Buffer=791.
#   RouterB: Moderate load (75%). Priority drop 75 packets. Buffer=1164.
#   RouterC: Low load (14%). Buffer drains 384. Buffer=898.
#
# ⏱️ Time step 1900 sec:
#   RouterA: Low load (35%). Buffer drains 289. Buffer=677.
#   RouterB: High congestion (93%). Tail drop 629 packets.
#   RouterC: High congestion (84%). Tail drop 318 packets.
#
# ⏱️ Time step 1910 sec:
#   RouterA: Moderate load (59%). Priority drop 59 packets. Buffer=913.
#   RouterB: Moderate load (57%). Priority drop 57 packets. Buffer=1228.
#   RouterC: High congestion (91%). Tail drop 455 packets.
#
# ⏱️ Time step 1920 sec:
#   RouterA: Low load (15%). Buffer drains 296. Buffer=692.
#   RouterB: Low load (42%). Buffer drains 431. Buffer=1007.
#   RouterC: Low load (32%). Buffer drains 348. Buffer=812.
#
# ⏱️ Time step 1930 sec:
#   RouterA: Moderate load (78%). Priority drop 78 packets. Buffer=1004.
#   RouterB: Moderate load (57%). Priority drop 57 packets. Buffer=1235.
#   RouterC: Low load (13%). Buffer drains 263. Buffer=614.
#
# ⏱️ Time step 1940 sec:
#   RouterA: Low load (44%). Buffer drains 367. Buffer=857.
#   RouterB: Moderate load (63%). Priority drop 63 packets. Buffer=1487.
#   RouterC: Moderate load (77%). Priority drop 77 packets. Buffer=922.
#
# ⏱️ Time step 1950 sec:
#   RouterA: Low load (28%). Buffer drains 299. Buffer=698.
#   RouterB: High congestion (92%). Tail drop 947 packets.
#   RouterC: Moderate load (75%). Priority drop 75 packets. Buffer=1222.
#
# ⏱️ Time step 1960 sec:
#   RouterA: Moderate load (65%). Priority drop 65 packets. Buffer=958.
#   RouterB: Moderate load (78%). Priority drop 78 packets. Buffer=1312.
#   RouterC: Low load (40%). Buffer drains 426. Buffer=996.
#
# ⏱️ Time step 1970 sec:
#   RouterA: High congestion (96%). Tail drop 438 packets.
#   RouterB: Moderate load (70%). Priority drop 70 packets. Buffer=1592.
#   RouterC: Moderate load (79%). Priority drop 79 packets. Buffer=1312.
#
# ⏱️ Time step 1980 sec:
#   RouterA: Moderate load (52%). Priority drop 52 packets. Buffer=1208.
#   RouterB: Low load (31%). Buffer drains 524. Buffer=1223.
#   RouterC: Moderate load (71%). Priority drop 71 packets. Buffer=1596.
#
# ⏱️ Time step 1990 sec:
#   RouterA: Low load (46%). Buffer drains 431. Buffer=1007.
#   RouterB: Low load (4%). Buffer drains 372. Buffer=871.
#   RouterC: Low load (12%). Buffer drains 496. Buffer=1160.
#
# ⏱️ Time step 2000 sec:
#   RouterA: Low load (40%). Buffer drains 362. Buffer=845.
#   RouterB: Moderate load (67%). Priority drop 67 packets. Buffer=1139.
#   RouterC: Low load (16%). Buffer drains 372. Buffer=868.
#
# ⏱️ Time step 2010 sec:
#   RouterA: Moderate load (52%). Priority drop 52 packets. Buffer=1053.
#   RouterB: Low load (32%). Buffer drains 389. Buffer=910.
#   RouterC: Moderate load (66%). Priority drop 66 packets. Buffer=1132.
#
# ⏱️ Time step 2020 sec:
#   RouterA: Moderate load (72%). Priority drop 72 packets. Buffer=1341.
#   RouterB: Moderate load (79%). Priority drop 79 packets. Buffer=1226.
#   RouterC: Moderate load (51%). Priority drop 51 packets. Buffer=1336.
#
# ⏱️ Time step 2030 sec:
#   RouterA: Low load (11%). Buffer drains 418. Buffer=978.
#   RouterB: Moderate load (77%). Priority drop 77 packets. Buffer=1534.
#   RouterC: Low load (7%). Buffer drains 411. Buffer=960.
#
# ⏱️ Time step 2040 sec:
#   RouterA: Low load (36%). Buffer drains 347. Buffer=811.
#   RouterB: Low load (15%). Buffer drains 482. Buffer=1127.
#   RouterC: Moderate load (50%). Priority drop 50 packets. Buffer=1160.
#
# ⏱️ Time step 2050 sec:
#   RouterA: Low load (46%). Buffer drains 312. Buffer=729.
#   RouterB: Moderate load (77%). Priority drop 77 packets. Buffer=1435.
#   RouterC: High congestion (86%). Tail drop 590 packets.
#
# ⏱️ Time step 2060 sec:
#   RouterA: Low load (6%). Buffer drains 227. Buffer=532.
#   RouterB: Moderate load (64%). Priority drop 64 packets. Buffer=1691.
#   RouterC: Low load (32%). Buffer drains 348. Buffer=812.
#
# ⏱️ Time step 2070 sec:
#   RouterA: Low load (30%). Buffer drains 204. Buffer=478.
#   RouterB: High congestion (98%). Tail drop 1181 packets.
#   RouterC: High congestion (100%). Tail drop 312 packets.
#
# ⏱️ Time step 2080 sec:
#   RouterA: Moderate load (74%). Priority drop 74 packets. Buffer=774.
#   RouterB: Low load (28%). Buffer drains 342. Buffer=798.
#   RouterC: Moderate load (71%). Priority drop 71 packets. Buffer=1284.
#
# ⏱️ Time step 2090 sec:
#   RouterA: Moderate load (64%). Priority drop 64 packets. Buffer=1030.
#   RouterB: Low load (47%). Buffer drains 309. Buffer=724.
#   RouterC: High congestion (82%). Tail drop 694 packets.
#
# ⏱️ Time step 2100 sec:
#   RouterA: Moderate load (56%). Priority drop 56 packets. Buffer=1254.
#   RouterB: High congestion (97%). Tail drop 209 packets.
#   RouterC: Low load (36%). Buffer drains 354. Buffer=826.
#
# ⏱️ Time step 2110 sec:
#   RouterA: Moderate load (52%). Priority drop 52 packets. Buffer=1462.
#   RouterB: Low load (24%). Buffer drains 336. Buffer=784.
#   RouterC: Low load (11%). Buffer drains 264. Buffer=617.
#
# ⏱️ Time step 2120 sec:
#   RouterA: High congestion (95%). Tail drop 937 packets.
#   RouterB: Low load (14%). Buffer drains 256. Buffer=598.
#   RouterC: Low load (3%). Buffer drains 189. Buffer=443.
#
# ⏱️ Time step 2130 sec:
#   RouterA: Moderate load (56%). Priority drop 56 packets. Buffer=1224.
#   RouterB: High congestion (100%). Tail drop 98 packets.
#   RouterC: Moderate load (70%). Priority drop 70 packets. Buffer=723.
#
# ⏱️ Time step 2140 sec:
#   RouterA: Low load (29%). Buffer drains 410. Buffer=959.
#   RouterB: High congestion (90%). Tail drop 450 packets.
#   RouterC: Low load (4%). Buffer drains 222. Buffer=521.
#
# ⏱️ Time step 2150 sec:
#   RouterA: Low load (48%). Buffer drains 359. Buffer=840.
#   RouterB: Low load (10%). Buffer drains 315. Buffer=735.
#   RouterC: Low load (49%). Buffer drains 229. Buffer=537.
#
# ⏱️ Time step 2160 sec:
#   RouterA: Low load (6%). Buffer drains 261. Buffer=609.
#   RouterB: Low load (15%). Buffer drains 243. Buffer=567.
#   RouterC: Low load (14%). Buffer drains 182. Buffer=425.
#
# ⏱️ Time step 2170 sec:
#   RouterA: Low load (22%). Buffer drains 215. Buffer=504.
#   RouterB: Moderate load (78%). Priority drop 78 packets. Buffer=879.
#   RouterC: High congestion (94%). Buffer at 895/1000.
#
# ⏱️ Time step 2180 sec:
#   RouterA: Low load (19%). Buffer drains 179. Buffer=420.
#   RouterB: High congestion (92%). Tail drop 339 packets.
#   RouterC: High congestion (96%). Tail drop 375 packets.
#
# ⏱️ Time step 2190 sec:
#   RouterA: Moderate load (69%). Priority drop 69 packets. Buffer=696.
#   RouterB: Low load (31%). Buffer drains 346. Buffer=809.
#   RouterC: Moderate load (65%). Priority drop 65 packets. Buffer=1260.
#
# ⏱️ Time step 2200 sec:
#   RouterA: Low load (34%). Buffer drains 259. Buffer=607.
#   RouterB: Low load (35%). Buffer drains 295. Buffer=689.
#   RouterC: Low load (44%). Buffer drains 444. Buffer=1036.
#
# ⏱️ Time step 2210 sec:
#   RouterA: Low load (5%). Buffer drains 189. Buffer=443.
#   RouterB: High congestion (89%). Tail drop 134 packets.
#   RouterC: Moderate load (51%). Priority drop 51 packets. Buffer=1240.
#
# ⏱️ Time step 2220 sec:
#   RouterA: Moderate load (59%). Priority drop 59 packets. Buffer=679.
#   RouterB: Moderate load (74%). Priority drop 74 packets. Buffer=1296.
#   RouterC: High congestion (97%). Tail drop 725 packets.
#
# ⏱️ Time step 2230 sec:
#   RouterA: Moderate load (73%). Priority drop 73 packets. Buffer=971.
#   RouterB: Moderate load (56%). Priority drop 56 packets. Buffer=1520.
#   RouterC: Moderate load (61%). Priority drop 61 packets. Buffer=1244.
#
# ⏱️ Time step 2240 sec:
#   RouterA: Moderate load (52%). Priority drop 52 packets. Buffer=1179.
#   RouterB: Moderate load (52%). Priority drop 52 packets. Buffer=1728.
#   RouterC: Moderate load (73%). Priority drop 73 packets. Buffer=1536.
#
# ⏱️ Time step 2250 sec:
#   RouterA: Low load (44%). Buffer drains 419. Buffer=980.
#   RouterB: High congestion (89%). Tail drop 1173 packets.
#   RouterC: Low load (40%). Buffer drains 520. Buffer=1216.
#
# ⏱️ Time step 2260 sec:
#   RouterA: Moderate load (64%). Priority drop 64 packets. Buffer=1236.
#   RouterB: Moderate load (71%). Priority drop 71 packets. Buffer=1284.
#   RouterC: Moderate load (74%). Priority drop 74 packets. Buffer=1512.
#
# ⏱️ Time step 2270 sec:
#   RouterA: Low load (47%). Buffer drains 441. Buffer=1030.
#   RouterB: High congestion (90%). Tail drop 734 packets.
#   RouterC: Low load (46%). Buffer drains 522. Buffer=1220.
#
# ⏱️ Time step 2280 sec:
#   RouterA: Moderate load (70%). Priority drop 70 packets. Buffer=1310.
#   RouterB: Moderate load (53%). Priority drop 53 packets. Buffer=1212.
#   RouterC: Low load (12%). Buffer drains 384. Buffer=896.
#
# ⏱️ Time step 2290 sec:
#   RouterA: Low load (35%). Buffer drains 445. Buffer=1040.
#   RouterB: High congestion (81%). Tail drop 617 packets.
#   RouterC: Low load (25%). Buffer drains 306. Buffer=715.
#
# ⏱️ Time step 2300 sec:
#   RouterA: Moderate load (72%). Priority drop 72 packets. Buffer=1328.
#   RouterB: Low load (28%). Buffer drains 342. Buffer=798.
#   RouterC: High congestion (98%). Tail drop 205 packets.
#
# ⏱️ Time step 2310 sec:
# ...
#
# ⏱️ Time step 6240 sec:
#   RouterA: Low load (49%). Buffer drains 335. Buffer=784.
#   RouterB: Low load (21%). Buffer drains 395. Buffer=922.
#   RouterC: Low load (32%). Buffer drains 422. Buffer=986.
#
# ⏱️ Time step 6250 sec:
#   RouterA: Low load (32%). Buffer drains 283. Buffer=661.
#   RouterB: High congestion (87%). Tail drop 357 packets.
#   RouterC: Moderate load (65%). Priority drop 65 packets. Buffer=1246.
#
# ⏱️ Time step 6260 sec:
#   RouterA: Low load (46%). Buffer drains 267. Buffer=624.
#   RouterB: Moderate load (64%). Priority drop 64 packets. Buffer=1256.
#   RouterC: Moderate load (71%). Priority drop 71 packets. Buffer=1530.
#
# ⏱️ Time step 6270 sec:
#   RouterA: High congestion (84%). Tail drop 44 packets.
#   RouterB: Low load (28%). Buffer drains 418. Buffer=978.
#   RouterC: Low load (42%). Buffer drains 522. Buffer=1218.
#
# ⏱️ Time step 6280 sec:
#   RouterA: Moderate load (68%). Priority drop 68 packets. Buffer=1272.
#   RouterB: High congestion (97%). Tail drop 463 packets.
#   RouterC: High congestion (96%). Tail drop 698 packets.
#
# ⏱️ Time step 6290 sec:
#   RouterA: Moderate load (57%). Priority drop 57 packets. Buffer=1500.
#   RouterB: Moderate load (54%). Priority drop 54 packets. Buffer=1216.
#   RouterC: High congestion (82%). Tail drop 410 packets.
#
# ⏱️ Time step 6300 sec:
#   RouterA: Moderate load (57%). Priority drop 57 packets. Buffer=1728.
#   RouterB: Moderate load (58%). Priority drop 58 packets. Buffer=1448.
#   RouterC: Moderate load (57%). Priority drop 57 packets. Buffer=1228.
#
# ⏱️ Time step 6310 sec:
#   RouterA: Low load (0%). Buffer drains 518. Buffer=1210.
#   RouterB: Moderate load (59%). Priority drop 59 packets. Buffer=1684.
#   RouterC: Low load (29%). Buffer drains 411. Buffer=962.
#
# ⏱️ Time step 6320 sec:
#   RouterA: Low load (33%). Buffer drains 412. Buffer=963.
#   RouterB: Moderate load (77%). Priority drop 77 packets. Buffer=1992.
#   RouterC: Low load (37%). Buffer drains 344. Buffer=803.
#
# ⏱️ Time step 6330 sec:
#   RouterA: Moderate load (53%). Priority drop 53 packets. Buffer=1175.
#   RouterB: Moderate load (73%). Priority drop 73 packets. Buffer=2284.
#   RouterC: High congestion (92%). Tail drop 263 packets.
#
# ⏱️ Time step 6340 sec:
#   RouterA: Moderate load (73%). Priority drop 73 packets. Buffer=1467.
#   RouterB: Moderate load (69%). Priority drop 69 packets. Buffer=2560.
#   RouterC: Moderate load (53%). Priority drop 53 packets. Buffer=1212.
#
# ⏱️ Time step 6350 sec:
#   RouterA: High congestion (84%). Tail drop 887 packets.
#   RouterB: Low load (37%). Buffer drains 823. Buffer=1922.
#   RouterC: Moderate load (62%). Priority drop 62 packets. Buffer=1460.
#
# ⏱️ Time step 6360 sec:
#   RouterA: Moderate load (79%). Priority drop 79 packets. Buffer=1316.
#   RouterB: Moderate load (60%). Priority drop 60 packets. Buffer=2162.
#   RouterC: Low load (41%). Buffer drains 499. Buffer=1166.
#
# ⏱️ Time step 6370 sec:
#   RouterA: Moderate load (63%). Priority drop 63 packets. Buffer=1568.
#   RouterB: Low load (42%). Buffer drains 711. Buffer=1661.
#   RouterC: Moderate load (52%). Priority drop 52 packets. Buffer=1374.
#
# ⏱️ Time step 6380 sec:
#   RouterA: Low load (30%). Buffer drains 515. Buffer=1203.
#   RouterB: High congestion (87%). Tail drop 1096 packets.
#   RouterC: Low load (29%). Buffer drains 455. Buffer=1064.
#
# ⏱️ Time step 6390 sec:
#   RouterA: Low load (41%). Buffer drains 422. Buffer=986.
#   RouterB: Moderate load (75%). Priority drop 75 packets. Buffer=1300.
#   RouterC: Low load (2%). Buffer drains 322. Buffer=752.
#
# ⏱️ Time step 6400 sec:
#   RouterA: High congestion (86%). Tail drop 416 packets.
#   RouterB: Low load (43%). Buffer drains 454. Buffer=1061.
#   RouterC: Low load (28%). Buffer drains 267. Buffer=625.
#
# ⏱️ Time step 6410 sec:
#   RouterA: Low load (27%). Buffer drains 340. Buffer=795.
#   RouterB: High congestion (87%). Tail drop 496 packets.
#   RouterC: High congestion (84%). Tail drop 45 packets.
#
# ⏱️ Time step 6420 sec:
#   RouterA: Low load (26%). Buffer drains 277. Buffer=648.
#   RouterB: Low load (40%). Buffer drains 360. Buffer=840.
#   RouterC: Moderate load (60%). Priority drop 60 packets. Buffer=1240.
#
# ⏱️ Time step 6430 sec:
#   RouterA: High congestion (87%). Tail drop 83 packets.
#   RouterB: Low load (46%). Buffer drains 321. Buffer=749.
#   RouterC: High congestion (98%). Tail drop 730 packets.
#
# ⏱️ Time step 6440 sec:
#   RouterA: Low load (21%). Buffer drains 331. Buffer=774.
#   RouterB: Moderate load (62%). Priority drop 62 packets. Buffer=997.
#   RouterC: High congestion (99%). Tail drop 495 packets.
#
# ⏱️ Time step 6450 sec:
#   RouterA: Low load (21%). Buffer drains 263. Buffer=616.
#   RouterB: High congestion (88%). Tail drop 437 packets.
#   RouterC: Moderate load (58%). Priority drop 58 packets. Buffer=1232.
#
# ⏱️ Time step 6460 sec:
#   RouterA: Low load (5%). Buffer drains 192. Buffer=449.
#   RouterB: Low load (46%). Buffer drains 369. Buffer=861.
#   RouterC: High congestion (94%). Tail drop 702 packets.
#
# ⏱️ Time step 6470 sec:
#   RouterA: Low load (7%). Buffer drains 145. Buffer=339.
#   RouterB: High congestion (96%). Tail drop 341 packets.
#   RouterC: Low load (34%). Buffer drains 351. Buffer=819.
#
# ⏱️ Time step 6480 sec:
#   RouterA: Low load (20%). Buffer drains 131. Buffer=308.
#   RouterB: Moderate load (71%). Priority drop 71 packets. Buffer=1284.
#   RouterC: Low load (8%). Buffer drains 257. Buffer=602.
#
# ⏱️ Time step 6490 sec:
#   RouterA: Moderate load (50%). Priority drop 50 packets. Buffer=508.
#   RouterB: Low load (15%). Buffer drains 407. Buffer=952.
#   RouterC: Moderate load (76%). Priority drop 76 packets. Buffer=906.
#
# ⏱️ Time step 6500 sec:
#   RouterA: Low load (27%). Buffer drains 192. Buffer=451.
#   RouterB: Moderate load (54%). Priority drop 54 packets. Buffer=1168.
#   RouterC: Low load (16%). Buffer drains 295. Buffer=691.
#
# ⏱️ Time step 6510 sec:
#   RouterA: Low load (9%). Buffer drains 148. Buffer=348.
#   RouterB: Moderate load (68%). Priority drop 68 packets. Buffer=1440.
#   RouterC: Moderate load (68%). Priority drop 68 packets. Buffer=963.
#
# ⏱️ Time step 6520 sec:
#   RouterA: Low load (28%). Buffer drains 146. Buffer=342.
#   RouterB: Moderate load (78%). Priority drop 78 packets. Buffer=1752.
#   RouterC: High congestion (83%). Tail drop 378 packets.
#
# ⏱️ Time step 6530 sec:
#   RouterA: Moderate load (61%). Priority drop 61 packets. Buffer=586.
#   RouterB: Moderate load (53%). Priority drop 53 packets. Buffer=1964.
#   RouterC: Low load (33%). Buffer drains 349. Buffer=816.
#
# ⏱️ Time step 6540 sec:
#   RouterA: Low load (34%). Buffer drains 226. Buffer=530.
#   RouterB: Moderate load (66%). Priority drop 66 packets. Buffer=2228.
#   RouterC: High congestion (90%). Tail drop 266 packets.
#
# ⏱️ Time step 6550 sec:
#   RouterA: High congestion (88%). Buffer at 970/1000.
#   RouterB: Low load (6%). Buffer drains 677. Buffer=1581.
#   RouterC: Low load (45%). Buffer drains 367. Buffer=858.
#
# ⏱️ Time step 6560 sec:
#   RouterA: Low load (35%). Buffer drains 343. Buffer=802.
#   RouterB: Moderate load (61%). Priority drop 61 packets. Buffer=1825.
#   RouterC: Moderate load (74%). Priority drop 74 packets. Buffer=1154.
#
# ⏱️ Time step 6570 sec:
#   RouterA: High congestion (82%). Tail drop 212 packets.
#   RouterB: Low load (25%). Buffer drains 585. Buffer=1365.
#   RouterC: Low load (35%). Buffer drains 398. Buffer=931.
#
# ⏱️ Time step 6580 sec:
#   RouterA: Low load (13%). Buffer drains 319. Buffer=746.
#   RouterB: Low load (3%). Buffer drains 414. Buffer=966.
#   RouterC: Low load (30%). Buffer drains 324. Buffer=757.
#
# ⏱️ Time step 6590 sec:
#   RouterA: Moderate load (63%). Priority drop 63 packets. Buffer=998.
#   RouterB: Low load (2%). Buffer drains 292. Buffer=684.
#   RouterC: Low load (2%). Buffer drains 230. Buffer=537.
#
# ⏱️ Time step 6600 sec:
#   RouterA: High congestion (91%). Tail drop 453 packets.
#   RouterB: Low load (16%). Buffer drains 229. Buffer=535.
#   RouterC: Low load (17%). Buffer drains 186. Buffer=436.
#
# ⏱️ Time step 6610 sec:
#   RouterA: Moderate load (68%). Priority drop 68 packets. Buffer=1272.
#   RouterB: Low load (22%). Buffer drains 193. Buffer=452.
#   RouterC: High congestion (90%). Buffer at 886/1000.
#
# ⏱️ Time step 6620 sec:
#   RouterA: Low load (38%). Buffer drains 438. Buffer=1024.
#   RouterB: High congestion (87%). Buffer at 887/1000.
#   RouterC: Low load (20%). Buffer drains 295. Buffer=691.
#
# ⏱️ Time step 6630 sec:
#   RouterA: Low load (28%). Buffer drains 349. Buffer=815.
#   RouterB: Low load (26%). Buffer drains 305. Buffer=712.
#   RouterC: High congestion (91%). Tail drop 146 packets.
#
# ⏱️ Time step 6640 sec:
#   RouterA: Low load (4%). Buffer drains 250. Buffer=585.
#   RouterB: Low load (18%). Buffer drains 240. Buffer=562.
#   RouterC: Moderate load (55%). Priority drop 55 packets. Buffer=1220.
#
# ⏱️ Time step 6650 sec:
#   RouterA: Moderate load (71%). Priority drop 71 packets. Buffer=869.
#   RouterB: Low load (23%). Buffer drains 203. Buffer=474.
#   RouterC: High congestion (91%). Tail drop 675 packets.
#
# ⏱️ Time step 6660 sec:
#   RouterA: Low load (42%). Buffer drains 323. Buffer=756.
#   RouterB: Moderate load (51%). Priority drop 51 packets. Buffer=678.
#   RouterC: High congestion (96%). Tail drop 480 packets.
#
# ⏱️ Time step 6670 sec:
#   RouterA: Moderate load (62%). Priority drop 62 packets. Buffer=1004.
#   RouterB: Moderate load (54%). Priority drop 54 packets. Buffer=894.
#   RouterC: Moderate load (65%). Priority drop 65 packets. Buffer=1260.
#
# ⏱️ Time step 6680 sec:
#   RouterA: Moderate load (76%). Priority drop 76 packets. Buffer=1308.
#   RouterB: Moderate load (50%). Priority drop 50 packets. Buffer=1094.
#   RouterC: Low load (9%). Buffer drains 391. Buffer=914.
#
# ⏱️ Time step 6690 sec:
#   RouterA: Low load (15%). Buffer drains 414. Buffer=969.
#   RouterB: Low load (2%). Buffer drains 331. Buffer=773.
#   RouterC: Moderate load (61%). Priority drop 61 packets. Buffer=1158.
#
# ⏱️ Time step 6700 sec:
#   RouterA: Moderate load (67%). Priority drop 67 packets. Buffer=1237.
#   RouterB: High congestion (80%). Tail drop 173 packets.
#   RouterC: High congestion (91%). Tail drop 613 packets.
#
# ⏱️ Time step 6710 sec:
#   RouterA: Low load (23%). Buffer drains 405. Buffer=947.
#   RouterB: High congestion (89%). Tail drop 445 packets.
#   RouterC: High congestion (85%). Tail drop 425 packets.
#
# ⏱️ Time step 6720 sec:
#   RouterA: Moderate load (72%). Priority drop 72 packets. Buffer=1235.
#   RouterB: Moderate load (58%). Priority drop 58 packets. Buffer=1232.
#   RouterC: Moderate load (53%). Priority drop 53 packets. Buffer=1212.
#
# ⏱️ Time step 6730 sec:
#   RouterA: Moderate load (79%). Priority drop 79 packets. Buffer=1551.
#   RouterB: Low load (0%). Buffer drains 369. Buffer=863.
#   RouterC: Low load (4%). Buffer drains 369. Buffer=863.
#
# ⏱️ Time step 6740 sec:
#   RouterA: Moderate load (66%). Priority drop 66 packets. Buffer=1815.
#   RouterB: Low load (7%). Buffer drains 269. Buffer=629.
#   RouterC: Moderate load (74%). Priority drop 74 packets. Buffer=1159.
#
# ⏱️ Time step 6750 sec:
#   RouterA: Low load (25%). Buffer drains 582. Buffer=1358.
#   RouterB: High congestion (90%). Tail drop 79 packets.
#   RouterC: Moderate load (62%). Priority drop 62 packets. Buffer=1407.
#
# ⏱️ Time step 6760 sec:
#   RouterA: Moderate load (69%). Priority drop 69 packets. Buffer=1634.
#   RouterB: Low load (13%). Buffer drains 319. Buffer=746.
#   RouterC: Low load (7%). Buffer drains 432. Buffer=1010.
#
# ⏱️ Time step 6770 sec:
#   RouterA: Low load (49%). Buffer drains 563. Buffer=1316.
#   RouterB: Moderate load (66%). Priority drop 66 packets. Buffer=1010.
#   RouterC: Low load (18%). Buffer drains 330. Buffer=770.
#
# ⏱️ Time step 6780 sec:
#   RouterA: Moderate load (58%). Priority drop 58 packets. Buffer=1548.
#   RouterB: Low load (36%). Buffer drains 357. Buffer=833.
#   RouterC: Low load (33%). Buffer drains 280. Buffer=655.
#
# ⏱️ Time step 6790 sec:
#   RouterA: Low load (43%). Buffer drains 528. Buffer=1235.
#   RouterB: Low load (24%). Buffer drains 285. Buffer=668.
#   RouterC: Moderate load (65%). Priority drop 65 packets. Buffer=915.
#
# ⏱️ Time step 6800 sec:
#   RouterA: Low load (26%). Buffer drains 409. Buffer=956.
#   RouterB: Moderate load (51%). Priority drop 51 packets. Buffer=872.
#   RouterC: Low load (27%). Buffer drains 315. Buffer=735.
#
# ⏱️ Time step 6810 sec:
#   RouterA: Low load (12%). Buffer drains 304. Buffer=712.
#   RouterB: Moderate load (55%). Priority drop 55 packets. Buffer=1092.
#   RouterC: High congestion (100%). Tail drop 235 packets.
#
# ⏱️ Time step 6820 sec:
#   RouterA: High congestion (82%). Tail drop 122 packets.
#   RouterB: Moderate load (69%). Priority drop 69 packets. Buffer=1368.
#   RouterC: Low load (3%). Buffer drains 304. Buffer=711.
#
# ⏱️ Time step 6830 sec:
#   RouterA: Moderate load (56%). Priority drop 56 packets. Buffer=1224.
#   RouterB: Low load (42%). Buffer drains 473. Buffer=1105.
#   RouterC: Low load (28%). Buffer drains 255. Buffer=596.
#
# ⏱️ Time step 6840 sec:
#   RouterA: Moderate load (78%). Priority drop 78 packets. Buffer=1536.
#   RouterB: Moderate load (66%). Priority drop 66 packets. Buffer=1369.
#   RouterC: Low load (43%). Buffer drains 243. Buffer=568.
#
# ⏱️ Time step 6850 sec:
#   RouterA: High congestion (89%). Tail drop 981 packets.
#   RouterB: Moderate load (72%). Priority drop 72 packets. Buffer=1657.
#   RouterC: Moderate load (59%). Priority drop 59 packets. Buffer=804.
#
# ⏱️ Time step 6860 sec:
#   RouterA: Moderate load (78%). Priority drop 78 packets. Buffer=1312.
#   RouterB: Low load (13%). Buffer drains 516. Buffer=1206.
#   RouterC: Low load (16%). Buffer drains 265. Buffer=619.
#
# ⏱️ Time step 6870 sec:
#   RouterA: Low load (21%). Buffer drains 425. Buffer=992.
#   RouterB: Low load (43%). Buffer drains 426. Buffer=995.
#   RouterC: High congestion (95%). Tail drop 94 packets.
#
# ⏱️ Time step 6880 sec:
#   RouterA: Low load (42%). Buffer drains 360. Buffer=842.
#   RouterB: Low load (6%). Buffer drains 307. Buffer=718.
#   RouterC: Low load (13%). Buffer drains 319. Buffer=746.
#
# ⏱️ Time step 6890 sec:
#   RouterA: Low load (41%). Buffer drains 314. Buffer=733.
#   RouterB: Moderate load (68%). Priority drop 68 packets. Buffer=990.
#   RouterC: Moderate load (57%). Priority drop 57 packets. Buffer=974.
#
# ⏱️ Time step 6900 sec:
#   RouterA: Low load (19%). Buffer drains 248. Buffer=580.
#   RouterB: Low load (17%). Buffer drains 322. Buffer=753.
#   RouterC: Moderate load (59%). Priority drop 59 packets. Buffer=1210.
#
# ⏱️ Time step 6910 sec:
#   RouterA: High congestion (95%). Tail drop 55 packets.
#   RouterB: Low load (49%). Buffer drains 299. Buffer=699.
#   RouterC: Moderate load (57%). Priority drop 57 packets. Buffer=1438.
#
# ⏱️ Time step 6920 sec:
#   RouterA: Low load (49%). Buffer drains 373. Buffer=872.
#   RouterB: Low load (34%). Buffer drains 260. Buffer=609.
#   RouterC: High congestion (86%). Tail drop 868 packets.
#
# ⏱️ Time step 6930 sec:
#   RouterA: High congestion (84%). Tail drop 292 packets.
#   RouterB: High congestion (92%). Tail drop 69 packets.
#   RouterC: Moderate load (71%). Priority drop 71 packets. Buffer=1284.
#
# ⏱️ Time step 6940 sec:
#   RouterA: High congestion (99%). Tail drop 495 packets.
#   RouterB: Low load (19%). Buffer drains 328. Buffer=767.
#   RouterC: Low load (24%). Buffer drains 421. Buffer=983.
#
# ⏱️ Time step 6950 sec:
#   RouterA: Moderate load (70%). Priority drop 70 packets. Buffer=1280.
#   RouterB: Low load (13%). Buffer drains 249. Buffer=583.
#   RouterC: Moderate load (52%). Priority drop 52 packets. Buffer=1191.
#
# ⏱️ Time step 6960 sec:
#   RouterA: Low load (37%). Buffer drains 439. Buffer=1026.
#   RouterB: Low load (6%). Buffer drains 183. Buffer=430.
#   RouterC: Low load (17%). Buffer drains 382. Buffer=894.
#
# ⏱️ Time step 6970 sec:
#   RouterA: Low load (38%). Buffer drains 364. Buffer=852.
#   RouterB: Low load (22%). Buffer drains 162. Buffer=378.
#   RouterC: Low load (38%). Buffer drains 325. Buffer=759.
#
# ⏱️ Time step 6980 sec:
#   RouterA: High congestion (88%). Tail drop 292 packets.
#   RouterB: High congestion (93%). Buffer at 843/1000.
#   RouterC: Low load (29%). Buffer drains 271. Buffer=633.
#
# ⏱️ Time step 6990 sec:
#   RouterA: Moderate load (64%). Priority drop 64 packets. Buffer=1256.
#   RouterB: Low load (32%). Buffer drains 300. Buffer=703.
#   RouterC: Low load (8%). Buffer drains 201. Buffer=472.

# %%
#LEAKY BUCKET
import pandas as pd

def run_leaky_bucket(congestion_file, bucket_capacity=200, leak_rate=50, timestep=10):
    """
    Apply Leaky Bucket per router across congestion timesteps.

    Args:
        congestion_file: CSV with Time, RouterA, RouterB, RouterC columns
        bucket_capacity: max buffer size (arbitrary units)
        leak_rate: fixed leak rate per timestep
        timestep: interval in seconds between samples
    """
    df = pd.read_csv(congestion_file)

    # Ensure Time column exists
    if "Time" not in df.columns:
        df.insert(0, "Time", [i * timestep for i in range(len(df))])

    routers = [c for c in df.columns if c.startswith("Router")]
    buckets = {r: 0 for r in routers}  # initialize bucket level per router

    for _, row in df.iterrows():
        time_label = row["Time"]
        print(f"\n⏱️ Time step {time_label} sec:")

        for r in routers:
            load = float(row[r])  # congestion percentage

            # Convert congestion % to incoming traffic (scaled)
            arrivals = int((load / 100) * bucket_capacity * 0.5)

            # Leak traffic
            leaked = min(buckets[r], leak_rate)
            buckets[r] -= leaked

            # Attempt to add arrivals
            if buckets[r] + arrivals <= bucket_capacity:
                buckets[r] += arrivals
                action = "queued"
            else:
                dropped = (buckets[r] + arrivals) - bucket_capacity
                buckets[r] = bucket_capacity
                action = f"dropped {dropped}"

            print(f"  {r}: load={load:.0f}%, arrivals={arrivals}, leaked={leaked}, "
                  f"bucket={buckets[r]}/{bucket_capacity}, action={action}")
congestion_file = "C:/Users/ASUS/Downloads/router_congestion_int.csv"
run_leaky_bucket(congestion_file)
# Out:
# ⏱️ Time step 0 sec:
#   RouterA: load=1%, arrivals=1, leaked=0, bucket=1/200, action=queued
#   RouterB: load=29%, arrivals=28, leaked=0, bucket=28/200, action=queued
#   RouterC: load=30%, arrivals=30, leaked=0, bucket=30/200, action=queued
#
# ⏱️ Time step 10 sec:
#   RouterA: load=3%, arrivals=3, leaked=1, bucket=3/200, action=queued
#   RouterB: load=27%, arrivals=27, leaked=28, bucket=27/200, action=queued
#   RouterC: load=68%, arrivals=68, leaked=30, bucket=68/200, action=queued
#
# ⏱️ Time step 20 sec:
#   RouterA: load=35%, arrivals=35, leaked=3, bucket=35/200, action=queued
#   RouterB: load=38%, arrivals=38, leaked=27, bucket=38/200, action=queued
#   RouterC: load=90%, arrivals=90, leaked=50, bucket=108/200, action=queued
#
# ⏱️ Time step 30 sec:
#   RouterA: load=97%, arrivals=97, leaked=35, bucket=97/200, action=queued
#   RouterB: load=66%, arrivals=66, leaked=38, bucket=66/200, action=queued
#   RouterC: load=3%, arrivals=3, leaked=50, bucket=61/200, action=queued
#
# ⏱️ Time step 40 sec:
#   RouterA: load=45%, arrivals=45, leaked=50, bucket=92/200, action=queued
#   RouterB: load=94%, arrivals=94, leaked=50, bucket=110/200, action=queued
#   RouterC: load=9%, arrivals=9, leaked=50, bucket=20/200, action=queued
#
# ⏱️ Time step 50 sec:
#   RouterA: load=2%, arrivals=2, leaked=50, bucket=44/200, action=queued
#   RouterB: load=16%, arrivals=16, leaked=50, bucket=76/200, action=queued
#   RouterC: load=31%, arrivals=31, leaked=20, bucket=31/200, action=queued
#
# ⏱️ Time step 60 sec:
#   RouterA: load=36%, arrivals=36, leaked=44, bucket=36/200, action=queued
#   RouterB: load=9%, arrivals=9, leaked=50, bucket=35/200, action=queued
#   RouterC: load=62%, arrivals=62, leaked=31, bucket=62/200, action=queued
#
# ⏱️ Time step 70 sec:
#   RouterA: load=23%, arrivals=23, leaked=36, bucket=23/200, action=queued
#   RouterB: load=34%, arrivals=34, leaked=35, bucket=34/200, action=queued
#   RouterC: load=29%, arrivals=28, leaked=50, bucket=40/200, action=queued
#
# ⏱️ Time step 80 sec:
#   RouterA: load=22%, arrivals=22, leaked=23, bucket=22/200, action=queued
#   RouterB: load=95%, arrivals=95, leaked=34, bucket=95/200, action=queued
#   RouterC: load=83%, arrivals=83, leaked=40, bucket=83/200, action=queued
#
# ⏱️ Time step 90 sec:
#   RouterA: load=56%, arrivals=56, leaked=22, bucket=56/200, action=queued
#   RouterB: load=92%, arrivals=92, leaked=50, bucket=137/200, action=queued
#   RouterC: load=13%, arrivals=13, leaked=50, bucket=46/200, action=queued
#
# ⏱️ Time step 100 sec:
#   RouterA: load=99%, arrivals=99, leaked=50, bucket=105/200, action=queued
#   RouterB: load=1%, arrivals=1, leaked=50, bucket=88/200, action=queued
#   RouterC: load=30%, arrivals=30, leaked=46, bucket=30/200, action=queued
#
# ⏱️ Time step 110 sec:
#   RouterA: load=71%, arrivals=71, leaked=50, bucket=126/200, action=queued
#   RouterB: load=28%, arrivals=28, leaked=50, bucket=66/200, action=queued
#   RouterC: load=73%, arrivals=73, leaked=30, bucket=73/200, action=queued
#
# ⏱️ Time step 120 sec:
#   RouterA: load=30%, arrivals=30, leaked=50, bucket=106/200, action=queued
#   RouterB: load=26%, arrivals=26, leaked=50, bucket=42/200, action=queued
#   RouterC: load=32%, arrivals=32, leaked=50, bucket=55/200, action=queued
#
# ⏱️ Time step 130 sec:
#   RouterA: load=96%, arrivals=96, leaked=50, bucket=152/200, action=queued
#   RouterB: load=65%, arrivals=65, leaked=42, bucket=65/200, action=queued
#   RouterC: load=65%, arrivals=65, leaked=50, bucket=70/200, action=queued
#
# ⏱️ Time step 140 sec:
#   RouterA: load=21%, arrivals=21, leaked=50, bucket=123/200, action=queued
#   RouterB: load=38%, arrivals=38, leaked=50, bucket=53/200, action=queued
#   RouterC: load=35%, arrivals=35, leaked=50, bucket=55/200, action=queued
#
# ⏱️ Time step 150 sec:
#   RouterA: load=56%, arrivals=56, leaked=50, bucket=129/200, action=queued
#   RouterB: load=51%, arrivals=51, leaked=50, bucket=54/200, action=queued
#   RouterC: load=30%, arrivals=30, leaked=50, bucket=35/200, action=queued
#
# ⏱️ Time step 160 sec:
#   RouterA: load=93%, arrivals=93, leaked=50, bucket=172/200, action=queued
#   RouterB: load=12%, arrivals=12, leaked=50, bucket=16/200, action=queued
#   RouterC: load=11%, arrivals=11, leaked=35, bucket=11/200, action=queued
#
# ⏱️ Time step 170 sec:
#   RouterA: load=10%, arrivals=10, leaked=50, bucket=132/200, action=queued
#   RouterB: load=85%, arrivals=85, leaked=16, bucket=85/200, action=queued
#   RouterC: load=53%, arrivals=53, leaked=11, bucket=53/200, action=queued
#
# ⏱️ Time step 180 sec:
#   RouterA: load=98%, arrivals=98, leaked=50, bucket=180/200, action=queued
#   RouterB: load=43%, arrivals=43, leaked=50, bucket=78/200, action=queued
#   RouterC: load=46%, arrivals=46, leaked=50, bucket=49/200, action=queued
#
# ⏱️ Time step 190 sec:
#   RouterA: load=84%, arrivals=84, leaked=50, bucket=200/200, action=dropped 14
#   RouterB: load=8%, arrivals=8, leaked=50, bucket=36/200, action=queued
#   RouterC: load=97%, arrivals=97, leaked=49, bucket=97/200, action=queued
#
# ⏱️ Time step 200 sec:
#   RouterA: load=2%, arrivals=2, leaked=50, bucket=152/200, action=queued
#   RouterB: load=39%, arrivals=39, leaked=36, bucket=39/200, action=queued
#   RouterC: load=0%, arrivals=0, leaked=50, bucket=47/200, action=queued
#
# ⏱️ Time step 210 sec:
#   RouterA: load=48%, arrivals=48, leaked=50, bucket=150/200, action=queued
#   RouterB: load=11%, arrivals=11, leaked=39, bucket=11/200, action=queued
#   RouterC: load=31%, arrivals=31, leaked=47, bucket=31/200, action=queued
#
# ⏱️ Time step 220 sec:
#   RouterA: load=67%, arrivals=67, leaked=50, bucket=167/200, action=queued
#   RouterB: load=71%, arrivals=71, leaked=11, bucket=71/200, action=queued
#   RouterC: load=30%, arrivals=30, leaked=31, bucket=30/200, action=queued
#
# ⏱️ Time step 230 sec:
#   RouterA: load=19%, arrivals=19, leaked=50, bucket=136/200, action=queued
#   RouterB: load=58%, arrivals=57, leaked=50, bucket=78/200, action=queued
#   RouterC: load=97%, arrivals=97, leaked=30, bucket=97/200, action=queued
#
# ⏱️ Time step 240 sec:
#   RouterA: load=85%, arrivals=85, leaked=50, bucket=171/200, action=queued
#   RouterB: load=77%, arrivals=77, leaked=50, bucket=105/200, action=queued
#   RouterC: load=52%, arrivals=52, leaked=50, bucket=99/200, action=queued
#
# ⏱️ Time step 250 sec:
#   RouterA: load=97%, arrivals=97, leaked=50, bucket=200/200, action=dropped 18
#   RouterB: load=90%, arrivals=90, leaked=50, bucket=145/200, action=queued
#   RouterC: load=88%, arrivals=88, leaked=50, bucket=137/200, action=queued
#
# ⏱️ Time step 260 sec:
#   RouterA: load=71%, arrivals=71, leaked=50, bucket=200/200, action=dropped 21
#   RouterB: load=91%, arrivals=91, leaked=50, bucket=186/200, action=queued
#   RouterC: load=10%, arrivals=10, leaked=50, bucket=97/200, action=queued
#
# ⏱️ Time step 270 sec:
#   RouterA: load=61%, arrivals=61, leaked=50, bucket=200/200, action=dropped 11
#   RouterB: load=79%, arrivals=79, leaked=50, bucket=200/200, action=dropped 15
#   RouterC: load=92%, arrivals=92, leaked=50, bucket=139/200, action=queued
#
# ⏱️ Time step 280 sec:
#   RouterA: load=75%, arrivals=75, leaked=50, bucket=200/200, action=dropped 25
#   RouterB: load=15%, arrivals=15, leaked=50, bucket=165/200, action=queued
#   RouterC: load=41%, arrivals=41, leaked=50, bucket=130/200, action=queued
#
# ⏱️ Time step 290 sec:
#   RouterA: load=45%, arrivals=45, leaked=50, bucket=195/200, action=queued
#   RouterB: load=28%, arrivals=28, leaked=50, bucket=143/200, action=queued
#   RouterC: load=98%, arrivals=98, leaked=50, bucket=178/200, action=queued
#
# ⏱️ Time step 300 sec:
#   RouterA: load=45%, arrivals=45, leaked=50, bucket=190/200, action=queued
#   RouterB: load=68%, arrivals=68, leaked=50, bucket=161/200, action=queued
#   RouterC: load=66%, arrivals=66, leaked=50, bucket=194/200, action=queued
#
# ⏱️ Time step 310 sec:
#   RouterA: load=67%, arrivals=67, leaked=50, bucket=200/200, action=dropped 7
#   RouterB: load=96%, arrivals=96, leaked=50, bucket=200/200, action=dropped 7
#   RouterC: load=79%, arrivals=79, leaked=50, bucket=200/200, action=dropped 23
#
# ⏱️ Time step 320 sec:
#   RouterA: load=62%, arrivals=62, leaked=50, bucket=200/200, action=dropped 12
#   RouterB: load=35%, arrivals=35, leaked=50, bucket=185/200, action=queued
#   RouterC: load=14%, arrivals=14, leaked=50, bucket=164/200, action=queued
#
# ⏱️ Time step 330 sec:
#   RouterA: load=34%, arrivals=34, leaked=50, bucket=184/200, action=queued
#   RouterB: load=10%, arrivals=10, leaked=50, bucket=145/200, action=queued
#   RouterC: load=70%, arrivals=70, leaked=50, bucket=184/200, action=queued
#
# ⏱️ Time step 340 sec:
#   RouterA: load=36%, arrivals=36, leaked=50, bucket=170/200, action=queued
#   RouterB: load=58%, arrivals=57, leaked=50, bucket=152/200, action=queued
#   RouterC: load=77%, arrivals=77, leaked=50, bucket=200/200, action=dropped 11
#
# ⏱️ Time step 350 sec:
#   RouterA: load=45%, arrivals=45, leaked=50, bucket=165/200, action=queued
#   RouterB: load=53%, arrivals=53, leaked=50, bucket=155/200, action=queued
#   RouterC: load=78%, arrivals=78, leaked=50, bucket=200/200, action=dropped 28
#
# ⏱️ Time step 360 sec:
#   RouterA: load=46%, arrivals=46, leaked=50, bucket=161/200, action=queued
#   RouterB: load=46%, arrivals=46, leaked=50, bucket=151/200, action=queued
#   RouterC: load=20%, arrivals=20, leaked=50, bucket=170/200, action=queued
#
# ⏱️ Time step 370 sec:
#   RouterA: load=26%, arrivals=26, leaked=50, bucket=137/200, action=queued
#   RouterB: load=40%, arrivals=40, leaked=50, bucket=141/200, action=queued
#   RouterC: load=73%, arrivals=73, leaked=50, bucket=193/200, action=queued
#
# ⏱️ Time step 380 sec:
#   RouterA: load=87%, arrivals=87, leaked=50, bucket=174/200, action=queued
#   RouterB: load=60%, arrivals=60, leaked=50, bucket=151/200, action=queued
#   RouterC: load=95%, arrivals=95, leaked=50, bucket=200/200, action=dropped 38
#
# ⏱️ Time step 390 sec:
#   RouterA: load=94%, arrivals=94, leaked=50, bucket=200/200, action=dropped 18
#   RouterB: load=72%, arrivals=72, leaked=50, bucket=173/200, action=queued
#   RouterC: load=7%, arrivals=7, leaked=50, bucket=157/200, action=queued
#
# ⏱️ Time step 400 sec:
#   RouterA: load=1%, arrivals=1, leaked=50, bucket=151/200, action=queued
#   RouterB: load=5%, arrivals=5, leaked=50, bucket=128/200, action=queued
#   RouterC: load=33%, arrivals=33, leaked=50, bucket=140/200, action=queued
#
# ⏱️ Time step 410 sec:
#   RouterA: load=46%, arrivals=46, leaked=50, bucket=147/200, action=queued
#   RouterB: load=66%, arrivals=66, leaked=50, bucket=144/200, action=queued
#   RouterC: load=40%, arrivals=40, leaked=50, bucket=130/200, action=queued
#
# ⏱️ Time step 420 sec:
#   RouterA: load=77%, arrivals=77, leaked=50, bucket=174/200, action=queued
#   RouterB: load=98%, arrivals=98, leaked=50, bucket=192/200, action=queued
#   RouterC: load=11%, arrivals=11, leaked=50, bucket=91/200, action=queued
#
# ⏱️ Time step 430 sec:
#   RouterA: load=4%, arrivals=4, leaked=50, bucket=128/200, action=queued
#   RouterB: load=99%, arrivals=99, leaked=50, bucket=200/200, action=dropped 41
#   RouterC: load=100%, arrivals=100, leaked=50, bucket=141/200, action=queued
#
# ⏱️ Time step 440 sec:
#   RouterA: load=31%, arrivals=31, leaked=50, bucket=109/200, action=queued
#   RouterB: load=76%, arrivals=76, leaked=50, bucket=200/200, action=dropped 26
#   RouterC: load=77%, arrivals=77, leaked=50, bucket=168/200, action=queued
#
# ⏱️ Time step 450 sec:
#   RouterA: load=18%, arrivals=18, leaked=50, bucket=77/200, action=queued
#   RouterB: load=98%, arrivals=98, leaked=50, bucket=200/200, action=dropped 48
#   RouterC: load=73%, arrivals=73, leaked=50, bucket=191/200, action=queued
#
# ⏱️ Time step 460 sec:
#   RouterA: load=9%, arrivals=9, leaked=50, bucket=36/200, action=queued
#   RouterB: load=55%, arrivals=55, leaked=50, bucket=200/200, action=dropped 5
#   RouterC: load=38%, arrivals=38, leaked=50, bucket=179/200, action=queued
#
# ⏱️ Time step 470 sec:
#   RouterA: load=10%, arrivals=10, leaked=36, bucket=10/200, action=queued
#   RouterB: load=17%, arrivals=17, leaked=50, bucket=167/200, action=queued
#   RouterC: load=60%, arrivals=60, leaked=50, bucket=189/200, action=queued
#
# ⏱️ Time step 480 sec:
#   RouterA: load=0%, arrivals=0, leaked=10, bucket=0/200, action=queued
#   RouterB: load=16%, arrivals=16, leaked=50, bucket=133/200, action=queued
#   RouterC: load=89%, arrivals=89, leaked=50, bucket=200/200, action=dropped 28
#
# ⏱️ Time step 490 sec:
#   RouterA: load=73%, arrivals=73, leaked=0, bucket=73/200, action=queued
#   RouterB: load=54%, arrivals=54, leaked=50, bucket=137/200, action=queued
#   RouterC: load=18%, arrivals=18, leaked=50, bucket=168/200, action=queued
#
# ⏱️ Time step 500 sec:
#   RouterA: load=28%, arrivals=28, leaked=50, bucket=51/200, action=queued
#   RouterB: load=13%, arrivals=13, leaked=50, bucket=100/200, action=queued
#   RouterC: load=66%, arrivals=66, leaked=50, bucket=184/200, action=queued
#
# ⏱️ Time step 510 sec:
#   RouterA: load=48%, arrivals=48, leaked=50, bucket=49/200, action=queued
#   RouterB: load=19%, arrivals=19, leaked=50, bucket=69/200, action=queued
#   RouterC: load=43%, arrivals=43, leaked=50, bucket=177/200, action=queued
#
# ⏱️ Time step 520 sec:
#   RouterA: load=36%, arrivals=36, leaked=49, bucket=36/200, action=queued
#   RouterB: load=66%, arrivals=66, leaked=50, bucket=85/200, action=queued
#   RouterC: load=93%, arrivals=93, leaked=50, bucket=200/200, action=dropped 20
#
# ⏱️ Time step 530 sec:
#   RouterA: load=3%, arrivals=3, leaked=36, bucket=3/200, action=queued
#   RouterB: load=59%, arrivals=59, leaked=50, bucket=94/200, action=queued
#   RouterC: load=62%, arrivals=62, leaked=50, bucket=200/200, action=dropped 12
#
# ⏱️ Time step 540 sec:
#   RouterA: load=39%, arrivals=39, leaked=3, bucket=39/200, action=queued
#   RouterB: load=17%, arrivals=17, leaked=50, bucket=61/200, action=queued
#   RouterC: load=18%, arrivals=18, leaked=50, bucket=168/200, action=queued
#
# ⏱️ Time step 550 sec:
#   RouterA: load=67%, arrivals=67, leaked=39, bucket=67/200, action=queued
#   RouterB: load=4%, arrivals=4, leaked=50, bucket=15/200, action=queued
#   RouterC: load=69%, arrivals=69, leaked=50, bucket=187/200, action=queued
#
# ⏱️ Time step 560 sec:
#   RouterA: load=0%, arrivals=0, leaked=50, bucket=17/200, action=queued
#   RouterB: load=98%, arrivals=98, leaked=15, bucket=98/200, action=queued
#   RouterC: load=94%, arrivals=94, leaked=50, bucket=200/200, action=dropped 31
#
# ⏱️ Time step 570 sec:
#   RouterA: load=26%, arrivals=26, leaked=17, bucket=26/200, action=queued
#   RouterB: load=12%, arrivals=12, leaked=50, bucket=60/200, action=queued
#   RouterC: load=6%, arrivals=6, leaked=50, bucket=156/200, action=queued
#
# ⏱️ Time step 580 sec:
#   RouterA: load=66%, arrivals=66, leaked=26, bucket=66/200, action=queued
#   RouterB: load=94%, arrivals=94, leaked=50, bucket=104/200, action=queued
#   RouterC: load=38%, arrivals=38, leaked=50, bucket=144/200, action=queued
#
# ⏱️ Time step 590 sec:
#   RouterA: load=62%, arrivals=62, leaked=50, bucket=78/200, action=queued
#   RouterB: load=15%, arrivals=15, leaked=50, bucket=69/200, action=queued
#   RouterC: load=19%, arrivals=19, leaked=50, bucket=113/200, action=queued
#
# ⏱️ Time step 600 sec:
#   RouterA: load=82%, arrivals=82, leaked=50, bucket=110/200, action=queued
#   RouterB: load=72%, arrivals=72, leaked=50, bucket=91/200, action=queued
#   RouterC: load=43%, arrivals=43, leaked=50, bucket=106/200, action=queued
#
# ⏱️ Time step 610 sec:
#   RouterA: load=43%, arrivals=43, leaked=50, bucket=103/200, action=queued
#   RouterB: load=88%, arrivals=88, leaked=50, bucket=129/200, action=queued
#   RouterC: load=59%, arrivals=59, leaked=50, bucket=115/200, action=queued
#
# ⏱️ Time step 620 sec:
#   RouterA: load=7%, arrivals=7, leaked=50, bucket=60/200, action=queued
#   RouterB: load=96%, arrivals=96, leaked=50, bucket=175/200, action=queued
#   RouterC: load=38%, arrivals=38, leaked=50, bucket=103/200, action=queued
#
# ⏱️ Time step 630 sec:
#   RouterA: load=3%, arrivals=3, leaked=50, bucket=13/200, action=queued
#   RouterB: load=43%, arrivals=43, leaked=50, bucket=168/200, action=queued
#   RouterC: load=38%, arrivals=38, leaked=50, bucket=91/200, action=queued
#
# ⏱️ Time step 640 sec:
#   RouterA: load=74%, arrivals=74, leaked=13, bucket=74/200, action=queued
#   RouterB: load=98%, arrivals=98, leaked=50, bucket=200/200, action=dropped 16
#   RouterC: load=26%, arrivals=26, leaked=50, bucket=67/200, action=queued
#
# ⏱️ Time step 650 sec:
#   RouterA: load=83%, arrivals=83, leaked=50, bucket=107/200, action=queued
#   RouterB: load=6%, arrivals=6, leaked=50, bucket=156/200, action=queued
#   RouterC: load=70%, arrivals=70, leaked=50, bucket=87/200, action=queued
#
# ⏱️ Time step 660 sec:
#   RouterA: load=13%, arrivals=13, leaked=50, bucket=70/200, action=queued
#   RouterB: load=59%, arrivals=59, leaked=50, bucket=165/200, action=queued
#   RouterC: load=77%, arrivals=77, leaked=50, bucket=114/200, action=queued
#
# ⏱️ Time step 670 sec:
#   RouterA: load=6%, arrivals=6, leaked=50, bucket=26/200, action=queued
#   RouterB: load=18%, arrivals=18, leaked=50, bucket=133/200, action=queued
#   RouterC: load=4%, arrivals=4, leaked=50, bucket=68/200, action=queued
#
# ⏱️ Time step 680 sec:
#   RouterA: load=44%, arrivals=44, leaked=26, bucket=44/200, action=queued
#   RouterB: load=93%, arrivals=93, leaked=50, bucket=176/200, action=queued
#   RouterC: load=63%, arrivals=63, leaked=50, bucket=81/200, action=queued
#
# ⏱️ Time step 690 sec:
#   RouterA: load=3%, arrivals=3, leaked=44, bucket=3/200, action=queued
#   RouterB: load=76%, arrivals=76, leaked=50, bucket=200/200, action=dropped 2
#   RouterC: load=64%, arrivals=64, leaked=50, bucket=95/200, action=queued
#
# ⏱️ Time step 700 sec:
#   RouterA: load=49%, arrivals=49, leaked=3, bucket=49/200, action=queued
#   RouterB: load=7%, arrivals=7, leaked=50, bucket=157/200, action=queued
#   RouterC: load=78%, arrivals=78, leaked=50, bucket=123/200, action=queued
#
# ⏱️ Time step 710 sec:
#   RouterA: load=48%, arrivals=48, leaked=49, bucket=48/200, action=queued
#   RouterB: load=100%, arrivals=100, leaked=50, bucket=200/200, action=dropped 7
#   RouterC: load=25%, arrivals=25, leaked=50, bucket=98/200, action=queued
#
# ⏱️ Time step 720 sec:
#   RouterA: load=38%, arrivals=38, leaked=48, bucket=38/200, action=queued
#   RouterB: load=38%, arrivals=38, leaked=50, bucket=188/200, action=queued
#   RouterC: load=65%, arrivals=65, leaked=50, bucket=113/200, action=queued
#
# ⏱️ Time step 730 sec:
#   RouterA: load=46%, arrivals=46, leaked=38, bucket=46/200, action=queued
#   RouterB: load=70%, arrivals=70, leaked=50, bucket=200/200, action=dropped 8
#   RouterC: load=85%, arrivals=85, leaked=50, bucket=148/200, action=queued
#
# ⏱️ Time step 740 sec:
#   RouterA: load=3%, arrivals=3, leaked=46, bucket=3/200, action=queued
#   RouterB: load=43%, arrivals=43, leaked=50, bucket=193/200, action=queued
#   RouterC: load=88%, arrivals=88, leaked=50, bucket=186/200, action=queued
#
# ⏱️ Time step 750 sec:
#   RouterA: load=2%, arrivals=2, leaked=3, bucket=2/200, action=queued
#   RouterB: load=46%, arrivals=46, leaked=50, bucket=189/200, action=queued
#   RouterC: load=99%, arrivals=99, leaked=50, bucket=200/200, action=dropped 35
#
# ⏱️ Time step 760 sec:
#   RouterA: load=52%, arrivals=52, leaked=2, bucket=52/200, action=queued
#   RouterB: load=2%, arrivals=2, leaked=50, bucket=141/200, action=queued
#   RouterC: load=12%, arrivals=12, leaked=50, bucket=162/200, action=queued
#
# ⏱️ Time step 770 sec:
#   RouterA: load=32%, arrivals=32, leaked=50, bucket=34/200, action=queued
#   RouterB: load=14%, arrivals=14, leaked=50, bucket=105/200, action=queued
#   RouterC: load=14%, arrivals=14, leaked=50, bucket=126/200, action=queued
#
# ⏱️ Time step 780 sec:
#   RouterA: load=74%, arrivals=74, leaked=34, bucket=74/200, action=queued
#   RouterB: load=27%, arrivals=27, leaked=50, bucket=82/200, action=queued
#   RouterC: load=82%, arrivals=82, leaked=50, bucket=158/200, action=queued
#
# ⏱️ Time step 790 sec:
#   RouterA: load=25%, arrivals=25, leaked=50, bucket=49/200, action=queued
#   RouterB: load=97%, arrivals=97, leaked=50, bucket=129/200, action=queued
#   RouterC: load=83%, arrivals=83, leaked=50, bucket=191/200, action=queued
#
# ⏱️ Time step 800 sec:
#   RouterA: load=91%, arrivals=91, leaked=49, bucket=91/200, action=queued
#   RouterB: load=73%, arrivals=73, leaked=50, bucket=152/200, action=queued
#   RouterC: load=88%, arrivals=88, leaked=50, bucket=200/200, action=dropped 29
#
# ⏱️ Time step 810 sec:
#   RouterA: load=14%, arrivals=14, leaked=50, bucket=55/200, action=queued
#   RouterB: load=24%, arrivals=24, leaked=50, bucket=126/200, action=queued
#   RouterC: load=46%, arrivals=46, leaked=50, bucket=196/200, action=queued
#
# ⏱️ Time step 820 sec:
#   RouterA: load=72%, arrivals=72, leaked=50, bucket=77/200, action=queued
#   RouterB: load=92%, arrivals=92, leaked=50, bucket=168/200, action=queued
#   RouterC: load=7%, arrivals=7, leaked=50, bucket=153/200, action=queued
#
# ⏱️ Time step 830 sec:
#   RouterA: load=21%, arrivals=21, leaked=50, bucket=48/200, action=queued
#   RouterB: load=15%, arrivals=15, leaked=50, bucket=133/200, action=queued
#   RouterC: load=4%, arrivals=4, leaked=50, bucket=107/200, action=queued
#
# ⏱️ Time step 840 sec:
#   RouterA: load=52%, arrivals=52, leaked=48, bucket=52/200, action=queued
#   RouterB: load=6%, arrivals=6, leaked=50, bucket=89/200, action=queued
#   RouterC: load=98%, arrivals=98, leaked=50, bucket=155/200, action=queued
#
# ⏱️ Time step 850 sec:
#   RouterA: load=95%, arrivals=95, leaked=50, bucket=97/200, action=queued
#   RouterB: load=34%, arrivals=34, leaked=50, bucket=73/200, action=queued
#   RouterC: load=79%, arrivals=79, leaked=50, bucket=184/200, action=queued
#
# ⏱️ Time step 860 sec:
#   RouterA: load=65%, arrivals=65, leaked=50, bucket=112/200, action=queued
#   RouterB: load=48%, arrivals=48, leaked=50, bucket=71/200, action=queued
#   RouterC: load=30%, arrivals=30, leaked=50, bucket=164/200, action=queued
#
# ⏱️ Time step 870 sec:
#   RouterA: load=7%, arrivals=7, leaked=50, bucket=69/200, action=queued
#   RouterB: load=50%, arrivals=50, leaked=50, bucket=71/200, action=queued
#   RouterC: load=50%, arrivals=50, leaked=50, bucket=164/200, action=queued
#
# ⏱️ Time step 880 sec:
#   RouterA: load=75%, arrivals=75, leaked=50, bucket=94/200, action=queued
#   RouterB: load=11%, arrivals=11, leaked=50, bucket=32/200, action=queued
#   RouterC: load=76%, arrivals=76, leaked=50, bucket=190/200, action=queued
#
# ⏱️ Time step 890 sec:
#   RouterA: load=76%, arrivals=76, leaked=50, bucket=120/200, action=queued
#   RouterB: load=38%, arrivals=38, leaked=32, bucket=38/200, action=queued
#   RouterC: load=75%, arrivals=75, leaked=50, bucket=200/200, action=dropped 15
#
# ⏱️ Time step 900 sec:
#   RouterA: load=42%, arrivals=42, leaked=50, bucket=112/200, action=queued
#   RouterB: load=22%, arrivals=22, leaked=38, bucket=22/200, action=queued
#   RouterC: load=96%, arrivals=96, leaked=50, bucket=200/200, action=dropped 46
#
# ⏱️ Time step 910 sec:
#   RouterA: load=48%, arrivals=48, leaked=50, bucket=110/200, action=queued
#   RouterB: load=34%, arrivals=34, leaked=22, bucket=34/200, action=queued
#   RouterC: load=66%, arrivals=66, leaked=50, bucket=200/200, action=dropped 16
#
# ⏱️ Time step 920 sec:
#   RouterA: load=22%, arrivals=22, leaked=50, bucket=82/200, action=queued
#   RouterB: load=78%, arrivals=78, leaked=34, bucket=78/200, action=queued
#   RouterC: load=77%, arrivals=77, leaked=50, bucket=200/200, action=dropped 27
#
# ⏱️ Time step 930 sec:
#   RouterA: load=14%, arrivals=14, leaked=50, bucket=46/200, action=queued
#   RouterB: load=97%, arrivals=97, leaked=50, bucket=125/200, action=queued
#   RouterC: load=98%, arrivals=98, leaked=50, bucket=200/200, action=dropped 48
#
# ⏱️ Time step 940 sec:
#   RouterA: load=3%, arrivals=3, leaked=46, bucket=3/200, action=queued
#   RouterB: load=47%, arrivals=47, leaked=50, bucket=122/200, action=queued
#   RouterC: load=31%, arrivals=31, leaked=50, bucket=181/200, action=queued
#
# ⏱️ Time step 950 sec:
#   RouterA: load=84%, arrivals=84, leaked=3, bucket=84/200, action=queued
#   RouterB: load=1%, arrivals=1, leaked=50, bucket=73/200, action=queued
#   RouterC: load=34%, arrivals=34, leaked=50, bucket=165/200, action=queued
#
# ⏱️ Time step 960 sec:
#   RouterA: load=95%, arrivals=95, leaked=50, bucket=129/200, action=queued
#   RouterB: load=27%, arrivals=27, leaked=50, bucket=50/200, action=queued
#   RouterC: load=28%, arrivals=28, leaked=50, bucket=143/200, action=queued
#
# ⏱️ Time step 970 sec:
#   RouterA: load=0%, arrivals=0, leaked=50, bucket=79/200, action=queued
#   RouterB: load=44%, arrivals=44, leaked=50, bucket=44/200, action=queued
#   RouterC: load=81%, arrivals=81, leaked=50, bucket=174/200, action=queued
#
# ⏱️ Time step 980 sec:
#   RouterA: load=44%, arrivals=44, leaked=50, bucket=73/200, action=queued
#   RouterB: load=87%, arrivals=87, leaked=44, bucket=87/200, action=queued
#   RouterC: load=14%, arrivals=14, leaked=50, bucket=138/200, action=queued
#
# ⏱️ Time step 990 sec:
#   RouterA: load=60%, arrivals=60, leaked=50, bucket=83/200, action=queued
#   RouterB: load=1%, arrivals=1, leaked=50, bucket=38/200, action=queued
#   RouterC: load=89%, arrivals=89, leaked=50, bucket=177/200, action=queued
#
# ⏱️ Time step 1000 sec:
#   RouterA: load=43%, arrivals=43, leaked=50, bucket=76/200, action=queued
#   RouterB: load=43%, arrivals=43, leaked=38, bucket=43/200, action=queued
#   RouterC: load=80%, arrivals=80, leaked=50, bucket=200/200, action=dropped 7
#
# ⏱️ Time step 1010 sec:
#   RouterA: load=13%, arrivals=13, leaked=50, bucket=39/200, action=queued
#   RouterB: load=18%, arrivals=18, leaked=43, bucket=18/200, action=queued
#   RouterC: load=88%, arrivals=88, leaked=50, bucket=200/200, action=dropped 38
#
# ⏱️ Time step 1020 sec:
#   RouterA: load=18%, arrivals=18, leaked=39, bucket=18/200, action=queued
#   RouterB: load=44%, arrivals=44, leaked=18, bucket=44/200, action=queued
#   RouterC: load=82%, arrivals=82, leaked=50, bucket=200/200, action=dropped 32
#
# ⏱️ Time step 1030 sec:
#   RouterA: load=25%, arrivals=25, leaked=18, bucket=25/200, action=queued
#   RouterB: load=92%, arrivals=92, leaked=44, bucket=92/200, action=queued
#   RouterC: load=84%, arrivals=84, leaked=50, bucket=200/200, action=dropped 34
#
# ⏱️ Time step 1040 sec:
#   RouterA: load=50%, arrivals=50, leaked=25, bucket=50/200, action=queued
#   RouterB: load=74%, arrivals=74, leaked=50, bucket=116/200, action=queued
#   RouterC: load=71%, arrivals=71, leaked=50, bucket=200/200, action=dropped 21
#
# ⏱️ Time step 1050 sec:
#   RouterA: load=41%, arrivals=41, leaked=50, bucket=41/200, action=queued
#   RouterB: load=32%, arrivals=32, leaked=50, bucket=98/200, action=queued
#   RouterC: load=13%, arrivals=13, leaked=50, bucket=163/200, action=queued
#
# ⏱️ Time step 1060 sec:
#   RouterA: load=70%, arrivals=70, leaked=41, bucket=70/200, action=queued
#   RouterB: load=16%, arrivals=16, leaked=50, bucket=64/200, action=queued
#   RouterC: load=47%, arrivals=47, leaked=50, bucket=160/200, action=queued
#
# ⏱️ Time step 1070 sec:
#   RouterA: load=10%, arrivals=10, leaked=50, bucket=30/200, action=queued
#   RouterB: load=21%, arrivals=21, leaked=50, bucket=35/200, action=queued
#   RouterC: load=31%, arrivals=31, leaked=50, bucket=141/200, action=queued
#
# ⏱️ Time step 1080 sec:
#   RouterA: load=14%, arrivals=14, leaked=30, bucket=14/200, action=queued
#   RouterB: load=45%, arrivals=45, leaked=35, bucket=45/200, action=queued
#   RouterC: load=72%, arrivals=72, leaked=50, bucket=163/200, action=queued
#
# ⏱️ Time step 1090 sec:
#   RouterA: load=50%, arrivals=50, leaked=14, bucket=50/200, action=queued
#   RouterB: load=96%, arrivals=96, leaked=45, bucket=96/200, action=queued
#   RouterC: load=40%, arrivals=40, leaked=50, bucket=153/200, action=queued
#
# ⏱️ Time step 1100 sec:
#   RouterA: load=23%, arrivals=23, leaked=50, bucket=23/200, action=queued
#   RouterB: load=77%, arrivals=77, leaked=50, bucket=123/200, action=queued
#   RouterC: load=54%, arrivals=54, leaked=50, bucket=157/200, action=queued
#
# ⏱️ Time step 1110 sec:
#   RouterA: load=14%, arrivals=14, leaked=23, bucket=14/200, action=queued
#   RouterB: load=40%, arrivals=40, leaked=50, bucket=113/200, action=queued
#   RouterC: load=25%, arrivals=25, leaked=50, bucket=132/200, action=queued
#
# ⏱️ Time step 1120 sec:
#   RouterA: load=76%, arrivals=76, leaked=14, bucket=76/200, action=queued
#   RouterB: load=46%, arrivals=46, leaked=50, bucket=109/200, action=queued
#   RouterC: load=0%, arrivals=0, leaked=50, bucket=82/200, action=queued
#
# ⏱️ Time step 1130 sec:
#   RouterA: load=28%, arrivals=28, leaked=50, bucket=54/200, action=queued
#   RouterB: load=40%, arrivals=40, leaked=50, bucket=99/200, action=queued
#   RouterC: load=60%, arrivals=60, leaked=50, bucket=92/200, action=queued
#
# ⏱️ Time step 1140 sec:
#   RouterA: load=12%, arrivals=12, leaked=50, bucket=16/200, action=queued
#   RouterB: load=44%, arrivals=44, leaked=50, bucket=93/200, action=queued
#   RouterC: load=71%, arrivals=71, leaked=50, bucket=113/200, action=queued
#
# ⏱️ Time step 1150 sec:
#   RouterA: load=68%, arrivals=68, leaked=16, bucket=68/200, action=queued
#   RouterB: load=61%, arrivals=61, leaked=50, bucket=104/200, action=queued
#   RouterC: load=91%, arrivals=91, leaked=50, bucket=154/200, action=queued
#
# ⏱️ Time step 1160 sec:
#   RouterA: load=98%, arrivals=98, leaked=50, bucket=116/200, action=queued
#   RouterB: load=65%, arrivals=65, leaked=50, bucket=119/200, action=queued
#   RouterC: load=94%, arrivals=94, leaked=50, bucket=198/200, action=queued
#
# ⏱️ Time step 1170 sec:
#   RouterA: load=63%, arrivals=63, leaked=50, bucket=129/200, action=queued
#   RouterB: load=92%, arrivals=92, leaked=50, bucket=161/200, action=queued
#   RouterC: load=70%, arrivals=70, leaked=50, bucket=200/200, action=dropped 18
#
# ⏱️ Time step 1180 sec:
#   RouterA: load=35%, arrivals=35, leaked=50, bucket=114/200, action=queued
#   RouterB: load=65%, arrivals=65, leaked=50, bucket=176/200, action=queued
#   RouterC: load=37%, arrivals=37, leaked=50, bucket=187/200, action=queued
#
# ⏱️ Time step 1190 sec:
#   RouterA: load=73%, arrivals=73, leaked=50, bucket=137/200, action=queued
#   RouterB: load=25%, arrivals=25, leaked=50, bucket=151/200, action=queued
#   RouterC: load=43%, arrivals=43, leaked=50, bucket=180/200, action=queued
#
# ⏱️ Time step 1200 sec:
#   RouterA: load=76%, arrivals=76, leaked=50, bucket=163/200, action=queued
#   RouterB: load=9%, arrivals=9, leaked=50, bucket=110/200, action=queued
#   RouterC: load=57%, arrivals=56, leaked=50, bucket=186/200, action=queued
#
# ⏱️ Time step 1210 sec:
#   RouterA: load=74%, arrivals=74, leaked=50, bucket=187/200, action=queued
#   RouterB: load=7%, arrivals=7, leaked=50, bucket=67/200, action=queued
#   RouterC: load=60%, arrivals=60, leaked=50, bucket=196/200, action=queued
#
# ⏱️ Time step 1220 sec:
#   RouterA: load=40%, arrivals=40, leaked=50, bucket=177/200, action=queued
#   RouterB: load=54%, arrivals=54, leaked=50, bucket=71/200, action=queued
#   RouterC: load=22%, arrivals=22, leaked=50, bucket=168/200, action=queued
#
# ⏱️ Time step 1230 sec:
#   RouterA: load=59%, arrivals=59, leaked=50, bucket=186/200, action=queued
#   RouterB: load=98%, arrivals=98, leaked=50, bucket=119/200, action=queued
#   RouterC: load=70%, arrivals=70, leaked=50, bucket=188/200, action=queued
#
# ⏱️ Time step 1240 sec:
#   RouterA: load=18%, arrivals=18, leaked=50, bucket=154/200, action=queued
#   RouterB: load=69%, arrivals=69, leaked=50, bucket=138/200, action=queued
#   RouterC: load=25%, arrivals=25, leaked=50, bucket=163/200, action=queued
#
# ⏱️ Time step 1250 sec:
#   RouterA: load=36%, arrivals=36, leaked=50, bucket=140/200, action=queued
#   RouterB: load=5%, arrivals=5, leaked=50, bucket=93/200, action=queued
#   RouterC: load=50%, arrivals=50, leaked=50, bucket=163/200, action=queued
#
# ⏱️ Time step 1260 sec:
#   RouterA: load=68%, arrivals=68, leaked=50, bucket=158/200, action=queued
#   RouterB: load=48%, arrivals=48, leaked=50, bucket=91/200, action=queued
#   RouterC: load=44%, arrivals=44, leaked=50, bucket=157/200, action=queued
#
# ⏱️ Time step 1270 sec:
#   RouterA: load=70%, arrivals=70, leaked=50, bucket=178/200, action=queued
#   RouterB: load=64%, arrivals=64, leaked=50, bucket=105/200, action=queued
#   RouterC: load=6%, arrivals=6, leaked=50, bucket=113/200, action=queued
#
# ⏱️ Time step 1280 sec:
#   RouterA: load=38%, arrivals=38, leaked=50, bucket=166/200, action=queued
#   RouterB: load=91%, arrivals=91, leaked=50, bucket=146/200, action=queued
#   RouterC: load=94%, arrivals=94, leaked=50, bucket=157/200, action=queued
#
# ⏱️ Time step 1290 sec:
#   RouterA: load=99%, arrivals=99, leaked=50, bucket=200/200, action=dropped 15
#   RouterB: load=48%, arrivals=48, leaked=50, bucket=144/200, action=queued
#   RouterC: load=48%, arrivals=48, leaked=50, bucket=155/200, action=queued
#
# ⏱️ Time step 1300 sec:
#   RouterA: load=0%, arrivals=0, leaked=50, bucket=150/200, action=queued
#   RouterB: load=40%, arrivals=40, leaked=50, bucket=134/200, action=queued
#   RouterC: load=40%, arrivals=40, leaked=50, bucket=145/200, action=queued
#
# ⏱️ Time step 1310 sec:
#   RouterA: load=28%, arrivals=28, leaked=50, bucket=128/200, action=queued
#   RouterB: load=18%, arrivals=18, leaked=50, bucket=102/200, action=queued
#   RouterC: load=74%, arrivals=74, leaked=50, bucket=169/200, action=queued
#
# ⏱️ Time step 1320 sec:
#   RouterA: load=89%, arrivals=89, leaked=50, bucket=167/200, action=queued
#   RouterB: load=96%, arrivals=96, leaked=50, bucket=148/200, action=queued
#   RouterC: load=24%, arrivals=24, leaked=50, bucket=143/200, action=queued
#
# ⏱️ Time step 1330 sec:
#   RouterA: load=89%, arrivals=89, leaked=50, bucket=200/200, action=dropped 6
#   RouterB: load=29%, arrivals=28, leaked=50, bucket=126/200, action=queued
#   RouterC: load=28%, arrivals=28, leaked=50, bucket=121/200, action=queued
#
# ⏱️ Time step 1340 sec:
#   RouterA: load=40%, arrivals=40, leaked=50, bucket=190/200, action=queued
#   RouterB: load=0%, arrivals=0, leaked=50, bucket=76/200, action=queued
#   RouterC: load=5%, arrivals=5, leaked=50, bucket=76/200, action=queued
#
# ⏱️ Time step 1350 sec:
#   RouterA: load=74%, arrivals=74, leaked=50, bucket=200/200, action=dropped 14
#   RouterB: load=7%, arrivals=7, leaked=50, bucket=33/200, action=queued
#   RouterC: load=64%, arrivals=64, leaked=50, bucket=90/200, action=queued
#
# ⏱️ Time step 1360 sec:
#   RouterA: load=68%, arrivals=68, leaked=50, bucket=200/200, action=dropped 18
#   RouterB: load=63%, arrivals=63, leaked=33, bucket=63/200, action=queued
#   RouterC: load=45%, arrivals=45, leaked=50, bucket=85/200, action=queued
#
# ⏱️ Time step 1370 sec:
#   RouterA: load=95%, arrivals=95, leaked=50, bucket=200/200, action=dropped 45
#   RouterB: load=26%, arrivals=26, leaked=50, bucket=39/200, action=queued
#   RouterC: load=21%, arrivals=21, leaked=50, bucket=56/200, action=queued
#
# ⏱️ Time step 1380 sec:
#   RouterA: load=81%, arrivals=81, leaked=50, bucket=200/200, action=dropped 31
#   RouterB: load=91%, arrivals=91, leaked=39, bucket=91/200, action=queued
#   RouterC: load=39%, arrivals=39, leaked=50, bucket=45/200, action=queued
#
# ⏱️ Time step 1390 sec:
#   RouterA: load=99%, arrivals=99, leaked=50, bucket=200/200, action=dropped 49
#   RouterB: load=20%, arrivals=20, leaked=50, bucket=61/200, action=queued
#   RouterC: load=92%, arrivals=92, leaked=45, bucket=92/200, action=queued
#
# ⏱️ Time step 1400 sec:
#   RouterA: load=42%, arrivals=42, leaked=50, bucket=192/200, action=queued
#   RouterB: load=72%, arrivals=72, leaked=50, bucket=83/200, action=queued
#   RouterC: load=8%, arrivals=8, leaked=50, bucket=50/200, action=queued
#
# ⏱️ Time step 1410 sec:
#   RouterA: load=16%, arrivals=16, leaked=50, bucket=158/200, action=queued
#   RouterB: load=20%, arrivals=20, leaked=50, bucket=53/200, action=queued
#   RouterC: load=93%, arrivals=93, leaked=50, bucket=93/200, action=queued
#
# ⏱️ Time step 1420 sec:
#   RouterA: load=78%, arrivals=78, leaked=50, bucket=186/200, action=queued
#   RouterB: load=82%, arrivals=82, leaked=50, bucket=85/200, action=queued
#   RouterC: load=91%, arrivals=91, leaked=50, bucket=134/200, action=queued
#
# ⏱️ Time step 1430 sec:
#   RouterA: load=89%, arrivals=89, leaked=50, bucket=200/200, action=dropped 25
#   RouterB: load=30%, arrivals=30, leaked=50, bucket=65/200, action=queued
#   RouterC: load=29%, arrivals=28, leaked=50, bucket=112/200, action=queued
#
# ⏱️ Time step 1440 sec:
#   RouterA: load=73%, arrivals=73, leaked=50, bucket=200/200, action=dropped 23
#   RouterB: load=84%, arrivals=84, leaked=50, bucket=99/200, action=queued
#   RouterC: load=88%, arrivals=88, leaked=50, bucket=150/200, action=queued
#
# ⏱️ Time step 1450 sec:
#   RouterA: load=20%, arrivals=20, leaked=50, bucket=170/200, action=queued
#   RouterB: load=33%, arrivals=33, leaked=50, bucket=82/200, action=queued
#   RouterC: load=71%, arrivals=71, leaked=50, bucket=171/200, action=queued
#
# ⏱️ Time step 1460 sec:
#   RouterA: load=82%, arrivals=82, leaked=50, bucket=200/200, action=dropped 2
#   RouterB: load=43%, arrivals=43, leaked=50, bucket=75/200, action=queued
#   RouterC: load=77%, arrivals=77, leaked=50, bucket=198/200, action=queued
#
# ⏱️ Time step 1470 sec:
#   RouterA: load=9%, arrivals=9, leaked=50, bucket=159/200, action=queued
#   RouterB: load=7%, arrivals=7, leaked=50, bucket=32/200, action=queued
#   RouterC: load=29%, arrivals=28, leaked=50, bucket=176/200, action=queued
#
# ⏱️ Time step 1480 sec:
#   RouterA: load=74%, arrivals=74, leaked=50, bucket=183/200, action=queued
#   RouterB: load=44%, arrivals=44, leaked=32, bucket=44/200, action=queued
#   RouterC: load=14%, arrivals=14, leaked=50, bucket=140/200, action=queued
#
# ⏱️ Time step 1490 sec:
#   RouterA: load=79%, arrivals=79, leaked=50, bucket=200/200, action=dropped 12
#   RouterB: load=39%, arrivals=39, leaked=44, bucket=39/200, action=queued
#   RouterC: load=43%, arrivals=43, leaked=50, bucket=133/200, action=queued
#
# ⏱️ Time step 1500 sec:
#   RouterA: load=60%, arrivals=60, leaked=50, bucket=200/200, action=dropped 10
#   RouterB: load=75%, arrivals=75, leaked=39, bucket=75/200, action=queued
#   RouterC: load=18%, arrivals=18, leaked=50, bucket=101/200, action=queued
#
# ⏱️ Time step 1510 sec:
#   RouterA: load=92%, arrivals=92, leaked=50, bucket=200/200, action=dropped 42
#   RouterB: load=30%, arrivals=30, leaked=50, bucket=55/200, action=queued
#   RouterC: load=62%, arrivals=62, leaked=50, bucket=113/200, action=queued
#
# ⏱️ Time step 1520 sec:
#   RouterA: load=57%, arrivals=56, leaked=50, bucket=200/200, action=dropped 6
#   RouterB: load=49%, arrivals=49, leaked=50, bucket=54/200, action=queued
#   RouterC: load=87%, arrivals=87, leaked=50, bucket=150/200, action=queued
#
# ⏱️ Time step 1530 sec:
#   RouterA: load=61%, arrivals=61, leaked=50, bucket=200/200, action=dropped 11
#   RouterB: load=3%, arrivals=3, leaked=50, bucket=7/200, action=queued
#   RouterC: load=7%, arrivals=7, leaked=50, bucket=107/200, action=queued
#
# ⏱️ Time step 1540 sec:
#   RouterA: load=1%, arrivals=1, leaked=50, bucket=151/200, action=queued
#   RouterB: load=77%, arrivals=77, leaked=7, bucket=77/200, action=queued
#   RouterC: load=25%, arrivals=25, leaked=50, bucket=82/200, action=queued
#
# ⏱️ Time step 1550 sec:
#   RouterA: load=99%, arrivals=99, leaked=50, bucket=200/200, action=queued
#   RouterB: load=90%, arrivals=90, leaked=50, bucket=117/200, action=queued
#   RouterC: load=99%, arrivals=99, leaked=50, bucket=131/200, action=queued
#
# ⏱️ Time step 1560 sec:
#   RouterA: load=57%, arrivals=56, leaked=50, bucket=200/200, action=dropped 6
#   RouterB: load=98%, arrivals=98, leaked=50, bucket=165/200, action=queued
#   RouterC: load=80%, arrivals=80, leaked=50, bucket=161/200, action=queued
#
# ⏱️ Time step 1570 sec:
#   RouterA: load=93%, arrivals=93, leaked=50, bucket=200/200, action=dropped 43
#   RouterB: load=17%, arrivals=17, leaked=50, bucket=132/200, action=queued
#   RouterC: load=16%, arrivals=16, leaked=50, bucket=127/200, action=queued
#
# ⏱️ Time step 1580 sec:
#   RouterA: load=85%, arrivals=85, leaked=50, bucket=200/200, action=dropped 35
#   RouterB: load=41%, arrivals=41, leaked=50, bucket=123/200, action=queued
#   RouterC: load=6%, arrivals=6, leaked=50, bucket=83/200, action=queued
#
# ⏱️ Time step 1590 sec:
#   RouterA: load=83%, arrivals=83, leaked=50, bucket=200/200, action=dropped 33
#   RouterB: load=96%, arrivals=96, leaked=50, bucket=169/200, action=queued
#   RouterC: load=68%, arrivals=68, leaked=50, bucket=101/200, action=queued
#
# ⏱️ Time step 1600 sec:
#   RouterA: load=41%, arrivals=41, leaked=50, bucket=191/200, action=queued
#   RouterB: load=48%, arrivals=48, leaked=50, bucket=167/200, action=queued
#   RouterC: load=87%, arrivals=87, leaked=50, bucket=138/200, action=queued
#
# ⏱️ Time step 1610 sec:
#   RouterA: load=81%, arrivals=81, leaked=50, bucket=200/200, action=dropped 22
#   RouterB: load=96%, arrivals=96, leaked=50, bucket=200/200, action=dropped 13
#   RouterC: load=19%, arrivals=19, leaked=50, bucket=107/200, action=queued
#
# ⏱️ Time step 1620 sec:
#   RouterA: load=52%, arrivals=52, leaked=50, bucket=200/200, action=dropped 2
#   RouterB: load=47%, arrivals=47, leaked=50, bucket=197/200, action=queued
#   RouterC: load=58%, arrivals=57, leaked=50, bucket=114/200, action=queued
#
# ⏱️ Time step 1630 sec:
#   RouterA: load=47%, arrivals=47, leaked=50, bucket=197/200, action=queued
#   RouterB: load=7%, arrivals=7, leaked=50, bucket=154/200, action=queued
#   RouterC: load=39%, arrivals=39, leaked=50, bucket=103/200, action=queued
#
# ⏱️ Time step 1640 sec:
#   RouterA: load=31%, arrivals=31, leaked=50, bucket=178/200, action=queued
#   RouterB: load=38%, arrivals=38, leaked=50, bucket=142/200, action=queued
#   RouterC: load=2%, arrivals=2, leaked=50, bucket=55/200, action=queued
#
# ⏱️ Time step 1650 sec:
#   RouterA: load=51%, arrivals=51, leaked=50, bucket=179/200, action=queued
#   RouterB: load=24%, arrivals=24, leaked=50, bucket=116/200, action=queued
#   RouterC: load=85%, arrivals=85, leaked=50, bucket=90/200, action=queued
#
# ⏱️ Time step 1660 sec:
#   RouterA: load=34%, arrivals=34, leaked=50, bucket=163/200, action=queued
#   RouterB: load=14%, arrivals=14, leaked=50, bucket=80/200, action=queued
#   RouterC: load=27%, arrivals=27, leaked=50, bucket=67/200, action=queued
#
# ⏱️ Time step 1670 sec:
#   RouterA: load=64%, arrivals=64, leaked=50, bucket=177/200, action=queued
#   RouterB: load=45%, arrivals=45, leaked=50, bucket=75/200, action=queued
#   RouterC: load=94%, arrivals=94, leaked=50, bucket=111/200, action=queued
#
# ⏱️ Time step 1680 sec:
#   RouterA: load=37%, arrivals=37, leaked=50, bucket=164/200, action=queued
#   RouterB: load=4%, arrivals=4, leaked=50, bucket=29/200, action=queued
#   RouterC: load=86%, arrivals=86, leaked=50, bucket=147/200, action=queued
#
# ⏱️ Time step 1690 sec:
#   RouterA: load=13%, arrivals=13, leaked=50, bucket=127/200, action=queued
#   RouterB: load=15%, arrivals=15, leaked=29, bucket=15/200, action=queued
#   RouterC: load=32%, arrivals=32, leaked=50, bucket=129/200, action=queued
#
# ⏱️ Time step 1700 sec:
#   RouterA: load=1%, arrivals=1, leaked=50, bucket=78/200, action=queued
#   RouterB: load=88%, arrivals=88, leaked=15, bucket=88/200, action=queued
#   RouterC: load=88%, arrivals=88, leaked=50, bucket=167/200, action=queued
#
# ⏱️ Time step 1710 sec:
#   RouterA: load=78%, arrivals=78, leaked=50, bucket=106/200, action=queued
#   RouterB: load=31%, arrivals=31, leaked=50, bucket=69/200, action=queued
#   RouterC: load=22%, arrivals=22, leaked=50, bucket=139/200, action=queued
#
# ⏱️ Time step 1720 sec:
#   RouterA: load=87%, arrivals=87, leaked=50, bucket=143/200, action=queued
#   RouterB: load=14%, arrivals=14, leaked=50, bucket=33/200, action=queued
#   RouterC: load=70%, arrivals=70, leaked=50, bucket=159/200, action=queued
#
# ⏱️ Time step 1730 sec:
#   RouterA: load=25%, arrivals=25, leaked=50, bucket=118/200, action=queued
#   RouterB: load=50%, arrivals=50, leaked=33, bucket=50/200, action=queued
#   RouterC: load=82%, arrivals=82, leaked=50, bucket=191/200, action=queued
#
# ⏱️ Time step 1740 sec:
#   RouterA: load=73%, arrivals=73, leaked=50, bucket=141/200, action=queued
#   RouterB: load=52%, arrivals=52, leaked=50, bucket=52/200, action=queued
#   RouterC: load=46%, arrivals=46, leaked=50, bucket=187/200, action=queued
#
# ⏱️ Time step 1750 sec:
#   RouterA: load=67%, arrivals=67, leaked=50, bucket=158/200, action=queued
#   RouterB: load=77%, arrivals=77, leaked=50, bucket=79/200, action=queued
#   RouterC: load=44%, arrivals=44, leaked=50, bucket=181/200, action=queued
#
# ⏱️ Time step 1760 sec:
#   RouterA: load=83%, arrivals=83, leaked=50, bucket=191/200, action=queued
#   RouterB: load=96%, arrivals=96, leaked=50, bucket=125/200, action=queued
#   RouterC: load=30%, arrivals=30, leaked=50, bucket=161/200, action=queued
#
# ⏱️ Time step 1770 sec:
#   RouterA: load=39%, arrivals=39, leaked=50, bucket=180/200, action=queued
#   RouterB: load=61%, arrivals=61, leaked=50, bucket=136/200, action=queued
#   RouterC: load=48%, arrivals=48, leaked=50, bucket=159/200, action=queued
#
# ⏱️ Time step 1780 sec:
#   RouterA: load=40%, arrivals=40, leaked=50, bucket=170/200, action=queued
#   RouterB: load=10%, arrivals=10, leaked=50, bucket=96/200, action=queued
#   RouterC: load=95%, arrivals=95, leaked=50, bucket=200/200, action=dropped 4
#
# ⏱️ Time step 1790 sec:
#   RouterA: load=94%, arrivals=94, leaked=50, bucket=200/200, action=dropped 14
#   RouterB: load=83%, arrivals=83, leaked=50, bucket=129/200, action=queued
#   RouterC: load=94%, arrivals=94, leaked=50, bucket=200/200, action=dropped 44
#
# ⏱️ Time step 1800 sec:
#   RouterA: load=24%, arrivals=24, leaked=50, bucket=174/200, action=queued
#   RouterB: load=58%, arrivals=57, leaked=50, bucket=136/200, action=queued
#   RouterC: load=63%, arrivals=63, leaked=50, bucket=200/200, action=dropped 13
#
# ⏱️ Time step 1810 sec:
#   RouterA: load=89%, arrivals=89, leaked=50, bucket=200/200, action=dropped 13
#   RouterB: load=59%, arrivals=59, leaked=50, bucket=145/200, action=queued
#   RouterC: load=10%, arrivals=10, leaked=50, bucket=160/200, action=queued
#
# ⏱️ Time step 1820 sec:
#   RouterA: load=24%, arrivals=24, leaked=50, bucket=174/200, action=queued
#   RouterB: load=69%, arrivals=69, leaked=50, bucket=164/200, action=queued
#   RouterC: load=30%, arrivals=30, leaked=50, bucket=140/200, action=queued
#
# ⏱️ Time step 1830 sec:
#   RouterA: load=70%, arrivals=70, leaked=50, bucket=194/200, action=queued
#   RouterB: load=71%, arrivals=71, leaked=50, bucket=185/200, action=queued
#   RouterC: load=29%, arrivals=28, leaked=50, bucket=118/200, action=queued
#
# ⏱️ Time step 1840 sec:
#   RouterA: load=83%, arrivals=83, leaked=50, bucket=200/200, action=dropped 27
#   RouterB: load=7%, arrivals=7, leaked=50, bucket=142/200, action=queued
#   RouterC: load=42%, arrivals=42, leaked=50, bucket=110/200, action=queued
#
# ⏱️ Time step 1850 sec:
#   RouterA: load=53%, arrivals=53, leaked=50, bucket=200/200, action=dropped 3
#   RouterB: load=26%, arrivals=26, leaked=50, bucket=118/200, action=queued
#   RouterC: load=21%, arrivals=21, leaked=50, bucket=81/200, action=queued
#
# ⏱️ Time step 1860 sec:
#   RouterA: load=85%, arrivals=85, leaked=50, bucket=200/200, action=dropped 35
#   RouterB: load=95%, arrivals=95, leaked=50, bucket=163/200, action=queued
#   RouterC: load=70%, arrivals=70, leaked=50, bucket=101/200, action=queued
#
# ⏱️ Time step 1870 sec:
#   RouterA: load=56%, arrivals=56, leaked=50, bucket=200/200, action=dropped 6
#   RouterB: load=57%, arrivals=56, leaked=50, bucket=169/200, action=queued
#   RouterC: load=91%, arrivals=91, leaked=50, bucket=142/200, action=queued
#
# ⏱️ Time step 1880 sec:
#   RouterA: load=12%, arrivals=12, leaked=50, bucket=162/200, action=queued
#   RouterB: load=1%, arrivals=1, leaked=50, bucket=120/200, action=queued
#   RouterC: load=53%, arrivals=53, leaked=50, bucket=145/200, action=queued
#
# ⏱️ Time step 1890 sec:
#   RouterA: load=46%, arrivals=46, leaked=50, bucket=158/200, action=queued
#   RouterB: load=75%, arrivals=75, leaked=50, bucket=145/200, action=queued
#   RouterC: load=14%, arrivals=14, leaked=50, bucket=109/200, action=queued
#
# ⏱️ Time step 1900 sec:
#   RouterA: load=35%, arrivals=35, leaked=50, bucket=143/200, action=queued
#   RouterB: load=93%, arrivals=93, leaked=50, bucket=188/200, action=queued
#   RouterC: load=84%, arrivals=84, leaked=50, bucket=143/200, action=queued
#
# ⏱️ Time step 1910 sec:
#   RouterA: load=59%, arrivals=59, leaked=50, bucket=152/200, action=queued
#   RouterB: load=57%, arrivals=56, leaked=50, bucket=194/200, action=queued
#   RouterC: load=91%, arrivals=91, leaked=50, bucket=184/200, action=queued
#
# ⏱️ Time step 1920 sec:
#   RouterA: load=15%, arrivals=15, leaked=50, bucket=117/200, action=queued
#   RouterB: load=42%, arrivals=42, leaked=50, bucket=186/200, action=queued
#   RouterC: load=32%, arrivals=32, leaked=50, bucket=166/200, action=queued
#
# ⏱️ Time step 1930 sec:
#   RouterA: load=78%, arrivals=78, leaked=50, bucket=145/200, action=queued
# ...
#   RouterC: load=62%, arrivals=62, leaked=50, bucket=200/200, action=dropped 12
#
# ⏱️ Time step 6360 sec:
#   RouterA: load=79%, arrivals=79, leaked=50, bucket=141/200, action=queued
#   RouterB: load=60%, arrivals=60, leaked=50, bucket=197/200, action=queued
#   RouterC: load=41%, arrivals=41, leaked=50, bucket=191/200, action=queued
#
# ⏱️ Time step 6370 sec:
#   RouterA: load=63%, arrivals=63, leaked=50, bucket=154/200, action=queued
#   RouterB: load=42%, arrivals=42, leaked=50, bucket=189/200, action=queued
#   RouterC: load=52%, arrivals=52, leaked=50, bucket=193/200, action=queued
#
# ⏱️ Time step 6380 sec:
#   RouterA: load=30%, arrivals=30, leaked=50, bucket=134/200, action=queued
#   RouterB: load=87%, arrivals=87, leaked=50, bucket=200/200, action=dropped 26
#   RouterC: load=29%, arrivals=28, leaked=50, bucket=171/200, action=queued
#
# ⏱️ Time step 6390 sec:
#   RouterA: load=41%, arrivals=41, leaked=50, bucket=125/200, action=queued
#   RouterB: load=75%, arrivals=75, leaked=50, bucket=200/200, action=dropped 25
#   RouterC: load=2%, arrivals=2, leaked=50, bucket=123/200, action=queued
#
# ⏱️ Time step 6400 sec:
#   RouterA: load=86%, arrivals=86, leaked=50, bucket=161/200, action=queued
#   RouterB: load=43%, arrivals=43, leaked=50, bucket=193/200, action=queued
#   RouterC: load=28%, arrivals=28, leaked=50, bucket=101/200, action=queued
#
# ⏱️ Time step 6410 sec:
#   RouterA: load=27%, arrivals=27, leaked=50, bucket=138/200, action=queued
#   RouterB: load=87%, arrivals=87, leaked=50, bucket=200/200, action=dropped 30
#   RouterC: load=84%, arrivals=84, leaked=50, bucket=135/200, action=queued
#
# ⏱️ Time step 6420 sec:
#   RouterA: load=26%, arrivals=26, leaked=50, bucket=114/200, action=queued
#   RouterB: load=40%, arrivals=40, leaked=50, bucket=190/200, action=queued
#   RouterC: load=60%, arrivals=60, leaked=50, bucket=145/200, action=queued
#
# ⏱️ Time step 6430 sec:
#   RouterA: load=87%, arrivals=87, leaked=50, bucket=151/200, action=queued
#   RouterB: load=46%, arrivals=46, leaked=50, bucket=186/200, action=queued
#   RouterC: load=98%, arrivals=98, leaked=50, bucket=193/200, action=queued
#
# ⏱️ Time step 6440 sec:
#   RouterA: load=21%, arrivals=21, leaked=50, bucket=122/200, action=queued
#   RouterB: load=62%, arrivals=62, leaked=50, bucket=198/200, action=queued
#   RouterC: load=99%, arrivals=99, leaked=50, bucket=200/200, action=dropped 42
#
# ⏱️ Time step 6450 sec:
#   RouterA: load=21%, arrivals=21, leaked=50, bucket=93/200, action=queued
#   RouterB: load=88%, arrivals=88, leaked=50, bucket=200/200, action=dropped 36
#   RouterC: load=58%, arrivals=57, leaked=50, bucket=200/200, action=dropped 7
#
# ⏱️ Time step 6460 sec:
#   RouterA: load=5%, arrivals=5, leaked=50, bucket=48/200, action=queued
#   RouterB: load=46%, arrivals=46, leaked=50, bucket=196/200, action=queued
#   RouterC: load=94%, arrivals=94, leaked=50, bucket=200/200, action=dropped 44
#
# ⏱️ Time step 6470 sec:
#   RouterA: load=7%, arrivals=7, leaked=48, bucket=7/200, action=queued
#   RouterB: load=96%, arrivals=96, leaked=50, bucket=200/200, action=dropped 42
#   RouterC: load=34%, arrivals=34, leaked=50, bucket=184/200, action=queued
#
# ⏱️ Time step 6480 sec:
#   RouterA: load=20%, arrivals=20, leaked=7, bucket=20/200, action=queued
#   RouterB: load=71%, arrivals=71, leaked=50, bucket=200/200, action=dropped 21
#   RouterC: load=8%, arrivals=8, leaked=50, bucket=142/200, action=queued
#
# ⏱️ Time step 6490 sec:
#   RouterA: load=50%, arrivals=50, leaked=20, bucket=50/200, action=queued
#   RouterB: load=15%, arrivals=15, leaked=50, bucket=165/200, action=queued
#   RouterC: load=76%, arrivals=76, leaked=50, bucket=168/200, action=queued
#
# ⏱️ Time step 6500 sec:
#   RouterA: load=27%, arrivals=27, leaked=50, bucket=27/200, action=queued
#   RouterB: load=54%, arrivals=54, leaked=50, bucket=169/200, action=queued
#   RouterC: load=16%, arrivals=16, leaked=50, bucket=134/200, action=queued
#
# ⏱️ Time step 6510 sec:
#   RouterA: load=9%, arrivals=9, leaked=27, bucket=9/200, action=queued
#   RouterB: load=68%, arrivals=68, leaked=50, bucket=187/200, action=queued
#   RouterC: load=68%, arrivals=68, leaked=50, bucket=152/200, action=queued
#
# ⏱️ Time step 6520 sec:
#   RouterA: load=28%, arrivals=28, leaked=9, bucket=28/200, action=queued
#   RouterB: load=78%, arrivals=78, leaked=50, bucket=200/200, action=dropped 15
#   RouterC: load=83%, arrivals=83, leaked=50, bucket=185/200, action=queued
#
# ⏱️ Time step 6530 sec:
#   RouterA: load=61%, arrivals=61, leaked=28, bucket=61/200, action=queued
#   RouterB: load=53%, arrivals=53, leaked=50, bucket=200/200, action=dropped 3
#   RouterC: load=33%, arrivals=33, leaked=50, bucket=168/200, action=queued
#
# ⏱️ Time step 6540 sec:
#   RouterA: load=34%, arrivals=34, leaked=50, bucket=45/200, action=queued
#   RouterB: load=66%, arrivals=66, leaked=50, bucket=200/200, action=dropped 16
#   RouterC: load=90%, arrivals=90, leaked=50, bucket=200/200, action=dropped 8
#
# ⏱️ Time step 6550 sec:
#   RouterA: load=88%, arrivals=88, leaked=45, bucket=88/200, action=queued
#   RouterB: load=6%, arrivals=6, leaked=50, bucket=156/200, action=queued
#   RouterC: load=45%, arrivals=45, leaked=50, bucket=195/200, action=queued
#
# ⏱️ Time step 6560 sec:
#   RouterA: load=35%, arrivals=35, leaked=50, bucket=73/200, action=queued
#   RouterB: load=61%, arrivals=61, leaked=50, bucket=167/200, action=queued
#   RouterC: load=74%, arrivals=74, leaked=50, bucket=200/200, action=dropped 19
#
# ⏱️ Time step 6570 sec:
#   RouterA: load=82%, arrivals=82, leaked=50, bucket=105/200, action=queued
#   RouterB: load=25%, arrivals=25, leaked=50, bucket=142/200, action=queued
#   RouterC: load=35%, arrivals=35, leaked=50, bucket=185/200, action=queued
#
# ⏱️ Time step 6580 sec:
#   RouterA: load=13%, arrivals=13, leaked=50, bucket=68/200, action=queued
#   RouterB: load=3%, arrivals=3, leaked=50, bucket=95/200, action=queued
#   RouterC: load=30%, arrivals=30, leaked=50, bucket=165/200, action=queued
#
# ⏱️ Time step 6590 sec:
#   RouterA: load=63%, arrivals=63, leaked=50, bucket=81/200, action=queued
#   RouterB: load=2%, arrivals=2, leaked=50, bucket=47/200, action=queued
#   RouterC: load=2%, arrivals=2, leaked=50, bucket=117/200, action=queued
#
# ⏱️ Time step 6600 sec:
#   RouterA: load=91%, arrivals=91, leaked=50, bucket=122/200, action=queued
#   RouterB: load=16%, arrivals=16, leaked=47, bucket=16/200, action=queued
#   RouterC: load=17%, arrivals=17, leaked=50, bucket=84/200, action=queued
#
# ⏱️ Time step 6610 sec:
#   RouterA: load=68%, arrivals=68, leaked=50, bucket=140/200, action=queued
#   RouterB: load=22%, arrivals=22, leaked=16, bucket=22/200, action=queued
#   RouterC: load=90%, arrivals=90, leaked=50, bucket=124/200, action=queued
#
# ⏱️ Time step 6620 sec:
#   RouterA: load=38%, arrivals=38, leaked=50, bucket=128/200, action=queued
#   RouterB: load=87%, arrivals=87, leaked=22, bucket=87/200, action=queued
#   RouterC: load=20%, arrivals=20, leaked=50, bucket=94/200, action=queued
#
# ⏱️ Time step 6630 sec:
#   RouterA: load=28%, arrivals=28, leaked=50, bucket=106/200, action=queued
#   RouterB: load=26%, arrivals=26, leaked=50, bucket=63/200, action=queued
#   RouterC: load=91%, arrivals=91, leaked=50, bucket=135/200, action=queued
#
# ⏱️ Time step 6640 sec:
#   RouterA: load=4%, arrivals=4, leaked=50, bucket=60/200, action=queued
#   RouterB: load=18%, arrivals=18, leaked=50, bucket=31/200, action=queued
#   RouterC: load=55%, arrivals=55, leaked=50, bucket=140/200, action=queued
#
# ⏱️ Time step 6650 sec:
#   RouterA: load=71%, arrivals=71, leaked=50, bucket=81/200, action=queued
#   RouterB: load=23%, arrivals=23, leaked=31, bucket=23/200, action=queued
#   RouterC: load=91%, arrivals=91, leaked=50, bucket=181/200, action=queued
#
# ⏱️ Time step 6660 sec:
#   RouterA: load=42%, arrivals=42, leaked=50, bucket=73/200, action=queued
#   RouterB: load=51%, arrivals=51, leaked=23, bucket=51/200, action=queued
#   RouterC: load=96%, arrivals=96, leaked=50, bucket=200/200, action=dropped 27
#
# ⏱️ Time step 6670 sec:
#   RouterA: load=62%, arrivals=62, leaked=50, bucket=85/200, action=queued
#   RouterB: load=54%, arrivals=54, leaked=50, bucket=55/200, action=queued
#   RouterC: load=65%, arrivals=65, leaked=50, bucket=200/200, action=dropped 15
#
# ⏱️ Time step 6680 sec:
#   RouterA: load=76%, arrivals=76, leaked=50, bucket=111/200, action=queued
#   RouterB: load=50%, arrivals=50, leaked=50, bucket=55/200, action=queued
#   RouterC: load=9%, arrivals=9, leaked=50, bucket=159/200, action=queued
#
# ⏱️ Time step 6690 sec:
#   RouterA: load=15%, arrivals=15, leaked=50, bucket=76/200, action=queued
#   RouterB: load=2%, arrivals=2, leaked=50, bucket=7/200, action=queued
#   RouterC: load=61%, arrivals=61, leaked=50, bucket=170/200, action=queued
#
# ⏱️ Time step 6700 sec:
#   RouterA: load=67%, arrivals=67, leaked=50, bucket=93/200, action=queued
#   RouterB: load=80%, arrivals=80, leaked=7, bucket=80/200, action=queued
#   RouterC: load=91%, arrivals=91, leaked=50, bucket=200/200, action=dropped 11
#
# ⏱️ Time step 6710 sec:
#   RouterA: load=23%, arrivals=23, leaked=50, bucket=66/200, action=queued
#   RouterB: load=89%, arrivals=89, leaked=50, bucket=119/200, action=queued
#   RouterC: load=85%, arrivals=85, leaked=50, bucket=200/200, action=dropped 35
#
# ⏱️ Time step 6720 sec:
#   RouterA: load=72%, arrivals=72, leaked=50, bucket=88/200, action=queued
#   RouterB: load=58%, arrivals=57, leaked=50, bucket=126/200, action=queued
#   RouterC: load=53%, arrivals=53, leaked=50, bucket=200/200, action=dropped 3
#
# ⏱️ Time step 6730 sec:
#   RouterA: load=79%, arrivals=79, leaked=50, bucket=117/200, action=queued
#   RouterB: load=0%, arrivals=0, leaked=50, bucket=76/200, action=queued
#   RouterC: load=4%, arrivals=4, leaked=50, bucket=154/200, action=queued
#
# ⏱️ Time step 6740 sec:
#   RouterA: load=66%, arrivals=66, leaked=50, bucket=133/200, action=queued
#   RouterB: load=7%, arrivals=7, leaked=50, bucket=33/200, action=queued
#   RouterC: load=74%, arrivals=74, leaked=50, bucket=178/200, action=queued
#
# ⏱️ Time step 6750 sec:
#   RouterA: load=25%, arrivals=25, leaked=50, bucket=108/200, action=queued
#   RouterB: load=90%, arrivals=90, leaked=33, bucket=90/200, action=queued
#   RouterC: load=62%, arrivals=62, leaked=50, bucket=190/200, action=queued
#
# ⏱️ Time step 6760 sec:
#   RouterA: load=69%, arrivals=69, leaked=50, bucket=127/200, action=queued
#   RouterB: load=13%, arrivals=13, leaked=50, bucket=53/200, action=queued
#   RouterC: load=7%, arrivals=7, leaked=50, bucket=147/200, action=queued
#
# ⏱️ Time step 6770 sec:
#   RouterA: load=49%, arrivals=49, leaked=50, bucket=126/200, action=queued
#   RouterB: load=66%, arrivals=66, leaked=50, bucket=69/200, action=queued
#   RouterC: load=18%, arrivals=18, leaked=50, bucket=115/200, action=queued
#
# ⏱️ Time step 6780 sec:
#   RouterA: load=58%, arrivals=57, leaked=50, bucket=133/200, action=queued
#   RouterB: load=36%, arrivals=36, leaked=50, bucket=55/200, action=queued
#   RouterC: load=33%, arrivals=33, leaked=50, bucket=98/200, action=queued
#
# ⏱️ Time step 6790 sec:
#   RouterA: load=43%, arrivals=43, leaked=50, bucket=126/200, action=queued
#   RouterB: load=24%, arrivals=24, leaked=50, bucket=29/200, action=queued
#   RouterC: load=65%, arrivals=65, leaked=50, bucket=113/200, action=queued
#
# ⏱️ Time step 6800 sec:
#   RouterA: load=26%, arrivals=26, leaked=50, bucket=102/200, action=queued
#   RouterB: load=51%, arrivals=51, leaked=29, bucket=51/200, action=queued
#   RouterC: load=27%, arrivals=27, leaked=50, bucket=90/200, action=queued
#
# ⏱️ Time step 6810 sec:
#   RouterA: load=12%, arrivals=12, leaked=50, bucket=64/200, action=queued
#   RouterB: load=55%, arrivals=55, leaked=50, bucket=56/200, action=queued
#   RouterC: load=100%, arrivals=100, leaked=50, bucket=140/200, action=queued
#
# ⏱️ Time step 6820 sec:
#   RouterA: load=82%, arrivals=82, leaked=50, bucket=96/200, action=queued
#   RouterB: load=69%, arrivals=69, leaked=50, bucket=75/200, action=queued
#   RouterC: load=3%, arrivals=3, leaked=50, bucket=93/200, action=queued
#
# ⏱️ Time step 6830 sec:
#   RouterA: load=56%, arrivals=56, leaked=50, bucket=102/200, action=queued
#   RouterB: load=42%, arrivals=42, leaked=50, bucket=67/200, action=queued
#   RouterC: load=28%, arrivals=28, leaked=50, bucket=71/200, action=queued
#
# ⏱️ Time step 6840 sec:
#   RouterA: load=78%, arrivals=78, leaked=50, bucket=130/200, action=queued
#   RouterB: load=66%, arrivals=66, leaked=50, bucket=83/200, action=queued
#   RouterC: load=43%, arrivals=43, leaked=50, bucket=64/200, action=queued
#
# ⏱️ Time step 6850 sec:
#   RouterA: load=89%, arrivals=89, leaked=50, bucket=169/200, action=queued
#   RouterB: load=72%, arrivals=72, leaked=50, bucket=105/200, action=queued
#   RouterC: load=59%, arrivals=59, leaked=50, bucket=73/200, action=queued
#
# ⏱️ Time step 6860 sec:
#   RouterA: load=78%, arrivals=78, leaked=50, bucket=197/200, action=queued
#   RouterB: load=13%, arrivals=13, leaked=50, bucket=68/200, action=queued
#   RouterC: load=16%, arrivals=16, leaked=50, bucket=39/200, action=queued
#
# ⏱️ Time step 6870 sec:
#   RouterA: load=21%, arrivals=21, leaked=50, bucket=168/200, action=queued
#   RouterB: load=43%, arrivals=43, leaked=50, bucket=61/200, action=queued
#   RouterC: load=95%, arrivals=95, leaked=39, bucket=95/200, action=queued
#
# ⏱️ Time step 6880 sec:
#   RouterA: load=42%, arrivals=42, leaked=50, bucket=160/200, action=queued
#   RouterB: load=6%, arrivals=6, leaked=50, bucket=17/200, action=queued
#   RouterC: load=13%, arrivals=13, leaked=50, bucket=58/200, action=queued
#
# ⏱️ Time step 6890 sec:
#   RouterA: load=41%, arrivals=41, leaked=50, bucket=151/200, action=queued
#   RouterB: load=68%, arrivals=68, leaked=17, bucket=68/200, action=queued
#   RouterC: load=57%, arrivals=56, leaked=50, bucket=64/200, action=queued
#
# ⏱️ Time step 6900 sec:
#   RouterA: load=19%, arrivals=19, leaked=50, bucket=120/200, action=queued
#   RouterB: load=17%, arrivals=17, leaked=50, bucket=35/200, action=queued
#   RouterC: load=59%, arrivals=59, leaked=50, bucket=73/200, action=queued
#
# ⏱️ Time step 6910 sec:
#   RouterA: load=95%, arrivals=95, leaked=50, bucket=165/200, action=queued
#   RouterB: load=49%, arrivals=49, leaked=35, bucket=49/200, action=queued
#   RouterC: load=57%, arrivals=56, leaked=50, bucket=79/200, action=queued
#
# ⏱️ Time step 6920 sec:
#   RouterA: load=49%, arrivals=49, leaked=50, bucket=164/200, action=queued
#   RouterB: load=34%, arrivals=34, leaked=49, bucket=34/200, action=queued
#   RouterC: load=86%, arrivals=86, leaked=50, bucket=115/200, action=queued
#
# ⏱️ Time step 6930 sec:
#   RouterA: load=84%, arrivals=84, leaked=50, bucket=198/200, action=queued
#   RouterB: load=92%, arrivals=92, leaked=34, bucket=92/200, action=queued
#   RouterC: load=71%, arrivals=71, leaked=50, bucket=136/200, action=queued
#
# ⏱️ Time step 6940 sec:
#   RouterA: load=99%, arrivals=99, leaked=50, bucket=200/200, action=dropped 47
#   RouterB: load=19%, arrivals=19, leaked=50, bucket=61/200, action=queued
#   RouterC: load=24%, arrivals=24, leaked=50, bucket=110/200, action=queued
#
# ⏱️ Time step 6950 sec:
#   RouterA: load=70%, arrivals=70, leaked=50, bucket=200/200, action=dropped 20
#   RouterB: load=13%, arrivals=13, leaked=50, bucket=24/200, action=queued
#   RouterC: load=52%, arrivals=52, leaked=50, bucket=112/200, action=queued
#
# ⏱️ Time step 6960 sec:
#   RouterA: load=37%, arrivals=37, leaked=50, bucket=187/200, action=queued
#   RouterB: load=6%, arrivals=6, leaked=24, bucket=6/200, action=queued
#   RouterC: load=17%, arrivals=17, leaked=50, bucket=79/200, action=queued
#
# ⏱️ Time step 6970 sec:
#   RouterA: load=38%, arrivals=38, leaked=50, bucket=175/200, action=queued
#   RouterB: load=22%, arrivals=22, leaked=6, bucket=22/200, action=queued
#   RouterC: load=38%, arrivals=38, leaked=50, bucket=67/200, action=queued
#
# ⏱️ Time step 6980 sec:
#   RouterA: load=88%, arrivals=88, leaked=50, bucket=200/200, action=dropped 13
#   RouterB: load=93%, arrivals=93, leaked=22, bucket=93/200, action=queued
#   RouterC: load=29%, arrivals=28, leaked=50, bucket=45/200, action=queued
#
# ⏱️ Time step 6990 sec:
#   RouterA: load=64%, arrivals=64, leaked=50, bucket=200/200, action=dropped 14
#   RouterB: load=32%, arrivals=32, leaked=50, bucket=75/200, action=queued
#   RouterC: load=8%, arrivals=8, leaked=45, bucket=8/200, action=queued

# %%
#TOKEN BUCKET
import pandas as pd

def run_token_bucket(congestion_file, bucket_capacity=200, token_rate=50, timestep=10):
    """
    Apply Token Bucket per router across congestion timesteps.

    Args:
        congestion_file: CSV with Time, RouterA, RouterB, RouterC columns
        bucket_capacity: max number of tokens
        token_rate: tokens added per timestep
        timestep: interval in seconds between samples
    """
    df = pd.read_csv(congestion_file)

    # Ensure Time column exists
    if "Time" not in df.columns:
        df.insert(0, "Time", [i * timestep for i in range(len(df))])

    routers = [c for c in df.columns if c.startswith("Router")]
    tokens = {r: bucket_capacity for r in routers}  # start full

    for _, row in df.iterrows():
        time_label = row["Time"]
        print(f"\n⏱️ Time step {time_label} sec:")

        for r in routers:
            load = float(row[r])  # congestion percentage

            # Convert congestion % to traffic demand
            demand = int((load / 100) * bucket_capacity * 0.5)

            # Refill tokens
            tokens[r] = min(bucket_capacity, tokens[r] + token_rate)

            # Serve traffic
            if demand <= tokens[r]:
                tokens[r] -= demand
                action = "sent"
            else:
                dropped = demand - tokens[r]
                tokens[r] = 0
                action = f"dropped {dropped}"

            print(f"  {r}: load={load:.0f}%, demand={demand}, "
                  f"tokens left={tokens[r]}/{bucket_capacity}, action={action}")
congestion_file = "C:/Users/ASUS/Downloads/router_congestion_int.csv"
run_token_bucket(congestion_file)
# Out:
# ⏱️ Time step 0 sec:
#   RouterA: load=1%, demand=1, tokens left=199/200, action=sent
#   RouterB: load=29%, demand=28, tokens left=172/200, action=sent
#   RouterC: load=30%, demand=30, tokens left=170/200, action=sent
#
# ⏱️ Time step 10 sec:
#   RouterA: load=3%, demand=3, tokens left=197/200, action=sent
#   RouterB: load=27%, demand=27, tokens left=173/200, action=sent
#   RouterC: load=68%, demand=68, tokens left=132/200, action=sent
#
# ⏱️ Time step 20 sec:
#   RouterA: load=35%, demand=35, tokens left=165/200, action=sent
#   RouterB: load=38%, demand=38, tokens left=162/200, action=sent
#   RouterC: load=90%, demand=90, tokens left=92/200, action=sent
#
# ⏱️ Time step 30 sec:
#   RouterA: load=97%, demand=97, tokens left=103/200, action=sent
#   RouterB: load=66%, demand=66, tokens left=134/200, action=sent
#   RouterC: load=3%, demand=3, tokens left=139/200, action=sent
#
# ⏱️ Time step 40 sec:
#   RouterA: load=45%, demand=45, tokens left=108/200, action=sent
#   RouterB: load=94%, demand=94, tokens left=90/200, action=sent
#   RouterC: load=9%, demand=9, tokens left=180/200, action=sent
#
# ⏱️ Time step 50 sec:
#   RouterA: load=2%, demand=2, tokens left=156/200, action=sent
#   RouterB: load=16%, demand=16, tokens left=124/200, action=sent
#   RouterC: load=31%, demand=31, tokens left=169/200, action=sent
#
# ⏱️ Time step 60 sec:
#   RouterA: load=36%, demand=36, tokens left=164/200, action=sent
#   RouterB: load=9%, demand=9, tokens left=165/200, action=sent
#   RouterC: load=62%, demand=62, tokens left=138/200, action=sent
#
# ⏱️ Time step 70 sec:
#   RouterA: load=23%, demand=23, tokens left=177/200, action=sent
#   RouterB: load=34%, demand=34, tokens left=166/200, action=sent
#   RouterC: load=29%, demand=28, tokens left=160/200, action=sent
#
# ⏱️ Time step 80 sec:
#   RouterA: load=22%, demand=22, tokens left=178/200, action=sent
#   RouterB: load=95%, demand=95, tokens left=105/200, action=sent
#   RouterC: load=83%, demand=83, tokens left=117/200, action=sent
#
# ⏱️ Time step 90 sec:
#   RouterA: load=56%, demand=56, tokens left=144/200, action=sent
#   RouterB: load=92%, demand=92, tokens left=63/200, action=sent
#   RouterC: load=13%, demand=13, tokens left=154/200, action=sent
#
# ⏱️ Time step 100 sec:
#   RouterA: load=99%, demand=99, tokens left=95/200, action=sent
#   RouterB: load=1%, demand=1, tokens left=112/200, action=sent
#   RouterC: load=30%, demand=30, tokens left=170/200, action=sent
#
# ⏱️ Time step 110 sec:
#   RouterA: load=71%, demand=71, tokens left=74/200, action=sent
#   RouterB: load=28%, demand=28, tokens left=134/200, action=sent
#   RouterC: load=73%, demand=73, tokens left=127/200, action=sent
#
# ⏱️ Time step 120 sec:
#   RouterA: load=30%, demand=30, tokens left=94/200, action=sent
#   RouterB: load=26%, demand=26, tokens left=158/200, action=sent
#   RouterC: load=32%, demand=32, tokens left=145/200, action=sent
#
# ⏱️ Time step 130 sec:
#   RouterA: load=96%, demand=96, tokens left=48/200, action=sent
#   RouterB: load=65%, demand=65, tokens left=135/200, action=sent
#   RouterC: load=65%, demand=65, tokens left=130/200, action=sent
#
# ⏱️ Time step 140 sec:
#   RouterA: load=21%, demand=21, tokens left=77/200, action=sent
#   RouterB: load=38%, demand=38, tokens left=147/200, action=sent
#   RouterC: load=35%, demand=35, tokens left=145/200, action=sent
#
# ⏱️ Time step 150 sec:
#   RouterA: load=56%, demand=56, tokens left=71/200, action=sent
#   RouterB: load=51%, demand=51, tokens left=146/200, action=sent
#   RouterC: load=30%, demand=30, tokens left=165/200, action=sent
#
# ⏱️ Time step 160 sec:
#   RouterA: load=93%, demand=93, tokens left=28/200, action=sent
#   RouterB: load=12%, demand=12, tokens left=184/200, action=sent
#   RouterC: load=11%, demand=11, tokens left=189/200, action=sent
#
# ⏱️ Time step 170 sec:
#   RouterA: load=10%, demand=10, tokens left=68/200, action=sent
#   RouterB: load=85%, demand=85, tokens left=115/200, action=sent
#   RouterC: load=53%, demand=53, tokens left=147/200, action=sent
#
# ⏱️ Time step 180 sec:
#   RouterA: load=98%, demand=98, tokens left=20/200, action=sent
#   RouterB: load=43%, demand=43, tokens left=122/200, action=sent
#   RouterC: load=46%, demand=46, tokens left=151/200, action=sent
#
# ⏱️ Time step 190 sec:
#   RouterA: load=84%, demand=84, tokens left=0/200, action=dropped 14
#   RouterB: load=8%, demand=8, tokens left=164/200, action=sent
#   RouterC: load=97%, demand=97, tokens left=103/200, action=sent
#
# ⏱️ Time step 200 sec:
#   RouterA: load=2%, demand=2, tokens left=48/200, action=sent
#   RouterB: load=39%, demand=39, tokens left=161/200, action=sent
#   RouterC: load=0%, demand=0, tokens left=153/200, action=sent
#
# ⏱️ Time step 210 sec:
#   RouterA: load=48%, demand=48, tokens left=50/200, action=sent
#   RouterB: load=11%, demand=11, tokens left=189/200, action=sent
#   RouterC: load=31%, demand=31, tokens left=169/200, action=sent
#
# ⏱️ Time step 220 sec:
#   RouterA: load=67%, demand=67, tokens left=33/200, action=sent
#   RouterB: load=71%, demand=71, tokens left=129/200, action=sent
#   RouterC: load=30%, demand=30, tokens left=170/200, action=sent
#
# ⏱️ Time step 230 sec:
#   RouterA: load=19%, demand=19, tokens left=64/200, action=sent
#   RouterB: load=58%, demand=57, tokens left=122/200, action=sent
#   RouterC: load=97%, demand=97, tokens left=103/200, action=sent
#
# ⏱️ Time step 240 sec:
#   RouterA: load=85%, demand=85, tokens left=29/200, action=sent
#   RouterB: load=77%, demand=77, tokens left=95/200, action=sent
#   RouterC: load=52%, demand=52, tokens left=101/200, action=sent
#
# ⏱️ Time step 250 sec:
#   RouterA: load=97%, demand=97, tokens left=0/200, action=dropped 18
#   RouterB: load=90%, demand=90, tokens left=55/200, action=sent
#   RouterC: load=88%, demand=88, tokens left=63/200, action=sent
#
# ⏱️ Time step 260 sec:
#   RouterA: load=71%, demand=71, tokens left=0/200, action=dropped 21
#   RouterB: load=91%, demand=91, tokens left=14/200, action=sent
#   RouterC: load=10%, demand=10, tokens left=103/200, action=sent
#
# ⏱️ Time step 270 sec:
#   RouterA: load=61%, demand=61, tokens left=0/200, action=dropped 11
#   RouterB: load=79%, demand=79, tokens left=0/200, action=dropped 15
#   RouterC: load=92%, demand=92, tokens left=61/200, action=sent
#
# ⏱️ Time step 280 sec:
#   RouterA: load=75%, demand=75, tokens left=0/200, action=dropped 25
#   RouterB: load=15%, demand=15, tokens left=35/200, action=sent
#   RouterC: load=41%, demand=41, tokens left=70/200, action=sent
#
# ⏱️ Time step 290 sec:
#   RouterA: load=45%, demand=45, tokens left=5/200, action=sent
#   RouterB: load=28%, demand=28, tokens left=57/200, action=sent
#   RouterC: load=98%, demand=98, tokens left=22/200, action=sent
#
# ⏱️ Time step 300 sec:
#   RouterA: load=45%, demand=45, tokens left=10/200, action=sent
#   RouterB: load=68%, demand=68, tokens left=39/200, action=sent
#   RouterC: load=66%, demand=66, tokens left=6/200, action=sent
#
# ⏱️ Time step 310 sec:
#   RouterA: load=67%, demand=67, tokens left=0/200, action=dropped 7
#   RouterB: load=96%, demand=96, tokens left=0/200, action=dropped 7
#   RouterC: load=79%, demand=79, tokens left=0/200, action=dropped 23
#
# ⏱️ Time step 320 sec:
#   RouterA: load=62%, demand=62, tokens left=0/200, action=dropped 12
#   RouterB: load=35%, demand=35, tokens left=15/200, action=sent
#   RouterC: load=14%, demand=14, tokens left=36/200, action=sent
#
# ⏱️ Time step 330 sec:
#   RouterA: load=34%, demand=34, tokens left=16/200, action=sent
#   RouterB: load=10%, demand=10, tokens left=55/200, action=sent
#   RouterC: load=70%, demand=70, tokens left=16/200, action=sent
#
# ⏱️ Time step 340 sec:
#   RouterA: load=36%, demand=36, tokens left=30/200, action=sent
#   RouterB: load=58%, demand=57, tokens left=48/200, action=sent
#   RouterC: load=77%, demand=77, tokens left=0/200, action=dropped 11
#
# ⏱️ Time step 350 sec:
#   RouterA: load=45%, demand=45, tokens left=35/200, action=sent
#   RouterB: load=53%, demand=53, tokens left=45/200, action=sent
#   RouterC: load=78%, demand=78, tokens left=0/200, action=dropped 28
#
# ⏱️ Time step 360 sec:
#   RouterA: load=46%, demand=46, tokens left=39/200, action=sent
#   RouterB: load=46%, demand=46, tokens left=49/200, action=sent
#   RouterC: load=20%, demand=20, tokens left=30/200, action=sent
#
# ⏱️ Time step 370 sec:
#   RouterA: load=26%, demand=26, tokens left=63/200, action=sent
#   RouterB: load=40%, demand=40, tokens left=59/200, action=sent
#   RouterC: load=73%, demand=73, tokens left=7/200, action=sent
#
# ⏱️ Time step 380 sec:
#   RouterA: load=87%, demand=87, tokens left=26/200, action=sent
#   RouterB: load=60%, demand=60, tokens left=49/200, action=sent
#   RouterC: load=95%, demand=95, tokens left=0/200, action=dropped 38
#
# ⏱️ Time step 390 sec:
#   RouterA: load=94%, demand=94, tokens left=0/200, action=dropped 18
#   RouterB: load=72%, demand=72, tokens left=27/200, action=sent
#   RouterC: load=7%, demand=7, tokens left=43/200, action=sent
#
# ⏱️ Time step 400 sec:
#   RouterA: load=1%, demand=1, tokens left=49/200, action=sent
#   RouterB: load=5%, demand=5, tokens left=72/200, action=sent
#   RouterC: load=33%, demand=33, tokens left=60/200, action=sent
#
# ⏱️ Time step 410 sec:
#   RouterA: load=46%, demand=46, tokens left=53/200, action=sent
#   RouterB: load=66%, demand=66, tokens left=56/200, action=sent
#   RouterC: load=40%, demand=40, tokens left=70/200, action=sent
#
# ⏱️ Time step 420 sec:
#   RouterA: load=77%, demand=77, tokens left=26/200, action=sent
#   RouterB: load=98%, demand=98, tokens left=8/200, action=sent
#   RouterC: load=11%, demand=11, tokens left=109/200, action=sent
#
# ⏱️ Time step 430 sec:
#   RouterA: load=4%, demand=4, tokens left=72/200, action=sent
#   RouterB: load=99%, demand=99, tokens left=0/200, action=dropped 41
#   RouterC: load=100%, demand=100, tokens left=59/200, action=sent
#
# ⏱️ Time step 440 sec:
#   RouterA: load=31%, demand=31, tokens left=91/200, action=sent
#   RouterB: load=76%, demand=76, tokens left=0/200, action=dropped 26
#   RouterC: load=77%, demand=77, tokens left=32/200, action=sent
#
# ⏱️ Time step 450 sec:
#   RouterA: load=18%, demand=18, tokens left=123/200, action=sent
#   RouterB: load=98%, demand=98, tokens left=0/200, action=dropped 48
#   RouterC: load=73%, demand=73, tokens left=9/200, action=sent
#
# ⏱️ Time step 460 sec:
#   RouterA: load=9%, demand=9, tokens left=164/200, action=sent
#   RouterB: load=55%, demand=55, tokens left=0/200, action=dropped 5
#   RouterC: load=38%, demand=38, tokens left=21/200, action=sent
#
# ⏱️ Time step 470 sec:
#   RouterA: load=10%, demand=10, tokens left=190/200, action=sent
#   RouterB: load=17%, demand=17, tokens left=33/200, action=sent
#   RouterC: load=60%, demand=60, tokens left=11/200, action=sent
#
# ⏱️ Time step 480 sec:
#   RouterA: load=0%, demand=0, tokens left=200/200, action=sent
#   RouterB: load=16%, demand=16, tokens left=67/200, action=sent
#   RouterC: load=89%, demand=89, tokens left=0/200, action=dropped 28
#
# ⏱️ Time step 490 sec:
#   RouterA: load=73%, demand=73, tokens left=127/200, action=sent
#   RouterB: load=54%, demand=54, tokens left=63/200, action=sent
#   RouterC: load=18%, demand=18, tokens left=32/200, action=sent
#
# ⏱️ Time step 500 sec:
#   RouterA: load=28%, demand=28, tokens left=149/200, action=sent
#   RouterB: load=13%, demand=13, tokens left=100/200, action=sent
#   RouterC: load=66%, demand=66, tokens left=16/200, action=sent
#
# ⏱️ Time step 510 sec:
#   RouterA: load=48%, demand=48, tokens left=151/200, action=sent
#   RouterB: load=19%, demand=19, tokens left=131/200, action=sent
#   RouterC: load=43%, demand=43, tokens left=23/200, action=sent
#
# ⏱️ Time step 520 sec:
#   RouterA: load=36%, demand=36, tokens left=164/200, action=sent
#   RouterB: load=66%, demand=66, tokens left=115/200, action=sent
#   RouterC: load=93%, demand=93, tokens left=0/200, action=dropped 20
#
# ⏱️ Time step 530 sec:
#   RouterA: load=3%, demand=3, tokens left=197/200, action=sent
#   RouterB: load=59%, demand=59, tokens left=106/200, action=sent
#   RouterC: load=62%, demand=62, tokens left=0/200, action=dropped 12
#
# ⏱️ Time step 540 sec:
#   RouterA: load=39%, demand=39, tokens left=161/200, action=sent
#   RouterB: load=17%, demand=17, tokens left=139/200, action=sent
#   RouterC: load=18%, demand=18, tokens left=32/200, action=sent
#
# ⏱️ Time step 550 sec:
#   RouterA: load=67%, demand=67, tokens left=133/200, action=sent
#   RouterB: load=4%, demand=4, tokens left=185/200, action=sent
#   RouterC: load=69%, demand=69, tokens left=13/200, action=sent
#
# ⏱️ Time step 560 sec:
#   RouterA: load=0%, demand=0, tokens left=183/200, action=sent
#   RouterB: load=98%, demand=98, tokens left=102/200, action=sent
#   RouterC: load=94%, demand=94, tokens left=0/200, action=dropped 31
#
# ⏱️ Time step 570 sec:
#   RouterA: load=26%, demand=26, tokens left=174/200, action=sent
#   RouterB: load=12%, demand=12, tokens left=140/200, action=sent
#   RouterC: load=6%, demand=6, tokens left=44/200, action=sent
#
# ⏱️ Time step 580 sec:
#   RouterA: load=66%, demand=66, tokens left=134/200, action=sent
#   RouterB: load=94%, demand=94, tokens left=96/200, action=sent
#   RouterC: load=38%, demand=38, tokens left=56/200, action=sent
#
# ⏱️ Time step 590 sec:
#   RouterA: load=62%, demand=62, tokens left=122/200, action=sent
#   RouterB: load=15%, demand=15, tokens left=131/200, action=sent
#   RouterC: load=19%, demand=19, tokens left=87/200, action=sent
#
# ⏱️ Time step 600 sec:
#   RouterA: load=82%, demand=82, tokens left=90/200, action=sent
#   RouterB: load=72%, demand=72, tokens left=109/200, action=sent
#   RouterC: load=43%, demand=43, tokens left=94/200, action=sent
#
# ⏱️ Time step 610 sec:
#   RouterA: load=43%, demand=43, tokens left=97/200, action=sent
#   RouterB: load=88%, demand=88, tokens left=71/200, action=sent
#   RouterC: load=59%, demand=59, tokens left=85/200, action=sent
#
# ⏱️ Time step 620 sec:
#   RouterA: load=7%, demand=7, tokens left=140/200, action=sent
#   RouterB: load=96%, demand=96, tokens left=25/200, action=sent
#   RouterC: load=38%, demand=38, tokens left=97/200, action=sent
#
# ⏱️ Time step 630 sec:
#   RouterA: load=3%, demand=3, tokens left=187/200, action=sent
#   RouterB: load=43%, demand=43, tokens left=32/200, action=sent
#   RouterC: load=38%, demand=38, tokens left=109/200, action=sent
#
# ⏱️ Time step 640 sec:
#   RouterA: load=74%, demand=74, tokens left=126/200, action=sent
#   RouterB: load=98%, demand=98, tokens left=0/200, action=dropped 16
#   RouterC: load=26%, demand=26, tokens left=133/200, action=sent
#
# ⏱️ Time step 650 sec:
#   RouterA: load=83%, demand=83, tokens left=93/200, action=sent
#   RouterB: load=6%, demand=6, tokens left=44/200, action=sent
#   RouterC: load=70%, demand=70, tokens left=113/200, action=sent
#
# ⏱️ Time step 660 sec:
#   RouterA: load=13%, demand=13, tokens left=130/200, action=sent
#   RouterB: load=59%, demand=59, tokens left=35/200, action=sent
#   RouterC: load=77%, demand=77, tokens left=86/200, action=sent
#
# ⏱️ Time step 670 sec:
#   RouterA: load=6%, demand=6, tokens left=174/200, action=sent
#   RouterB: load=18%, demand=18, tokens left=67/200, action=sent
#   RouterC: load=4%, demand=4, tokens left=132/200, action=sent
#
# ⏱️ Time step 680 sec:
#   RouterA: load=44%, demand=44, tokens left=156/200, action=sent
#   RouterB: load=93%, demand=93, tokens left=24/200, action=sent
#   RouterC: load=63%, demand=63, tokens left=119/200, action=sent
#
# ⏱️ Time step 690 sec:
#   RouterA: load=3%, demand=3, tokens left=197/200, action=sent
#   RouterB: load=76%, demand=76, tokens left=0/200, action=dropped 2
#   RouterC: load=64%, demand=64, tokens left=105/200, action=sent
#
# ⏱️ Time step 700 sec:
#   RouterA: load=49%, demand=49, tokens left=151/200, action=sent
#   RouterB: load=7%, demand=7, tokens left=43/200, action=sent
#   RouterC: load=78%, demand=78, tokens left=77/200, action=sent
#
# ⏱️ Time step 710 sec:
#   RouterA: load=48%, demand=48, tokens left=152/200, action=sent
#   RouterB: load=100%, demand=100, tokens left=0/200, action=dropped 7
#   RouterC: load=25%, demand=25, tokens left=102/200, action=sent
#
# ⏱️ Time step 720 sec:
#   RouterA: load=38%, demand=38, tokens left=162/200, action=sent
#   RouterB: load=38%, demand=38, tokens left=12/200, action=sent
#   RouterC: load=65%, demand=65, tokens left=87/200, action=sent
#
# ⏱️ Time step 730 sec:
#   RouterA: load=46%, demand=46, tokens left=154/200, action=sent
#   RouterB: load=70%, demand=70, tokens left=0/200, action=dropped 8
#   RouterC: load=85%, demand=85, tokens left=52/200, action=sent
#
# ⏱️ Time step 740 sec:
#   RouterA: load=3%, demand=3, tokens left=197/200, action=sent
#   RouterB: load=43%, demand=43, tokens left=7/200, action=sent
#   RouterC: load=88%, demand=88, tokens left=14/200, action=sent
#
# ⏱️ Time step 750 sec:
#   RouterA: load=2%, demand=2, tokens left=198/200, action=sent
#   RouterB: load=46%, demand=46, tokens left=11/200, action=sent
#   RouterC: load=99%, demand=99, tokens left=0/200, action=dropped 35
#
# ⏱️ Time step 760 sec:
#   RouterA: load=52%, demand=52, tokens left=148/200, action=sent
#   RouterB: load=2%, demand=2, tokens left=59/200, action=sent
#   RouterC: load=12%, demand=12, tokens left=38/200, action=sent
#
# ⏱️ Time step 770 sec:
#   RouterA: load=32%, demand=32, tokens left=166/200, action=sent
#   RouterB: load=14%, demand=14, tokens left=95/200, action=sent
#   RouterC: load=14%, demand=14, tokens left=74/200, action=sent
#
# ⏱️ Time step 780 sec:
#   RouterA: load=74%, demand=74, tokens left=126/200, action=sent
#   RouterB: load=27%, demand=27, tokens left=118/200, action=sent
#   RouterC: load=82%, demand=82, tokens left=42/200, action=sent
#
# ⏱️ Time step 790 sec:
#   RouterA: load=25%, demand=25, tokens left=151/200, action=sent
#   RouterB: load=97%, demand=97, tokens left=71/200, action=sent
#   RouterC: load=83%, demand=83, tokens left=9/200, action=sent
#
# ⏱️ Time step 800 sec:
#   RouterA: load=91%, demand=91, tokens left=109/200, action=sent
#   RouterB: load=73%, demand=73, tokens left=48/200, action=sent
#   RouterC: load=88%, demand=88, tokens left=0/200, action=dropped 29
#
# ⏱️ Time step 810 sec:
#   RouterA: load=14%, demand=14, tokens left=145/200, action=sent
#   RouterB: load=24%, demand=24, tokens left=74/200, action=sent
#   RouterC: load=46%, demand=46, tokens left=4/200, action=sent
#
# ⏱️ Time step 820 sec:
#   RouterA: load=72%, demand=72, tokens left=123/200, action=sent
#   RouterB: load=92%, demand=92, tokens left=32/200, action=sent
#   RouterC: load=7%, demand=7, tokens left=47/200, action=sent
#
# ⏱️ Time step 830 sec:
#   RouterA: load=21%, demand=21, tokens left=152/200, action=sent
#   RouterB: load=15%, demand=15, tokens left=67/200, action=sent
#   RouterC: load=4%, demand=4, tokens left=93/200, action=sent
#
# ⏱️ Time step 840 sec:
#   RouterA: load=52%, demand=52, tokens left=148/200, action=sent
#   RouterB: load=6%, demand=6, tokens left=111/200, action=sent
#   RouterC: load=98%, demand=98, tokens left=45/200, action=sent
#
# ⏱️ Time step 850 sec:
#   RouterA: load=95%, demand=95, tokens left=103/200, action=sent
#   RouterB: load=34%, demand=34, tokens left=127/200, action=sent
#   RouterC: load=79%, demand=79, tokens left=16/200, action=sent
#
# ⏱️ Time step 860 sec:
#   RouterA: load=65%, demand=65, tokens left=88/200, action=sent
#   RouterB: load=48%, demand=48, tokens left=129/200, action=sent
#   RouterC: load=30%, demand=30, tokens left=36/200, action=sent
#
# ⏱️ Time step 870 sec:
#   RouterA: load=7%, demand=7, tokens left=131/200, action=sent
#   RouterB: load=50%, demand=50, tokens left=129/200, action=sent
#   RouterC: load=50%, demand=50, tokens left=36/200, action=sent
#
# ⏱️ Time step 880 sec:
#   RouterA: load=75%, demand=75, tokens left=106/200, action=sent
#   RouterB: load=11%, demand=11, tokens left=168/200, action=sent
#   RouterC: load=76%, demand=76, tokens left=10/200, action=sent
#
# ⏱️ Time step 890 sec:
#   RouterA: load=76%, demand=76, tokens left=80/200, action=sent
#   RouterB: load=38%, demand=38, tokens left=162/200, action=sent
#   RouterC: load=75%, demand=75, tokens left=0/200, action=dropped 15
#
# ⏱️ Time step 900 sec:
#   RouterA: load=42%, demand=42, tokens left=88/200, action=sent
#   RouterB: load=22%, demand=22, tokens left=178/200, action=sent
#   RouterC: load=96%, demand=96, tokens left=0/200, action=dropped 46
#
# ⏱️ Time step 910 sec:
#   RouterA: load=48%, demand=48, tokens left=90/200, action=sent
#   RouterB: load=34%, demand=34, tokens left=166/200, action=sent
#   RouterC: load=66%, demand=66, tokens left=0/200, action=dropped 16
#
# ⏱️ Time step 920 sec:
#   RouterA: load=22%, demand=22, tokens left=118/200, action=sent
#   RouterB: load=78%, demand=78, tokens left=122/200, action=sent
#   RouterC: load=77%, demand=77, tokens left=0/200, action=dropped 27
#
# ⏱️ Time step 930 sec:
#   RouterA: load=14%, demand=14, tokens left=154/200, action=sent
#   RouterB: load=97%, demand=97, tokens left=75/200, action=sent
#   RouterC: load=98%, demand=98, tokens left=0/200, action=dropped 48
#
# ⏱️ Time step 940 sec:
#   RouterA: load=3%, demand=3, tokens left=197/200, action=sent
#   RouterB: load=47%, demand=47, tokens left=78/200, action=sent
#   RouterC: load=31%, demand=31, tokens left=19/200, action=sent
#
# ⏱️ Time step 950 sec:
#   RouterA: load=84%, demand=84, tokens left=116/200, action=sent
#   RouterB: load=1%, demand=1, tokens left=127/200, action=sent
#   RouterC: load=34%, demand=34, tokens left=35/200, action=sent
#
# ⏱️ Time step 960 sec:
#   RouterA: load=95%, demand=95, tokens left=71/200, action=sent
#   RouterB: load=27%, demand=27, tokens left=150/200, action=sent
#   RouterC: load=28%, demand=28, tokens left=57/200, action=sent
#
# ⏱️ Time step 970 sec:
#   RouterA: load=0%, demand=0, tokens left=121/200, action=sent
#   RouterB: load=44%, demand=44, tokens left=156/200, action=sent
#   RouterC: load=81%, demand=81, tokens left=26/200, action=sent
#
# ⏱️ Time step 980 sec:
#   RouterA: load=44%, demand=44, tokens left=127/200, action=sent
#   RouterB: load=87%, demand=87, tokens left=113/200, action=sent
#   RouterC: load=14%, demand=14, tokens left=62/200, action=sent
#
# ⏱️ Time step 990 sec:
#   RouterA: load=60%, demand=60, tokens left=117/200, action=sent
#   RouterB: load=1%, demand=1, tokens left=162/200, action=sent
#   RouterC: load=89%, demand=89, tokens left=23/200, action=sent
#
# ⏱️ Time step 1000 sec:
#   RouterA: load=43%, demand=43, tokens left=124/200, action=sent
#   RouterB: load=43%, demand=43, tokens left=157/200, action=sent
#   RouterC: load=80%, demand=80, tokens left=0/200, action=dropped 7
#
# ⏱️ Time step 1010 sec:
#   RouterA: load=13%, demand=13, tokens left=161/200, action=sent
#   RouterB: load=18%, demand=18, tokens left=182/200, action=sent
#   RouterC: load=88%, demand=88, tokens left=0/200, action=dropped 38
#
# ⏱️ Time step 1020 sec:
#   RouterA: load=18%, demand=18, tokens left=182/200, action=sent
#   RouterB: load=44%, demand=44, tokens left=156/200, action=sent
#   RouterC: load=82%, demand=82, tokens left=0/200, action=dropped 32
#
# ⏱️ Time step 1030 sec:
#   RouterA: load=25%, demand=25, tokens left=175/200, action=sent
#   RouterB: load=92%, demand=92, tokens left=108/200, action=sent
#   RouterC: load=84%, demand=84, tokens left=0/200, action=dropped 34
#
# ⏱️ Time step 1040 sec:
#   RouterA: load=50%, demand=50, tokens left=150/200, action=sent
#   RouterB: load=74%, demand=74, tokens left=84/200, action=sent
#   RouterC: load=71%, demand=71, tokens left=0/200, action=dropped 21
#
# ⏱️ Time step 1050 sec:
#   RouterA: load=41%, demand=41, tokens left=159/200, action=sent
#   RouterB: load=32%, demand=32, tokens left=102/200, action=sent
#   RouterC: load=13%, demand=13, tokens left=37/200, action=sent
#
# ⏱️ Time step 1060 sec:
#   RouterA: load=70%, demand=70, tokens left=130/200, action=sent
#   RouterB: load=16%, demand=16, tokens left=136/200, action=sent
#   RouterC: load=47%, demand=47, tokens left=40/200, action=sent
#
# ⏱️ Time step 1070 sec:
#   RouterA: load=10%, demand=10, tokens left=170/200, action=sent
#   RouterB: load=21%, demand=21, tokens left=165/200, action=sent
#   RouterC: load=31%, demand=31, tokens left=59/200, action=sent
#
# ⏱️ Time step 1080 sec:
#   RouterA: load=14%, demand=14, tokens left=186/200, action=sent
#   RouterB: load=45%, demand=45, tokens left=155/200, action=sent
#   RouterC: load=72%, demand=72, tokens left=37/200, action=sent
#
# ⏱️ Time step 1090 sec:
#   RouterA: load=50%, demand=50, tokens left=150/200, action=sent
#   RouterB: load=96%, demand=96, tokens left=104/200, action=sent
#   RouterC: load=40%, demand=40, tokens left=47/200, action=sent
#
# ⏱️ Time step 1100 sec:
#   RouterA: load=23%, demand=23, tokens left=177/200, action=sent
#   RouterB: load=77%, demand=77, tokens left=77/200, action=sent
#   RouterC: load=54%, demand=54, tokens left=43/200, action=sent
#
# ⏱️ Time step 1110 sec:
#   RouterA: load=14%, demand=14, tokens left=186/200, action=sent
#   RouterB: load=40%, demand=40, tokens left=87/200, action=sent
#   RouterC: load=25%, demand=25, tokens left=68/200, action=sent
#
# ⏱️ Time step 1120 sec:
#   RouterA: load=76%, demand=76, tokens left=124/200, action=sent
#   RouterB: load=46%, demand=46, tokens left=91/200, action=sent
#   RouterC: load=0%, demand=0, tokens left=118/200, action=sent
#
# ⏱️ Time step 1130 sec:
#   RouterA: load=28%, demand=28, tokens left=146/200, action=sent
#   RouterB: load=40%, demand=40, tokens left=101/200, action=sent
#   RouterC: load=60%, demand=60, tokens left=108/200, action=sent
#
# ⏱️ Time step 1140 sec:
#   RouterA: load=12%, demand=12, tokens left=184/200, action=sent
#   RouterB: load=44%, demand=44, tokens left=107/200, action=sent
#   RouterC: load=71%, demand=71, tokens left=87/200, action=sent
#
# ⏱️ Time step 1150 sec:
#   RouterA: load=68%, demand=68, tokens left=132/200, action=sent
#   RouterB: load=61%, demand=61, tokens left=96/200, action=sent
#   RouterC: load=91%, demand=91, tokens left=46/200, action=sent
#
# ⏱️ Time step 1160 sec:
#   RouterA: load=98%, demand=98, tokens left=84/200, action=sent
#   RouterB: load=65%, demand=65, tokens left=81/200, action=sent
#   RouterC: load=94%, demand=94, tokens left=2/200, action=sent
#
# ⏱️ Time step 1170 sec:
#   RouterA: load=63%, demand=63, tokens left=71/200, action=sent
#   RouterB: load=92%, demand=92, tokens left=39/200, action=sent
#   RouterC: load=70%, demand=70, tokens left=0/200, action=dropped 18
#
# ⏱️ Time step 1180 sec:
#   RouterA: load=35%, demand=35, tokens left=86/200, action=sent
#   RouterB: load=65%, demand=65, tokens left=24/200, action=sent
#   RouterC: load=37%, demand=37, tokens left=13/200, action=sent
#
# ⏱️ Time step 1190 sec:
#   RouterA: load=73%, demand=73, tokens left=63/200, action=sent
#   RouterB: load=25%, demand=25, tokens left=49/200, action=sent
#   RouterC: load=43%, demand=43, tokens left=20/200, action=sent
#
# ⏱️ Time step 1200 sec:
#   RouterA: load=76%, demand=76, tokens left=37/200, action=sent
#   RouterB: load=9%, demand=9, tokens left=90/200, action=sent
#   RouterC: load=57%, demand=56, tokens left=14/200, action=sent
#
# ⏱️ Time step 1210 sec:
#   RouterA: load=74%, demand=74, tokens left=13/200, action=sent
#   RouterB: load=7%, demand=7, tokens left=133/200, action=sent
#   RouterC: load=60%, demand=60, tokens left=4/200, action=sent
#
# ⏱️ Time step 1220 sec:
#   RouterA: load=40%, demand=40, tokens left=23/200, action=sent
#   RouterB: load=54%, demand=54, tokens left=129/200, action=sent
#   RouterC: load=22%, demand=22, tokens left=32/200, action=sent
#
# ⏱️ Time step 1230 sec:
#   RouterA: load=59%, demand=59, tokens left=14/200, action=sent
#   RouterB: load=98%, demand=98, tokens left=81/200, action=sent
#   RouterC: load=70%, demand=70, tokens left=12/200, action=sent
#
# ⏱️ Time step 1240 sec:
#   RouterA: load=18%, demand=18, tokens left=46/200, action=sent
#   RouterB: load=69%, demand=69, tokens left=62/200, action=sent
#   RouterC: load=25%, demand=25, tokens left=37/200, action=sent
#
# ⏱️ Time step 1250 sec:
#   RouterA: load=36%, demand=36, tokens left=60/200, action=sent
#   RouterB: load=5%, demand=5, tokens left=107/200, action=sent
#   RouterC: load=50%, demand=50, tokens left=37/200, action=sent
#
# ⏱️ Time step 1260 sec:
#   RouterA: load=68%, demand=68, tokens left=42/200, action=sent
#   RouterB: load=48%, demand=48, tokens left=109/200, action=sent
#   RouterC: load=44%, demand=44, tokens left=43/200, action=sent
#
# ⏱️ Time step 1270 sec:
#   RouterA: load=70%, demand=70, tokens left=22/200, action=sent
#   RouterB: load=64%, demand=64, tokens left=95/200, action=sent
#   RouterC: load=6%, demand=6, tokens left=87/200, action=sent
#
# ⏱️ Time step 1280 sec:
#   RouterA: load=38%, demand=38, tokens left=34/200, action=sent
#   RouterB: load=91%, demand=91, tokens left=54/200, action=sent
#   RouterC: load=94%, demand=94, tokens left=43/200, action=sent
#
# ⏱️ Time step 1290 sec:
#   RouterA: load=99%, demand=99, tokens left=0/200, action=dropped 15
#   RouterB: load=48%, demand=48, tokens left=56/200, action=sent
#   RouterC: load=48%, demand=48, tokens left=45/200, action=sent
#
# ⏱️ Time step 1300 sec:
#   RouterA: load=0%, demand=0, tokens left=50/200, action=sent
#   RouterB: load=40%, demand=40, tokens left=66/200, action=sent
#   RouterC: load=40%, demand=40, tokens left=55/200, action=sent
#
# ⏱️ Time step 1310 sec:
#   RouterA: load=28%, demand=28, tokens left=72/200, action=sent
#   RouterB: load=18%, demand=18, tokens left=98/200, action=sent
#   RouterC: load=74%, demand=74, tokens left=31/200, action=sent
#
# ⏱️ Time step 1320 sec:
#   RouterA: load=89%, demand=89, tokens left=33/200, action=sent
#   RouterB: load=96%, demand=96, tokens left=52/200, action=sent
#   RouterC: load=24%, demand=24, tokens left=57/200, action=sent
#
# ⏱️ Time step 1330 sec:
#   RouterA: load=89%, demand=89, tokens left=0/200, action=dropped 6
#   RouterB: load=29%, demand=28, tokens left=74/200, action=sent
#   RouterC: load=28%, demand=28, tokens left=79/200, action=sent
#
# ⏱️ Time step 1340 sec:
#   RouterA: load=40%, demand=40, tokens left=10/200, action=sent
#   RouterB: load=0%, demand=0, tokens left=124/200, action=sent
#   RouterC: load=5%, demand=5, tokens left=124/200, action=sent
#
# ⏱️ Time step 1350 sec:
#   RouterA: load=74%, demand=74, tokens left=0/200, action=dropped 14
#   RouterB: load=7%, demand=7, tokens left=167/200, action=sent
#   RouterC: load=64%, demand=64, tokens left=110/200, action=sent
#
# ⏱️ Time step 1360 sec:
#   RouterA: load=68%, demand=68, tokens left=0/200, action=dropped 18
#   RouterB: load=63%, demand=63, tokens left=137/200, action=sent
#   RouterC: load=45%, demand=45, tokens left=115/200, action=sent
#
# ⏱️ Time step 1370 sec:
#   RouterA: load=95%, demand=95, tokens left=0/200, action=dropped 45
#   RouterB: load=26%, demand=26, tokens left=161/200, action=sent
#   RouterC: load=21%, demand=21, tokens left=144/200, action=sent
#
# ⏱️ Time step 1380 sec:
#   RouterA: load=81%, demand=81, tokens left=0/200, action=dropped 31
#   RouterB: load=91%, demand=91, tokens left=109/200, action=sent
#   RouterC: load=39%, demand=39, tokens left=155/200, action=sent
#
# ⏱️ Time step 1390 sec:
#   RouterA: load=99%, demand=99, tokens left=0/200, action=dropped 49
#   RouterB: load=20%, demand=20, tokens left=139/200, action=sent
#   RouterC: load=92%, demand=92, tokens left=108/200, action=sent
#
# ⏱️ Time step 1400 sec:
#   RouterA: load=42%, demand=42, tokens left=8/200, action=sent
#   RouterB: load=72%, demand=72, tokens left=117/200, action=sent
#   RouterC: load=8%, demand=8, tokens left=150/200, action=sent
#
# ⏱️ Time step 1410 sec:
#   RouterA: load=16%, demand=16, tokens left=42/200, action=sent
#   RouterB: load=20%, demand=20, tokens left=147/200, action=sent
#   RouterC: load=93%, demand=93, tokens left=107/200, action=sent
#
# ⏱️ Time step 1420 sec:
#   RouterA: load=78%, demand=78, tokens left=14/200, action=sent
#   RouterB: load=82%, demand=82, tokens left=115/200, action=sent
#   RouterC: load=91%, demand=91, tokens left=66/200, action=sent
#
# ⏱️ Time step 1430 sec:
#   RouterA: load=89%, demand=89, tokens left=0/200, action=dropped 25
#   RouterB: load=30%, demand=30, tokens left=135/200, action=sent
#   RouterC: load=29%, demand=28, tokens left=88/200, action=sent
#
# ⏱️ Time step 1440 sec:
#   RouterA: load=73%, demand=73, tokens left=0/200, action=dropped 23
#   RouterB: load=84%, demand=84, tokens left=101/200, action=sent
#   RouterC: load=88%, demand=88, tokens left=50/200, action=sent
#
# ⏱️ Time step 1450 sec:
#   RouterA: load=20%, demand=20, tokens left=30/200, action=sent
#   RouterB: load=33%, demand=33, tokens left=118/200, action=sent
#   RouterC: load=71%, demand=71, tokens left=29/200, action=sent
#
# ⏱️ Time step 1460 sec:
#   RouterA: load=82%, demand=82, tokens left=0/200, action=dropped 2
#   RouterB: load=43%, demand=43, tokens left=125/200, action=sent
#   RouterC: load=77%, demand=77, tokens left=2/200, action=sent
#
# ⏱️ Time step 1470 sec:
#   RouterA: load=9%, demand=9, tokens left=41/200, action=sent
#   RouterB: load=7%, demand=7, tokens left=168/200, action=sent
#   RouterC: load=29%, demand=28, tokens left=24/200, action=sent
#
# ⏱️ Time step 1480 sec:
#   RouterA: load=74%, demand=74, tokens left=17/200, action=sent
#   RouterB: load=44%, demand=44, tokens left=156/200, action=sent
#   RouterC: load=14%, demand=14, tokens left=60/200, action=sent
#
# ⏱️ Time step 1490 sec:
#   RouterA: load=79%, demand=79, tokens left=0/200, action=dropped 12
#   RouterB: load=39%, demand=39, tokens left=161/200, action=sent
#   RouterC: load=43%, demand=43, tokens left=67/200, action=sent
#
# ⏱️ Time step 1500 sec:
#   RouterA: load=60%, demand=60, tokens left=0/200, action=dropped 10
#   RouterB: load=75%, demand=75, tokens left=125/200, action=sent
#   RouterC: load=18%, demand=18, tokens left=99/200, action=sent
#
# ⏱️ Time step 1510 sec:
#   RouterA: load=92%, demand=92, tokens left=0/200, action=dropped 42
#   RouterB: load=30%, demand=30, tokens left=145/200, action=sent
#   RouterC: load=62%, demand=62, tokens left=87/200, action=sent
#
# ⏱️ Time step 1520 sec:
#   RouterA: load=57%, demand=56, tokens left=0/200, action=dropped 6
#   RouterB: load=49%, demand=49, tokens left=146/200, action=sent
#   RouterC: load=87%, demand=87, tokens left=50/200, action=sent
#
# ⏱️ Time step 1530 sec:
#   RouterA: load=61%, demand=61, tokens left=0/200, action=dropped 11
#   RouterB: load=3%, demand=3, tokens left=193/200, action=sent
#   RouterC: load=7%, demand=7, tokens left=93/200, action=sent
#
# ⏱️ Time step 1540 sec:
#   RouterA: load=1%, demand=1, tokens left=49/200, action=sent
#   RouterB: load=77%, demand=77, tokens left=123/200, action=sent
#   RouterC: load=25%, demand=25, tokens left=118/200, action=sent
#
# ⏱️ Time step 1550 sec:
#   RouterA: load=99%, demand=99, tokens left=0/200, action=sent
#   RouterB: load=90%, demand=90, tokens left=83/200, action=sent
#   RouterC: load=99%, demand=99, tokens left=69/200, action=sent
#
# ⏱️ Time step 1560 sec:
#   RouterA: load=57%, demand=56, tokens left=0/200, action=dropped 6
#   RouterB: load=98%, demand=98, tokens left=35/200, action=sent
#   RouterC: load=80%, demand=80, tokens left=39/200, action=sent
#
# ⏱️ Time step 1570 sec:
#   RouterA: load=93%, demand=93, tokens left=0/200, action=dropped 43
#   RouterB: load=17%, demand=17, tokens left=68/200, action=sent
#   RouterC: load=16%, demand=16, tokens left=73/200, action=sent
#
# ⏱️ Time step 1580 sec:
#   RouterA: load=85%, demand=85, tokens left=0/200, action=dropped 35
#   RouterB: load=41%, demand=41, tokens left=77/200, action=sent
#   RouterC: load=6%, demand=6, tokens left=117/200, action=sent
#
# ⏱️ Time step 1590 sec:
#   RouterA: load=83%, demand=83, tokens left=0/200, action=dropped 33
#   RouterB: load=96%, demand=96, tokens left=31/200, action=sent
#   RouterC: load=68%, demand=68, tokens left=99/200, action=sent
#
# ⏱️ Time step 1600 sec:
#   RouterA: load=41%, demand=41, tokens left=9/200, action=sent
#   RouterB: load=48%, demand=48, tokens left=33/200, action=sent
#   RouterC: load=87%, demand=87, tokens left=62/200, action=sent
#
# ⏱️ Time step 1610 sec:
#   RouterA: load=81%, demand=81, tokens left=0/200, action=dropped 22
#   RouterB: load=96%, demand=96, tokens left=0/200, action=dropped 13
#   RouterC: load=19%, demand=19, tokens left=93/200, action=sent
#
# ⏱️ Time step 1620 sec:
#   RouterA: load=52%, demand=52, tokens left=0/200, action=dropped 2
#   RouterB: load=47%, demand=47, tokens left=3/200, action=sent
#   RouterC: load=58%, demand=57, tokens left=86/200, action=sent
#
# ⏱️ Time step 1630 sec:
#   RouterA: load=47%, demand=47, tokens left=3/200, action=sent
#   RouterB: load=7%, demand=7, tokens left=46/200, action=sent
#   RouterC: load=39%, demand=39, tokens left=97/200, action=sent
#
# ⏱️ Time step 1640 sec:
#   RouterA: load=31%, demand=31, tokens left=22/200, action=sent
#   RouterB: load=38%, demand=38, tokens left=58/200, action=sent
#   RouterC: load=2%, demand=2, tokens left=145/200, action=sent
#
# ⏱️ Time step 1650 sec:
#   RouterA: load=51%, demand=51, tokens left=21/200, action=sent
#   RouterB: load=24%, demand=24, tokens left=84/200, action=sent
#   RouterC: load=85%, demand=85, tokens left=110/200, action=sent
#
# ⏱️ Time step 1660 sec:
#   RouterA: load=34%, demand=34, tokens left=37/200, action=sent
#   RouterB: load=14%, demand=14, tokens left=120/200, action=sent
#   RouterC: load=27%, demand=27, tokens left=133/200, action=sent
#
# ⏱️ Time step 1670 sec:
#   RouterA: load=64%, demand=64, tokens left=23/200, action=sent
#   RouterB: load=45%, demand=45, tokens left=125/200, action=sent
#   RouterC: load=94%, demand=94, tokens left=89/200, action=sent
#
# ⏱️ Time step 1680 sec:
#   RouterA: load=37%, demand=37, tokens left=36/200, action=sent
#   RouterB: load=4%, demand=4, tokens left=171/200, action=sent
#   RouterC: load=86%, demand=86, tokens left=53/200, action=sent
#
# ⏱️ Time step 1690 sec:
#   RouterA: load=13%, demand=13, tokens left=73/200, action=sent
#   RouterB: load=15%, demand=15, tokens left=185/200, action=sent
#   RouterC: load=32%, demand=32, tokens left=71/200, action=sent
#
# ⏱️ Time step 1700 sec:
#   RouterA: load=1%, demand=1, tokens left=122/200, action=sent
#   RouterB: load=88%, demand=88, tokens left=112/200, action=sent
#   RouterC: load=88%, demand=88, tokens left=33/200, action=sent
#
# ⏱️ Time step 1710 sec:
#   RouterA: load=78%, demand=78, tokens left=94/200, action=sent
#   RouterB: load=31%, demand=31, tokens left=131/200, action=sent
#   RouterC: load=22%, demand=22, tokens left=61/200, action=sent
#
# ⏱️ Time step 1720 sec:
#   RouterA: load=87%, demand=87, tokens left=57/200, action=sent
#   RouterB: load=14%, demand=14, tokens left=167/200, action=sent
#   RouterC: load=70%, demand=70, tokens left=41/200, action=sent
#
# ⏱️ Time step 1730 sec:
#   RouterA: load=25%, demand=25, tokens left=82/200, action=sent
#   RouterB: load=50%, demand=50, tokens left=150/200, action=sent
#   RouterC: load=82%, demand=82, tokens left=9/200, action=sent
#
# ⏱️ Time step 1740 sec:
#   RouterA: load=73%, demand=73, tokens left=59/200, action=sent
#   RouterB: load=52%, demand=52, tokens left=148/200, action=sent
#   RouterC: load=46%, demand=46, tokens left=13/200, action=sent
#
# ⏱️ Time step 1750 sec:
#   RouterA: load=67%, demand=67, tokens left=42/200, action=sent
#   RouterB: load=77%, demand=77, tokens left=121/200, action=sent
#   RouterC: load=44%, demand=44, tokens left=19/200, action=sent
#
# ⏱️ Time step 1760 sec:
#   RouterA: load=83%, demand=83, tokens left=9/200, action=sent
#   RouterB: load=96%, demand=96, tokens left=75/200, action=sent
#   RouterC: load=30%, demand=30, tokens left=39/200, action=sent
#
# ⏱️ Time step 1770 sec:
#   RouterA: load=39%, demand=39, tokens left=20/200, action=sent
#   RouterB: load=61%, demand=61, tokens left=64/200, action=sent
#   RouterC: load=48%, demand=48, tokens left=41/200, action=sent
#
# ⏱️ Time step 1780 sec:
#   RouterA: load=40%, demand=40, tokens left=30/200, action=sent
#   RouterB: load=10%, demand=10, tokens left=104/200, action=sent
#   RouterC: load=95%, demand=95, tokens left=0/200, action=dropped 4
#
# ⏱️ Time step 1790 sec:
#   RouterA: load=94%, demand=94, tokens left=0/200, action=dropped 14
#   RouterB: load=83%, demand=83, tokens left=71/200, action=sent
#   RouterC: load=94%, demand=94, tokens left=0/200, action=dropped 44
#
# ⏱️ Time step 1800 sec:
#   RouterA: load=24%, demand=24, tokens left=26/200, action=sent
#   RouterB: load=58%, demand=57, tokens left=64/200, action=sent
#   RouterC: load=63%, demand=63, tokens left=0/200, action=dropped 13
#
# ⏱️ Time step 1810 sec:
#   RouterA: load=89%, demand=89, tokens left=0/200, action=dropped 13
#   RouterB: load=59%, demand=59, tokens left=55/200, action=sent
#   RouterC: load=10%, demand=10, tokens left=40/200, action=sent
#
# ⏱️ Time step 1820 sec:
#   RouterA: load=24%, demand=24, tokens left=26/200, action=sent
#   RouterB: load=69%, demand=69, tokens left=36/200, action=sent
#   RouterC: load=30%, demand=30, tokens left=60/200, action=sent
#
# ⏱️ Time step 1830 sec:
#   RouterA: load=70%, demand=70, tokens left=6/200, action=sent
#   RouterB: load=71%, demand=71, tokens left=15/200, action=sent
#   RouterC: load=29%, demand=28, tokens left=82/200, action=sent
#
# ⏱️ Time step 1840 sec:
#   RouterA: load=83%, demand=83, tokens left=0/200, action=dropped 27
#   RouterB: load=7%, demand=7, tokens left=58/200, action=sent
#   RouterC: load=42%, demand=42, tokens left=90/200, action=sent
#
# ⏱️ Time step 1850 sec:
#   RouterA: load=53%, demand=53, tokens left=0/200, action=dropped 3
#   RouterB: load=26%, demand=26, tokens left=82/200, action=sent
#   RouterC: load=21%, demand=21, tokens left=119/200, action=sent
#
# ⏱️ Time step 1860 sec:
#   RouterA: load=85%, demand=85, tokens left=0/200, action=dropped 35
#   RouterB: load=95%, demand=95, tokens left=37/200, action=sent
#   RouterC: load=70%, demand=70, tokens left=99/200, action=sent
#
# ⏱️ Time step 1870 sec:
#   RouterA: load=56%, demand=56, tokens left=0/200, action=dropped 6
#   RouterB: load=57%, demand=56, tokens left=31/200, action=sent
#   RouterC: load=91%, demand=91, tokens left=58/200, action=sent
#
# ⏱️ Time step 1880 sec:
#   RouterA: load=12%, demand=12, tokens left=38/200, action=sent
#   RouterB: load=1%, demand=1, tokens left=80/200, action=sent
#   RouterC: load=53%, demand=53, tokens left=55/200, action=sent
#
# ⏱️ Time step 1890 sec:
#   RouterA: load=46%, demand=46, tokens left=42/200, action=sent
#   RouterB: load=75%, demand=75, tokens left=55/200, action=sent
#   RouterC: load=14%, demand=14, tokens left=91/200, action=sent
#
# ⏱️ Time step 1900 sec:
#   RouterA: load=35%, demand=35, tokens left=57/200, action=sent
#   RouterB: load=93%, demand=93, tokens left=12/200, action=sent
#   RouterC: load=84%, demand=84, tokens left=57/200, action=sent
#
# ⏱️ Time step 1910 sec:
#   RouterA: load=59%, demand=59, tokens left=48/200, action=sent
#   RouterB: load=57%, demand=56, tokens left=6/200, action=sent
#   RouterC: load=91%, demand=91, tokens left=16/200, action=sent
#
# ⏱️ Time step 1920 sec:
#   RouterA: load=15%, demand=15, tokens left=83/200, action=sent
#   RouterB: load=42%, demand=42, tokens left=14/200, action=sent
#   RouterC: load=32%, demand=32, tokens left=34/200, action=sent
#
# ⏱️ Time step 1930 sec:
#   RouterA: load=78%, demand=78, tokens left=55/200, action=sent
#   RouterB: load=57%, demand=56, tokens left=8/200, action=sent
#   RouterC: load=13%, demand=13, tokens left=71/200, action=sent
#
# ⏱️ Time step 1940 sec:
#   RouterA: load=44%, demand=44, tokens left=61/200, action=sent
#   RouterB: load=63%, demand=63, tokens left=0/200, action=dropped 5
#   RouterC: load=77%, demand=77, tokens left=44/200, action=sent
#
# ⏱️ Time step 1950 sec:
#   RouterA: load=28%, demand=28, tokens left=83/200, action=sent
#   RouterB: load=92%, demand=92, tokens left=0/200, action=dropped 42
#   RouterC: load=75%, demand=75, tokens left=19/200, action=sent
#
# ⏱️ Time step 1960 sec:
#   RouterA: load=65%, demand=65, tokens left=68/200, action=sent
#   RouterB: load=78%, demand=78, tokens left=0/200, action=dropped 28
#   RouterC: load=40%, demand=40, tokens left=29/200, action=sent
#
# ⏱️ Time step 1970 sec:
#   RouterA: load=96%, demand=96, tokens left=22/200, action=sent
#   RouterB: load=70%, demand=70, tokens left=0/200, action=dropped 20
#   RouterC: load=79%, demand=79, tokens left=0/200, action=sent
#
# ⏱️ Time step 1980 sec:
#   RouterA: load=52%, demand=52, tokens left=20/200, action=sent
#   RouterB: load=31%, demand=31, tokens left=19/200, action=sent
#   RouterC: load=71%, demand=71, tokens left=0/200, action=dropped 21
#
# ⏱️ Time step 1990 sec:
#   RouterA: load=46%, demand=46, tokens left=24/200, action=sent
#   RouterB: load=4%, demand=4, tokens left=65/200, action=sent
#   RouterC: load=12%, demand=12, tokens left=38/200, action=sent
#
# ⏱️ Time step 2000 sec:
#   RouterA: load=40%, demand=40, tokens left=34/200, action=sent
#   RouterB: load=67%, demand=67, tokens left=48/200, action=sent
#   RouterC: load=16%, demand=16, tokens left=72/200, action=sent
#
# ⏱️ Time step 2010 sec:
#   RouterA: load=52%, demand=52, tokens left=32/200, action=sent
#   RouterB: load=32%, demand=32, tokens left=66/200, action=sent
#   RouterC: load=66%, demand=66, tokens left=56/200, action=sent
#
# ⏱️ Time step 2020 sec:
#   RouterA: load=72%, demand=72, tokens left=10/200, action=sent
#   RouterB: load=79%, demand=79, tokens left=37/200, action=sent
#   RouterC: load=51%, demand=51, tokens left=55/200, action=sent
#
# ⏱️ Time step 2030 sec:
#   RouterA: load=11%, demand=11, tokens left=49/200, action=sent
#   RouterB: load=77%, demand=77, tokens left=10/200, action=sent
#   RouterC: load=7%, demand=7, tokens left=98/200, action=sent
#
# ⏱️ Time step 2040 sec:
#   RouterA: load=36%, demand=36, tokens left=63/200, action=sent
#   RouterB: load=15%, demand=15, tokens left=45/200, action=sent
#   RouterC: load=50%, demand=50, tokens left=98/200, action=sent
#
# ⏱️ Time step 2050 sec:
#   RouterA: load=46%, demand=46, tokens left=67/200, action=sent
#   RouterB: load=77%, demand=77, tokens left=18/200, action=sent
#   RouterC: load=86%, demand=86, tokens left=62/200, action=sent
#
# ⏱️ Time step 2060 sec:
#   RouterA: load=6%, demand=6, tokens left=111/200, action=sent
#   RouterB: load=64%, demand=64, tokens left=4/200, action=sent
#   RouterC: load=32%, demand=32, tokens left=80/200, action=sent
#
# ⏱️ Time step 2070 sec:
#   RouterA: load=30%, demand=30, tokens left=131/200, action=sent
#   RouterB: load=98%, demand=98, tokens left=0/200, action=dropped 44
#   RouterC: load=100%, demand=100, tokens left=30/200, action=sent
#
# ⏱️ Time step 2080 sec:
#   RouterA: load=74%, demand=74, tokens left=107/200, action=sent
#   RouterB: load=28%, demand=28, tokens left=22/200, action=sent
#   RouterC: load=71%, demand=71, tokens left=9/200, action=sent
#
# ⏱️ Time step 2090 sec:
#   RouterA: load=64%, demand=64, tokens left=93/200, action=sent
#   RouterB: load=47%, demand=47, tokens left=25/200, action=sent
#   RouterC: load=82%, demand=82, tokens left=0/200, action=dropped 23
#
# ⏱️ Time step 2100 sec:
#   RouterA: load=56%, demand=56, tokens left=87/200, action=sent
#   RouterB: load=97%, demand=97, tokens left=0/200, action=dropped 22
#   RouterC: load=36%, demand=36, tokens left=14/200, action=sent
#
# ⏱️ Time step 2110 sec:
#   RouterA: load=52%, demand=52, tokens left=85/200, action=sent
#   RouterB: load=24%, demand=24, tokens left=26/200, action=sent
#   RouterC: load=11%, demand=11, tokens left=53/200, action=sent
#
# ⏱️ Time step 2120 sec:
#   RouterA: load=95%, demand=95, tokens left=40/200, action=sent
#   RouterB: load=14%, demand=14, tokens left=62/200, action=sent
#   RouterC: load=3%, demand=3, tokens left=100/200, action=sent
#
# ⏱️ Time step 2130 sec:
#   RouterA: load=56%, demand=56, tokens left=34/200, action=sent
#   RouterB: load=100%, demand=100, tokens left=12/200, action=sent
#   RouterC: load=70%, demand=70, tokens left=80/200, action=sent
#
# ⏱️ Time step 2140 sec:
#   RouterA: load=29%, demand=28, tokens left=56/200, action=sent
#   RouterB: load=90%, demand=90, tokens left=0/200, action=dropped 28
#   RouterC: load=4%, demand=4, tokens left=126/200, action=sent
#
# ⏱️ Time step 2150 sec:
#   RouterA: load=48%, demand=48, tokens left=58/200, action=sent
#   RouterB: load=10%, demand=10, tokens left=40/200, action=sent
#   RouterC: load=49%, demand=49, tokens left=127/200, action=sent
#
# ⏱️ Time step 2160 sec:
#   RouterA: load=6%, demand=6, tokens left=102/200, action=sent
#   RouterB: load=15%, demand=15, tokens left=75/200, action=sent
#   RouterC: load=14%, demand=14, tokens left=163/200, action=sent
#
# ⏱️ Time step 2170 sec:
#   RouterA: load=22%, demand=22, tokens left=130/200, action=sent
#   RouterB: load=78%, demand=78, tokens left=47/200, action=sent
#   RouterC: load=94%, demand=94, tokens left=106/200, action=sent
#
# ⏱️ Time step 2180 sec:
#   RouterA: load=19%, demand=19, tokens left=161/200, action=sent
#   RouterB: load=92%, demand=92, tokens left=5/200, action=sent
#   RouterC: load=96%, demand=96, tokens left=60/200, action=sent
#
# ⏱️ Time step 2190 sec:
#   RouterA: load=69%, demand=69, tokens left=131/200, action=sent
#   RouterB: load=31%, demand=31, tokens left=24/200, action=sent
#   RouterC: load=65%, demand=65, tokens left=45/200, action=sent
#
# ⏱️ Time step 2200 sec:
#   RouterA: load=34%, demand=34, tokens left=147/200, action=sent
# ...
#
# ⏱️ Time step 6270 sec:
#   RouterA: load=84%, demand=84, tokens left=111/200, action=sent
#   RouterB: load=28%, demand=28, tokens left=22/200, action=sent
#   RouterC: load=42%, demand=42, tokens left=77/200, action=sent
#
# ⏱️ Time step 6280 sec:
#   RouterA: load=68%, demand=68, tokens left=93/200, action=sent
#   RouterB: load=97%, demand=97, tokens left=0/200, action=dropped 25
#   RouterC: load=96%, demand=96, tokens left=31/200, action=sent
#
# ⏱️ Time step 6290 sec:
#   RouterA: load=57%, demand=56, tokens left=87/200, action=sent
#   RouterB: load=54%, demand=54, tokens left=0/200, action=dropped 4
#   RouterC: load=82%, demand=82, tokens left=0/200, action=dropped 1
#
# ⏱️ Time step 6300 sec:
#   RouterA: load=57%, demand=56, tokens left=81/200, action=sent
#   RouterB: load=58%, demand=57, tokens left=0/200, action=dropped 7
#   RouterC: load=57%, demand=56, tokens left=0/200, action=dropped 6
#
# ⏱️ Time step 6310 sec:
#   RouterA: load=0%, demand=0, tokens left=131/200, action=sent
#   RouterB: load=59%, demand=59, tokens left=0/200, action=dropped 9
#   RouterC: load=29%, demand=28, tokens left=22/200, action=sent
#
# ⏱️ Time step 6320 sec:
#   RouterA: load=33%, demand=33, tokens left=148/200, action=sent
#   RouterB: load=77%, demand=77, tokens left=0/200, action=dropped 27
#   RouterC: load=37%, demand=37, tokens left=35/200, action=sent
#
# ⏱️ Time step 6330 sec:
#   RouterA: load=53%, demand=53, tokens left=145/200, action=sent
#   RouterB: load=73%, demand=73, tokens left=0/200, action=dropped 23
#   RouterC: load=92%, demand=92, tokens left=0/200, action=dropped 7
#
# ⏱️ Time step 6340 sec:
#   RouterA: load=73%, demand=73, tokens left=122/200, action=sent
#   RouterB: load=69%, demand=69, tokens left=0/200, action=dropped 19
#   RouterC: load=53%, demand=53, tokens left=0/200, action=dropped 3
#
# ⏱️ Time step 6350 sec:
#   RouterA: load=84%, demand=84, tokens left=88/200, action=sent
#   RouterB: load=37%, demand=37, tokens left=13/200, action=sent
#   RouterC: load=62%, demand=62, tokens left=0/200, action=dropped 12
#
# ⏱️ Time step 6360 sec:
#   RouterA: load=79%, demand=79, tokens left=59/200, action=sent
#   RouterB: load=60%, demand=60, tokens left=3/200, action=sent
#   RouterC: load=41%, demand=41, tokens left=9/200, action=sent
#
# ⏱️ Time step 6370 sec:
#   RouterA: load=63%, demand=63, tokens left=46/200, action=sent
#   RouterB: load=42%, demand=42, tokens left=11/200, action=sent
#   RouterC: load=52%, demand=52, tokens left=7/200, action=sent
#
# ⏱️ Time step 6380 sec:
#   RouterA: load=30%, demand=30, tokens left=66/200, action=sent
#   RouterB: load=87%, demand=87, tokens left=0/200, action=dropped 26
#   RouterC: load=29%, demand=28, tokens left=29/200, action=sent
#
# ⏱️ Time step 6390 sec:
#   RouterA: load=41%, demand=41, tokens left=75/200, action=sent
#   RouterB: load=75%, demand=75, tokens left=0/200, action=dropped 25
#   RouterC: load=2%, demand=2, tokens left=77/200, action=sent
#
# ⏱️ Time step 6400 sec:
#   RouterA: load=86%, demand=86, tokens left=39/200, action=sent
#   RouterB: load=43%, demand=43, tokens left=7/200, action=sent
#   RouterC: load=28%, demand=28, tokens left=99/200, action=sent
#
# ⏱️ Time step 6410 sec:
#   RouterA: load=27%, demand=27, tokens left=62/200, action=sent
#   RouterB: load=87%, demand=87, tokens left=0/200, action=dropped 30
#   RouterC: load=84%, demand=84, tokens left=65/200, action=sent
#
# ⏱️ Time step 6420 sec:
#   RouterA: load=26%, demand=26, tokens left=86/200, action=sent
#   RouterB: load=40%, demand=40, tokens left=10/200, action=sent
#   RouterC: load=60%, demand=60, tokens left=55/200, action=sent
#
# ⏱️ Time step 6430 sec:
#   RouterA: load=87%, demand=87, tokens left=49/200, action=sent
#   RouterB: load=46%, demand=46, tokens left=14/200, action=sent
#   RouterC: load=98%, demand=98, tokens left=7/200, action=sent
#
# ⏱️ Time step 6440 sec:
#   RouterA: load=21%, demand=21, tokens left=78/200, action=sent
#   RouterB: load=62%, demand=62, tokens left=2/200, action=sent
#   RouterC: load=99%, demand=99, tokens left=0/200, action=dropped 42
#
# ⏱️ Time step 6450 sec:
#   RouterA: load=21%, demand=21, tokens left=107/200, action=sent
#   RouterB: load=88%, demand=88, tokens left=0/200, action=dropped 36
#   RouterC: load=58%, demand=57, tokens left=0/200, action=dropped 7
#
# ⏱️ Time step 6460 sec:
#   RouterA: load=5%, demand=5, tokens left=152/200, action=sent
#   RouterB: load=46%, demand=46, tokens left=4/200, action=sent
#   RouterC: load=94%, demand=94, tokens left=0/200, action=dropped 44
#
# ⏱️ Time step 6470 sec:
#   RouterA: load=7%, demand=7, tokens left=193/200, action=sent
#   RouterB: load=96%, demand=96, tokens left=0/200, action=dropped 42
#   RouterC: load=34%, demand=34, tokens left=16/200, action=sent
#
# ⏱️ Time step 6480 sec:
#   RouterA: load=20%, demand=20, tokens left=180/200, action=sent
#   RouterB: load=71%, demand=71, tokens left=0/200, action=dropped 21
#   RouterC: load=8%, demand=8, tokens left=58/200, action=sent
#
# ⏱️ Time step 6490 sec:
#   RouterA: load=50%, demand=50, tokens left=150/200, action=sent
#   RouterB: load=15%, demand=15, tokens left=35/200, action=sent
#   RouterC: load=76%, demand=76, tokens left=32/200, action=sent
#
# ⏱️ Time step 6500 sec:
#   RouterA: load=27%, demand=27, tokens left=173/200, action=sent
#   RouterB: load=54%, demand=54, tokens left=31/200, action=sent
#   RouterC: load=16%, demand=16, tokens left=66/200, action=sent
#
# ⏱️ Time step 6510 sec:
#   RouterA: load=9%, demand=9, tokens left=191/200, action=sent
#   RouterB: load=68%, demand=68, tokens left=13/200, action=sent
#   RouterC: load=68%, demand=68, tokens left=48/200, action=sent
#
# ⏱️ Time step 6520 sec:
#   RouterA: load=28%, demand=28, tokens left=172/200, action=sent
#   RouterB: load=78%, demand=78, tokens left=0/200, action=dropped 15
#   RouterC: load=83%, demand=83, tokens left=15/200, action=sent
#
# ⏱️ Time step 6530 sec:
#   RouterA: load=61%, demand=61, tokens left=139/200, action=sent
#   RouterB: load=53%, demand=53, tokens left=0/200, action=dropped 3
#   RouterC: load=33%, demand=33, tokens left=32/200, action=sent
#
# ⏱️ Time step 6540 sec:
#   RouterA: load=34%, demand=34, tokens left=155/200, action=sent
#   RouterB: load=66%, demand=66, tokens left=0/200, action=dropped 16
#   RouterC: load=90%, demand=90, tokens left=0/200, action=dropped 8
#
# ⏱️ Time step 6550 sec:
#   RouterA: load=88%, demand=88, tokens left=112/200, action=sent
#   RouterB: load=6%, demand=6, tokens left=44/200, action=sent
#   RouterC: load=45%, demand=45, tokens left=5/200, action=sent
#
# ⏱️ Time step 6560 sec:
#   RouterA: load=35%, demand=35, tokens left=127/200, action=sent
#   RouterB: load=61%, demand=61, tokens left=33/200, action=sent
#   RouterC: load=74%, demand=74, tokens left=0/200, action=dropped 19
#
# ⏱️ Time step 6570 sec:
#   RouterA: load=82%, demand=82, tokens left=95/200, action=sent
#   RouterB: load=25%, demand=25, tokens left=58/200, action=sent
#   RouterC: load=35%, demand=35, tokens left=15/200, action=sent
#
# ⏱️ Time step 6580 sec:
#   RouterA: load=13%, demand=13, tokens left=132/200, action=sent
#   RouterB: load=3%, demand=3, tokens left=105/200, action=sent
#   RouterC: load=30%, demand=30, tokens left=35/200, action=sent
#
# ⏱️ Time step 6590 sec:
#   RouterA: load=63%, demand=63, tokens left=119/200, action=sent
#   RouterB: load=2%, demand=2, tokens left=153/200, action=sent
#   RouterC: load=2%, demand=2, tokens left=83/200, action=sent
#
# ⏱️ Time step 6600 sec:
#   RouterA: load=91%, demand=91, tokens left=78/200, action=sent
#   RouterB: load=16%, demand=16, tokens left=184/200, action=sent
#   RouterC: load=17%, demand=17, tokens left=116/200, action=sent
#
# ⏱️ Time step 6610 sec:
#   RouterA: load=68%, demand=68, tokens left=60/200, action=sent
#   RouterB: load=22%, demand=22, tokens left=178/200, action=sent
#   RouterC: load=90%, demand=90, tokens left=76/200, action=sent
#
# ⏱️ Time step 6620 sec:
#   RouterA: load=38%, demand=38, tokens left=72/200, action=sent
#   RouterB: load=87%, demand=87, tokens left=113/200, action=sent
#   RouterC: load=20%, demand=20, tokens left=106/200, action=sent
#
# ⏱️ Time step 6630 sec:
#   RouterA: load=28%, demand=28, tokens left=94/200, action=sent
#   RouterB: load=26%, demand=26, tokens left=137/200, action=sent
#   RouterC: load=91%, demand=91, tokens left=65/200, action=sent
#
# ⏱️ Time step 6640 sec:
#   RouterA: load=4%, demand=4, tokens left=140/200, action=sent
#   RouterB: load=18%, demand=18, tokens left=169/200, action=sent
#   RouterC: load=55%, demand=55, tokens left=60/200, action=sent
#
# ⏱️ Time step 6650 sec:
#   RouterA: load=71%, demand=71, tokens left=119/200, action=sent
#   RouterB: load=23%, demand=23, tokens left=177/200, action=sent
#   RouterC: load=91%, demand=91, tokens left=19/200, action=sent
#
# ⏱️ Time step 6660 sec:
#   RouterA: load=42%, demand=42, tokens left=127/200, action=sent
#   RouterB: load=51%, demand=51, tokens left=149/200, action=sent
#   RouterC: load=96%, demand=96, tokens left=0/200, action=dropped 27
#
# ⏱️ Time step 6670 sec:
#   RouterA: load=62%, demand=62, tokens left=115/200, action=sent
#   RouterB: load=54%, demand=54, tokens left=145/200, action=sent
#   RouterC: load=65%, demand=65, tokens left=0/200, action=dropped 15
#
# ⏱️ Time step 6680 sec:
#   RouterA: load=76%, demand=76, tokens left=89/200, action=sent
#   RouterB: load=50%, demand=50, tokens left=145/200, action=sent
#   RouterC: load=9%, demand=9, tokens left=41/200, action=sent
#
# ⏱️ Time step 6690 sec:
#   RouterA: load=15%, demand=15, tokens left=124/200, action=sent
#   RouterB: load=2%, demand=2, tokens left=193/200, action=sent
#   RouterC: load=61%, demand=61, tokens left=30/200, action=sent
#
# ⏱️ Time step 6700 sec:
#   RouterA: load=67%, demand=67, tokens left=107/200, action=sent
#   RouterB: load=80%, demand=80, tokens left=120/200, action=sent
#   RouterC: load=91%, demand=91, tokens left=0/200, action=dropped 11
#
# ⏱️ Time step 6710 sec:
#   RouterA: load=23%, demand=23, tokens left=134/200, action=sent
#   RouterB: load=89%, demand=89, tokens left=81/200, action=sent
#   RouterC: load=85%, demand=85, tokens left=0/200, action=dropped 35
#
# ⏱️ Time step 6720 sec:
#   RouterA: load=72%, demand=72, tokens left=112/200, action=sent
#   RouterB: load=58%, demand=57, tokens left=74/200, action=sent
#   RouterC: load=53%, demand=53, tokens left=0/200, action=dropped 3
#
# ⏱️ Time step 6730 sec:
#   RouterA: load=79%, demand=79, tokens left=83/200, action=sent
#   RouterB: load=0%, demand=0, tokens left=124/200, action=sent
#   RouterC: load=4%, demand=4, tokens left=46/200, action=sent
#
# ⏱️ Time step 6740 sec:
#   RouterA: load=66%, demand=66, tokens left=67/200, action=sent
#   RouterB: load=7%, demand=7, tokens left=167/200, action=sent
#   RouterC: load=74%, demand=74, tokens left=22/200, action=sent
#
# ⏱️ Time step 6750 sec:
#   RouterA: load=25%, demand=25, tokens left=92/200, action=sent
#   RouterB: load=90%, demand=90, tokens left=110/200, action=sent
#   RouterC: load=62%, demand=62, tokens left=10/200, action=sent
#
# ⏱️ Time step 6760 sec:
#   RouterA: load=69%, demand=69, tokens left=73/200, action=sent
#   RouterB: load=13%, demand=13, tokens left=147/200, action=sent
#   RouterC: load=7%, demand=7, tokens left=53/200, action=sent
#
# ⏱️ Time step 6770 sec:
#   RouterA: load=49%, demand=49, tokens left=74/200, action=sent
#   RouterB: load=66%, demand=66, tokens left=131/200, action=sent
#   RouterC: load=18%, demand=18, tokens left=85/200, action=sent
#
# ⏱️ Time step 6780 sec:
#   RouterA: load=58%, demand=57, tokens left=67/200, action=sent
#   RouterB: load=36%, demand=36, tokens left=145/200, action=sent
#   RouterC: load=33%, demand=33, tokens left=102/200, action=sent
#
# ⏱️ Time step 6790 sec:
#   RouterA: load=43%, demand=43, tokens left=74/200, action=sent
#   RouterB: load=24%, demand=24, tokens left=171/200, action=sent
#   RouterC: load=65%, demand=65, tokens left=87/200, action=sent
#
# ⏱️ Time step 6800 sec:
#   RouterA: load=26%, demand=26, tokens left=98/200, action=sent
#   RouterB: load=51%, demand=51, tokens left=149/200, action=sent
#   RouterC: load=27%, demand=27, tokens left=110/200, action=sent
#
# ⏱️ Time step 6810 sec:
#   RouterA: load=12%, demand=12, tokens left=136/200, action=sent
#   RouterB: load=55%, demand=55, tokens left=144/200, action=sent
#   RouterC: load=100%, demand=100, tokens left=60/200, action=sent
#
# ⏱️ Time step 6820 sec:
#   RouterA: load=82%, demand=82, tokens left=104/200, action=sent
#   RouterB: load=69%, demand=69, tokens left=125/200, action=sent
#   RouterC: load=3%, demand=3, tokens left=107/200, action=sent
#
# ⏱️ Time step 6830 sec:
#   RouterA: load=56%, demand=56, tokens left=98/200, action=sent
#   RouterB: load=42%, demand=42, tokens left=133/200, action=sent
#   RouterC: load=28%, demand=28, tokens left=129/200, action=sent
#
# ⏱️ Time step 6840 sec:
#   RouterA: load=78%, demand=78, tokens left=70/200, action=sent
#   RouterB: load=66%, demand=66, tokens left=117/200, action=sent
#   RouterC: load=43%, demand=43, tokens left=136/200, action=sent
#
# ⏱️ Time step 6850 sec:
#   RouterA: load=89%, demand=89, tokens left=31/200, action=sent
#   RouterB: load=72%, demand=72, tokens left=95/200, action=sent
#   RouterC: load=59%, demand=59, tokens left=127/200, action=sent
#
# ⏱️ Time step 6860 sec:
#   RouterA: load=78%, demand=78, tokens left=3/200, action=sent
#   RouterB: load=13%, demand=13, tokens left=132/200, action=sent
#   RouterC: load=16%, demand=16, tokens left=161/200, action=sent
#
# ⏱️ Time step 6870 sec:
#   RouterA: load=21%, demand=21, tokens left=32/200, action=sent
#   RouterB: load=43%, demand=43, tokens left=139/200, action=sent
#   RouterC: load=95%, demand=95, tokens left=105/200, action=sent
#
# ⏱️ Time step 6880 sec:
#   RouterA: load=42%, demand=42, tokens left=40/200, action=sent
#   RouterB: load=6%, demand=6, tokens left=183/200, action=sent
#   RouterC: load=13%, demand=13, tokens left=142/200, action=sent
#
# ⏱️ Time step 6890 sec:
#   RouterA: load=41%, demand=41, tokens left=49/200, action=sent
#   RouterB: load=68%, demand=68, tokens left=132/200, action=sent
#   RouterC: load=57%, demand=56, tokens left=136/200, action=sent
#
# ⏱️ Time step 6900 sec:
#   RouterA: load=19%, demand=19, tokens left=80/200, action=sent
#   RouterB: load=17%, demand=17, tokens left=165/200, action=sent
#   RouterC: load=59%, demand=59, tokens left=127/200, action=sent
#
# ⏱️ Time step 6910 sec:
#   RouterA: load=95%, demand=95, tokens left=35/200, action=sent
#   RouterB: load=49%, demand=49, tokens left=151/200, action=sent
#   RouterC: load=57%, demand=56, tokens left=121/200, action=sent
#
# ⏱️ Time step 6920 sec:
#   RouterA: load=49%, demand=49, tokens left=36/200, action=sent
#   RouterB: load=34%, demand=34, tokens left=166/200, action=sent
#   RouterC: load=86%, demand=86, tokens left=85/200, action=sent
#
# ⏱️ Time step 6930 sec:
#   RouterA: load=84%, demand=84, tokens left=2/200, action=sent
#   RouterB: load=92%, demand=92, tokens left=108/200, action=sent
#   RouterC: load=71%, demand=71, tokens left=64/200, action=sent
#
# ⏱️ Time step 6940 sec:
#   RouterA: load=99%, demand=99, tokens left=0/200, action=dropped 47
#   RouterB: load=19%, demand=19, tokens left=139/200, action=sent
#   RouterC: load=24%, demand=24, tokens left=90/200, action=sent
#
# ⏱️ Time step 6950 sec:
#   RouterA: load=70%, demand=70, tokens left=0/200, action=dropped 20
#   RouterB: load=13%, demand=13, tokens left=176/200, action=sent
#   RouterC: load=52%, demand=52, tokens left=88/200, action=sent
#
# ⏱️ Time step 6960 sec:
#   RouterA: load=37%, demand=37, tokens left=13/200, action=sent
#   RouterB: load=6%, demand=6, tokens left=194/200, action=sent
#   RouterC: load=17%, demand=17, tokens left=121/200, action=sent
#
# ⏱️ Time step 6970 sec:
#   RouterA: load=38%, demand=38, tokens left=25/200, action=sent
#   RouterB: load=22%, demand=22, tokens left=178/200, action=sent
#   RouterC: load=38%, demand=38, tokens left=133/200, action=sent
#
# ⏱️ Time step 6980 sec:
#   RouterA: load=88%, demand=88, tokens left=0/200, action=dropped 13
#   RouterB: load=93%, demand=93, tokens left=107/200, action=sent
#   RouterC: load=29%, demand=28, tokens left=155/200, action=sent
#
# ⏱️ Time step 6990 sec:
#   RouterA: load=64%, demand=64, tokens left=0/200, action=dropped 14
#   RouterB: load=32%, demand=32, tokens left=125/200, action=sent
#   RouterC: load=8%, demand=8, tokens left=192/200, action=sent

# %%
#CHOOSING MULTIPLE BEST
import pandas as pd

METHODS = {
    1: 'Dynamic Rerouting (Hybrid Ant Colony Optimization)',
    2: 'Bandwidth Adjustment and QoS',
    3: 'Traffic Shaping and Policing',
    4: 'Active Queue Management (AQM)',
    5: 'Congestion Control Protocols (End-to-End)',
    6: 'Buffer Management',
    7: 'Leaky Bucket',
    8: 'Token Bucket'
}

def pick_methods(a, b, c):
    """Return list of method IDs to apply based on congestion states."""
    methods = []

    # High congestion > 70%
    if a > 70 or b > 70 or c > 70:
        methods.append(1)   # Dynamic rerouting
        methods.append(8)   # Token bucket shaping
        methods.append(4)   # AQM
        methods.append(5)   # End-to-end congestion control
        methods.append(6)   # Buffer management

    # Moderate congestion 40–70%
    if 40 <= a <= 70 or 40 <= b <= 70 or 40 <= c <= 70:
        methods.append(2)   # Bandwidth Adjustment
        methods.append(3)   # Traffic shaping & policing
        methods.append(7)   # Leaky bucket

    # Low congestion < 40%
    if a < 40 and b < 40 and c < 40:
        methods.append(5)   # Normal TCP congestion control only

    return sorted(set(methods))  # remove duplicates


def assign_methods(congestion_csv, timestep=10):
    df = pd.read_csv(congestion_csv)

    if "Time" not in df.columns:
        df.insert(0, "Time", [i*timestep for i in range(len(df))])

    results = []
    for _, row in df.iterrows():
        t = row["Time"]
        A, B, C = row["RouterA"], row["RouterB"], row["RouterC"]

        method_ids = pick_methods(A, B, C)
        method_names = [METHODS[mid] for mid in method_ids]

        results.append({
            "Time": t,
            "RouterA": A,
            "RouterB": B,
            "RouterC": C,
            "ChosenMethodsIDs": method_ids,
            "ChosenMethods": method_names
        })

    return pd.DataFrame(results)


# Example usage:
# Example usage:
df_out = assign_methods("C:/Users/ASUS/Downloads/router_congestion_int.csv")
print(df_out.to_string(index=False))  # <-- prints ALL rows with all timestamps
# Out:
#  Time  RouterA  RouterB  RouterC         ChosenMethodsIDs                                                                                                                                                                                                                             ChosenMethods
#     0        1       29       30                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#    10        3       27       68                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#    20       35       38       90          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#    30       97       66        3 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#    40       45       94        9 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#    50        2       16       31                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#    60       36        9       62                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#    70       23       34       29                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#    80       22       95       83          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#    90       56       92       13 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   100       99        1       30          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   110       71       28       73          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   120       30       26       32                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#   130       96       65       65 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   140       21       38       35                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#   150       56       51       30                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   160       93       12       11          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   170       10       85       53 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   180       98       43       46 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   190       84        8       97          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   200        2       39        0                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#   210       48       11       31                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   220       67       71       30 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   230       19       58       97 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   240       85       77       52 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   250       97       90       88          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   260       71       91       10          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   270       61       79       92 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   280       75       15       41 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   290       45       28       98 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   300       45       68       66                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   310       67       96       79 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   320       62       35       14                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   330       34       10       70                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   340       36       58       77 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   350       45       53       78 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   360       46       46       20                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   370       26       40       73 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   380       87       60       95 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   390       94       72        7          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   400        1        5       33                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#   410       46       66       40                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   420       77       98       11          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   430        4       99      100          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   440       31       76       77          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   450       18       98       73          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   460        9       55       38                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   470       10       17       60                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   480        0       16       89          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   490       73       54       18 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   500       28       13       66                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   510       48       19       43                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   520       36       66       93 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   530        3       59       62                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   540       39       17       18                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#   550       67        4       69                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   560        0       98       94          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   570       26       12        6                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#   580       66       94       38 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   590       62       15       19                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   600       82       72       43 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   610       43       88       59 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   620        7       96       38          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   630        3       43       38                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   640       74       98       26          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   650       83        6       70 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   660       13       59       77 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   670        6       18        4                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#   680       44       93       63 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   690        3       76       64 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   700       49        7       78 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   710       48      100       25 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   720       38       38       65                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   730       46       70       85 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   740        3       43       88 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   750        2       46       99 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   760       52        2       12                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   770       32       14       14                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#   780       74       27       82          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   790       25       97       83          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   800       91       73       88          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   810       14       24       46                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   820       72       92        7          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   830       21       15        4                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#   840       52        6       98 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   850       95       34       79          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   860       65       48       30                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   870        7       50       50                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   880       75       11       76          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   890       76       38       75          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   900       42       22       96 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   910       48       34       66                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   920       22       78       77          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   930       14       97       98          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   940        3       47       31                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#   950       84        1       34          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   960       95       27       28          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#   970        0       44       81 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   980       44       87       14 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#   990       60        1       89 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1000       43       43       80 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1010       13       18       88          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1020       18       44       82 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1030       25       92       84          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1040       50       74       71 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1050       41       32       13                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1060       70       16       47                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1070       10       21       31                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#  1080       14       45       72 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1090       50       96       40 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1100       23       77       54 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1110       14       40       25                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1120       76       46        0 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1130       28       40       60                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1140       12       44       71 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1150       68       61       91 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1160       98       65       94 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1170       63       92       70 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1180       35       65       37                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1190       73       25       43 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1200       76        9       57 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1210       74        7       60 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1220       40       54       22                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1230       59       98       70 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1240       18       69       25                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1250       36        5       50                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1260       68       48       44                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1270       70       64        6                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1280       38       91       94          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1290       99       48       48 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1300        0       40       40                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1310       28       18       74          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1320       89       96       24          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1330       89       29       28          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1340       40        0        5                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1350       74        7       64 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1360       68       63       45                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1370       95       26       21          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1380       81       91       39          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1390       99       20       92          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1400       42       72        8 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1410       16       20       93          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1420       78       82       91          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1430       89       30       29          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1440       73       84       88          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1450       20       33       71          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1460       82       43       77 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1470        9        7       29                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#  1480       74       44       14 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1490       79       39       43 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1500       60       75       18 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1510       92       30       62 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1520       57       49       87 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1530       61        3        7                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  1540        1       77       25          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1550       99       90       99          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1560       57       98       80 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1570       93       17       16          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1580       85       41        6 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1590       83       96       68 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1600       41       48       87 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  1610       81       96       19          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  1620       52       47       58                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
# ...
#  6460        5       46       94 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6470        7       96       34          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6480       20       71        8          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6490       50       15       76 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6500       27       54       16                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6510        9       68       68                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6520       28       78       83          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6530       61       53       33                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6540       34       66       90 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6550       88        6       45 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6560       35       61       74 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6570       82       25       35          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6580       13        3       30                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#  6590       63        2        2                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6600       91       16       17          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6610       68       22       90 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6620       38       87       20          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6630       28       26       91          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6640        4       18       55                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6650       71       23       91          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6660       42       51       96 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6670       62       54       65                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6680       76       50        9 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6690       15        2       61                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6700       67       80       91 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6710       23       89       85          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6720       72       58       53 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6730       79        0        4          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6740       66        7       74 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6750       25       90       62 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6760       69       13        7                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6770       49       66       18                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6780       58       36       33                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6790       43       24       65                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6800       26       51       27                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6810       12       55      100 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6820       82       69        3 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6830       56       42       28                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6840       78       66       43 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6850       89       72       59 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6860       78       13       16          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6870       21       43       95 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6880       42        6       13                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6890       41       68       57                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6900       19       17       59                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6910       95       49       57 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6920       49       34       86 [1, 2, 3, 4, 5, 6, 7, 8] [Dynamic Rerouting (Hybrid Ant Colony Optimization), Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Leaky Bucket, Token Bucket]
#  6930       84       92       71          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6940       99       19       24          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6950       70       13       52                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]
#  6960       37        6       17                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#  6970       38       22       38                      [5]                                                                                                                                                                                               [Congestion Control Protocols (End-to-End)]
#  6980       88       93       29          [1, 4, 5, 6, 8]                                                                           [Dynamic Rerouting (Hybrid Ant Colony Optimization), Active Queue Management (AQM), Congestion Control Protocols (End-to-End), Buffer Management, Token Bucket]
#  6990       64       32        8                [2, 3, 7]                                                                                                                                                                [Bandwidth Adjustment and QoS, Traffic Shaping and Policing, Leaky Bucket]

# %%
# CHOOSING BEST SINGLE
import pandas as pd

METHODS = {
    1: 'Dynamic Rerouting (Hybrid Ant Colony Optimization)',
    2: 'Bandwidth Adjustment and QoS',
    3: 'Traffic Shaping and Policing',
    4: 'Active Queue Management (AQM)',
    5: 'Congestion Control Protocols (End-to-End)',
    6: 'Buffer Management',
    7: 'Leaky Bucket',
    8: 'Token Bucket'
}

def pick_best_method(a, b, c):
    """
    Return a single best method ID based on refined congestion rules.
    Uses maximum router load as the decision driver.
    """
    max_load = max(a, b, c)

    if max_load > 85:
        return 1   # Dynamic Rerouting
    elif max_load > 70:
        return 4   # AQM
    elif max_load > 60:
        return 3   # Traffic Shaping / Policing
    elif max_load > 50:
        return 2   # Bandwidth Adjustment
    elif max_load > 40:
        return 8   # Token Bucket
    elif max_load > 30:
        return 7   # Leaky Bucket
    elif max_load > 20:
        return 6   # Buffer Management
    else:
        return 5   # End-to-End Congestion Control

def assign_best_methods(congestion_csv, timestep=10):
    """
    Assigns a single 'best' congestion control method per time step
    based on router congestion percentages.
    """
    df = pd.read_csv(congestion_csv)

    # Add synthetic time column if missing
    if "Time" not in df.columns:
        df.insert(0, "Time", [i*timestep for i in range(len(df))])

    expected_cols = {"RouterA", "RouterB", "RouterC"}
    if not expected_cols.issubset(set(df.columns)):
        raise ValueError(f"Congestion CSV must contain {expected_cols}, found {df.columns}")

    results = []
    for _, row in df.iterrows():
        t = row["Time"]
        A, B, C = row["RouterA"], row["RouterB"], row["RouterC"]

        best_id = pick_best_method(A, B, C)
        best_name = METHODS[best_id]

        results.append({
            "Time": t,
            "RouterA": A,
            "RouterB": B,
            "RouterC": C,
            "ChosenMethodID": best_id,
            "ChosenMethod": best_name
        })

    return pd.DataFrame(results)


# === Example usage ===
congestion_file = "C:/Users/ASUS/Downloads/router_congestion_int.csv"

df_out = assign_best_methods(congestion_file)

# Print all timestamps in a clean format
print(df_out.to_string(index=False))

# Optionally save to CSV for easy viewing
df_out.to_csv("C:/Users/ASUS/Downloads/best_methods_output.csv", index=False)
# Out:
#  Time  RouterA  RouterB  RouterC  ChosenMethodID                                       ChosenMethod
#     0        1       29       30               6                                  Buffer Management
#    10        3       27       68               3                       Traffic Shaping and Policing
#    20       35       38       90               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#    30       97       66        3               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#    40       45       94        9               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#    50        2       16       31               7                                       Leaky Bucket
#    60       36        9       62               3                       Traffic Shaping and Policing
#    70       23       34       29               7                                       Leaky Bucket
#    80       22       95       83               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#    90       56       92       13               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   100       99        1       30               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   110       71       28       73               4                      Active Queue Management (AQM)
#   120       30       26       32               7                                       Leaky Bucket
#   130       96       65       65               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   140       21       38       35               7                                       Leaky Bucket
#   150       56       51       30               2                       Bandwidth Adjustment and QoS
#   160       93       12       11               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   170       10       85       53               4                      Active Queue Management (AQM)
#   180       98       43       46               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   190       84        8       97               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   200        2       39        0               7                                       Leaky Bucket
#   210       48       11       31               8                                       Token Bucket
#   220       67       71       30               4                      Active Queue Management (AQM)
#   230       19       58       97               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   240       85       77       52               4                      Active Queue Management (AQM)
#   250       97       90       88               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   260       71       91       10               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   270       61       79       92               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   280       75       15       41               4                      Active Queue Management (AQM)
#   290       45       28       98               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   300       45       68       66               3                       Traffic Shaping and Policing
#   310       67       96       79               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   320       62       35       14               3                       Traffic Shaping and Policing
#   330       34       10       70               3                       Traffic Shaping and Policing
#   340       36       58       77               4                      Active Queue Management (AQM)
#   350       45       53       78               4                      Active Queue Management (AQM)
#   360       46       46       20               8                                       Token Bucket
#   370       26       40       73               4                      Active Queue Management (AQM)
#   380       87       60       95               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   390       94       72        7               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   400        1        5       33               7                                       Leaky Bucket
#   410       46       66       40               3                       Traffic Shaping and Policing
#   420       77       98       11               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   430        4       99      100               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   440       31       76       77               4                      Active Queue Management (AQM)
#   450       18       98       73               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   460        9       55       38               2                       Bandwidth Adjustment and QoS
#   470       10       17       60               2                       Bandwidth Adjustment and QoS
#   480        0       16       89               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   490       73       54       18               4                      Active Queue Management (AQM)
#   500       28       13       66               3                       Traffic Shaping and Policing
#   510       48       19       43               8                                       Token Bucket
#   520       36       66       93               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   530        3       59       62               3                       Traffic Shaping and Policing
#   540       39       17       18               7                                       Leaky Bucket
#   550       67        4       69               3                       Traffic Shaping and Policing
#   560        0       98       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   570       26       12        6               6                                  Buffer Management
#   580       66       94       38               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   590       62       15       19               3                       Traffic Shaping and Policing
#   600       82       72       43               4                      Active Queue Management (AQM)
#   610       43       88       59               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   620        7       96       38               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   630        3       43       38               8                                       Token Bucket
#   640       74       98       26               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   650       83        6       70               4                      Active Queue Management (AQM)
#   660       13       59       77               4                      Active Queue Management (AQM)
#   670        6       18        4               5          Congestion Control Protocols (End-to-End)
#   680       44       93       63               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   690        3       76       64               4                      Active Queue Management (AQM)
#   700       49        7       78               4                      Active Queue Management (AQM)
#   710       48      100       25               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   720       38       38       65               3                       Traffic Shaping and Policing
#   730       46       70       85               4                      Active Queue Management (AQM)
#   740        3       43       88               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   750        2       46       99               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   760       52        2       12               2                       Bandwidth Adjustment and QoS
#   770       32       14       14               7                                       Leaky Bucket
#   780       74       27       82               4                      Active Queue Management (AQM)
#   790       25       97       83               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   800       91       73       88               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   810       14       24       46               8                                       Token Bucket
#   820       72       92        7               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   830       21       15        4               6                                  Buffer Management
#   840       52        6       98               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   850       95       34       79               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   860       65       48       30               3                       Traffic Shaping and Policing
#   870        7       50       50               8                                       Token Bucket
#   880       75       11       76               4                      Active Queue Management (AQM)
#   890       76       38       75               4                      Active Queue Management (AQM)
#   900       42       22       96               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   910       48       34       66               3                       Traffic Shaping and Policing
#   920       22       78       77               4                      Active Queue Management (AQM)
#   930       14       97       98               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   940        3       47       31               8                                       Token Bucket
#   950       84        1       34               4                      Active Queue Management (AQM)
#   960       95       27       28               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   970        0       44       81               4                      Active Queue Management (AQM)
#   980       44       87       14               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#   990       60        1       89               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1000       43       43       80               4                      Active Queue Management (AQM)
#  1010       13       18       88               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1020       18       44       82               4                      Active Queue Management (AQM)
#  1030       25       92       84               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1040       50       74       71               4                      Active Queue Management (AQM)
#  1050       41       32       13               8                                       Token Bucket
#  1060       70       16       47               3                       Traffic Shaping and Policing
#  1070       10       21       31               7                                       Leaky Bucket
#  1080       14       45       72               4                      Active Queue Management (AQM)
#  1090       50       96       40               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1100       23       77       54               4                      Active Queue Management (AQM)
#  1110       14       40       25               7                                       Leaky Bucket
#  1120       76       46        0               4                      Active Queue Management (AQM)
#  1130       28       40       60               2                       Bandwidth Adjustment and QoS
#  1140       12       44       71               4                      Active Queue Management (AQM)
#  1150       68       61       91               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1160       98       65       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1170       63       92       70               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1180       35       65       37               3                       Traffic Shaping and Policing
#  1190       73       25       43               4                      Active Queue Management (AQM)
#  1200       76        9       57               4                      Active Queue Management (AQM)
#  1210       74        7       60               4                      Active Queue Management (AQM)
#  1220       40       54       22               2                       Bandwidth Adjustment and QoS
#  1230       59       98       70               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1240       18       69       25               3                       Traffic Shaping and Policing
#  1250       36        5       50               8                                       Token Bucket
#  1260       68       48       44               3                       Traffic Shaping and Policing
#  1270       70       64        6               3                       Traffic Shaping and Policing
#  1280       38       91       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1290       99       48       48               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1300        0       40       40               7                                       Leaky Bucket
#  1310       28       18       74               4                      Active Queue Management (AQM)
#  1320       89       96       24               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1330       89       29       28               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1340       40        0        5               7                                       Leaky Bucket
#  1350       74        7       64               4                      Active Queue Management (AQM)
#  1360       68       63       45               3                       Traffic Shaping and Policing
#  1370       95       26       21               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1380       81       91       39               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1390       99       20       92               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1400       42       72        8               4                      Active Queue Management (AQM)
#  1410       16       20       93               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1420       78       82       91               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1430       89       30       29               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1440       73       84       88               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1450       20       33       71               4                      Active Queue Management (AQM)
#  1460       82       43       77               4                      Active Queue Management (AQM)
#  1470        9        7       29               6                                  Buffer Management
#  1480       74       44       14               4                      Active Queue Management (AQM)
#  1490       79       39       43               4                      Active Queue Management (AQM)
#  1500       60       75       18               4                      Active Queue Management (AQM)
#  1510       92       30       62               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1520       57       49       87               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1530       61        3        7               3                       Traffic Shaping and Policing
#  1540        1       77       25               4                      Active Queue Management (AQM)
#  1550       99       90       99               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1560       57       98       80               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1570       93       17       16               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1580       85       41        6               4                      Active Queue Management (AQM)
#  1590       83       96       68               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1600       41       48       87               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1610       81       96       19               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1620       52       47       58               2                       Bandwidth Adjustment and QoS
#  1630       47        7       39               8                                       Token Bucket
#  1640       31       38        2               7                                       Leaky Bucket
#  1650       51       24       85               4                      Active Queue Management (AQM)
#  1660       34       14       27               7                                       Leaky Bucket
#  1670       64       45       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1680       37        4       86               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1690       13       15       32               7                                       Leaky Bucket
#  1700        1       88       88               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1710       78       31       22               4                      Active Queue Management (AQM)
#  1720       87       14       70               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1730       25       50       82               4                      Active Queue Management (AQM)
#  1740       73       52       46               4                      Active Queue Management (AQM)
#  1750       67       77       44               4                      Active Queue Management (AQM)
#  1760       83       96       30               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1770       39       61       48               3                       Traffic Shaping and Policing
#  1780       40       10       95               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1790       94       83       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1800       24       58       63               3                       Traffic Shaping and Policing
#  1810       89       59       10               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1820       24       69       30               3                       Traffic Shaping and Policing
#  1830       70       71       29               4                      Active Queue Management (AQM)
#  1840       83        7       42               4                      Active Queue Management (AQM)
#  1850       53       26       21               2                       Bandwidth Adjustment and QoS
#  1860       85       95       70               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1870       56       57       91               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1880       12        1       53               2                       Bandwidth Adjustment and QoS
#  1890       46       75       14               4                      Active Queue Management (AQM)
#  1900       35       93       84               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1910       59       57       91               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1920       15       42       32               8                                       Token Bucket
#  1930       78       57       13               4                      Active Queue Management (AQM)
#  1940       44       63       77               4                      Active Queue Management (AQM)
#  1950       28       92       75               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1960       65       78       40               4                      Active Queue Management (AQM)
#  1970       96       70       79               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  1980       52       31       71               4                      Active Queue Management (AQM)
#  1990       46        4       12               8                                       Token Bucket
#  2000       40       67       16               3                       Traffic Shaping and Policing
#  2010       52       32       66               3                       Traffic Shaping and Policing
#  2020       72       79       51               4                      Active Queue Management (AQM)
#  2030       11       77        7               4                      Active Queue Management (AQM)
#  2040       36       15       50               8                                       Token Bucket
#  2050       46       77       86               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2060        6       64       32               3                       Traffic Shaping and Policing
#  2070       30       98      100               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2080       74       28       71               4                      Active Queue Management (AQM)
#  2090       64       47       82               4                      Active Queue Management (AQM)
#  2100       56       97       36               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2110       52       24       11               2                       Bandwidth Adjustment and QoS
#  2120       95       14        3               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2130       56      100       70               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2140       29       90        4               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2150       48       10       49               8                                       Token Bucket
#  2160        6       15       14               5          Congestion Control Protocols (End-to-End)
#  2170       22       78       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2180       19       92       96               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2190       69       31       65               3                       Traffic Shaping and Policing
#  2200       34       35       44               8                                       Token Bucket
#  2210        5       89       51               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2220       59       74       97               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2230       73       56       61               4                      Active Queue Management (AQM)
#  2240       52       52       73               4                      Active Queue Management (AQM)
#  2250       44       89       40               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2260       64       71       74               4                      Active Queue Management (AQM)
#  2270       47       90       46               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2280       70       53       12               3                       Traffic Shaping and Policing
#  2290       35       81       25               4                      Active Queue Management (AQM)
#  2300       72       28       98               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2310       44       22        0               8                                       Token Bucket
#  2320       36       62       70               3                       Traffic Shaping and Policing
#  2330       83       82       51               4                      Active Queue Management (AQM)
#  2340       70        6        6               3                       Traffic Shaping and Policing
#  2350       25       97       50               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2360       28       44       27               8                                       Token Bucket
#  2370       92       71       80               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2380       11       69       45               3                       Traffic Shaping and Policing
#  2390       67       22       10               3                       Traffic Shaping and Policing
#  2400       88       45       14               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2410       40       20        3               7                                       Leaky Bucket
#  2420       96       36       58               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2430       61       41       61               3                       Traffic Shaping and Policing
#  2440       28       31       78               4                      Active Queue Management (AQM)
#  2450       93       84       85               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2460       77       88       46               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2470       35       80       19               4                      Active Queue Management (AQM)
#  2480        1       66       45               3                       Traffic Shaping and Policing
#  2490       50       85       97               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2500       29       61       55               3                       Traffic Shaping and Policing
#  2510       31       41       21               8                                       Token Bucket
#  2520       54       97       39               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2530       49       27       15               8                                       Token Bucket
#  2540       60       94       23               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2550       18       10       55               2                       Bandwidth Adjustment and QoS
#  2560        7       12        1               5          Congestion Control Protocols (End-to-End)
#  2570       17       23       41               8                                       Token Bucket
#  2580       29       57       44               2                       Bandwidth Adjustment and QoS
#  2590       35       86       78               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2600      100       15       10               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2610       19       10       36               7                                       Leaky Bucket
#  2620       29       99       51               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2630        2       67       64               3                       Traffic Shaping and Policing
#  2640        1       20       32               7                                       Leaky Bucket
#  2650       53       47        7               2                       Bandwidth Adjustment and QoS
#  2660       27       45       61               3                       Traffic Shaping and Policing
#  2670       55       28       17               2                       Bandwidth Adjustment and QoS
#  2680       34       53       13               2                       Bandwidth Adjustment and QoS
#  2690       14       33       67               3                       Traffic Shaping and Policing
#  2700       63       49       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2710       53       66       70               3                       Traffic Shaping and Policing
#  2720       55       95       21               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2730       64       69       99               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2740       17       89       10               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2750       88       73       55               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2760       38       14        8               7                                       Leaky Bucket
#  2770        2       96       50               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2780       88       15       52               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2790       48       70       11               3                       Traffic Shaping and Policing
#  2800        5       75       13               4                      Active Queue Management (AQM)
#  2810       45       98       11               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2820       31       73        6               4                      Active Queue Management (AQM)
#  2830       37       56       11               2                       Bandwidth Adjustment and QoS
#  2840       71       31       75               4                      Active Queue Management (AQM)
#  2850       30       31       32               7                                       Leaky Bucket
#  2860       19       16       25               6                                  Buffer Management
#  2870       62       71       87               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2880       93       28       83               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2890       99       64       39               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2900       12       32       89               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2910        3        9       76               4                      Active Queue Management (AQM)
#  2920       76        4       63               4                      Active Queue Management (AQM)
#  2930       90       14       63               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2940       26       85       66               4                      Active Queue Management (AQM)
#  2950       52       46       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2960       84       44       42               4                      Active Queue Management (AQM)
#  2970       96       80        0               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2980       72       88       63               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  2990       93       68       95               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3000       25        0       48               8                                       Token Bucket
#  3010       79       98       52               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3020       32       61        3               3                       Traffic Shaping and Policing
#  3030       50       53       36               2                       Bandwidth Adjustment and QoS
#  3040       41       58       65               3                       Traffic Shaping and Policing
#  3050       41       94        8               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3060        9       36       64               3                       Traffic Shaping and Policing
#  3070       90       67       72               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3080       56       49       85               4                      Active Queue Management (AQM)
#  3090       85       37        3               4                      Active Queue Management (AQM)
#  3100       20       36       84               4                      Active Queue Management (AQM)
#  3110       90       87       87               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3120       88       47       37               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3130       36        0       61               3                       Traffic Shaping and Policing
#  3140       64       62       17               3                       Traffic Shaping and Policing
#  3150       52       31       72               4                      Active Queue Management (AQM)
#  3160       11        6       31               7                                       Leaky Bucket
#  3170       40       20       53               2                       Bandwidth Adjustment and QoS
#  3180       25       18       68               3                       Traffic Shaping and Policing
#  3190       26       28       37               7                                       Leaky Bucket
#  3200       47       33       41               8                                       Token Bucket
#  3210        1       90       23               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3220       19       50       65               3                       Traffic Shaping and Policing
#  3230       90       96       54               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3240        5       74        0               4                      Active Queue Management (AQM)
#  3250       68       53       55               3                       Traffic Shaping and Policing
#  3260       93       26       57               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3270        2       13       35               7                                       Leaky Bucket
#  3280        6       72       87               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3290        3       64       24               3                       Traffic Shaping and Policing
#  3300       44       82       38               4                      Active Queue Management (AQM)
#  3310       53       53        0               2                       Bandwidth Adjustment and QoS
#  3320       39       19       74               4                      Active Queue Management (AQM)
#  3330        1       82       58               4                      Active Queue Management (AQM)
#  3340       77       21        6               4                      Active Queue Management (AQM)
#  3350        6       95       92               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3360       38       40       66               3                       Traffic Shaping and Policing
#  3370       52       80       20               4                      Active Queue Management (AQM)
#  3380       51       85       68               4                      Active Queue Management (AQM)
#  3390       27       52       37               2                       Bandwidth Adjustment and QoS
#  3400       85       47       31               4                      Active Queue Management (AQM)
#  3410       69       19       37               3                       Traffic Shaping and Policing
#  3420       66       18       51               3                       Traffic Shaping and Policing
#  3430       54       34       81               4                      Active Queue Management (AQM)
#  3440       38       10       97               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3450       96       49       97               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3460        3       76       88               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3470        2       58       60               2                       Bandwidth Adjustment and QoS
#  3480       73       25        1               4                      Active Queue Management (AQM)
#  3490       49       36       88               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3500       82       51       84               4                      Active Queue Management (AQM)
#  3510       45       86        4               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3520       14        4       50               8                                       Token Bucket
#  3530       10       60       89               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3540       86       88       93               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3550       33       25       39               7                                       Leaky Bucket
#  3560       22       26        5               6                                  Buffer Management
#  3570       52       93       40               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3580       92       63       52               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3590       10       39       90               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3600        1       86       49               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3610       48       55       28               2                       Bandwidth Adjustment and QoS
#  3620       47       64        2               3                       Traffic Shaping and Policing
#  3630        5       77       20               4                      Active Queue Management (AQM)
#  3640       85       18       47               4                      Active Queue Management (AQM)
#  3650       73       31       79               4                      Active Queue Management (AQM)
#  3660       37       68       19               3                       Traffic Shaping and Policing
#  3670       29       63       86               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3680       92       47       27               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3690       20       14        9               5          Congestion Control Protocols (End-to-End)
#  3700       45       93       32               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3710       99       69       99               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3720       37       24       91               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3730       64       10        9               3                       Traffic Shaping and Policing
#  3740        1       92       51               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3750       82       36       72               4                      Active Queue Management (AQM)
#  3760       23       51       77               4                      Active Queue Management (AQM)
#  3770       28       92       83               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3780       71       73       18               4                      Active Queue Management (AQM)
#  3790       68       31       50               3                       Traffic Shaping and Policing
#  3800       95       16       95               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3810       98       89       99               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3820       16       44       87               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3830       85       93        4               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3840        4       86       71               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3850       57       94       96               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3860       19       66       74               4                      Active Queue Management (AQM)
#  3870       92       27       45               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3880       63       52       13               3                       Traffic Shaping and Policing
#  3890       33       15       75               4                      Active Queue Management (AQM)
#  3900       18       12        0               5          Congestion Control Protocols (End-to-End)
#  3910       88       69        8               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3920       48       89       39               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3930       97       96       38               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3940       28       44       66               3                       Traffic Shaping and Policing
#  3950      100        4       12               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3960       73        8       65               4                      Active Queue Management (AQM)
#  3970       25       50       43               8                                       Token Bucket
#  3980       86       66        9               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  3990       70       26       83               4                      Active Queue Management (AQM)
#  4000       47       69       76               4                      Active Queue Management (AQM)
#  4010       71       82       92               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4020       50       44       49               8                                       Token Bucket
#  4030        4       15       92               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4040        9       77       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4050       86       63       36               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4060       23       94       12               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4070       53       75       30               4                      Active Queue Management (AQM)
#  4080        1       25       39               7                                       Leaky Bucket
#  4090       86       96       18               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4100       91       19       27               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4110        3       77       88               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4120       20       14       14               5          Congestion Control Protocols (End-to-End)
#  4130        4       72       90               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4140        8       62       46               3                       Traffic Shaping and Policing
#  4150       14       84       70               4                      Active Queue Management (AQM)
#  4160        8       81       99               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4170       73       21       62               4                      Active Queue Management (AQM)
#  4180       83       74       40               4                      Active Queue Management (AQM)
#  4190       93       24       97               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4200       84       32       15               4                      Active Queue Management (AQM)
#  4210       33       70       60               3                       Traffic Shaping and Policing
#  4220       64       10       91               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4230       92       16       28               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4240       49       34        7               8                                       Token Bucket
#  4250       24       38       67               3                       Traffic Shaping and Policing
#  4260       12       39       39               7                                       Leaky Bucket
#  4270       87       17       64               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4280       31       91       41               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4290        5       43       31               8                                       Token Bucket
#  4300       11       16       31               7                                       Leaky Bucket
#  4310       73       13        2               4                      Active Queue Management (AQM)
#  4320       89       38        8               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4330       74       53       76               4                      Active Queue Management (AQM)
#  4340       71       80       95               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4350       91       96        0               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4360       80       15       52               4                      Active Queue Management (AQM)
#  4370       30       71        4               4                      Active Queue Management (AQM)
#  4380        4       37       79               4                      Active Queue Management (AQM)
#  4390       89       32       90               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4400       86        5       69               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4410       41       27       38               8                                       Token Bucket
#  4420       33       87       41               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4430       40       26       89               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4440       10       49       49               8                                       Token Bucket
#  4450       46       45       92               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4460       80        0       33               4                      Active Queue Management (AQM)
#  4470       68       94        1               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4480       42       22       97               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4490       78      100       54               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4500       44       97       12               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4510       70       48        1               3                       Traffic Shaping and Policing
#  4520       61       22       10               3                       Traffic Shaping and Policing
#  4530       32       44       33               8                                       Token Bucket
#  4540       98       27       23               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4550       93       10       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4560       62      100       82               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4570       87        9       24               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4580       60       74       18               4                      Active Queue Management (AQM)
#  4590        0       31       19               7                                       Leaky Bucket
#  4600       30        0       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4610       83       21        1               4                      Active Queue Management (AQM)
#  4620        9       47       25               8                                       Token Bucket
#  4630       54       46       82               4                      Active Queue Management (AQM)
#  4640       11       29       91               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4650       41       82       95               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4660       68      100       14               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4670       38       55       44               2                       Bandwidth Adjustment and QoS
#  4680       98        3       11               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4690       12       48       53               2                       Bandwidth Adjustment and QoS
#  4700       14       72       29               4                      Active Queue Management (AQM)
#  4710        7       33       35               7                                       Leaky Bucket
#  4720       75       81       44               4                      Active Queue Management (AQM)
#  4730       61       59       72               4                      Active Queue Management (AQM)
#  4740       27       74       65               4                      Active Queue Management (AQM)
#  4750       66       38       34               3                       Traffic Shaping and Policing
#  4760       87       48       28               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4770       24      100       47               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  4780       64       75       36               4                      Active Queue Management (AQM)
# ...
#  5400       56       90       56               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5410       27       68       85               4                      Active Queue Management (AQM)
#  5420       17       56       59               2                       Bandwidth Adjustment and QoS
#  5430       64       96       30               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5440       21       83        0               4                      Active Queue Management (AQM)
#  5450       34        2       82               4                      Active Queue Management (AQM)
#  5460       43       11       79               4                      Active Queue Management (AQM)
#  5470        8       25       47               8                                       Token Bucket
#  5480       46       55       27               2                       Bandwidth Adjustment and QoS
#  5490       61       44       74               4                      Active Queue Management (AQM)
#  5500        4       46        6               8                                       Token Bucket
#  5510       40       58       95               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5520        2       66       91               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5530       48       74       64               4                      Active Queue Management (AQM)
#  5540        8       91       10               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5550       73       48       10               4                      Active Queue Management (AQM)
#  5560       87       75       45               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5570       88       92        7               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5580       31       25       39               7                                       Leaky Bucket
#  5590       78       47       12               4                      Active Queue Management (AQM)
#  5600        8       76       93               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5610        6        0       67               3                       Traffic Shaping and Policing
#  5620       94       63       85               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5630       98       58       23               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5640       45       52       31               2                       Bandwidth Adjustment and QoS
#  5650        0       80       63               4                      Active Queue Management (AQM)
#  5660       96       23       31               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5670       74       89       93               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5680       54       87       56               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5690       11       69       33               3                       Traffic Shaping and Policing
#  5700       77        9       81               4                      Active Queue Management (AQM)
#  5710       42       68       63               3                       Traffic Shaping and Policing
#  5720       53       74       83               4                      Active Queue Management (AQM)
#  5730       70       31       15               3                       Traffic Shaping and Policing
#  5740        6        7       74               4                      Active Queue Management (AQM)
#  5750       29       47       72               4                      Active Queue Management (AQM)
#  5760       28       65       46               3                       Traffic Shaping and Policing
#  5770       88       80      100               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5780       94       70       13               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5790       83        9       58               4                      Active Queue Management (AQM)
#  5800       47       59       15               2                       Bandwidth Adjustment and QoS
#  5810        9       19       87               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5820       16       82       97               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5830       28       18       62               3                       Traffic Shaping and Policing
#  5840       90       36       38               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5850       65       26       53               3                       Traffic Shaping and Policing
#  5860       43       31       72               4                      Active Queue Management (AQM)
#  5870       89       11       44               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5880        4       68       56               3                       Traffic Shaping and Policing
#  5890       11       68       79               4                      Active Queue Management (AQM)
#  5900       40       58       80               4                      Active Queue Management (AQM)
#  5910       64       48       58               3                       Traffic Shaping and Policing
#  5920       47       45       88               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5930       66       78       93               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  5940       20        1       37               7                                       Leaky Bucket
#  5950       83       66       23               4                      Active Queue Management (AQM)
#  5960       75       42       49               4                      Active Queue Management (AQM)
#  5970        4       48        4               8                                       Token Bucket
#  5980       36       82       31               4                      Active Queue Management (AQM)
#  5990       26       29       98               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6000       30       14       87               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6010       55        1       14               2                       Bandwidth Adjustment and QoS
#  6020       60       29       72               4                      Active Queue Management (AQM)
#  6030       78       54       82               4                      Active Queue Management (AQM)
#  6040       75       71       46               4                      Active Queue Management (AQM)
#  6050       87       28       30               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6060       20       78       74               4                      Active Queue Management (AQM)
#  6070       93       93        2               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6080       98       21       71               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6090        9       13       16               5          Congestion Control Protocols (End-to-End)
#  6100        4       61       89               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6110       10        1       67               3                       Traffic Shaping and Policing
#  6120       30       67       15               3                       Traffic Shaping and Policing
#  6130       19       58       70               3                       Traffic Shaping and Policing
#  6140       76       88       92               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6150       25       81       28               4                      Active Queue Management (AQM)
#  6160       82       94       90               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6170       96        8       23               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6180       35       36        1               7                                       Leaky Bucket
#  6190       41       37        0               8                                       Token Bucket
#  6200       21      100       33               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6210       56       67       55               3                       Traffic Shaping and Policing
#  6220        0       72       89               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6230       78       35       62               4                      Active Queue Management (AQM)
#  6240       49       21       32               8                                       Token Bucket
#  6250       32       87       65               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6260       46       64       71               4                      Active Queue Management (AQM)
#  6270       84       28       42               4                      Active Queue Management (AQM)
#  6280       68       97       96               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6290       57       54       82               4                      Active Queue Management (AQM)
#  6300       57       58       57               2                       Bandwidth Adjustment and QoS
#  6310        0       59       29               2                       Bandwidth Adjustment and QoS
#  6320       33       77       37               4                      Active Queue Management (AQM)
#  6330       53       73       92               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6340       73       69       53               4                      Active Queue Management (AQM)
#  6350       84       37       62               4                      Active Queue Management (AQM)
#  6360       79       60       41               4                      Active Queue Management (AQM)
#  6370       63       42       52               3                       Traffic Shaping and Policing
#  6380       30       87       29               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6390       41       75        2               4                      Active Queue Management (AQM)
#  6400       86       43       28               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6410       27       87       84               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6420       26       40       60               2                       Bandwidth Adjustment and QoS
#  6430       87       46       98               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6440       21       62       99               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6450       21       88       58               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6460        5       46       94               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6470        7       96       34               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6480       20       71        8               4                      Active Queue Management (AQM)
#  6490       50       15       76               4                      Active Queue Management (AQM)
#  6500       27       54       16               2                       Bandwidth Adjustment and QoS
#  6510        9       68       68               3                       Traffic Shaping and Policing
#  6520       28       78       83               4                      Active Queue Management (AQM)
#  6530       61       53       33               3                       Traffic Shaping and Policing
#  6540       34       66       90               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6550       88        6       45               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6560       35       61       74               4                      Active Queue Management (AQM)
#  6570       82       25       35               4                      Active Queue Management (AQM)
#  6580       13        3       30               6                                  Buffer Management
#  6590       63        2        2               3                       Traffic Shaping and Policing
#  6600       91       16       17               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6610       68       22       90               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6620       38       87       20               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6630       28       26       91               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6640        4       18       55               2                       Bandwidth Adjustment and QoS
#  6650       71       23       91               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6660       42       51       96               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6670       62       54       65               3                       Traffic Shaping and Policing
#  6680       76       50        9               4                      Active Queue Management (AQM)
#  6690       15        2       61               3                       Traffic Shaping and Policing
#  6700       67       80       91               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6710       23       89       85               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6720       72       58       53               4                      Active Queue Management (AQM)
#  6730       79        0        4               4                      Active Queue Management (AQM)
#  6740       66        7       74               4                      Active Queue Management (AQM)
#  6750       25       90       62               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6760       69       13        7               3                       Traffic Shaping and Policing
#  6770       49       66       18               3                       Traffic Shaping and Policing
#  6780       58       36       33               2                       Bandwidth Adjustment and QoS
#  6790       43       24       65               3                       Traffic Shaping and Policing
#  6800       26       51       27               2                       Bandwidth Adjustment and QoS
#  6810       12       55      100               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6820       82       69        3               4                      Active Queue Management (AQM)
#  6830       56       42       28               2                       Bandwidth Adjustment and QoS
#  6840       78       66       43               4                      Active Queue Management (AQM)
#  6850       89       72       59               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6860       78       13       16               4                      Active Queue Management (AQM)
#  6870       21       43       95               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6880       42        6       13               8                                       Token Bucket
#  6890       41       68       57               3                       Traffic Shaping and Policing
#  6900       19       17       59               2                       Bandwidth Adjustment and QoS
#  6910       95       49       57               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6920       49       34       86               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6930       84       92       71               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6940       99       19       24               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6950       70       13       52               3                       Traffic Shaping and Policing
#  6960       37        6       17               7                                       Leaky Bucket
#  6970       38       22       38               7                                       Leaky Bucket
#  6980       88       93       29               1 Dynamic Rerouting (Hybrid Ant Colony Optimization)
#  6990       64       32        8               3                       Traffic Shaping and Policing
